# %% [markdown]
# # Abordagem 1
#
# Usando a abordagem 1 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística *Vocabullary* com o teste **MFT**.
#
# As etapas desta abordagem são:
#
# 1. Rankear as palavras das instâncias completas
# 2. Quebrar as instâncias em sentenças
# 3. Filtrar as sentenças que contêm ao menos uma das palavras mais bem rankeadas na etapa anterior
# 4. Filtrar as sentenças com palavras relevantes (adjetivos ou verbos)
# 5. Classificar as sentenças usando o *Oráculo*
# 6. Filtrar as sentenças classificadas de forma unânime
# 7. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

imdb_df = pd.read_csv('./data/imdb_sampled/data-1000samples.csv')
imdb_df.head(5)
# Out:
#    label  \
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                                                                                                                                                                                  Here's example number 87,358 of Hollywood's anti-Biblical bias, so typical of them.<br /><br />Early on, Ray Liotta's wife has did and women are being interviewed for the position of housekeeper. The first interviewee is an old-fashioned-looking (dress, mannerisms, speech) who immediately lays down here strict rules, stating that "there will be two hours of Bible study ever day."<br /><br />This is said, of course, to make it sound like reading the Bible is the worse punishment you could ever inflict on someone, especially a kid. Once again, the Bible is equated with stuffy, mean-spirited people. That woman, of course, is dismissed immediately.<br /><br />Naturally, the liberal black woman (Whoopi Goldberg - who else?) is the one who is hired and, voilà, saves the day! <br /><br />Yawn.
# 1                                                                                                                                                                                                                                                                                                                                                  I don't know about the real Cobb but I got the distinct impression that the filmmakers' aim was to try to soften his jagged edges and reputation, not give us a true portrait of the man himself. In the movie, besides a few racist remarks, he's shown to be just another hard-nosed, cantakerous old coot (he's so full of life!) with a heart of gold(more or less). This is also the worst acting I've seen T.L.Jones do(he brings nothing new or subtle to his stereotyped character). He just doesn't flesh out Cobb in a way that pulls me into the movie. Not for one minute did I forget that it was Tommy Lee Jones on the screen pretending to be Ty Cobb. Robert Wuhl didnt impress either. The "comedic" elements in this movie were just distracting and didnt ring true at all. A bloody waste of time, it is
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Reba is a very dumb show. You can predict pretty much anything that's about to happen. Barbra Jean is just too stupid. It's like she's not even a character. A show like this should at least have SOMEONE who resembles a real-life person. I guess Barbra Jean represents a retarded person. Keira or whatever her name is, Reba, Brock, they're all stupid! Keira is like the smartest person on the show, and she's still stupid. EVERYONE IS STUPID! That's my opinion on Reba. Since I have said all I can say about this show, I'll just take up the next few lines of text by saying what I am currently saying right now and do it until there's 10 lines. There. Reba gets 2/10.
# 3                                                                                                                                                                                                                                                                                                                          "One Crazy Summer" is the funniest, craziest (not necessarily the best), movie I have ever seen.<br /><br />Just when one crazy scene is done, another emerges. It never lets you rest. Just one thing after another. The soundtrack is great. The songs are the right ones for the scenes.<br /><br />It is also a clean movie. Little that is dirty in it.<br /><br />Of course, it has the story of the guys you wouldn't trust with your lunch money, taking up a challenge, and winning over people with more resources. Who'd want to see it if they failed? There is a serious side, in that parents and children do not live up to each others' dreams. One should always have an open mind, and weigh all the options. This applies both to parents and children. In "One Crazy Summer", the parents are wrong. This is not always the case.
# 4  "A young man, recently engaged to be married, is the victim of a traffic accident and dies as a result of his injuries. His father, desperate to revive his son, agrees to let a scientist friend try his experimental soul transmigration process to save him. After the young man returns to life, the father and fiancée notice a dark and violent change in the young man's behavior, leading them to believe something went horribly wrong in the revival process," according to the DVD sleeve's synopsis.<br /><br />At one point, Edward Norris (as Philip Bennett) is asked, "What do you think this is, Boys Town?" Mr. Norris should know, since he was in "Boys Town". "The Man with Two Lives " is more like "Black Friday" minus Karloff and Lugosi. You do the math. This film might have been a contender, with a re-worked script; it does feature an intriguing final act. After a tepid "shoot out", hang in for the drama to pick up with a well-played scene between star Norris and pursuing detective Addison Richards (as George Bradley).<br /><br />**** The Man with Two Lives (1942) Phil Rosen ~ Edward Norris, Eleanor Lawson, Addison Richards
#
#    words
# 0    127
# 1    149
# 2    124
# 3    149
# 4    196

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
imdb_models = {
    'bert': 'textattack/bert-base-uncased-imdb', 
    'albert': 'textattack/albert-base-v2-imdb', 
    'distilbert': 'textattack/distilbert-base-uncased-imdb', 
    'roberta': 'textattack/roberta-base-imdb', 
    'xlnet': 'textattack/xlnet-base-cased-imdb'
}

# %%
m1 = load_model(imdb_models['albert'])
m2 = load_model(imdb_models['distilbert'])
m3 = load_model(imdb_models['roberta'])
m4 = load_model(imdb_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(imdb_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-imdb...
# Loading model textattack/distilbert-base-uncased-imdb...
# Loading model textattack/roberta-base-imdb...
# Some weights of the model checkpoint at textattack/roberta-base-imdb were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-imdb...
# Loading model textattack/bert-base-uncased-imdb...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp1

tg = PosNegTemplateGeneratorApp1(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = imdb_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates = tg.generate_templates(instances)
# Out:
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Converting texts to sentences...
# :: 31 sentences were generated.
# Filtering instances by contaning ranked words...
# :: 13 sentences remaining.
# Filtering instances by relevant words...
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 6m 8.6s

# %%
df = tg.to_dataframe()
df
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
tg.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in imdb_df['text'].values]

# %%
tg = PosNegTemplateGeneratorApp1(model, models)
templates = tg.generate_templates(instances)
# Out:
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Converting texts to sentences...
# :: 7973 sentences were generated.
# Filtering instances by contaning ranked words...
# :: 3497 sentences remaining.
# Filtering instances by relevant words...
# :: 60 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 123m 6.7s

# %%
df = tg.to_dataframe()
df
# Out:
#     label  \
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
# 5       1
# 6       1
# 7       1
# 8       0
# 9       1
# 10      0
# 11      1
# 12      0
# 13      1
# 14      0
# 15      0
# 16      1
# 17      0
# 18      1
# 19      1
# 20      1
# 21      0
# 22      0
# 23      0
# 24      1
# 25      1
# 26      1
# 27      0
# 28      1
# 29      1
# 30      1
# 31      0
# 32      1
# 33      1
# 34      1
# 35      0
# 36      0
# 37      0
# 38      0
# 39      1
# 40      1
# 41      1
# 42      1
# 43      1
# 44      1
# 45      1
# 46      1
# 47      1
# 48      1
# 49      0
# 50      1
# 51      0
# 52      0
# 53      1
# 54      0
# 55      1
# 56      1
# 57      1
# 58      1
# 59      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                      original_text  \
# 0                                                                                                                                                                                                                                                                                                                                              That horrible last film was about gangsters killing a kid and then being haunted by a voodoo clown.
# 1                                                                                                                                                                                                                                                                                                                                      This journey in the center of the earth is despicable technical possibilities nevertheless current in 1976.
# 2   I saw a screener of this movie but I am going to buy it not only for myself but for several true film fans i have the unfortunate feeling this great film will be widely unrecognized as is the case with so many other non commercial films this is a comedic yet heart wrenching movie it will make you laugh it will make you cry it will make you think and yes you will think about it when its over and isn't that what a good movie is!
# 3                                                                                                                                                                                                                                                                                                           Everything in this movie rang false to me...the characters, the dialogue, the manipulative soundtrack, the corny narration, all of it.
# 4                                                                                                                                                                                                                                                                                                                      Seriously he could feel guilty over killing a fly then feeling guilty over feeling guilty for killing the fly and so forth.
# 5                                                                         "Subconscious Cruelty" has to be one of the most beautiful films I have ever seen.Still it's extremely grim and gory at times,so fans of politically correct mainstream horror garbage shouldn't bother.The film mixes many wonderful visuals with plenty of sleaze and gore.It is extremely odd,vicious and disturbing,so fans of bizarre cinema won't be disappointed.
# 6                                                                                                                                                                                                                                                                                                                                       I saw Two Hands back in Sydney a few years ago and it instantly became one of my all-time favourite films.
# 7                                                                                                                                                                                                                                                                                                                                                 And the build up to them trying to overcome this is the heart of this very fine and moving film.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                        Terrible, just terrible!!
# 9                                                                                                                                                                          Suchet is amazing as always and fortunately is on screen most of the time.<br /><br />I did find out who the murderer was but still it's not predictable and It's also very believable.<br /><br />So in conclusion a great movie and as always a pleasure.<br /><br />
# 10                                                                                                                                                                                                                                                                                                                                                    The only thing good about this movie is the artwork on the promotion poster by H. R. Geiger.
# 11                                                                                                                                                                                                                                            I still don't understand why it had to be black and white, but that's the only negativity I can see about the film, and it sure is a perfect example to see the definitive rise of Brazilian cinema.
# 12                                                                                                                                                                                                                                                        "Tunnel Vision" is a really dull, implausible and tension-free Aussie thriller that obviously imitates popular sex-thrillers like "Fatal Attraction", "Disclosure" and "Basic Instinct".
# 13                                                                                                                                                            Most notable in the cast of "newbies" is Rachel Kimsey (Rebekah), who I've seen lately on "The Young and The Restless" and Kevin Kazakoff, who plays the angst-ridden Kirby, a war-weary man who's torn between wanting to live and let live or stepping in to "do the right thing."
# 14                                                                                                                                                                                                                                                if it weren't for all the polish and expensive filters, 'nasaan ka man' would feel just like your typical, second-rate local movie - - hyperactive drama, predictable plot twists, "yeah right!"
# 15                                                                                                                                                                                                                  this film has no plot, no good acting, to be honest it has nothing, the same songs play over and over awful acting and if you can actually sit there and watch the whole thing and enjoy it there is something wrong with you.
# 16                                                                                                                                                                                                                                                                                                                                                                                  The acting couple was awesome, as well as the scene selection.
# 17                         What saves this film from becoming a Hallmark spectacle and debacle of the usual sort, whenever films about serial killers are concerned, is the direction, which is a double-edged sword; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much, but at the same times created a truly dull and stereotypical view of the American police through the King-angle.
# 18                                                                                                                                                                                                                This is the movie equivalent of Marmite.<br /><br />I personally have committed every second of it to memory, it is cyclical, claustrophobic, introspective, magical and stands as being one of the most unique films ever made.
# 19                                                                                                                                                                                                                                                                                                                                                                      The only sad thing is that it is not available on PAL VHS or Region 2 DVD.
# 20                                                                                                                                                                                                                                                                                                                                                    This is one great show, that it makes me wonder why it got pulled off the air so many times.
# 21                                                                                                                                                                                                                                                                                                                                                                                        Plot - good initial idea but truly terrible development.
# 22                                                                                                                                                                                                                                                                                                                                                                                         It has an apathetic story, with a dodgy narrative flow.
# 23                                                                                                                                                                                                                                                                                                                              The only thing to enjoy is Pink Floyd's wonderful soundtrack, which is too good for stereotypical waste like this.
# 24                                                                                                                                                                                                                                                                                                          I'm not so sure I possess it now, and I have long since parted company with that particular girlfriend (pity really... my first love).
# 25                                                                                                                                                                                                                                                                                           The last five minutes are intense, and certainly contain some of the best film making/cgi you will ever see, ever.<br /><br />Ed Wood would be proud.
# 26                                                                                                                                                                                                                                                                                                                                          Pitch Black is a perfect example of making a great film with out the resources of an excessive budget.
# 27                                                                                                                                                                                                                                                                                          Heart of Darkness, a short novel written by Joseph Conrad about greed, corruption, and traveling through Africa was, to say the least, a tedious read.
# 28                                                                                                                                                                                                          They are successful in their plan, but the D. Juan Cesar makes things go wrong when he gives a valuable ring to his mistress.<br /><br />"Du Rififi Chez les Hommes" is a magnificent film-noir, certainly among the best I have seen.
# 29                                                                                                                                                                                                                                                                                                        It moves a little slowly at times but offers so many strange and fanciful ideas and eye-popping visuals that it's hard not to be amused.
# 30                                                                                                                                                                                                                                                                                                                                                                                     It's flamboyant and spirited entertainment.<br /><br />8/10
# 31                                                                                                                                                                                                                                                                                                                                            The casting of Robert Culp is probably the only decent move the production team made with this film.
# 32                                                                                                                                                                                                                                                                                                                                                                                          The mystery and its solution was a great noir conceit.
# 33                                                                                                                                                                                                                                                                                                                            Amusing in its vaudevillian goofiness, yet makes a bitingly crucial point about the motivations behind life choices.
# 34                                                                                                                                                                                                                                                                                        One example is the role of Macro, played by Guido Mannari who has tremendous screen presence in an important role, but is mostly left in the background.
# 35                                                                                                                                                                                                                                                                                                                                                                                             Movies like this give independent films a bad name!
# 36                                                                                                                                                                                                                                                                                                                                 The show can be quite boring, when it comes to judging, Tyra tends to go on and on and it's really off-putting.
# 37                                                                                         The less-then-stellar parts of this film are the story which is VERY prolonged at best (but again I think this is because of the budget they had - they had to prolong certain scenes to create the feature length 97 minutes), the acting (again it's because the actors had no story to work with), very few exceptional camera shots, and the music.
# 38                                                                                                                                                                                                                                        I'm not anti-opera, but I would have preferred them to spend that time letting us get to know the characters, who were all stiff and underdeveloped.<br /><br />I was really disappointed in this movie.
# 39                                                                                                                                                                                                                                                                                                                                                                                              Hilarious, clean, light-hearted, and quote-worthy.
# 40                                                                                                                                                                                                                                                                                                                                                                                                 This is my all-time, number one favorite movie.
# 41                                                                                                                                                                                                                                                                                                                                                                                                     This is probably my least favorite episode.
# 42                                                                                                                                                                                                                                                                                                                                                                       THE MAGIC GARDEN is perhaps one of my most vivid '70s childhood memories.
# 43                                                                                                                                                                                                                         The difficult concepts used here are introduced in a very simple way, with daily objects; although you must believe them without checking by yourself -if you are not a scientist- (and even if you are a scientist!!).
# 44                                                                                                                                                                                                                                                                                                                         It's a good film, I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy scary film.
# 45                                                                                                                                                                                                                                                                                                     The Regard of Flight, written and performed by Bill Irwin, is a true classic theatre piece which translated quite well to the small screen.
# 46                                                                                                                                                                                                                                                                                                                                                                             The animal cruelty gets my heart, but not long enough to be guilty.
# 47                                                                                                                                                                                                                                                                                                                                There are all sorts of directorial touches to keep you amused, and the (non-dated) soundtrack cooks all the way.
# 48                                                                                                                                                                                                                                                                                                                                                                                              Holly Hunter is the obsessive workaholic producer.
# 49                                                                                                                                                                                                                                                                               I am not into that at all, I was just expecting an informative docudrama of the 9/11 report.<br /><br />Instead, I got an almost incomprehensible, violent movie.
# 50                                                                                                                                                                                                                                                                                                                               Meanwhile it's my favourite film.<br /><br />The last song is one of the saddest and happiest I ever listened to.
# 51                                                                                                                                                                                                                                                                                                                <br /><br />The shock value is the least appealing thing about this film - a minor detail that has been blown out of proportion.
# 52                                                                                                                                                                                            An uninspired 15 year-old?<br /><br />Could have been written by one of the kids who did the Columbine shooting.<br /><br />Totally nonsensical, not funny all, boooooooriiing...<br /><br />Plus this: the French do not put their flag everywhere.
# 53                                                                                                                                                                                           But "Viva Variety" certainly should get high marks for original concepts, and even though it was often more odd than funny, it was certainly worthwhile, especially when they road tripped to Las Vegas and brought in even glitzier acts to perform.
# 54                                                                                              I still gave this movie a 4 because at least it was fast pace and I did want to see what was going to happen at the end, though I (as most anyone who watched the first one) predicted it would go down the way it did and after seeing it I found it anti-climactic and wished they had either made a proper sequel or just left the story alone.
# 55                                                                                                                                                                                                                                                                                  Oh, they're believable, all right-- but it is quite frustrating when nobody seems to be hitting their cues on time in a song as fast-paced as, say, "Kiss Me."
# 56                                                                                                                                                                                                                                                                                                                                                                                                                   Wonderful acting, great cast.
# 57                                                                                                                                              Once again, Bugs faces dumb opponent, one he calls "Nero," but lion is fierce and Bugs will need all his wits and somewhat-fake bravado to fend off this beast.<br /><br />About half the gags are stupid and the other half funny, but always fast-moving, colorful and good enough to recommend.
# 58                                                                                                                                                                                                                                                                                                                                                                      von Sydow is masterful and dynamic in this role that dominates the screen.
# 59                                                                                                                                                                                                          He continues to ask questions, ignoring the girls obvious traumatised atmosphere.<br /><br />The story is about two girls who are taken home, after spending some time in a mental home after an 'incident' that happened before hand.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                               masked_text  \
# 0                                                                                                                                                                                                                                                                                                                                      That {mask} last film was about gangsters killing a kid and then being haunted by a {mask} clown .
# 1                                                                                                                                                                                                                                                                                                                                   This journey in the center of the earth is {mask} {mask} possibilities nevertheless current in 1976 .
# 2   I saw a screener of this movie but I am going to buy it not only for myself but for several true film fans i have the {mask} feeling this great film will be widely {mask} as is the case with so many other non commercial films this is a comedic yet heart wrenching movie it will make you laugh it will make you cry it will make you think and yes you will think about it when its over and is n't that what a good movie is !
# 3                                                                                                                                                                                                                                                                                                Everything in this movie rang {mask} to me ... the characters , the dialogue , the {mask} soundtrack , the corny narration , all of it .
# 4                                                                                                                                                                                                                                                                                                           Seriously he could feel guilty over killing a fly then feeling guilty over feeling {mask} for killing the fly and so {mask} .
# 5                                                  `` Subconscious Cruelty '' has to be one of the most {mask} films I have ever seen.Still it 's extremely grim and gory at times , so fans of politically correct mainstream horror garbage should n't bother.The film mixes many wonderful visuals with plenty of sleaze and gore.It is extremely {mask} , vicious and disturbing , so fans of bizarre cinema wo n't be disappointed .
# 6                                                                                                                                                                                                                                                                                                                                  I saw Two Hands back in Sydney a few years ago and it instantly became one of my {mask} {mask} films .
# 7                                                                                                                                                                                                                                                                                                                                     And the build up to them trying to overcome this is the heart of this very {mask} and {mask} film .
# 8                                                                                                                                                                                                                                                                                                                                                                                                                {mask} , just {mask} ! !
# 9                                                                                                                                               Suchet is amazing as always and fortunately is on screen most of the time. < br / > < br / > I did find out who the murderer was but still it 's not predictable and It 's also very {mask} < br / > < br / > So in conclusion a {mask} movie and as always a pleasure. < br / > < br / >
# 10                                                                                                                                                                                                                                                                                                                                      The {mask} thing {mask} about this movie is the artwork on the promotion poster by H. R. Geiger .
# 11                                                                                                                                                                                                                                   I still do n't understand why it had to be black and white , but that 's the only negativity I can see about the film , and it sure is a {mask} example to see the {mask} rise of Brazilian cinema .
# 12                                                                                                                                                                                                                                `` Tunnel Vision '' is a really {mask} , implausible and {mask} Aussie thriller that obviously imitates popular sex-thrillers like `` Fatal Attraction '' , `` Disclosure '' and `` Basic Instinct '' .
# 13                                                                                                                              {mask} {mask} in the cast of `` newbies '' is Rachel Kimsey ( Rebekah ) , who I 've seen lately on `` The Young and The Restless '' and Kevin Kazakoff , who plays the angst-ridden Kirby , a war-weary man who 's torn between wanting to live and let live or stepping in to `` do the right thing . ''
# 14                                                                                                                                                                                                                                      if it were n't for all the polish and expensive filters , 'nasaan ka man ' would feel just like your typical , second-rate local movie - - {mask} drama , {mask} plot twists , `` yeah right ! ''
# 15                                                                                                                                                                                                  this film has no plot , no {mask} acting , to be honest it has nothing , the same songs play over and over {mask} acting and if you can actually sit there and watch the whole thing and enjoy it there is something wrong with you .
# 16                                                                                                                                                                                                                                                                                                                                                                        The {mask} couple was {mask} , as well as the scene selection .
# 17               What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly {mask} and {mask} view of the American police through the King-angle .
# 18                                                                                                                                                                                                    This is the movie equivalent of Marmite. < br / > < br / > I personally have committed every second of it to memory , it is cyclical , {mask} , introspective , {mask} and stands as being one of the most unique films ever made .
# 19                                                                                                                                                                                                                                                                                                                                                       The {mask} {mask} thing is that it is not available on PAL VHS or Region 2 DVD .
# 20                                                                                                                                                                                                                                                                                                                                        This is one {mask} show , that it makes me {mask} why it got pulled off the air so many times .
# 21                                                                                                                                                                                                                                                                                                                                                                             Plot - {mask} {mask} idea but truly terrible development .
# 22                                                                                                                                                                                                                                                                                                                                                                                It has an apathetic story , with a {mask} {mask} flow .
# 23                                                                                                                                                                                                                                                                                                                       The {mask} thing to enjoy is Pink Floyd 's wonderful soundtrack , which is too good for {mask} waste like this .
# 24                                                                                                                                                                                                                                                                                        I 'm not so {mask} I possess it now , and I have long since parted company with that particular girlfriend ( pity really ... my {mask} love ) .
# 25                                                                                                                                                                                                                                                                       The last five minutes are {mask} , and certainly contain some of the {mask} film making/cgi you will ever see , ever. < br / > < br / > Ed Wood would be proud .
# 26                                                                                                                                                                                                                                                                                                                                Pitch Black is a {mask} example of making a {mask} film with out the resources of an excessive budget .
# 27                                                                                                                                                                                                                                                                           Heart of Darkness , a short novel written by Joseph Conrad about greed , corruption , and traveling through Africa was , to say the {mask} , a {mask} read .
# 28                                                                                                                                                                                      They are successful in their plan , but the D. Juan Cesar makes things go wrong when he gives a valuable ring to his mistress. < br / > < br / > '' Du Rififi Chez les Hommes '' is a {mask} film-noir , certainly among the {mask} I have seen .
# 29                                                                                                                                                                                                                                                                                                It moves a little slowly at times but offers so many {mask} and {mask} ideas and eye-popping visuals that it 's hard not to be amused .
# 30                                                                                                                                                                                                                                                                                                                                                                          It 's {mask} and {mask} entertainment. < br / > < br / > 8/10
# 31                                                                                                                                                                                                                                                                                                                                The casting of Robert Culp is probably the {mask} {mask} move the production team made with this film .
# 32                                                                                                                                                                                                                                                                                                                                                                             The mystery and its solution was a {mask} {mask} conceit .
# 33                                                                                                                                                                                                                                                                                                                        Amusing in its {mask} goofiness , yet makes a bitingly {mask} point about the motivations behind life choices .
# 34                                                                                                                                                                                                                                                                                One example is the role of Macro , played by Guido Mannari who has {mask} {mask} presence in an important role , but is mostly left in the background .
# 35                                                                                                                                                                                                                                                                                                                                                                                      Movies like this {mask} {mask} films a bad name !
# 36                                                                                                                                                                                                                                                                                                                         The show can be quite {mask} , when it comes to judging , Tyra tends to go on and on and it 's really {mask} .
# 37                                                                                     The {mask} parts of this film are the story which is VERY {mask} at best ( but again I think this is because of the budget they had - they had to prolong certain scenes to create the feature length 97 minutes ) , the acting ( again it 's because the actors had no story to work with ) , very few exceptional camera shots , and the music .
# 38                                                                                                                                                                                                                         I 'm not anti-opera , but I would have preferred them to spend that time letting us get to know the characters , who were all {mask} and underdeveloped. < br / > < br / > I was really {mask} in this movie .
# 39                                                                                                                                                                                                                                                                                                                                                                                          {mask} , clean , light-hearted , and {mask} .
# 40                                                                                                                                                                                                                                                                                                                                                                                          This is my {mask} , number one {mask} movie .
# 41                                                                                                                                                                                                                                                                                                                                                                                            This is probably my {mask} {mask} episode .
# 42                                                                                                                                                                                                                                                                                                                                                          THE MAGIC GARDEN is perhaps one of my {mask} {mask} '70s childhood memories .
# 43                                                                                                                                                                                                           The {mask} concepts used here are introduced in a very simple way , with {mask} objects ; although you must believe them without checking by yourself -if you are not a scientist- ( and even if you are a scientist ! ! ) .
# 44                                                                                                                                                                                                                                                                                                          It 's a {mask} film , I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy {mask} film .
# 45                                                                                                                                                                                                                                                                                        The Regard of Flight , written and performed by Bill Irwin , is a {mask} {mask} theatre piece which translated quite well to the small screen .
# ...
# 24                                                                                                                                                                                                                                                                                        I 'm not so {neg_adj} I possess it now , and I have long since parted company with that particular girlfriend ( pity really ... my {neg_adj} love ) .
# 25                                                                                                                                                                                                                                                                       The last five minutes are {pos_adj} , and certainly contain some of the {pos_adj} film making/cgi you will ever see , ever. < br / > < br / > Ed Wood would be proud .
# 26                                                                                                                                                                                                                                                                                                                                Pitch Black is a {pos_adj} example of making a {pos_adj} film with out the resources of an excessive budget .
# 27                                                                                                                                                                                                                                                                           Heart of Darkness , a short novel written by Joseph Conrad about greed , corruption , and traveling through Africa was , to say the {neg_adj} , a {neg_adj} read .
# 28                                                                                                                                                                                      They are successful in their plan , but the D. Juan Cesar makes things go wrong when he gives a valuable ring to his mistress. < br / > < br / > '' Du Rififi Chez les Hommes '' is a {pos_adj} film-noir , certainly among the {pos_adj} I have seen .
# 29                                                                                                                                                                                                                                                                                                It moves a little slowly at times but offers so many {neg_adj} and {neg_adj} ideas and eye-popping visuals that it 's hard not to be amused .
# 30                                                                                                                                                                                                                                                                                                                                                                          It 's {pos_adj} and {pos_adj} entertainment. < br / > < br / > 8/10
# 31                                                                                                                                                                                                                                                                                                                                The casting of Robert Culp is probably the {pos_adj} {pos_adj} move the production team made with this film .
# 32                                                                                                                                                                                                                                                                                                                                                                             The mystery and its solution was a {pos_adj} {pos_adj} conceit .
# 33                                                                                                                                                                                                                                                                                                                        Amusing in its {pos_adj} goofiness , yet makes a bitingly {pos_adj} point about the motivations behind life choices .
# 34                                                                                                                                                                                                                                                                                One example is the role of Macro , played by Guido Mannari who has {pos_adj} {neg_adj} presence in an important role , but is mostly left in the background .
# 35                                                                                                                                                                                                                                                                                                                                                                                      Movies like this {neg_adj} {pos_adj} films a bad name !
# 36                                                                                                                                                                                                                                                                                                                         The show can be quite {neg_adj} , when it comes to judging , Tyra tends to go on and on and it 's really {neg_adj} .
# 37                                                                                     The {neg_adj} parts of this film are the story which is VERY {neg_adj} at best ( but again I think this is because of the budget they had - they had to prolong certain scenes to create the feature length 97 minutes ) , the acting ( again it 's because the actors had no story to work with ) , very few exceptional camera shots , and the music .
# 38                                                                                                                                                                                                                         I 'm not anti-opera , but I would have preferred them to spend that time letting us get to know the characters , who were all {neg_adj} and underdeveloped. < br / > < br / > I was really {neg_adj} in this movie .
# 39                                                                                                                                                                                                                                                                                                                                                                                          {pos_adj} , clean , light-hearted , and {pos_adj} .
# 40                                                                                                                                                                                                                                                                                                                                                                                          This is my {pos_adj} , number one {pos_adj} movie .
# 41                                                                                                                                                                                                                                                                                                                                                                                            This is probably my {neg_adj} {pos_adj} episode .
# 42                                                                                                                                                                                                                                                                                                                                                          THE MAGIC GARDEN is perhaps one of my {neg_adj} {pos_adj} '70s childhood memories .
# 43                                                                                                                                                                                                           The {neg_adj} concepts used here are introduced in a very simple way , with {pos_adj} objects ; although you must believe them without checking by yourself -if you are not a scientist- ( and even if you are a scientist ! ! ) .
# 44                                                                                                                                                                                                                                                                                                          It 's a {pos_adj} film , I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy {pos_adj} film .
# 45                                                                                                                                                                                                                                                                                        The Regard of Flight , written and performed by Bill Irwin , is a {pos_adj} {pos_adj} theatre piece which translated quite well to the small screen .
# 46                                                                                                                                                                                                                                                                                                                                                                  The {neg_adj} cruelty gets my heart , but not long enough to be {pos_adj} .
# 47                                                                                                                                                                                                                                                                                                                           There are all sorts of {neg_adj} touches to keep you amused , and the ( {neg_adj} ) soundtrack cooks all the way .
# 48                                                                                                                                                                                                                                                                                                                                                                                           Holly Hunter is the {neg_adj} {neg_adj} producer .
# 49                                                                                                                                                                                                                                                                      I am not into that at all , I was just expecting an informative docudrama of the 9/11 report. < br / > < br / > Instead , I got an almost {neg_adj} , {neg_adj} movie .
# 50                                                                                                                                                                                                                                                                                                               Meanwhile it 's my {pos_adj} {neg_adj} < br / > < br / > The last song is one of the saddest and happiest I ever listened to .
# 51                                                                                                                                                                                                                                                                                                  < br / > < br / > The shock value is the {neg_adj} {neg_adj} thing about this film - a minor detail that has been blown out of proportion .
# 52                                                                                                                                                                 An {neg_adj} 15 year-old ? < br / > < br / > Could have been written by one of the kids who did the Columbine shooting. < br / > < br / > Totally {neg_adj} , not funny all , boooooooriiing ... < br / > < br / > Plus this : the French do not put their flag everywhere .
# 53                                                                                                                                                                             But `` Viva Variety '' certainly should get high marks for original concepts , and even though it was often more odd than {neg_adj} , it was certainly {pos_adj} , especially when they road tripped to Las Vegas and brought in even glitzier acts to perform .
# 54                                                                                        I still gave this movie a 4 because at {neg_adj} it was fast pace and I did want to see what was going to happen at the end , though I ( as most anyone who watched the first one ) predicted it would go down the way it did and after seeing it I found it {neg_adj} and wished they had either made a proper sequel or just left the story alone .
# 55                                                                                                                                                                                                                                                                       Oh , they 're {pos_adj} , all right -- but it is quite {neg_adj} when nobody seems to be hitting their cues on time in a song as fast-paced as , say , `` Kiss Me . ''
# 56                                                                                                                                                                                                                                                                                                                                                                                                          {pos_adj} acting , {pos_adj} cast .
# 57                                                                                                                    Once again , Bugs faces dumb opponent , one he calls `` Nero , '' but lion is fierce and Bugs will need all his wits and somewhat-fake bravado to fend off this beast. < br / > < br / > About half the gags are stupid and the other half funny , but always fast-moving , {pos_adj} and {pos_adj} enough to recommend .
# 58                                                                                                                                                                                                                                                                                                                                                                von Sydow is {pos_adj} and {pos_adj} in this role that dominates the screen .
# 59                                                                                                                                                                                            He continues to ask questions , ignoring the girls {neg_adj} traumatised {pos_adj} < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .

# %%
tg.lexicons
# Out:
# {'pos_adj': ['tremendous',
#   'independent',
#   'despicable',
#   'classic',
#   'magical',
#   'believable.',
#   'Wonderful',
#   'tension-free',
#   'quote-worthy',
#   'Hilarious',
#   'awesome',
#   'great',
#   'narrative',
#   'vivid',
#   'vaudevillian',
#   'intense',
#   'best',
#   'only',
#   'scary',
#   'colorful',
#   'definitive',
#   'claustrophobic',
#   'beautiful',
#   'flamboyant',
#   'atmosphere.',
#   'spirited',
#   'magnificent',
#   'daily',
#   'guilty',
#   'crucial',
#   'worthwhile',
#   'favourite',
#   'good',
#   'favorite',
#   'believable',
#   'all-time',
#   'perfect',
#   'unrecognized',
#   'dynamic',
#   'masterful',
#   'decent',
#   'forth',
#   'true',
#   'noir'],
#  'neg_adj': ['workaholic',
#   'acting',
#   'stiff',
#   'anti-climactic',
#   'stereotypical',
#   'first',
#   'horrible',
#   'funny',
#   'predictable',
#   'non-dated',
#   'off-putting',
#   'frustrating',
#   'directorial',
#   'incomprehensible',
#   'screen',
#   'sure',
#   'less-then-stellar',
#   'fanciful',
#   'fine',
#   'obsessive',
#   'terrible',
#   'odd',
#   'manipulative',
#   'prolonged',
#   'least',
#   'notable',
#   'wonder',
#   'uninspired',
#   'appealing',
#   'give',
#   'awful',
#   'dodgy',
#   'boring',
#   'hyperactive',
#   'tedious',
#   'strange',
#   'voodoo',
#   'film.',
#   'technical',
#   'moving',
#   'animal',
#   'Most',
#   'dull',
#   'disappointed',
#   'violent',
#   'false',
#   'sad',
#   'Terrible',
#   'nonsensical',
#   'initial',
#   'difficult',
#   'obvious',
#   'most',
#   'unfortunate']}

# %% [markdown]
# # Usando os templates gerados pelo TemplateGenerator no CheckList

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
suite.save('./suites/posneg-approach1.suite')
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 54 examples
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template3
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template4
# Predicting 54 examples
# Running Test: MFT with vocabullary - template5
# Predicting 44 examples
# Running Test: MFT with vocabullary - template6
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template7
# Predicting 44 examples
# Running Test: MFT with vocabullary - template8
# Predicting 54 examples
# Running Test: MFT with vocabullary - template9
# Predicting 54 examples
# Running Test: MFT with vocabullary - template10
# Predicting 44 examples
# Running Test: MFT with vocabullary - template11
# Predicting 44 examples
# Running Test: MFT with vocabullary - template12
# Predicting 44 examples
# Running Test: MFT with vocabullary - template13
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template14
# Predicting 54 examples
# Running Test: MFT with vocabullary - template15
# Predicting 54 examples
# Running Test: MFT with vocabullary - template16
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template17
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template18
# Predicting 54 examples
# Running Test: MFT with vocabullary - template19
# Predicting 44 examples
# Running Test: MFT with vocabullary - template20
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template21
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template22
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template23
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template24
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template25
# Predicting 54 examples
# Running Test: MFT with vocabullary - template26
# Predicting 44 examples
# Running Test: MFT with vocabullary - template27
# Predicting 44 examples
# Running Test: MFT with vocabullary - template28
# Predicting 54 examples
# Running Test: MFT with vocabullary - template29
# Predicting 44 examples
# Running Test: MFT with vocabullary - template30
# Predicting 54 examples
# Running Test: MFT with vocabullary - template31
# Predicting 44 examples
# Running Test: MFT with vocabullary - template32
# Predicting 44 examples
# Running Test: MFT with vocabullary - template33
# Predicting 44 examples
# Running Test: MFT with vocabullary - template34
# Predicting 44 examples
# Running Test: MFT with vocabullary - template35
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template36
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template37
# Predicting 54 examples
# Running Test: MFT with vocabullary - template38
# Predicting 54 examples
# Running Test: MFT with vocabullary - template39
# Predicting 54 examples
# Running Test: MFT with vocabullary - template40
# Predicting 44 examples
# Running Test: MFT with vocabullary - template41
# Predicting 44 examples
# Running Test: MFT with vocabullary - template42
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template43
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template44
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template45
# Predicting 44 examples
# Running Test: MFT with vocabullary - template46
# Predicting 44 examples
# Running Test: MFT with vocabullary - template47
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template48
# Predicting 54 examples
# Running Test: MFT with vocabullary - template49
# Predicting 54 examples
# Running Test: MFT with vocabullary - template50
# Predicting 54 examples
# Running Test: MFT with vocabullary - template51
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template52
# Predicting 54 examples
# Running Test: MFT with vocabullary - template53
# Predicting 54 examples
# Running Test: MFT with vocabullary - template54
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template55
# Predicting 54 examples
# Running Test: MFT with vocabullary - template56
# Predicting 2376 examples
# Running Test: MFT with vocabullary - template57
# Predicting 44 examples
# Running Test: MFT with vocabullary - template58
# Predicting 44 examples
# Running Test: MFT with vocabullary - template59
# Predicting 44 examples
# Running Test: MFT with vocabullary - template60
# Predicting 2376 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      54
# Fails (rate):    5 (9.3%)
#
# Example fails:
# 0.8 That difficult last film was about gangsters killing a kid and then being haunted by a difficult clown .
# ----
# 0.7 That funny last film was about gangsters killing a kid and then being haunted by a funny clown .
# ----
# 1.0 That fine last film was about gangsters killing a kid and then being haunted by a fine clown .
# ----
#
#
# Test: MFT with vocabullary - template2
# Test cases:      2376
# Fails (rate):    114 (4.8%)
#
# Example fails:
# 0.3 This journey in the center of the earth is quote-worthy Terrible possibilities nevertheless current in 1976 .
# ----
# 0.0 This journey in the center of the earth is only tedious possibilities nevertheless current in 1976 .
# ----
# 0.4 This journey in the center of the earth is definitive unfortunate possibilities nevertheless current in 1976 .
# ----
#
#
# Test: MFT with vocabullary - template3
# Test cases:      2376
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template4
# Test cases:      54
# Fails (rate):    32 (59.3%)
#
# Example fails:
# 0.9 Everything in this movie rang workaholic to me ... the characters , the dialogue , the workaholic soundtrack , the corny narration , all of it .
# ----
# 1.0 Everything in this movie rang film. to me ... the characters , the dialogue , the film. soundtrack , the corny narration , all of it .
# ----
# 1.0 Everything in this movie rang animal to me ... the characters , the dialogue , the animal soundtrack , the corny narration , all of it .
# ----
#
#
# Test: MFT with vocabullary - template5
# Test cases:      44
# Fails (rate):    10 (22.7%)
#
# Example fails:
# 0.8 Seriously he could feel guilty over killing a fly then feeling guilty over feeling perfect for killing the fly and so perfect .
# ----
# 0.9 Seriously he could feel guilty over killing a fly then feeling guilty over feeling magical for killing the fly and so magical .
# ----
# 1.0 Seriously he could feel guilty over killing a fly then feeling guilty over feeling believable. for killing the fly and so believable. .
# ----
#
#
# Test: MFT with vocabullary - template6
# Test cases:      2376
# Fails (rate):    30 (1.3%)
#
# Example fails:
# 0.2 `` Subconscious Cruelty '' has to be one of the most guilty films I have ever seen.Still it 's extremely grim and gory at times , so fans of politically correct mainstream horror garbage should n't bother.The film mixes many wonderful visuals with plenty of sleaze and gore.It is extremely disappointed , vicious and disturbing , so fans of bizarre cinema wo n't be disappointed .
# ----
# 0.3 `` Subconscious Cruelty '' has to be one of the most vaudevillian films I have ever seen.Still it 's extremely grim and gory at times , so fans of politically correct mainstream horror garbage should n't bother.The film mixes many wonderful visuals with plenty of sleaze and gore.It is extremely Terrible , vicious and disturbing , so fans of bizarre cinema wo n't be disappointed .
# ----
# 0.1 `` Subconscious Cruelty '' has to be one of the most unrecognized films I have ever seen.Still it 's extremely grim and gory at times , so fans of politically correct mainstream horror garbage should n't bother.The film mixes many wonderful visuals with plenty of sleaze and gore.It is extremely Terrible , vicious and disturbing , so fans of bizarre cinema wo n't be disappointed .
# ----
#
#
# Test: MFT with vocabullary - template7
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template8
# Test cases:      54
# Fails (rate):    13 (24.1%)
#
# Example fails:
# 0.0 And the build up to them trying to overcome this is the heart of this very uninspired and uninspired film .
# ----
# 0.0 And the build up to them trying to overcome this is the heart of this very horrible and horrible film .
# ----
# 0.0 And the build up to them trying to overcome this is the heart of this very disappointed and disappointed film .
# ----
#
#
# Test: MFT with vocabullary - template9
# Test cases:      54
# Fails (rate):    7 (13.0%)
#
# Example fails:
# 1.0 moving , just moving ! !
# ----
# 0.5 sure , just sure ! !
# ----
# 0.8 fine , just fine ! !
# ----
#
#
# Test: MFT with vocabullary - template10
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template11
# Test cases:      44
# Fails (rate):    31 (70.5%)
#
# Example fails:
# 1.0 The intense thing intense about this movie is the artwork on the promotion poster by H. R. Geiger .
# ----
# 0.9 The favourite thing favourite about this movie is the artwork on the promotion poster by H. R. Geiger .
# ----
# 0.9 The spirited thing spirited about this movie is the artwork on the promotion poster by H. R. Geiger .
# ----
#
#
# Test: MFT with vocabullary - template12
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template13
# Test cases:      2376
# Fails (rate):    1857 (78.2%)
#
# Example fails:
# 1.0 `` Tunnel Vision '' is a really dodgy , implausible and intense Aussie thriller that obviously imitates popular sex-thrillers like `` Fatal Attraction '' , `` Disclosure '' and `` Basic Instinct '' .
# ----
# 1.0 `` Tunnel Vision '' is a really odd , implausible and masterful Aussie thriller that obviously imitates popular sex-thrillers like `` Fatal Attraction '' , `` Disclosure '' and `` Basic Instinct '' .
# ----
# 1.0 `` Tunnel Vision '' is a really uninspired , implausible and crucial Aussie thriller that obviously imitates popular sex-thrillers like `` Fatal Attraction '' , `` Disclosure '' and `` Basic Instinct '' .
# ----
#
#
# Test: MFT with vocabullary - template14
# Test cases:      54
# Fails (rate):    40 (74.1%)
#
# Example fails:
# 0.0 stereotypical stereotypical in the cast of `` newbies '' is Rachel Kimsey ( Rebekah ) , who I 've seen lately on `` The Young and The Restless '' and Kevin Kazakoff , who plays the angst-ridden Kirby , a war-weary man who 's torn between wanting to live and let live or stepping in to `` do the right thing . ''
# ----
# 0.0 horrible horrible in the cast of `` newbies '' is Rachel Kimsey ( Rebekah ) , who I 've seen lately on `` The Young and The Restless '' and Kevin Kazakoff , who plays the angst-ridden Kirby , a war-weary man who 's torn between wanting to live and let live or stepping in to `` do the right thing . ''
# ----
# 0.0 terrible terrible in the cast of `` newbies '' is Rachel Kimsey ( Rebekah ) , who I 've seen lately on `` The Young and The Restless '' and Kevin Kazakoff , who plays the angst-ridden Kirby , a war-weary man who 's torn between wanting to live and let live or stepping in to `` do the right thing . ''
# ----
#
#
# Test: MFT with vocabullary - template15
# Test cases:      54
# Fails (rate):    2 (3.7%)
#
# Example fails:
# 0.8 if it were n't for all the polish and expensive filters , 'nasaan ka man ' would feel just like your typical , second-rate local movie - - less-then-stellar drama , less-then-stellar plot twists , `` yeah right ! ''
# ----
# 1.0 if it were n't for all the polish and expensive filters , 'nasaan ka man ' would feel just like your typical , second-rate local movie - - fine drama , fine plot twists , `` yeah right ! ''
# ----
#
#
# Test: MFT with vocabullary - template16
# Test cases:      2376
# Fails (rate):    253 (10.6%)
#
# Example fails:
# 0.9 this film has no plot , no atmosphere. acting , to be honest it has nothing , the same songs play over and over fine acting and if you can actually sit there and watch the whole thing and enjoy it there is something wrong with you .
# ----
# 1.0 this film has no plot , no perfect acting , to be honest it has nothing , the same songs play over and over less-then-stellar acting and if you can actually sit there and watch the whole thing and enjoy it there is something wrong with you .
# ----
# 0.8 this film has no plot , no vaudevillian acting , to be honest it has nothing , the same songs play over and over funny acting and if you can actually sit there and watch the whole thing and enjoy it there is something wrong with you .
# ----
#
#
# Test: MFT with vocabullary - template17
# Test cases:      2376
# Fails (rate):    803 (33.8%)
#
# Example fails:
# 0.1 The film. couple was guilty , as well as the scene selection .
# ----
# 0.0 The uninspired couple was forth , as well as the scene selection .
# ----
# 0.2 The least couple was intense , as well as the scene selection .
# ----
#
#
# Test: MFT with vocabullary - template18
# Test cases:      54
# Fails (rate):    30 (55.6%)
#
# Example fails:
# 1.0 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly difficult and difficult view of the American police through the King-angle .
# ----
# 1.0 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly sure and sure view of the American police through the King-angle .
# ----
# 0.9 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly obvious and obvious view of the American police through the King-angle .
# ----
#
#
# Test: MFT with vocabullary - template19
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template20
# Test cases:      2376
# Fails (rate):    201 (8.5%)
#
# Example fails:
# 0.2 The claustrophobic acting thing is that it is not available on PAL VHS or Region 2 DVD .
# ----
# 0.0 The beautiful tedious thing is that it is not available on PAL VHS or Region 2 DVD .
# ----
# 0.0 The forth tedious thing is that it is not available on PAL VHS or Region 2 DVD .
# ----
#
#
# Test: MFT with vocabullary - template21
# Test cases:      2376
# Fails (rate):    84 (3.5%)
#
# Example fails:
# 0.0 This is one unrecognized show , that it makes me tedious why it got pulled off the air so many times .
# ----
# 0.3 This is one claustrophobic show , that it makes me disappointed why it got pulled off the air so many times .
# ----
# 0.1 This is one only show , that it makes me horrible why it got pulled off the air so many times .
# ----
#
#
# Test: MFT with vocabullary - template22
# Test cases:      2376
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template23
# Test cases:      2376
# Fails (rate):    1076 (45.3%)
#
# Example fails:
# 1.0 It has an apathetic story , with a technical masterful flow .
# ----
# 1.0 It has an apathetic story , with a nonsensical tremendous flow .
# ----
# 0.9 It has an apathetic story , with a strange crucial flow .
# ----
#
#
# Test: MFT with vocabullary - template24
# Test cases:      2376
# Fails (rate):    1435 (60.4%)
#
# Example fails:
# 1.0 The tremendous thing to enjoy is Pink Floyd 's wonderful soundtrack , which is too good for tedious waste like this .
# ----
# 0.9 The dynamic thing to enjoy is Pink Floyd 's wonderful soundtrack , which is too good for incomprehensible waste like this .
# ----
# 0.9 The noir thing to enjoy is Pink Floyd 's wonderful soundtrack , which is too good for wonder waste like this .
# ----
#
#
# Test: MFT with vocabullary - template25
# Test cases:      54
# Fails (rate):    4 (7.4%)
#
# Example fails:
# 0.2 I 'm not so boring I possess it now , and I have long since parted company with that particular girlfriend ( pity really ... my boring love ) .
# ----
# 0.0 I 'm not so dull I possess it now , and I have long since parted company with that particular girlfriend ( pity really ... my dull love ) .
# ----
# 0.4 I 'm not so disappointed I possess it now , and I have long since parted company with that particular girlfriend ( pity really ... my disappointed love ) .
# ----
#
#
# Test: MFT with vocabullary - template26
# Test cases:      44
# Fails (rate):    2 (4.5%)
#
# Example fails:
# 0.1 The last five minutes are unrecognized , and certainly contain some of the unrecognized film making/cgi you will ever see , ever. < br / > < br / > Ed Wood would be proud .
# ----
# 0.2 The last five minutes are guilty , and certainly contain some of the guilty film making/cgi you will ever see , ever. < br / > < br / > Ed Wood would be proud .
# ----
#
#
# Test: MFT with vocabullary - template27
# Test cases:      44
# Fails (rate):    20 (45.5%)
#
# Example fails:
# 0.0 Pitch Black is a guilty example of making a guilty film with out the resources of an excessive budget .
# ----
# 0.0 Pitch Black is a only example of making a only film with out the resources of an excessive budget .
# ----
# 0.2 Pitch Black is a decent example of making a decent film with out the resources of an excessive budget .
# ----
#
#
# Test: MFT with vocabullary - template28
# Test cases:      54
# Fails (rate):    31 (57.4%)
#
# Example fails:
# 1.0 Heart of Darkness , a short novel written by Joseph Conrad about greed , corruption , and traveling through Africa was , to say the funny , a funny read .
# ----
# 0.8 Heart of Darkness , a short novel written by Joseph Conrad about greed , corruption , and traveling through Africa was , to say the obvious , a obvious read .
# ----
# 1.0 Heart of Darkness , a short novel written by Joseph Conrad about greed , corruption , and traveling through Africa was , to say the violent , a violent read .
# ----
#
#
# Test: MFT with vocabullary - template29
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template30
# Test cases:      54
# Fails (rate):    11 (20.4%)
#
# Example fails:
# 0.0 It moves a little slowly at times but offers so many boring and boring ideas and eye-popping visuals that it 's hard not to be amused .
# ----
# 0.0 It moves a little slowly at times but offers so many incomprehensible and incomprehensible ideas and eye-popping visuals that it 's hard not to be amused .
# ----
# 0.0 It moves a little slowly at times but offers so many tedious and tedious ideas and eye-popping visuals that it 's hard not to be amused .
# ----
#
#
# Test: MFT with vocabullary - template31
# Test cases:      44
# Fails (rate):    2 (4.5%)
#
# Example fails:
# 0.1 It 's unrecognized and unrecognized entertainment. < br / > < br / > 8/10
# ----
# 0.5 It 's decent and decent entertainment. < br / > < br / > 8/10
# ----
#
#
# Test: MFT with vocabullary - template32
# Test cases:      44
# Fails (rate):    42 (95.5%)
#
# Example fails:
# 1.0 The casting of Robert Culp is probably the magnificent magnificent move the production team made with this film .
# ----
# 1.0 The casting of Robert Culp is probably the Hilarious Hilarious move the production team made with this film .
# ----
# 0.6 The casting of Robert Culp is probably the vaudevillian vaudevillian move the production team made with this film .
# ----
#
#
# Test: MFT with vocabullary - template33
# Test cases:      44
# Fails (rate):    2 (4.5%)
#
# Example fails:
# 0.4 The mystery and its solution was a unrecognized unrecognized conceit .
# ----
# 0.5 The mystery and its solution was a despicable despicable conceit .
# ----
#
#
# Test: MFT with vocabullary - template34
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template35
# Test cases:      2376
# Fails (rate):    765 (32.2%)
#
# Example fails:
# 0.0 One example is the role of Macro , played by Guido Mannari who has quote-worthy dull presence in an important role , but is mostly left in the background .
# ----
# 0.0 One example is the role of Macro , played by Guido Mannari who has quote-worthy fanciful presence in an important role , but is mostly left in the background .
# ----
# 0.1 One example is the role of Macro , played by Guido Mannari who has great incomprehensible presence in an important role , but is mostly left in the background .
# ----
#
#
# Test: MFT with vocabullary - template36
# Test cases:      2376
# Fails (rate):    54 (2.3%)
#
# Example fails:
# 1.0 Movies like this moving believable. films a bad name !
# ----
# 0.6 Movies like this fine beautiful films a bad name !
# ----
# 0.6 Movies like this fine awesome films a bad name !
# ----
#
#
# Test: MFT with vocabullary - template37
# Test cases:      54
# Fails (rate):    35 (64.8%)
#
# Example fails:
# 0.9 The show can be quite obsessive , when it comes to judging , Tyra tends to go on and on and it 's really obsessive .
# ----
# 1.0 The show can be quite violent , when it comes to judging , Tyra tends to go on and on and it 's really violent .
# ----
# 1.0 The show can be quite difficult , when it comes to judging , Tyra tends to go on and on and it 's really difficult .
# ----
#
#
# Test: MFT with vocabullary - template38
# Test cases:      54
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template39
# Test cases:      54
# Fails (rate):    6 (11.1%)
#
# Example fails:
# 1.0 I 'm not anti-opera , but I would have preferred them to spend that time letting us get to know the characters , who were all first and underdeveloped. < br / > < br / > I was really first in this movie .
# ----
# 0.8 I 'm not anti-opera , but I would have preferred them to spend that time letting us get to know the characters , who were all most and underdeveloped. < br / > < br / > I was really most in this movie .
# ----
# 1.0 I 'm not anti-opera , but I would have preferred them to spend that time letting us get to know the characters , who were all moving and underdeveloped. < br / > < br / > I was really moving in this movie .
# ----
#
#
# Test: MFT with vocabullary - template40
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template41
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template42
# Test cases:      2376
# Fails (rate):    587 (24.7%)
#
# Example fails:
# 0.0 This is probably my disappointed magical episode .
# ----
# 0.2 This is probably my unfortunate guilty episode .
# ----
# 0.0 This is probably my incomprehensible forth episode .
# ----
#
#
# Test: MFT with vocabullary - template43
# Test cases:      2376
# Fails (rate):    711 (29.9%)
#
# Example fails:
# 0.2 THE MAGIC GARDEN is perhaps one of my stereotypical daily '70s childhood memories .
# ----
# 0.0 THE MAGIC GARDEN is perhaps one of my incomprehensible claustrophobic '70s childhood memories .
# ----
# 0.2 THE MAGIC GARDEN is perhaps one of my dodgy beautiful '70s childhood memories .
# ----
#
#
# Test: MFT with vocabullary - template44
# Test cases:      2376
# Fails (rate):    986 (41.5%)
#
# Example fails:
# 0.0 The false concepts used here are introduced in a very simple way , with awesome objects ; although you must believe them without checking by yourself -if you are not a scientist- ( and even if you are a scientist ! ! ) .
# ----
# 0.2 The frustrating concepts used here are introduced in a very simple way , with decent objects ; although you must believe them without checking by yourself -if you are not a scientist- ( and even if you are a scientist ! ! ) .
# ----
# 0.1 The uninspired concepts used here are introduced in a very simple way , with favourite objects ; although you must believe them without checking by yourself -if you are not a scientist- ( and even if you are a scientist ! ! ) .
# ----
#
#
# Test: MFT with vocabullary - template45
# Test cases:      44
# Fails (rate):    17 (38.6%)
#
# Example fails:
# 0.2 It 's a quote-worthy film , I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy quote-worthy film .
# ----
# 0.0 It 's a narrative film , I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy narrative film .
# ----
# 0.1 It 's a crucial film , I counted 3 actual screams in the audience whilst the film was on and it was a very jumpy crucial film .
# ----
#
#
# Test: MFT with vocabullary - template46
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template47
# Test cases:      2376
# Fails (rate):    438 (18.4%)
#
# Example fails:
# 0.3 The technical cruelty gets my heart , but not long enough to be scary .
# ----
# 0.2 The voodoo cruelty gets my heart , but not long enough to be decent .
# ----
# 0.0 The boring cruelty gets my heart , but not long enough to be claustrophobic .
# ----
#
#
# Test: MFT with vocabullary - template48
# Test cases:      54
# Fails (rate):    7 (13.0%)
#
# Example fails:
# 0.0 There are all sorts of terrible touches to keep you amused , and the ( terrible ) soundtrack cooks all the way .
# ----
# 0.1 There are all sorts of dull touches to keep you amused , and the ( dull ) soundtrack cooks all the way .
# ----
# 0.0 There are all sorts of incomprehensible touches to keep you amused , and the ( incomprehensible ) soundtrack cooks all the way .
# ----
#
#
# Test: MFT with vocabullary - template49
# Test cases:      54
# Fails (rate):    42 (77.8%)
#
# Example fails:
# 0.0 Holly Hunter is the boring boring producer .
# ----
# 0.2 Holly Hunter is the prolonged prolonged producer .
# ----
# 0.4 Holly Hunter is the screen screen producer .
# ----
#
#
# Test: MFT with vocabullary - template50
# Test cases:      54
# Fails (rate):    6 (11.1%)
#
# Example fails:
# 0.6 I am not into that at all , I was just expecting an informative docudrama of the 9/11 report. < br / > < br / > Instead , I got an almost notable , notable movie .
# ----
# 1.0 I am not into that at all , I was just expecting an informative docudrama of the 9/11 report. < br / > < br / > Instead , I got an almost funny , funny movie .
# ----
# 1.0 I am not into that at all , I was just expecting an informative docudrama of the 9/11 report. < br / > < br / > Instead , I got an almost appealing , appealing movie .
# ----
#
#
# Test: MFT with vocabullary - template51
# Test cases:      2376
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template52
# Test cases:      54
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template53
# Test cases:      54
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template54
# Test cases:      2376
# Fails (rate):    802 (33.8%)
#
# Example fails:
# 0.0 But `` Viva Variety '' certainly should get high marks for original concepts , and even though it was often more odd than obvious , it was certainly scary , especially when they road tripped to Las Vegas and brought in even glitzier acts to perform .
# ----
# 0.0 But `` Viva Variety '' certainly should get high marks for original concepts , and even though it was often more odd than least , it was certainly worthwhile , especially when they road tripped to Las Vegas and brought in even glitzier acts to perform .
# ----
# 0.1 But `` Viva Variety '' certainly should get high marks for original concepts , and even though it was often more odd than obsessive , it was certainly worthwhile , especially when they road tripped to Las Vegas and brought in even glitzier acts to perform .
# ----
#
#
# Test: MFT with vocabullary - template55
# Test cases:      54
# Fails (rate):    18 (33.3%)
#
# Example fails:
# 0.8 I still gave this movie a 4 because at less-then-stellar it was fast pace and I did want to see what was going to happen at the end , though I ( as most anyone who watched the first one ) predicted it would go down the way it did and after seeing it I found it less-then-stellar and wished they had either made a proper sequel or just left the story alone .
# ----
# 1.0 I still gave this movie a 4 because at funny it was fast pace and I did want to see what was going to happen at the end , though I ( as most anyone who watched the first one ) predicted it would go down the way it did and after seeing it I found it funny and wished they had either made a proper sequel or just left the story alone .
# ----
# 1.0 I still gave this movie a 4 because at moving it was fast pace and I did want to see what was going to happen at the end , though I ( as most anyone who watched the first one ) predicted it would go down the way it did and after seeing it I found it moving and wished they had either made a proper sequel or just left the story alone .
# ----
#
#
# Test: MFT with vocabullary - template56
# Test cases:      2376
# Fails (rate):    2370 (99.7%)
#
# Example fails:
# 0.0 Oh , they 're best , all right -- but it is quite screen when nobody seems to be hitting their cues on time in a song as fast-paced as , say , `` Kiss Me . ''
# ----
# 0.0 Oh , they 're good , all right -- but it is quite give when nobody seems to be hitting their cues on time in a song as fast-paced as , say , `` Kiss Me . ''
# ----
# 0.0 Oh , they 're noir , all right -- but it is quite Most when nobody seems to be hitting their cues on time in a song as fast-paced as , say , `` Kiss Me . ''
# ----
#
#
# Test: MFT with vocabullary - template57
# Test cases:      44
# Fails (rate):    16 (36.4%)
#
# Example fails:
# 0.0 claustrophobic acting , claustrophobic cast .
# ----
# 0.4 atmosphere. acting , atmosphere. cast .
# ----
# 0.0 daily acting , daily cast .
# ----
#
#
# Test: MFT with vocabullary - template58
# Test cases:      44
# Fails (rate):    1 (2.3%)
#
# Example fails:
# 0.1 Once again , Bugs faces dumb opponent , one he calls `` Nero , '' but lion is fierce and Bugs will need all his wits and somewhat-fake bravado to fend off this beast. < br / > < br / > About half the gags are stupid and the other half funny , but always fast-moving , only and only enough to recommend .
# ----
#
#
# Test: MFT with vocabullary - template59
# Test cases:      44
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template60
# Test cases:      2376
# Fails (rate):    53 (2.2%)
#
# Example fails:
# 0.9 He continues to ask questions , ignoring the girls prolonged traumatised believable < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .
# ----
# 0.9 He continues to ask questions , ignoring the girls violent traumatised believable. < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .
# ----
# 0.9 He continues to ask questions , ignoring the girls violent traumatised believable < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .
# ----

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach1.suite')

suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…
