# %% [markdown]
# # Abordagem 1
#
# Usando a abordagem 1 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística *Vocabullary* com o teste **MFT**.
#
# As etapas desta abordagem são:
#
# 1. Rankear as palavras das instâncias completas
# 2. Quebrar as instâncias em sentenças
# 3. Filtrar as sentenças que contêm ao menos uma das palavras mais bem rankeadas na etapa anterior
# 4. Filtrar as sentenças com palavras relevantes (adjetivos ou verbos)
# 5. Classificar as sentenças usando o *Oráculo*
# 6. Filtrar as sentenças classificadas de forma unânime
# 7. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

imdb_df = pd.read_csv('./data/imdb_sampled/data-1000samples.csv')
imdb_df.head(5)
# Out:
#    label  \
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                                                                                                                                                                                  Here's example number 87,358 of Hollywood's anti-Biblical bias, so typical of them.<br /><br />Early on, Ray Liotta's wife has did and women are being interviewed for the position of housekeeper. The first interviewee is an old-fashioned-looking (dress, mannerisms, speech) who immediately lays down here strict rules, stating that "there will be two hours of Bible study ever day."<br /><br />This is said, of course, to make it sound like reading the Bible is the worse punishment you could ever inflict on someone, especially a kid. Once again, the Bible is equated with stuffy, mean-spirited people. That woman, of course, is dismissed immediately.<br /><br />Naturally, the liberal black woman (Whoopi Goldberg - who else?) is the one who is hired and, voilà, saves the day! <br /><br />Yawn.
# 1                                                                                                                                                                                                                                                                                                                                                  I don't know about the real Cobb but I got the distinct impression that the filmmakers' aim was to try to soften his jagged edges and reputation, not give us a true portrait of the man himself. In the movie, besides a few racist remarks, he's shown to be just another hard-nosed, cantakerous old coot (he's so full of life!) with a heart of gold(more or less). This is also the worst acting I've seen T.L.Jones do(he brings nothing new or subtle to his stereotyped character). He just doesn't flesh out Cobb in a way that pulls me into the movie. Not for one minute did I forget that it was Tommy Lee Jones on the screen pretending to be Ty Cobb. Robert Wuhl didnt impress either. The "comedic" elements in this movie were just distracting and didnt ring true at all. A bloody waste of time, it is
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Reba is a very dumb show. You can predict pretty much anything that's about to happen. Barbra Jean is just too stupid. It's like she's not even a character. A show like this should at least have SOMEONE who resembles a real-life person. I guess Barbra Jean represents a retarded person. Keira or whatever her name is, Reba, Brock, they're all stupid! Keira is like the smartest person on the show, and she's still stupid. EVERYONE IS STUPID! That's my opinion on Reba. Since I have said all I can say about this show, I'll just take up the next few lines of text by saying what I am currently saying right now and do it until there's 10 lines. There. Reba gets 2/10.
# 3                                                                                                                                                                                                                                                                                                                          "One Crazy Summer" is the funniest, craziest (not necessarily the best), movie I have ever seen.<br /><br />Just when one crazy scene is done, another emerges. It never lets you rest. Just one thing after another. The soundtrack is great. The songs are the right ones for the scenes.<br /><br />It is also a clean movie. Little that is dirty in it.<br /><br />Of course, it has the story of the guys you wouldn't trust with your lunch money, taking up a challenge, and winning over people with more resources. Who'd want to see it if they failed? There is a serious side, in that parents and children do not live up to each others' dreams. One should always have an open mind, and weigh all the options. This applies both to parents and children. In "One Crazy Summer", the parents are wrong. This is not always the case.
# 4  "A young man, recently engaged to be married, is the victim of a traffic accident and dies as a result of his injuries. His father, desperate to revive his son, agrees to let a scientist friend try his experimental soul transmigration process to save him. After the young man returns to life, the father and fiancée notice a dark and violent change in the young man's behavior, leading them to believe something went horribly wrong in the revival process," according to the DVD sleeve's synopsis.<br /><br />At one point, Edward Norris (as Philip Bennett) is asked, "What do you think this is, Boys Town?" Mr. Norris should know, since he was in "Boys Town". "The Man with Two Lives " is more like "Black Friday" minus Karloff and Lugosi. You do the math. This film might have been a contender, with a re-worked script; it does feature an intriguing final act. After a tepid "shoot out", hang in for the drama to pick up with a well-played scene between star Norris and pursuing detective Addison Richards (as George Bradley).<br /><br />**** The Man with Two Lives (1942) Phil Rosen ~ Edward Norris, Eleanor Lawson, Addison Richards
#
#    words
# 0    127
# 1    149
# 2    124
# 3    149
# 4    196

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
imdb_models = {
    'bert': 'textattack/bert-base-uncased-imdb', 
    'albert': 'textattack/albert-base-v2-imdb', 
    'distilbert': 'textattack/distilbert-base-uncased-imdb', 
    'roberta': 'textattack/roberta-base-imdb', 
    'xlnet': 'textattack/xlnet-base-cased-imdb'
}

# %%
m1 = load_model(imdb_models['albert'])
m2 = load_model(imdb_models['distilbert'])
m3 = load_model(imdb_models['roberta'])
m4 = load_model(imdb_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(imdb_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-imdb...
# Loading model textattack/distilbert-base-uncased-imdb...
# Loading model textattack/roberta-base-imdb...
# Some weights of the model checkpoint at textattack/roberta-base-imdb were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-imdb...
# Loading model textattack/bert-base-uncased-imdb...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp1

tg = PosNegTemplateGeneratorApp1(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = imdb_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates = tg.generate_templates(instances)
# Out:
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Converting texts to sentences...
# :: 31 sentences were generated.
# Filtering instances by contaning ranked words...
# :: 13 sentences remaining.
# Filtering instances by relevant words...
# :: 1 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 6m 8.6s

# %%
df = tg.to_dataframe()
df
# Out:
#    label  \
# 0      1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       original_text  \
# 0  This story of a young white teacher who takes a position teaching poor black kids on an island in the Carolina's is a great advertisement for teaching , and for simply helping each other .Set in the early 60s , with the civil rights issues , Viet Nam and all that came with the 60s ,it is forgotten that the Peace Corps and many young people struck out to make a difference helping the unprivileged .Conrack with his open style of teaching is interested in these kids as people , and encourages an honest interaction in his class that scares the power's that be .The greatest part was that Jon Voight said they had a 20 year reunion and 18 of those kids became teachers !!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  masked_text  \
# 0  This story of a young white teacher who takes a position teaching poor black kids on an island in the Carolina 's {mask} a {mask} advertisement for teaching , and for simply helping each other .Set in the early 60s , with the civil rights issues , Viet Nam and all that came with the 60s , it is forgotten that the Peace Corps and many young people struck out to make a difference helping the unprivileged .Conrack with his open style of teaching is interested in these kids as people , and encourages an honest interaction in his class that scares the power 's that be .The greatest part was that Jon Voight said they had a 20 year reunion and 18 of those kids became teachers ! !
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       template_text
# 0  This story of a young white teacher who takes a position teaching poor black kids on an island in the Carolina 's {neg_verb} a {pos_adj} advertisement for teaching , and for simply helping each other .Set in the early 60s , with the civil rights issues , Viet Nam and all that came with the 60s , it is forgotten that the Peace Corps and many young people struck out to make a difference helping the unprivileged .Conrack with his open style of teaching is interested in these kids as people , and encourages an honest interaction in his class that scares the power 's that be .The greatest part was that Jon Voight said they had a 20 year reunion and 18 of those kids became teachers ! !

# %%
tg.lexicons
# Out:
# {'pos_verb': [], 'neg_verb': ['is'], 'pos_adj': ['great'], 'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in imdb_df['text'].values]

# %%
tg = PosNegTemplateGeneratorApp1(model, models)
templates = tg.generate_templates(instances)
# Out:
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Converting texts to sentences...
# :: 7973 sentences were generated.
# Filtering instances by contaning ranked words...
# :: 3497 sentences remaining.
# Filtering instances by relevant words...
# :: 366 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 123m 6.7s

# %%
df = tg.to_dataframe()
df
# Out:
#      label  \
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# ..     ...
# 361      1
# 362      1
# 363      1
# 364      0
# 365      0
#
#                                                                                                                                                                                                                                                                                                                                             original_text  \
# 0                                                                                                                                                                                                                                     This is also the worst acting I've seen T.L.Jones do(he brings nothing new or subtle to his stereotyped character).
# 1                                                                                                                                                                                                                                                                                                       I guess Barbra Jean represents a retarded person.
# 2                                                                                                                                                                                                                                                                                                                                The soundtrack is great.
# 3                                                                                                                                                                                                                                                     That horrible last film was about gangsters killing a kid and then being haunted by a voodoo clown.
# 4                                                                                                                                                                                                                                                                                          It would basically just be a B-movie that likes to show boobs.
# ..                                                                                                                                                                                                                                                                                                                                                    ...
# 361                                                                                                                                                                                                                                                                Danson is outstanding as the title character and edward fox makes a wonderful villain.
# 362                                                                                                                                                                                                                                                                                           It is different for everyone but for most of us it is love.
# 363  The second live action outing for Asterix is far better than the glued together elements of ten different stories that was called the first film, instead staying fairly close to the original comic.<br /><br />In a nutshell, Queen Cleopatra has made a bet with Caeser to build a palace in Egypt to show that the Egyptians are a great people.
# 364                                                                                                                                                                                                                                                  will this comment contain any spoilers?<br /><br />no, because i just did not understand this movie.
# 365                                                                                                                He continues to ask questions, ignoring the girls obvious traumatised atmosphere.<br /><br />The story is about two girls who are taken home, after spending some time in a mental home after an 'incident' that happened before hand.
#
#                                                                                                                                                                                                                                                                                                                                                             masked_text  \
# 0                                                                                                                                                                                                                                             This is also the {mask} {mask} I 've seen T.L.Jones do ( he brings nothing new or subtle to his stereotyped character ) .
# 1                                                                                                                                                                                                                                                                                                                     I {mask} Barbra Jean represents a {mask} person .
# 2                                                                                                                                                                                                                                                                                                                                        The soundtrack {mask} {mask} .
# 3                                                                                                                                                                                                                                                                    That {mask} last film was about gangsters killing a kid and then being haunted by a {mask} clown .
# 4                                                                                                                                                                                                                                                                                                  It {mask} basically just {mask} a B-movie that likes to show boobs .
# ..                                                                                                                                                                                                                                                                                                                                                                  ...
# 361                                                                                                                                                                                                                                                                              Danson {mask} {mask} as the title character and edward fox makes a wonderful villain .
# 362                                                                                                                                                                                                                                                                                                       It {mask} {mask} for everyone but for most of us it is love .
# 363  The second live action {mask} for Asterix {mask} far better than the glued together elements of ten different stories that was called the first film , instead staying fairly close to the original comic. < br / > < br / > In a nutshell , Queen Cleopatra has made a bet with Caeser to build a palace in Egypt to show that the Egyptians are a great people .
# 364                                                                                                                                                                                                                                                        {mask} this comment contain any spoilers ? < br / > < br / > no , because i just did not {mask} this movie .
# 365                                                                                                                         He continues to ask questions , ignoring the girls {mask} traumatised {mask} < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .
#
#                                                                                                                                                                                                                                                                                                                                                                   template_text
# 0                                                                                                                                                                                                                                              This is also the {neg_adj} {neg_verb} I 've seen T.L.Jones do ( he brings nothing new or subtle to his stereotyped character ) .
# 1                                                                                                                                                                                                                                                                                                                      I {neg_verb} Barbra Jean represents a {neg_adj} person .
# 2                                                                                                                                                                                                                                                                                                                                         The soundtrack {neg_verb} {pos_adj} .
# 3                                                                                                                                                                                                                                                                      That {neg_adj} last film was about gangsters killing a kid and then being haunted by a {neg_adj} clown .
# 4                                                                                                                                                                                                                                                                                                  It {neg_verb} basically just {neg_verb} a B-movie that likes to show boobs .
# ..                                                                                                                                                                                                                                                                                                                                                                          ...
# 361                                                                                                                                                                                                                                                                               Danson {neg_verb} {pos_adj} as the title character and edward fox makes a wonderful villain .
# 362                                                                                                                                                                                                                                                                                                        It {neg_verb} {pos_adj} for everyone but for most of us it is love .
# 363  The second live action {neg_verb} for Asterix {neg_verb} far better than the glued together elements of ten different stories that was called the first film , instead staying fairly close to the original comic. < br / > < br / > In a nutshell , Queen Cleopatra has made a bet with Caeser to build a palace in Egypt to show that the Egyptians are a great people .
# 364                                                                                                                                                                                                                                                        {pos_verb} this comment contain any spoilers ? < br / > < br / > no , because i just did not {neg_verb} this movie .
# 365                                                                                                                           He continues to ask questions , ignoring the girls {neg_adj} traumatised {pos_adj} < br / > < br / > The story is about two girls who are taken home , after spending some time in a mental home after an 'incident ' that happened before hand .
#
# [366 rows x 4 columns]

# %%
tg.lexicons
# Out:
# {'pos_verb': ['animating',
#   'felt',
#   'present',
#   'helps',
#   'lives',
#   'discuss',
#   'find',
#   'dancing',
#   'sit',
#   'watch',
#   "'ll",
#   'praying',
#   'thru',
#   'kept',
#   'loved',
#   'written',
#   'editing',
#   'resorts',
#   'fans',
#   'focuses',
#   'realised',
#   'noticed',
#   'sets',
#   'plays',
#   'restrained',
#   'am',
#   'Combined',
#   'mind',
#   'makes',
#   'feeling',
#   'will',
#   'moving.Watching',
#   'enjoy',
#   'delighted',
#   'convincing',
#   'balancing',
#   'pleasing',
#   'bears',
#   'take',
#   'realizes',
#   'coming',
#   'appreciate',
#   'entertaining',
#   'enjoyed',
#   'laughing',
#   'becoming',
#   'being',
#   'need',
#   'may',
#   'promoted',
#   'surprised',
#   'believe',
#   'revolve',
#   'deal',
#   'Surprised',
#   'know',
#   'depicts',
#   'inspire',
#   'captured',
#   'bind',
#   'listing',
#   'reckoned',
#   'cleanse',
#   "'m",
#   'watched',
#   'exploring',
#   'taking',
#   'recommend',
#   'deserves'],
#  'neg_verb': ['relegated',
#   'goes',
#   'convoluted',
#   'Truly',
#   'tries',
#   'requires',
#   'lacks',
#   'dealt',
#   'shown',
#   'all.',
#   'tread',
#   'went',
#   'teeter',
#   'throws',
#   'thought',
#   'sickening',
#   'annoyed',
#   'created',
#   'was',
#   'left',
#   'confirmed',
#   'researched',
#   'lost',
#   'shakes',
#   'follow',
#   'fails',
#   'play',
#   'expect',
#   'rated',
#   'puts',
#   'could',
#   'seeing',
#   'done',
#   'is',
#   'disgusted',
#   'became',
#   'succeeded',
#   'quit',
#   'tinted',
#   'follows',
#   'ponder',
#   'denies',
#   'die',
#   'exercising',
#   'released',
#   'seen',
#   'frustrated',
#   'acting',
#   'screams',
#   'heard',
#   'jettisoned',
#   'expects',
#   'were',
#   'judge',
#   'make',
#   'realized',
#   'going',
#   'ending',
#   'depend',
#   'try',
#   'canceled',
#   'wasted',
#   'lacking',
#   'expecting',
#   'followed',
#   'IS',
#   'looking',
#   'alas',
#   'sucked',
#   'smack',
#   'get',
#   'required',
#   'high',
#   'aimed',
#   'does',
#   'came',
#   'be',
#   'might',
#   'sounded',
#   'been',
#   "'ve",
#   'allowing',
#   'read',
#   'has',
#   'adds',
#   'forget',
#   'decided',
#   'says',
#   'see',
#   'supposed',
#   'considered',
#   'unconvincing',
#   'made',
#   'raw',
#   'missing',
#   'slaps',
#   'have',
#   'guess',
#   'telling',
#   'trying',
#   'sucks',
#   'making',
#   'must',
#   'starts',
#   'appeal',
#   'can',
#   'saw',
#   'continue',
#   'padding',
#   'disappointed',
#   'cared',
#   'cries',
#   'lack',
#   'likes',
#   'stop',
#   'call',
#   'doing',
#   'are',
#   'should',
#   'irritating',
#   'did',
#   'reminded',
#   'got',
#   "'s",
#   'let',
#   'had',
#   'would',
#   'washed',
#   'say',
#   'emphasize',
#   'consists',
#   'understand',
#   'passed',
#   'needed',
#   'outing',
#   'shut',
#   'looks',
#   'overrated',
#   'compares',
#   'choose',
#   'think',
#   'go',
#   'give',
#   'sandwiched',
#   'turned',
#   'saving',
#   'seem',
#   'related',
#   'interesting',
#   'puked',
#   'denying',
#   'degenerates',
#   'assaulted',
#   'happens',
#   'consisted',
#   'leaves',
#   'suck'],
#  'pos_adj': ['WWII',
#   'solid',
#   'magnificent',
#   'Hilarious',
#   'classic',
#   'worthwhile',
#   'believable',
#   'genius.',
#   'cool',
#   'magical',
#   'likable',
#   'favourite',
#   'today.',
#   'innovation.',
#   'favorite',
#   'great',
#   'definitive',
#   'vivid',
#   'unrecognized',
#   'tele-realistic',
#   'strongest',
#   'flamboyant',
#   'outstanding',
#   'Wonderful',
#   'all-time',
#   'influential.',
#   'nuttest',
#   '15-year-old',
#   'subplots',
#   'powerful',
#   'colorful',
#   'eerie',
#   'suspenseful',
#   'hard',
#   'fun',
#   'greatest',
#   'marvelous',
#   'real',
#   'claustrophobic',
#   'talent',
#   'narrative',
#   'touching',
#   'rare',
#   'remarkable',
#   'mediocre',
#   'aware',
#   'good',
#   'forth',
#   'happy',
#   'spirited',
#   'amazing',
#   'tremendous',
#   'guilty',
#   'intense',
#   'decent',
#   'alternative',
#   'quote-worthy',
#   'minor',
#   'excellent',
#   'much',
#   'believable.',
#   'GOOD',
#   'masterful',
#   'novel',
#   'hilarious',
#   'gifted',
#   'Australian',
#   'heartfelt',
#   'perfect',
#   'normal',
#   'wonderful',
#   'talented',
#   'symbolic',
#   'spectacular',
#   'tension-free',
#   'noir',
#   'Egyptian',
#   'true',
#   'only',
#   'crucial',
#   'independent',
#   'funniest',
#   'nonstop',
#   'watchable',
#   'beautiful',
#   'anathema',
#   'enjoyable',
#   'different',
#   'dynamic',
#   'atmosphere.',
#   'nice',
#   'pleasurable',
#   'despicable',
#   'imdb.com.',
#   'daily',
#   'awesome',
#   'three-dimensional',
#   'scary',
#   'vaudevillian',
#   'incredible',
#   'best',
#   'dead',
#   'foregone'],
#  'neg_adj': ['trite',
#   'bad',
#   'false',
#   'few',
#   'unintentional',
#   'unfunny',
#   'hyperactive',
#   'little',
#   'spare',
#   'pitiful',
#   'worse',
#   'predictable',
#   'contemptible',
#   'most',
#   'funny',
#   'topless',
#   'Ridiculous',
#   'violent',
#   'anti-climactic',
#   'campy',
#   'Most',
#   'unfortunate',
#   'disgusted',
#   'sad',
#   'laughable',
#   'dodgy',
#   'over-insured',
#   'sole',
#   'acting',
#   'sure',
#   'shuttle',
#   'stereotypical',
#   'ready',
#   'hollow',
#   'non-dated',
#   'negative',
#   'worst',
#   'hysterical',
#   'poor',
#   'animal',
#   'typical',
#   'least',
#   'directorial',
#   'terrible',
#   'low',
#   'initial',
#   'dull',
#   'workaholic',
#   'below',
#   'drug-induced',
#   'shallow',
#   'worst/best',
#   'cringeful',
#   'wrong',
#   'funny-dumb',
#   'screen',
#   'painful',
#   'difficult',
#   'unbelievable',
#   'uninteresting',
#   'less-then-stellar',
#   'uninspired',
#   'Many',
#   'obvious',
#   'Terrible',
#   'technical',
#   'wonder',
#   'thin',
#   'nonsensical',
#   'off-putting',
#   'sub-par',
#   'impressive.',
#   'disappointed',
#   'stiff',
#   'horrible',
#   'awful',
#   'ageless',
#   'voodoo',
#   'prolonged',
#   'notable',
#   'strange',
#   'rubbish',
#   'obsessive',
#   'film.',
#   'many',
#   'manipulative',
#   "ripoff's.",
#   'give',
#   'unrealistic',
#   'incompetent',
#   'appealing',
#   'like',
#   'tedious',
#   'boring',
#   'stupid',
#   'first',
#   'interesting',
#   'retarded',
#   'odd',
#   'moving',
#   'incomprehensible',
#   'fine',
#   'laughable.',
#   'cheap',
#   'HORRIBLE',
#   'frustrating',
#   'superficial',
#   'fanciful',
#   'mockumentary']}

# %% [markdown]
# # Usando os templates gerados pelo TemplateGenerator no CheckList

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_verb', lexicons['pos_verb'])
editor.add_lexicon('neg_verb', lexicons['neg_verb'])
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
suite.save('./suites/posneg-approach1.suite')
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 17108 examples
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template3
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template4
# Predicting 109 examples
# Running Test: MFT with vocabullary - template5
# Predicting 157 examples
# Running Test: MFT with vocabullary - template6
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template7
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template8
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template9
# Predicting 157 examples
# Running Test: MFT with vocabullary - template10
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template11
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template12
# Predicting 157 examples
# Running Test: MFT with vocabullary - template13
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template14
# Predicting 157 examples
# Running Test: MFT with vocabullary - template15
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template16
# Predicting 157 examples
# Running Test: MFT with vocabullary - template17
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template18
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template19
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template20
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template21
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template22
# Predicting 157 examples
# Running Test: MFT with vocabullary - template23
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template24
# Predicting 157 examples
# Running Test: MFT with vocabullary - template25
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template26
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template27
# Predicting 157 examples
# Running Test: MFT with vocabullary - template28
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template29
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template30
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template31
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template32
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template33
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template34
# Predicting 109 examples
# Running Test: MFT with vocabullary - template35
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template36
# Predicting 103 examples
# Running Test: MFT with vocabullary - template37
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template38
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template39
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template40
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template41
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template42
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template43
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template44
# Predicting 157 examples
# Running Test: MFT with vocabullary - template45
# Predicting 103 examples
# Running Test: MFT with vocabullary - template46
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template47
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template48
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template49
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template50
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template51
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template52
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template53
# Predicting 109 examples
# Running Test: MFT with vocabullary - template54
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template55
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template56
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template57
# Predicting 109 examples
# Running Test: MFT with vocabullary - template58
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template59
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template60
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template61
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template62
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template63
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template64
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template65
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template66
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template67
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template68
# Predicting 103 examples
# Running Test: MFT with vocabullary - template69
# Predicting 157 examples
# Running Test: MFT with vocabullary - template70
# Predicting 103 examples
# Running Test: MFT with vocabullary - template71
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template72
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template73
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template74
# Predicting 69 examples
# Running Test: MFT with vocabullary - template75
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template76
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template77
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template78
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template79
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template80
# Predicting 103 examples
# Running Test: MFT with vocabullary - template81
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template82
# Predicting 157 examples
# Running Test: MFT with vocabullary - template83
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template84
# Predicting 157 examples
# Running Test: MFT with vocabullary - template85
# Predicting 157 examples
# Running Test: MFT with vocabullary - template86
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template87
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template88
# Predicting 69 examples
# Running Test: MFT with vocabullary - template89
# Predicting 157 examples
# Running Test: MFT with vocabullary - template90
# Predicting 109 examples
# Running Test: MFT with vocabullary - template91
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template92
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template93
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template94
# Predicting 109 examples
# Running Test: MFT with vocabullary - template95
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template96
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template97
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template98
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template99
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template100
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template101
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template102
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template103
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template104
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template105
# Predicting 157 examples
# Running Test: MFT with vocabullary - template106
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template107
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template108
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template109
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template110
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template111
# Predicting 157 examples
# Running Test: MFT with vocabullary - template112
# Predicting 109 examples
# Running Test: MFT with vocabullary - template113
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template114
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template115
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template116
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template117
# Predicting 157 examples
# Running Test: MFT with vocabullary - template118
# Predicting 157 examples
# Running Test: MFT with vocabullary - template119
# Predicting 157 examples
# Running Test: MFT with vocabullary - template120
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template121
# Predicting 103 examples
# Running Test: MFT with vocabullary - template122
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template123
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template124
# Predicting 157 examples
# Running Test: MFT with vocabullary - template125
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template126
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template127
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template128
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template129
# Predicting 157 examples
# Running Test: MFT with vocabullary - template130
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template131
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template132
# Predicting 157 examples
# Running Test: MFT with vocabullary - template133
# Predicting 157 examples
# Running Test: MFT with vocabullary - template134
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template135
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template136
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template137
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template138
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template139
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template140
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template141
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template142
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template143
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template144
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template145
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template146
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template147
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template148
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template149
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template150
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template151
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template152
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template153
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template154
# Predicting 109 examples
# Running Test: MFT with vocabullary - template155
# Predicting 103 examples
# Running Test: MFT with vocabullary - template156
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template157
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template158
# Predicting 103 examples
# Running Test: MFT with vocabullary - template159
# Predicting 157 examples
# Running Test: MFT with vocabullary - template160
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template161
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template162
# Predicting 157 examples
# Running Test: MFT with vocabullary - template163
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template164
# Predicting 109 examples
# Running Test: MFT with vocabullary - template165
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template166
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template167
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template168
# Predicting 103 examples
# Running Test: MFT with vocabullary - template169
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template170
# Predicting 157 examples
# Running Test: MFT with vocabullary - template171
# Predicting 157 examples
# Running Test: MFT with vocabullary - template172
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template173
# Predicting 157 examples
# Running Test: MFT with vocabullary - template174
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template175
# Predicting 157 examples
# Running Test: MFT with vocabullary - template176
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template177
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template178
# Predicting 157 examples
# Running Test: MFT with vocabullary - template179
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template180
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template181
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template182
# Predicting 109 examples
# Running Test: MFT with vocabullary - template183
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template184
# Predicting 103 examples
# Running Test: MFT with vocabullary - template185
# Predicting 157 examples
# Running Test: MFT with vocabullary - template186
# Predicting 157 examples
# Running Test: MFT with vocabullary - template187
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template188
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template189
# Predicting 157 examples
# Running Test: MFT with vocabullary - template190
# Predicting 103 examples
# Running Test: MFT with vocabullary - template191
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template192
# Predicting 157 examples
# Running Test: MFT with vocabullary - template193
# Predicting 103 examples
# Running Test: MFT with vocabullary - template194
# Predicting 69 examples
# Running Test: MFT with vocabullary - template195
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template196
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template197
# Predicting 103 examples
# Running Test: MFT with vocabullary - template198
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template199
# Predicting 157 examples
# Running Test: MFT with vocabullary - template200
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template201
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template202
# Predicting 157 examples
# Running Test: MFT with vocabullary - template203
# Predicting 157 examples
# Running Test: MFT with vocabullary - template204
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template205
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template206
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template207
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template208
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template209
# Predicting 109 examples
# Running Test: MFT with vocabullary - template210
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template211
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template212
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template213
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template214
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template215
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template216
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template217
# Predicting 157 examples
# Running Test: MFT with vocabullary - template218
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template219
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template220
# Predicting 69 examples
# Running Test: MFT with vocabullary - template221
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template222
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template223
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template224
# Predicting 109 examples
# Running Test: MFT with vocabullary - template225
# Predicting 157 examples
# Running Test: MFT with vocabullary - template226
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template227
# Predicting 157 examples
# Running Test: MFT with vocabullary - template228
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template229
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template230
# Predicting 157 examples
# Running Test: MFT with vocabullary - template231
# Predicting 109 examples
# Running Test: MFT with vocabullary - template232
# Predicting 157 examples
# Running Test: MFT with vocabullary - template233
# Predicting 157 examples
# Running Test: MFT with vocabullary - template234
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template235
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template236
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template237
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template238
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template239
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template240
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template241
# Predicting 69 examples
# Running Test: MFT with vocabullary - template242
# Predicting 103 examples
# Running Test: MFT with vocabullary - template243
# Predicting 103 examples
# Running Test: MFT with vocabullary - template244
# Predicting 157 examples
# Running Test: MFT with vocabullary - template245
# Predicting 157 examples
# Running Test: MFT with vocabullary - template246
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template247
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template248
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template249
# Predicting 157 examples
# Running Test: MFT with vocabullary - template250
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template251
# Predicting 157 examples
# Running Test: MFT with vocabullary - template252
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template253
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template254
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template255
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template256
# Predicting 69 examples
# Running Test: MFT with vocabullary - template257
# Predicting 103 examples
# Running Test: MFT with vocabullary - template258
# Predicting 103 examples
# Running Test: MFT with vocabullary - template259
# Predicting 157 examples
# Running Test: MFT with vocabullary - template260
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template261
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template262
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template263
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template264
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template265
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template266
# Predicting 109 examples
# Running Test: MFT with vocabullary - template267
# Predicting 157 examples
# Running Test: MFT with vocabullary - template268
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template269
# Predicting 109 examples
# Running Test: MFT with vocabullary - template270
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template271
# Predicting 157 examples
# Running Test: MFT with vocabullary - template272
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template273
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template274
# Predicting 69 examples
# Running Test: MFT with vocabullary - template275
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template276
# Predicting 157 examples
# Running Test: MFT with vocabullary - template277
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template278
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template279
# Predicting 69 examples
# Running Test: MFT with vocabullary - template280
# Predicting 157 examples
# Running Test: MFT with vocabullary - template281
# Predicting 157 examples
# Running Test: MFT with vocabullary - template282
# Predicting 109 examples
# Running Test: MFT with vocabullary - template283
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template284
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template285
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template286
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template287
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template288
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template289
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template290
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template291
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template292
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template293
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template294
# Predicting 157 examples
# Running Test: MFT with vocabullary - template295
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template296
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template297
# Predicting 109 examples
# Running Test: MFT with vocabullary - template298
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template299
# Predicting 157 examples
# Running Test: MFT with vocabullary - template300
# Predicting 109 examples
# Running Test: MFT with vocabullary - template301
# Predicting 157 examples
# Running Test: MFT with vocabullary - template302
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template303
# Predicting 157 examples
# Running Test: MFT with vocabullary - template304
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template305
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template306
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template307
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template308
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template309
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template310
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template311
# Predicting 109 examples
# Running Test: MFT with vocabullary - template312
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template313
# Predicting 11227 examples
# Running Test: MFT with vocabullary - template314
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template315
# Predicting 157 examples
# Running Test: MFT with vocabullary - template316
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template317
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template318
# Predicting 157 examples
# Running Test: MFT with vocabullary - template319
# Predicting 7521 examples
# Running Test: MFT with vocabullary - template320
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template321
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template322
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template323
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template324
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template325
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template326
# Predicting 157 examples
# Running Test: MFT with vocabullary - template327
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template328
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template329
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template330
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template331
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template332
# Predicting 157 examples
# Running Test: MFT with vocabullary - template333
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template334
# Predicting 103 examples
# Running Test: MFT with vocabullary - template335
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template336
# Predicting 157 examples
# Running Test: MFT with vocabullary - template337
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template338
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template339
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template340
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template341
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template342
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template343
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template344
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template345
# Predicting 7107 examples
# Running Test: MFT with vocabullary - template346
# Predicting 103 examples
# Running Test: MFT with vocabullary - template347
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template348
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template349
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template350
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template351
# Predicting 157 examples
# Running Test: MFT with vocabullary - template352
# Predicting 157 examples
# Running Test: MFT with vocabullary - template353
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template354
# Predicting 157 examples
# Running Test: MFT with vocabullary - template355
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template356
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template357
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template358
# Predicting 17108 examples
# Running Test: MFT with vocabullary - template359
# Predicting 157 examples
# Running Test: MFT with vocabullary - template360
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template361
# Predicting 103 examples
# Running Test: MFT with vocabullary - template362
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template363
# Predicting 16171 examples
# Running Test: MFT with vocabullary - template364
# Predicting 157 examples
# Running Test: MFT with vocabullary - template365
# Predicting 10833 examples
# Running Test: MFT with vocabullary - template366
# Predicting 11227 examples

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach1.suite')

suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…

# %%
table = suite.visual_summary_by_test('Test: MFT with vocabullary - template5')

failed = table.candidate_testcases
tests = table.filtered_testcases

for item in tests:
    if not item in failed:
        print(item['examples'][0]['new']['text'])
# Out:
# It relegated basically just relegated a B-movie that likes to show boobs .
# It goes basically just goes a B-movie that likes to show boobs .
# It convoluted basically just convoluted a B-movie that likes to show boobs .
# It Truly basically just Truly a B-movie that likes to show boobs .
# It tries basically just tries a B-movie that likes to show boobs .
# It requires basically just requires a B-movie that likes to show boobs .
# It lacks basically just lacks a B-movie that likes to show boobs .
# It dealt basically just dealt a B-movie that likes to show boobs .
# It shown basically just shown a B-movie that likes to show boobs .
# It all. basically just all. a B-movie that likes to show boobs .
# It tread basically just tread a B-movie that likes to show boobs .
# It went basically just went a B-movie that likes to show boobs .
# It teeter basically just teeter a B-movie that likes to show boobs .
# It throws basically just throws a B-movie that likes to show boobs .
# It thought basically just thought a B-movie that likes to show boobs .
# It sickening basically just sickening a B-movie that likes to show boobs .
# It annoyed basically just annoyed a B-movie that likes to show boobs .
# It created basically just created a B-movie that likes to show boobs .
# It was basically just was a B-movie that likes to show boobs .
# It left basically just left a B-movie that likes to show boobs .
# It confirmed basically just confirmed a B-movie that likes to show boobs .
# It researched basically just researched a B-movie that likes to show boobs .
# It lost basically just lost a B-movie that likes to show boobs .
# It shakes basically just shakes a B-movie that likes to show boobs .
# It follow basically just follow a B-movie that likes to show boobs .
# It fails basically just fails a B-movie that likes to show boobs .
# It play basically just play a B-movie that likes to show boobs .
# It expect basically just expect a B-movie that likes to show boobs .
# It rated basically just rated a B-movie that likes to show boobs .
# It puts basically just puts a B-movie that likes to show boobs .
# It could basically just could a B-movie that likes to show boobs .
# It seeing basically just seeing a B-movie that likes to show boobs .
# It done basically just done a B-movie that likes to show boobs .
# It is basically just is a B-movie that likes to show boobs .
# It disgusted basically just disgusted a B-movie that likes to show boobs .
# It became basically just became a B-movie that likes to show boobs .
# It succeeded basically just succeeded a B-movie that likes to show boobs .
# It quit basically just quit a B-movie that likes to show boobs .
# It tinted basically just tinted a B-movie that likes to show boobs .
# It follows basically just follows a B-movie that likes to show boobs .
# It ponder basically just ponder a B-movie that likes to show boobs .
# It denies basically just denies a B-movie that likes to show boobs .
# It die basically just die a B-movie that likes to show boobs .
# It exercising basically just exercising a B-movie that likes to show boobs .
# It released basically just released a B-movie that likes to show boobs .
# It seen basically just seen a B-movie that likes to show boobs .
# It frustrated basically just frustrated a B-movie that likes to show boobs .
# It acting basically just acting a B-movie that likes to show boobs .
# It screams basically just screams a B-movie that likes to show boobs .
# It heard basically just heard a B-movie that likes to show boobs .
# It jettisoned basically just jettisoned a B-movie that likes to show boobs .
# It expects basically just expects a B-movie that likes to show boobs .
# It were basically just were a B-movie that likes to show boobs .
# It judge basically just judge a B-movie that likes to show boobs .
# It make basically just make a B-movie that likes to show boobs .
# It realized basically just realized a B-movie that likes to show boobs .
# It going basically just going a B-movie that likes to show boobs .
# It ending basically just ending a B-movie that likes to show boobs .
# It depend basically just depend a B-movie that likes to show boobs .
# It try basically just try a B-movie that likes to show boobs .
# It canceled basically just canceled a B-movie that likes to show boobs .
# It wasted basically just wasted a B-movie that likes to show boobs .
# It lacking basically just lacking a B-movie that likes to show boobs .
# It expecting basically just expecting a B-movie that likes to show boobs .
# It followed basically just followed a B-movie that likes to show boobs .
# It IS basically just IS a B-movie that likes to show boobs .
# It looking basically just looking a B-movie that likes to show boobs .
# It alas basically just alas a B-movie that likes to show boobs .
# It sucked basically just sucked a B-movie that likes to show boobs .
# It smack basically just smack a B-movie that likes to show boobs .
# It get basically just get a B-movie that likes to show boobs .
# It required basically just required a B-movie that likes to show boobs .
# It high basically just high a B-movie that likes to show boobs .
# It aimed basically just aimed a B-movie that likes to show boobs .
# It does basically just does a B-movie that likes to show boobs .
# It came basically just came a B-movie that likes to show boobs .
# It be basically just be a B-movie that likes to show boobs .
# It might basically just might a B-movie that likes to show boobs .
# It sounded basically just sounded a B-movie that likes to show boobs .
# It been basically just been a B-movie that likes to show boobs .
# It 've basically just 've a B-movie that likes to show boobs .
# It allowing basically just allowing a B-movie that likes to show boobs .
# It read basically just read a B-movie that likes to show boobs .
# It has basically just has a B-movie that likes to show boobs .
# It adds basically just adds a B-movie that likes to show boobs .
# It forget basically just forget a B-movie that likes to show boobs .
# It decided basically just decided a B-movie that likes to show boobs .
# It says basically just says a B-movie that likes to show boobs .
# It see basically just see a B-movie that likes to show boobs .
# It supposed basically just supposed a B-movie that likes to show boobs .
# It considered basically just considered a B-movie that likes to show boobs .
# It unconvincing basically just unconvincing a B-movie that likes to show boobs .
# It made basically just made a B-movie that likes to show boobs .
# It raw basically just raw a B-movie that likes to show boobs .
# It missing basically just missing a B-movie that likes to show boobs .
# It slaps basically just slaps a B-movie that likes to show boobs .
# It have basically just have a B-movie that likes to show boobs .
# It guess basically just guess a B-movie that likes to show boobs .
# It telling basically just telling a B-movie that likes to show boobs .
# It trying basically just trying a B-movie that likes to show boobs .
# It sucks basically just sucks a B-movie that likes to show boobs .
# It making basically just making a B-movie that likes to show boobs .
# It must basically just must a B-movie that likes to show boobs .
# It starts basically just starts a B-movie that likes to show boobs .
# It appeal basically just appeal a B-movie that likes to show boobs .
# It can basically just can a B-movie that likes to show boobs .
# It saw basically just saw a B-movie that likes to show boobs .
# It continue basically just continue a B-movie that likes to show boobs .
# It padding basically just padding a B-movie that likes to show boobs .
# It disappointed basically just disappointed a B-movie that likes to show boobs .
# It cared basically just cared a B-movie that likes to show boobs .
# It cries basically just cries a B-movie that likes to show boobs .
# It lack basically just lack a B-movie that likes to show boobs .
# It likes basically just likes a B-movie that likes to show boobs .
# It stop basically just stop a B-movie that likes to show boobs .
# It call basically just call a B-movie that likes to show boobs .
# It doing basically just doing a B-movie that likes to show boobs .
# It are basically just are a B-movie that likes to show boobs .
# It should basically just should a B-movie that likes to show boobs .
# It irritating basically just irritating a B-movie that likes to show boobs .
# It did basically just did a B-movie that likes to show boobs .
# It reminded basically just reminded a B-movie that likes to show boobs .
# It got basically just got a B-movie that likes to show boobs .
# It 's basically just 's a B-movie that likes to show boobs .
# It let basically just let a B-movie that likes to show boobs .
# It had basically just had a B-movie that likes to show boobs .
# It would basically just would a B-movie that likes to show boobs .
# It washed basically just washed a B-movie that likes to show boobs .
# It say basically just say a B-movie that likes to show boobs .
# It emphasize basically just emphasize a B-movie that likes to show boobs .
# It consists basically just consists a B-movie that likes to show boobs .
# It understand basically just understand a B-movie that likes to show boobs .
# It passed basically just passed a B-movie that likes to show boobs .
# It needed basically just needed a B-movie that likes to show boobs .
# It outing basically just outing a B-movie that likes to show boobs .
# It shut basically just shut a B-movie that likes to show boobs .
# It looks basically just looks a B-movie that likes to show boobs .
# It overrated basically just overrated a B-movie that likes to show boobs .
# It compares basically just compares a B-movie that likes to show boobs .
# It choose basically just choose a B-movie that likes to show boobs .
# It think basically just think a B-movie that likes to show boobs .
# It go basically just go a B-movie that likes to show boobs .
# It give basically just give a B-movie that likes to show boobs .
# It sandwiched basically just sandwiched a B-movie that likes to show boobs .
# It turned basically just turned a B-movie that likes to show boobs .
# It saving basically just saving a B-movie that likes to show boobs .
# It seem basically just seem a B-movie that likes to show boobs .
# It related basically just related a B-movie that likes to show boobs .
# It interesting basically just interesting a B-movie that likes to show boobs .
# It puked basically just puked a B-movie that likes to show boobs .
# It denying basically just denying a B-movie that likes to show boobs .
# It degenerates basically just degenerates a B-movie that likes to show boobs .
# It assaulted basically just assaulted a B-movie that likes to show boobs .
# It happens basically just happens a B-movie that likes to show boobs .
# It consisted basically just consisted a B-movie that likes to show boobs .
# It leaves basically just leaves a B-movie that likes to show boobs .
# It suck basically just suck a B-movie that likes to show boobs .
