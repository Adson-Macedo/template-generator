# %% [markdown]
# # Abordagem randômica
#
# Usando a abordagem randômica para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística *Vocabullary* com o teste **MFT**.
#
# As etapas desta abordagem são:
#
# 1. Quebrar as instâncias em sentenças
# 2. Selecionar uma amostra de *K* sentenças de forma aleatória
# 3. Rankear as palavras de cada sentença
# 4. Realizar as predições de cada sentença usando o *Oráculo*
# 5. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
import random

sys.path.append('../')
random.seed(220)

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

imdb_df = pd.read_csv('./data/imdb_sampled/data-1000samples.csv')
imdb_df.head(5)
# Out:
#    label  \
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                                                                                                                                                                                  Here's example number 87,358 of Hollywood's anti-Biblical bias, so typical of them.<br /><br />Early on, Ray Liotta's wife has did and women are being interviewed for the position of housekeeper. The first interviewee is an old-fashioned-looking (dress, mannerisms, speech) who immediately lays down here strict rules, stating that "there will be two hours of Bible study ever day."<br /><br />This is said, of course, to make it sound like reading the Bible is the worse punishment you could ever inflict on someone, especially a kid. Once again, the Bible is equated with stuffy, mean-spirited people. That woman, of course, is dismissed immediately.<br /><br />Naturally, the liberal black woman (Whoopi Goldberg - who else?) is the one who is hired and, voilà, saves the day! <br /><br />Yawn.
# 1                                                                                                                                                                                                                                                                                                                                                  I don't know about the real Cobb but I got the distinct impression that the filmmakers' aim was to try to soften his jagged edges and reputation, not give us a true portrait of the man himself. In the movie, besides a few racist remarks, he's shown to be just another hard-nosed, cantakerous old coot (he's so full of life!) with a heart of gold(more or less). This is also the worst acting I've seen T.L.Jones do(he brings nothing new or subtle to his stereotyped character). He just doesn't flesh out Cobb in a way that pulls me into the movie. Not for one minute did I forget that it was Tommy Lee Jones on the screen pretending to be Ty Cobb. Robert Wuhl didnt impress either. The "comedic" elements in this movie were just distracting and didnt ring true at all. A bloody waste of time, it is
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Reba is a very dumb show. You can predict pretty much anything that's about to happen. Barbra Jean is just too stupid. It's like she's not even a character. A show like this should at least have SOMEONE who resembles a real-life person. I guess Barbra Jean represents a retarded person. Keira or whatever her name is, Reba, Brock, they're all stupid! Keira is like the smartest person on the show, and she's still stupid. EVERYONE IS STUPID! That's my opinion on Reba. Since I have said all I can say about this show, I'll just take up the next few lines of text by saying what I am currently saying right now and do it until there's 10 lines. There. Reba gets 2/10.
# 3                                                                                                                                                                                                                                                                                                                          "One Crazy Summer" is the funniest, craziest (not necessarily the best), movie I have ever seen.<br /><br />Just when one crazy scene is done, another emerges. It never lets you rest. Just one thing after another. The soundtrack is great. The songs are the right ones for the scenes.<br /><br />It is also a clean movie. Little that is dirty in it.<br /><br />Of course, it has the story of the guys you wouldn't trust with your lunch money, taking up a challenge, and winning over people with more resources. Who'd want to see it if they failed? There is a serious side, in that parents and children do not live up to each others' dreams. One should always have an open mind, and weigh all the options. This applies both to parents and children. In "One Crazy Summer", the parents are wrong. This is not always the case.
# 4  "A young man, recently engaged to be married, is the victim of a traffic accident and dies as a result of his injuries. His father, desperate to revive his son, agrees to let a scientist friend try his experimental soul transmigration process to save him. After the young man returns to life, the father and fiancée notice a dark and violent change in the young man's behavior, leading them to believe something went horribly wrong in the revival process," according to the DVD sleeve's synopsis.<br /><br />At one point, Edward Norris (as Philip Bennett) is asked, "What do you think this is, Boys Town?" Mr. Norris should know, since he was in "Boys Town". "The Man with Two Lives " is more like "Black Friday" minus Karloff and Lugosi. You do the math. This film might have been a contender, with a re-worked script; it does feature an intriguing final act. After a tepid "shoot out", hang in for the drama to pick up with a well-played scene between star Norris and pursuing detective Addison Richards (as George Bradley).<br /><br />**** The Man with Two Lives (1942) Phil Rosen ~ Edward Norris, Eleanor Lawson, Addison Richards
#
#    words
# 0    127
# 1    149
# 2    124
# 3    149
# 4    196

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
imdb_models = {
    'bert': 'textattack/bert-base-uncased-imdb', 
    'albert': 'textattack/albert-base-v2-imdb', 
    'distilbert': 'textattack/distilbert-base-uncased-imdb', 
    'roberta': 'textattack/roberta-base-imdb', 
    'xlnet': 'textattack/xlnet-base-cased-imdb'
}

# %%
m1 = load_model(imdb_models['albert'])
m2 = load_model(imdb_models['distilbert'])
m3 = load_model(imdb_models['roberta'])
m4 = load_model(imdb_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(imdb_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-imdb...
# Loading model textattack/distilbert-base-uncased-imdb...
# Loading model textattack/roberta-base-imdb...
# Some weights of the model checkpoint at textattack/roberta-base-imdb were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-imdb...
# Loading model textattack/bert-base-uncased-imdb...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorRandom

tg = PosNegTemplateGeneratorRandom(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = imdb_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates = tg.generate_templates(instances, n_masks=2, k_templates=1)
# Out:
# Converting texts to sentences...
# :: 31 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 0m 3.1s

# %%
df = tg.to_dataframe()
df
# Out:
#    label  \
# 0      1
#
#                                                                                                           original_text  \
# 0  Its enough to make you think we as humans may have a chance to survive ourselves ,maybe , hopefully .See this film .
#
#                                                                                                              masked_text  \
# 0  Its {mask} to make you think we as humans may have a chance to survive ourselves , maybe , hopefully .See this film .
#
#                                                                                                               template_text
# 0  Its {neg_adj} to make you think we as humans may have a chance to survive ourselves , maybe , hopefully .See this film .

# %%
tg.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': ['enough']}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in imdb_df['text'].values]

# %%
tg = PosNegTemplateGeneratorRandom(model, models)
templates = tg.generate_templates(instances, n_masks=2, k_templates=80)
# Out:
# Converting texts to sentences...
# :: 7973 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 1m 10.3s

# %%
df = tg.to_dataframe()
df
# Out:
#     label  \
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
# ..    ...
# 75      0
# 76      1
# 77      0
# 78      0
# 79      1
#
#                                                                                                                                                                                                        original_text  \
# 0   The acting is terrible as Andrew grows up in his twenties and looks terrible with his sunken in face, never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan.
# 1                                                                                                                          I AM NOT LYNNE BATES MY NAMES IS RITICHIE BUT LYNNE IS MY MUM I'M JUST USING HER ACCOUNT!
# 2                                                                                                                                                             The marathon card game beat Goodfellas, Sopranos, etc.
# 3                                                                                                                  Where have our William Holden's gone and will they make these moving, wonderful, movies any more?
# 4                                                                                                                                                                         And there was no tournament to compete in.
# ..                                                                                                                                                                                                               ...
# 75                                                                                                                                                                                     The title is misleading also.
# 76                            The gifted Christina Ricci has an impressive performance in the role of a young tramp abused since her childhood by her father and having had sex with the whole town where she lives.
# 77                                                                                                                                                                                                        Nuff said.
# 78                                                                                                                                                                                          It was absolutely awful!
# 79                                                                                                                                                                               Anderson is obviously a film lover.
#
#                                                                                                                                                                                                        masked_text  \
# 0   The acting is {mask} as Andrew grows up in his twenties and looks {mask} with his sunken in face , never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan .
# 1                                                                                                                      I AM NOT LYNNE BATES MY NAMES IS RITICHIE BUT LYNNE IS MY MUM I 'M JUST USING HER ACCOUNT !
# 2                                                                                                                                                        The marathon card game beat Goodfellas , Sopranos , etc .
# 3                                                                                                             Where have our William Holden 's gone and will they make these moving , {mask} , movies any {mask} ?
# 4                                                                                                                                                                      And there was no tournament to compete in .
# ..                                                                                                                                                                                                             ...
# 75                                                                                                                                                                                  The title is misleading also .
# 76                            The gifted Christina Ricci has an {mask} performance in the role of a young tramp abused since her childhood by her father and having had sex with the {mask} town where she lives .
# 77                                                                                                                                                                                                     Nuff said .
# 78                                                                                                                                                                                      It was absolutely {mask} !
# 79                                                                                                                                                                            Anderson is obviously a film lover .
#
#                                                                                                                                                                                                            template_text
# 0   The acting is {neg_adj} as Andrew grows up in his twenties and looks {neg_adj} with his sunken in face , never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan .
# 1                                                                                                                            I AM NOT LYNNE BATES MY NAMES IS RITICHIE BUT LYNNE IS MY MUM I 'M JUST USING HER ACCOUNT !
# 2                                                                                                                                                              The marathon card game beat Goodfellas , Sopranos , etc .
# 3                                                                                                             Where have our William Holden 's gone and will they make these moving , {pos_adj} , movies any {pos_adj} ?
# 4                                                                                                                                                                            And there was no tournament to compete in .
# ..                                                                                                                                                                                                                   ...
# 75                                                                                                                                                                                        The title is misleading also .
# 76                            The gifted Christina Ricci has an {neg_adj} performance in the role of a young tramp abused since her childhood by her father and having had sex with the {neg_adj} town where she lives .
# 77                                                                                                                                                                                                           Nuff said .
# 78                                                                                                                                                                                         It was absolutely {neg_adj} !
# 79                                                                                                                                                                                  Anderson is obviously a film lover .
#
# [80 rows x 4 columns]

# %%
print(tg.lexicons)
# Out:
# {'pos_adj': ['inexpensive', 'br', 'lovers-on-the-lam', 'nondescript', '<', 'tragic', 'eternal', 'upside-down', 'positive', 'pleasant', 'pregnant', 'best', 'fantastic', 'more', 'great', 'gory', 'sardonic', 'Italian', 'innovative', 'oft-noted', 'wonderful', 'mature', 'excellent', 'stunning', 'entertaining', 'good', '*', 'special', 'beautiful', 'archivist', 'enthusiastic'], 'neg_adj': ['tame', 'whole', 'worst', 'patient', 'audacious', 'entire', 'inept', 'poor', 'usual', 'terrible', 'common', 'blunted', 'absurd', 'pro-movie', 'first', 'half', 'human', 'alert', 'sleazy', 'repetitive', 'forty', 'funny', 'high', 'impressive', 'many', 'few', 'trite', 'main', 'forced', 'awful', 'stupid', 'own', 'tedious', 'various', 'fellow']}

# %% [markdown]
# # Usando os templates gerados pelo TemplateGenerator no CheckList

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
suite.save('./suites/posneg-random.suite')
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 35 examples
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 1 examples
# Running Test: MFT with vocabullary - template3
# Predicting 1 examples
# Running Test: MFT with vocabullary - template4
# Predicting 31 examples
# Running Test: MFT with vocabullary - template5
# Predicting 1 examples
# Running Test: MFT with vocabullary - template6
# Predicting 31 examples
# Running Test: MFT with vocabullary - template7
# Predicting 35 examples
# Running Test: MFT with vocabullary - template8
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template9
# Predicting 31 examples
# Running Test: MFT with vocabullary - template10
# Predicting 1 examples
# Running Test: MFT with vocabullary - template11
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template12
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template13
# Predicting 1 examples
# Running Test: MFT with vocabullary - template14
# Predicting 1 examples
# Running Test: MFT with vocabullary - template15
# Predicting 31 examples
# Running Test: MFT with vocabullary - template16
# Predicting 31 examples
# Running Test: MFT with vocabullary - template17
# Predicting 35 examples
# Running Test: MFT with vocabullary - template18
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template19
# Predicting 35 examples
# Running Test: MFT with vocabullary - template20
# Predicting 1 examples
# Running Test: MFT with vocabullary - template21
# Predicting 31 examples
# Running Test: MFT with vocabullary - template22
# Predicting 1 examples
# Running Test: MFT with vocabullary - template23
# Predicting 35 examples
# Running Test: MFT with vocabullary - template24
# Predicting 31 examples
# Running Test: MFT with vocabullary - template25
# Predicting 35 examples
# Running Test: MFT with vocabullary - template26
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template27
# Predicting 31 examples
# Running Test: MFT with vocabullary - template28
# Predicting 1 examples
# Running Test: MFT with vocabullary - template29
# Predicting 35 examples
# Running Test: MFT with vocabullary - template30
# Predicting 31 examples
# Running Test: MFT with vocabullary - template31
# Predicting 31 examples
# Running Test: MFT with vocabullary - template32
# Predicting 1 examples
# Running Test: MFT with vocabullary - template33
# Predicting 35 examples
# Running Test: MFT with vocabullary - template34
# Predicting 35 examples
# Running Test: MFT with vocabullary - template35
# Predicting 1 examples
# Running Test: MFT with vocabullary - template36
# Predicting 1 examples
# Running Test: MFT with vocabullary - template37
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template38
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template39
# Predicting 31 examples
# Running Test: MFT with vocabullary - template40
# Predicting 35 examples
# Running Test: MFT with vocabullary - template41
# Predicting 1 examples
# Running Test: MFT with vocabullary - template42
# Predicting 35 examples
# Running Test: MFT with vocabullary - template43
# Predicting 1 examples
# Running Test: MFT with vocabullary - template44
# Predicting 35 examples
# Running Test: MFT with vocabullary - template45
# Predicting 35 examples
# Running Test: MFT with vocabullary - template46
# Predicting 1 examples
# Running Test: MFT with vocabullary - template47
# Predicting 35 examples
# Running Test: MFT with vocabullary - template48
# Predicting 35 examples
# Running Test: MFT with vocabullary - template49
# Predicting 1 examples
# Running Test: MFT with vocabullary - template50
# Predicting 1 examples
# Running Test: MFT with vocabullary - template51
# Predicting 1 examples
# Running Test: MFT with vocabullary - template52
# Predicting 31 examples
# Running Test: MFT with vocabullary - template53
# Predicting 31 examples
# Running Test: MFT with vocabullary - template54
# Predicting 31 examples
# Running Test: MFT with vocabullary - template55
# Predicting 1 examples
# Running Test: MFT with vocabullary - template56
# Predicting 1 examples
# Running Test: MFT with vocabullary - template57
# Predicting 35 examples
# Running Test: MFT with vocabullary - template58
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template59
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template60
# Predicting 35 examples
# Running Test: MFT with vocabullary - template61
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template62
# Predicting 35 examples
# Running Test: MFT with vocabullary - template63
# Predicting 1 examples
# Running Test: MFT with vocabullary - template64
# Predicting 1085 examples
# Running Test: MFT with vocabullary - template65
# Predicting 31 examples
# Running Test: MFT with vocabullary - template66
# Predicting 35 examples
# Running Test: MFT with vocabullary - template67
# Predicting 35 examples
# Running Test: MFT with vocabullary - template68
# Predicting 35 examples
# Running Test: MFT with vocabullary - template69
# Predicting 35 examples
# Running Test: MFT with vocabullary - template70
# Predicting 35 examples
# Running Test: MFT with vocabullary - template71
# Predicting 31 examples
# Running Test: MFT with vocabullary - template72
# Predicting 1 examples
# Running Test: MFT with vocabullary - template73
# Predicting 31 examples
# Running Test: MFT with vocabullary - template74
# Predicting 1 examples
# Running Test: MFT with vocabullary - template75
# Predicting 1 examples
# Running Test: MFT with vocabullary - template76
# Predicting 1 examples
# Running Test: MFT with vocabullary - template77
# Predicting 35 examples
# Running Test: MFT with vocabullary - template78
# Predicting 1 examples
# Running Test: MFT with vocabullary - template79
# Predicting 35 examples
# Running Test: MFT with vocabullary - template80
# Predicting 1 examples

# %%
suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      35
# Fails (rate):    3 (8.6%)
#
# Example fails:
# 0.6 The acting is whole as Andrew grows up in his twenties and looks whole with his sunken in face , never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan .
# ----
# 0.7 The acting is funny as Andrew grows up in his twenties and looks funny with his sunken in face , never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan .
# ----
# 0.5 The acting is own as Andrew grows up in his twenties and looks own with his sunken in face , never ending grin and Dukes of Hazard clothes on looks more like a drunken has been than the son of Satan .
# ----
#
#
# Test: MFT with vocabullary - template2
# Test cases:      1
# Fails (rate):    1 (100.0%)
#
# Example fails:
# 0.3 I AM NOT LYNNE BATES MY NAMES IS RITICHIE BUT LYNNE IS MY MUM I 'M JUST USING HER ACCOUNT !
# ----
#
#
# Test: MFT with vocabullary - template3
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template4
# Test cases:      31
# Fails (rate):    15 (48.4%)
#
# Example fails:
# 0.0 Where have our William Holden 's gone and will they make these moving , nondescript , movies any nondescript ?
# ----
# 0.0 Where have our William Holden 's gone and will they make these moving , pregnant , movies any pregnant ?
# ----
# 0.0 Where have our William Holden 's gone and will they make these moving , more , movies any more ?
# ----
#
#
# Test: MFT with vocabullary - template5
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template6
# Test cases:      31
# Fails (rate):    9 (29.0%)
#
# Example fails:
# 0.7 I truly do n't care for anyone except maybe the special woman .
# ----
# 0.5 I truly do n't care for anyone except maybe the beautiful woman .
# ----
# 0.6 I truly do n't care for anyone except maybe the < woman .
# ----
#
#
# Test: MFT with vocabullary - template7
# Test cases:      35
# Fails (rate):    21 (60.0%)
#
# Example fails:
# 0.1 by awful years !
# ----
# 0.2 by whole years !
# ----
# 0.0 by trite years !
# ----
#
#
# Test: MFT with vocabullary - template8
# Test cases:      1085
# Fails (rate):    906 (83.5%)
#
# Example fails:
# 0.1 John Hurt is a great actor , with fellow oft-noted performances over many years , but he was born to play the storyteller .
# ----
# 0.0 John Hurt is a great actor , with blunted pleasant performances over many years , but he was born to play the storyteller .
# ----
# 0.0 John Hurt is a great actor , with whole inexpensive performances over many years , but he was born to play the storyteller .
# ----
#
#
# Test: MFT with vocabullary - template9
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template10
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template11
# Test cases:      1085
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template12
# Test cases:      1085
# Fails (rate):    86 (7.9%)
#
# Example fails:
# 0.0 Julie is , as worst , sardonic - singing and acting brilliantly .
# ----
# 0.5 Julie is , as poor , mature - singing and acting brilliantly .
# ----
# 0.1 Julie is , as worst , oft-noted - singing and acting brilliantly .
# ----
#
#
# Test: MFT with vocabullary - template13
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template14
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template15
# Test cases:      31
# Fails (rate):    15 (48.4%)
#
# Example fails:
# 0.4 < archivist / > < br / > _____ < br / > < br / > 10/10
# ----
# 0.0 < pregnant / > < br / > _____ < br / > < br / > 10/10
# ----
# 0.3 < mature / > < br / > _____ < br / > < br / > 10/10
# ----
#
#
# Test: MFT with vocabullary - template16
# Test cases:      31
# Fails (rate):    26 (83.9%)
#
# Example fails:
# 0.1 If you 're looking for entertainment at < prices then you need The < Job .
# ----
# 0.0 If you 're looking for entertainment at pregnant prices then you need The pregnant Job .
# ----
# 0.1 If you 're looking for entertainment at * prices then you need The * Job .
# ----
#
#
# Test: MFT with vocabullary - template17
# Test cases:      35
# Fails (rate):    22 (62.9%)
#
# Example fails:
# 1.0 THE QUICKIE ( 1 outta 5 stars ) < br / > < br / > Pretty whole movie ... an old-as-the-hills story about a high-ranking gangster who wants to quit , passing on his empire to his whole son .
# ----
# 1.0 THE QUICKIE ( 1 outta 5 stars ) < br / > < br / > Pretty alert movie ... an old-as-the-hills story about a high-ranking gangster who wants to quit , passing on his empire to his alert son .
# ----
# 1.0 THE QUICKIE ( 1 outta 5 stars ) < br / > < br / > Pretty tame movie ... an old-as-the-hills story about a high-ranking gangster who wants to quit , passing on his empire to his tame son .
# ----
#
#
# Test: MFT with vocabullary - template18
# Test cases:      1085
# Fails (rate):    650 (59.9%)
#
# Example fails:
# 0.0 had been poor , * or just simply interesting .
# ----
# 0.1 had been fellow , nondescript or just simply interesting .
# ----
# 0.0 had been audacious , pregnant or just simply interesting .
# ----
#
#
# Test: MFT with vocabullary - template19
# Test cases:      35
# Fails (rate):    10 (28.6%)
#
# Example fails:
# 0.0 theme of threesomes and tedious sex .
# ----
# 0.4 theme of threesomes and inept sex .
# ----
# 0.0 theme of threesomes and stupid sex .
# ----
#
#
# Test: MFT with vocabullary - template20
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template21
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template22
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template23
# Test cases:      35
# Fails (rate):    18 (51.4%)
#
# Example fails:
# 1.0 The music is impressive , the impressive theme of the adagietto from Mahler 's fifth is used again and again .
# ----
# 0.8 The music is alert , the alert theme of the adagietto from Mahler 's fifth is used again and again .
# ----
# 0.9 The music is entire , the entire theme of the adagietto from Mahler 's fifth is used again and again .
# ----
#
#
# Test: MFT with vocabullary - template24
# Test cases:      31
# Fails (rate):    2 (6.5%)
#
# Example fails:
# 0.1 Who can forget California Joe , the great `` Queen 's Own Buttler '' with his song `` Garryowen '' , the touching Mrs Custer ( Olivia de Havilland ) , the diabolic Sharp well played by Arthur Kennedy ? < br / > < br / > An < blow remains on this epic and < freso .
# ----
# 0.1 Who can forget California Joe , the great `` Queen 's Own Buttler '' with his song `` Garryowen '' , the touching Mrs Custer ( Olivia de Havilland ) , the diabolic Sharp well played by Arthur Kennedy ? < br / > < br / > An * blow remains on this epic and * freso .
# ----
#
#
# Test: MFT with vocabullary - template25
# Test cases:      35
# Fails (rate):    27 (77.1%)
#
# Example fails:
# 1.0 When I first saw this film it was not an first one .
# ----
# 1.0 When I first saw this film it was not an absurd one .
# ----
# 1.0 When I first saw this film it was not an few one .
# ----
#
#
# Test: MFT with vocabullary - template26
# Test cases:      1085
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template27
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template28
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template29
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template30
# Test cases:      31
# Fails (rate):    7 (22.6%)
#
# Example fails:
# 0.0 but none of this matters , for , director tarsem singh has given us one of the most visually pregnant movies ever .
# ----
# 0.0 but none of this matters , for , director tarsem singh has given us one of the most visually nondescript movies ever .
# ----
# 0.0 but none of this matters , for , director tarsem singh has given us one of the most visually upside-down movies ever .
# ----
#
#
# Test: MFT with vocabullary - template31
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template32
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template33
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template34
# Test cases:      35
# Fails (rate):    3 (8.6%)
#
# Example fails:
# 0.7 She needs to be the center of attention and she 'll act patient to make it so .
# ----
# 0.6 She needs to be the center of attention and she 'll act own to make it so .
# ----
# 0.5 She needs to be the center of attention and she 'll act alert to make it so .
# ----
#
#
# Test: MFT with vocabullary - template35
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template36
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template37
# Test cases:      1085
# Fails (rate):    91 (8.4%)
#
# Example fails:
# 0.0 This tedious approach , once you get used to it , provides you with all sorts of pregnant scenes and images .
# ----
# 0.0 This awful approach , once you get used to it , provides you with all sorts of sardonic scenes and images .
# ----
# 0.0 This stupid approach , once you get used to it , provides you with all sorts of more scenes and images .
# ----
#
#
# Test: MFT with vocabullary - template38
# Test cases:      1085
# Fails (rate):    256 (23.6%)
#
# Example fails:
# 0.6 'Moms ' Mabley is not a bit trite , though I remember her as a very special talk show guest from my youth .
# ----
# 0.7 'Moms ' Mabley is not a bit blunted , though I remember her as a very < talk show guest from my youth .
# ----
# 0.7 'Moms ' Mabley is not a bit trite , though I remember her as a very < talk show guest from my youth .
# ----
#
#
# Test: MFT with vocabullary - template39
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template40
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.3 The stupid paying world of crime offers the greatest appeal to his stupid senses .
# ----
#
#
# Test: MFT with vocabullary - template41
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template42
# Test cases:      35
# Fails (rate):    16 (45.7%)
#
# Example fails:
# 0.3 or to say it in my forced Language `` Skikkelig gebrokkent '' .
# ----
# 0.0 or to say it in my sleazy Language `` Skikkelig gebrokkent '' .
# ----
# 0.1 or to say it in my blunted Language `` Skikkelig gebrokkent '' .
# ----
#
#
# Test: MFT with vocabullary - template43
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template44
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.7 A impressive star dud .
# ----
#
#
# Test: MFT with vocabullary - template45
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template46
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template47
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 1.0 To even mention it along with Platoon or Full Metal Jacket is pro-movie .
# ----
#
#
# Test: MFT with vocabullary - template48
# Test cases:      35
# Fails (rate):    25 (71.4%)
#
# Example fails:
# 0.0 If you do n't mind being grossed out a bit ( ok a lot , but it 's awful grossed out ) , see this movie .
# ----
# 0.1 If you do n't mind being grossed out a bit ( ok a lot , but it 's entire grossed out ) , see this movie .
# ----
# 0.0 If you do n't mind being grossed out a bit ( ok a lot , but it 's audacious grossed out ) , see this movie .
# ----
#
#
# Test: MFT with vocabullary - template49
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template50
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template51
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template52
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template53
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template54
# Test cases:      31
# Fails (rate):    12 (38.7%)
#
# Example fails:
# 1.0 I can not believe the fantastic reaction to this movie .
# ----
# 1.0 I can not believe the stunning reaction to this movie .
# ----
# 0.6 I can not believe the Italian reaction to this movie .
# ----
#
#
# Test: MFT with vocabullary - template55
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template56
# Test cases:      1
# Fails (rate):    1 (100.0%)
#
# Example fails:
# 0.5 which , of course , he was n't .
# ----
#
#
# Test: MFT with vocabullary - template57
# Test cases:      35
# Fails (rate):    14 (40.0%)
#
# Example fails:
# 0.2 In Career mode , you collect SKATE , get money , get poor scores and other poor things in 2 minutes .
# ----
# 0.0 In Career mode , you collect SKATE , get money , get repetitive scores and other repetitive things in 2 minutes .
# ----
# 0.5 In Career mode , you collect SKATE , get money , get blunted scores and other blunted things in 2 minutes .
# ----
#
#
# Test: MFT with vocabullary - template58
# Test cases:      1085
# Fails (rate):    584 (53.8%)
#
# Example fails:
# 0.9 You do n't see this here. < entertaining / > < br / > Even if you do n't compare , standing on it 's many , this movie to too rushed .
# ----
# 1.0 You do n't see this here. < excellent / > < br / > Even if you do n't compare , standing on it 's audacious , this movie to too rushed .
# ----
# 1.0 You do n't see this here. < mature / > < br / > Even if you do n't compare , standing on it 's pro-movie , this movie to too rushed .
# ----
#
#
# Test: MFT with vocabullary - template59
# Test cases:      1085
# Fails (rate):    63 (5.8%)
#
# Example fails:
# 0.7 According to my forced IMDb users , ( excellent SPOILER * ) RAPTOR uses stock footage from the Carnotaur films .
# ----
# 1.0 According to my impressive IMDb users , ( excellent SPOILER * ) RAPTOR uses stock footage from the Carnotaur films .
# ----
# 0.5 According to my various IMDb users , ( entertaining SPOILER * ) RAPTOR uses stock footage from the Carnotaur films .
# ----
#
#
# Test: MFT with vocabullary - template60
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template61
# Test cases:      1085
# Fails (rate):    318 (29.3%)
#
# Example fails:
# 0.0 And this movie contains one of the awful innovative facts about Sean Bean 's career .
# ----
# 0.0 And this movie contains one of the repetitive fantastic facts about Sean Bean 's career .
# ----
# 0.0 And this movie contains one of the forced nondescript facts about Sean Bean 's career .
# ----
#
#
# Test: MFT with vocabullary - template62
# Test cases:      35
# Fails (rate):    18 (51.4%)
#
# Example fails:
# 1.0 This Killjoy is honestly the downright main actor I 've seen in any movie , and I 've seen a lot of movies .
# ----
# 1.0 This Killjoy is honestly the downright own actor I 've seen in any movie , and I 've seen a lot of movies .
# ----
# 1.0 This Killjoy is honestly the downright high actor I 've seen in any movie , and I 've seen a lot of movies .
# ----
#
#
# Test: MFT with vocabullary - template63
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template64
# Test cases:      1085
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template65
# Test cases:      31
# Fails (rate):    7 (22.6%)
#
# Example fails:
# 0.1 Here 's another lovers-on-the-lam surprise .
# ----
# 0.5 Here 's another gory surprise .
# ----
# 0.4 Here 's another pregnant surprise .
# ----
#
#
# Test: MFT with vocabullary - template66
# Test cases:      35
# Fails (rate):    2 (5.7%)
#
# Example fails:
# 1.0 It seems companies are probably paying for services which post junk funny comments on IMDb. < br / > < br / > This movie was funny .
# ----
# 1.0 It seems companies are probably paying for services which post junk impressive comments on IMDb. < br / > < br / > This movie was impressive .
# ----
#
#
# Test: MFT with vocabullary - template67
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 0.6 Spike tries to hard to make himself into something he 's not , which is to say , he tries to be whole .
# ----
#
#
# Test: MFT with vocabullary - template68
# Test cases:      35
# Fails (rate):    1 (2.9%)
#
# Example fails:
# 1.0 I ca n't believe that I actually sat thru this impressive film .
# ----
#
#
# Test: MFT with vocabullary - template69
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template70
# Test cases:      35
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template71
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template72
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template73
# Test cases:      31
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template74
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template75
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template76
# Test cases:      1
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template77
# Test cases:      35
# Fails (rate):    12 (34.3%)
#
# Example fails:
# 0.0 The gifted Christina Ricci has an inept performance in the role of a young tramp abused since her childhood by her father and having had sex with the inept town where she lives .
# ----
# 0.0 The gifted Christina Ricci has an sleazy performance in the role of a young tramp abused since her childhood by her father and having had sex with the sleazy town where she lives .
# ----
# 0.0 The gifted Christina Ricci has an tedious performance in the role of a young tramp abused since her childhood by her father and having had sex with the tedious town where she lives .
# ----
#
#
# Test: MFT with vocabullary - template78
# Test cases:      1
# Fails (rate):    1 (100.0%)
#
# Example fails:
# 0.5 Nuff said .
# ----
#
#
# Test: MFT with vocabullary - template79
# Test cases:      35
# Fails (rate):    20 (57.1%)
#
# Example fails:
# 0.7 It was absolutely blunted !
# ----
# 0.9 It was absolutely various !
# ----
# 1.0 It was absolutely funny !
# ----
#
#
# Test: MFT with vocabullary - template80
# Test cases:      1
# Fails (rate):    1 (100.0%)
#
# Example fails:
# 0.5 Anderson is obviously a film lover .
# ----

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-random.suite')

suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…
