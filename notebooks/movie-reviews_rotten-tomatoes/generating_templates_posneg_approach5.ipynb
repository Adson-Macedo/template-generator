# %% [markdown]
# # Abordagem 5
#
# Usando a abordagem 5 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística "Vocabulary" com o teste MFT.
#
# As etapas desta abordagem são:
#
# 1. Quebrar as instâncias em sentenças
# 2. Rankear as palavras de cada sentença
# 3. Filtrar as sentenças pelo tamanho (maior ou igual a 5 palavras)
# 4. Filtrar sentenças com palavras relevantes (verbos ou adjetivos)
# 5. Filtrar sentenças com alta confiança na predição das palavras relevantes da etapa anterior
# 6. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

movie_reviews_rt_df = pd.read_csv('./data/data-rt-100samples.csv')
movie_reviews_rt_df.head(5)
# Out:
#    label  \
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#
#                                                                        text  \
# 0  allen's underestimated charm delivers more goodies than lumps of coal .
# 1                   skip the film and buy the philip glass soundtrack cd .
# 2          involving at times  but lapses quite casually into the absurd .
# 3  while hoffman's performance is great  the subject matter goes nowhere .
# 4   a flick about our infantilized culture that isn't entirely infantile .
#
#    words
# 0     11
# 1     11
# 2     11
# 3     11
# 4     11

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
movie_reviews_models = {
    'bert': 'textattack/bert-base-uncased-rotten-tomatoes', 
    'albert': 'textattack/albert-base-v2-rotten-tomatoes', 
    'distilbert': 'textattack/distilbert-base-uncased-rotten-tomatoes', 
    'roberta': 'textattack/roberta-base-rotten-tomatoes', 
    'xlnet': 'textattack/xlnet-base-cased-rotten-tomatoes'
}

# %%
m0 = load_model(movie_reviews_models['bert'])
m1 = load_model(movie_reviews_models['albert'])
m2 = load_model(movie_reviews_models['distilbert'])
m3 = load_model(movie_reviews_models['roberta'])
m4 = load_model(movie_reviews_models['xlnet'])

# Models to be used as oracle
models_1 = [m1, m2, m3, m4]
models_2 = [m0, m2, m3, m4]
models_3 = [m0, m1, m3, m4]
models_4 = [m0, m1, m2, m4]
models_5 = [m0, m1, m2, m3]
# Target model
model_bert = m0
model_albert = m1
model_distilbert = m2
model_roberta = m3
model_xlnet = m4
# Out:
# Loading model textattack/bert-base-uncased-rotten-tomatoes...
# Loading model textattack/albert-base-v2-rotten-tomatoes...
# Loading model textattack/distilbert-base-uncased-rotten-tomatoes...
# Loading model textattack/roberta-base-rotten-tomatoes...
# Some weights of the model checkpoint at textattack/roberta-base-rotten-tomatoes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-rotten-tomatoes...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp5

tg0 = PosNegTemplateGeneratorApp5(model_bert, models_1)
tg1 = PosNegTemplateGeneratorApp5(model_albert, models_2)
tg2 = PosNegTemplateGeneratorApp5(model_distilbert, models_3)
tg3 = PosNegTemplateGeneratorApp5(model_roberta, models_4)
tg4 = PosNegTemplateGeneratorApp5(model_xlnet, models_5)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = movie_reviews_rt_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates0 = tg0.generate_templates(instances, n_masks=2, ranked_words_count=4)
templates1 = tg1.generate_templates(instances, n_masks=2, ranked_words_count=4)
templates2 = tg2.generate_templates(instances, n_masks=2, ranked_words_count=4)
templates3 = tg3.generate_templates(instances, n_masks=2, ranked_words_count=4)
templates4 = tg4.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 6 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: of, index: 17, tag: ADP, rank_score: -0.00011205673217773438}
# {word: wonders, index: 16, tag: NOUN, rank_score: -7.635354995727539e-05}
# {word: elegantly, index: 0, tag: ADV, rank_score: -5.036592483520508e-05}
# {word: detailed, index: 15, tag: ADJ, rank_score: -1.6689300537109375e-05}
#
# ['ADJ']
# {word: future, index: 2, tag: NOUN, rank_score: -0.06550866365432739}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.0017756223678588867}
# {word: one, index: 3, tag: NUM, rank_score: 0.0016388297080993652}
# {word: for, index: 0, tag: ADP, rank_score: 0.0016148090362548828}
#
# ['ADJ']
# {word: of, index: 15, tag: ADP, rank_score: -0.0016689896583557129}
# {word: for, index: 11, tag: ADP, rank_score: -0.0008890032768249512}
# {word: more, index: 13, tag: ADJ, rank_score: -0.000647127628326416}
# {word: member, index: 14, tag: NOUN, rank_score: -0.00031298398971557617}
#
# ['ADJ']
# {word: refreshingly, index: 10, tag: ADV, rank_score: 0.0010156035423278809}
# {word: no, index: 1, tag: DET, rank_score: 0.000680387020111084}
# {word: by, index: 0, tag: ADP, rank_score: 0.0005499720573425293}
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.0003120899200439453}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.8234872817993164}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.8017554879188538}
# {word: through, index: 1, tag: ADP, rank_score: -0.7771927118301392}
# {word: one, index: 9, tag: NUM, rank_score: -0.7656691074371338}
#
# ['ADJ']
# {word: goes, index: 9, tag: VERB, rank_score: -0.9912518262863159}
# {word: while, index: 0, tag: ADP, rank_score: -0.8817930817604065}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.0024411678314208984}
# {word: great, index: 5, tag: ADJ, rank_score: -0.001394033432006836}
#
# :: 0 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.
# Converting texts to sentences...
# :: 6 sentences were generated.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: elegantly, index: 0, tag: ADV, rank_score: -0.0026738643646240234}
# {word: crystallize, index: 9, tag: VERB, rank_score: -0.002629220485687256}
# {word: wonders, index: 16, tag: NOUN, rank_score: -0.0023320913314819336}
# {word: expressively, index: 3, tag: ADV, rank_score: -0.0016664862632751465}
#
# ['ADJ']
# {word: for, index: 0, tag: ADP, rank_score: -0.12896734476089478}
# {word: the, index: 1, tag: DET, rank_score: -0.09513872861862183}
# {word: future, index: 2, tag: NOUN, rank_score: -0.06810325384140015}
# {word: mr, index: 5, tag: NOUN, rank_score: 0.026988327503204346}
#
# ['ADJ']
# {word: plympton, index: 7, tag: NOUN, rank_score: 0.2397146224975586}
# {word: find, index: 9, tag: VERB, rank_score: 0.18597519397735596}
# {word: room, index: 10, tag: NOUN, rank_score: -0.16984784603118896}
# {word: of, index: 15, tag: ADP, rank_score: -0.16583406925201416}
#
# ['ADJ']
# {word: but, index: 6, tag: CONJ, rank_score: -0.04724925756454468}
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.02178877592086792}
# {word: by, index: 0, tag: ADP, rank_score: -0.007844924926757812}
# {word: is, index: 8, tag: VERB, rank_score: -0.005815982818603516}
#
# ['ADJ']
# {word: from-television, index: 11, tag: NOUN, rank_score: -0.40260833501815796}
# {word: if, index: 17, tag: ADP, rank_score: -0.38727879524230957}
# {word: looks, index: 15, tag: VERB, rank_score: -0.20822632312774658}
# {word: on, index: 20, tag: ADP, rank_score: -0.16086214780807495}
#
# ['ADJ']
# {word: while, index: 0, tag: ADP, rank_score: -0.9056574702262878}
# {word: great, index: 5, tag: ADJ, rank_score: -0.1910417079925537}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.08988571166992188}
# {word: goes, index: 9, tag: VERB, rank_score: -0.08244305849075317}
#
# :: 0 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.
# Converting texts to sentences...
# :: 6 sentences were generated.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: and, index: 2, tag: CONJ, rank_score: -0.0047067999839782715}
# {word: wonders, index: 16, tag: NOUN, rank_score: -0.003041088581085205}
# {word: of, index: 17, tag: ADP, rank_score: -0.0019152164459228516}
# {word: moments, index: 12, tag: NOUN, rank_score: -0.001737356185913086}
#
# ['ADJ']
# {word: mr, index: 5, tag: NOUN, rank_score: 0.12407886981964111}
# {word: one, index: 3, tag: NUM, rank_score: 0.05982488393783569}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.041512906551361084}
# {word: for, index: 0, tag: ADP, rank_score: -0.011348724365234375}
#
# ['ADJ']
# {word: room, index: 10, tag: NOUN, rank_score: -0.21790781617164612}
# {word: band, index: 18, tag: NOUN, rank_score: 0.11481207609176636}
# {word: his, index: 16, tag: PRON, rank_score: 0.1122368574142456}
# {word: more, index: 13, tag: ADJ, rank_score: 0.11195629835128784}
#
# ['ADJ']
# {word: but, index: 6, tag: CONJ, rank_score: -0.012876689434051514}
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.009108424186706543}
# {word: is, index: 8, tag: VERB, rank_score: -0.003394782543182373}
# {word: no, index: 1, tag: DET, rank_score: -0.0031695961952209473}
#
# ['ADJ']
# {word: if, index: 17, tag: ADP, rank_score: -0.21166658401489258}
# {word: bursting, index: 0, tag: VERB, rank_score: 0.16942322254180908}
# {word: the, index: 2, tag: DET, rank_score: 0.16166549921035767}
# {word: of, index: 4, tag: ADP, rank_score: 0.13625973463058472}
#
# ['ADJ']
# {word: while, index: 0, tag: ADP, rank_score: 0.24310076236724854}
# {word: performance, index: 3, tag: NOUN, rank_score: -0.1947731375694275}
# {word: great, index: 5, tag: ADJ, rank_score: -0.18993842601776123}
# {word: subject, index: 7, tag: ADJ, rank_score: -0.15534278750419617}
#
# :: 1 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.
# Converting texts to sentences...
# :: 6 sentences were generated.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: and, index: 2, tag: CONJ, rank_score: -0.0038405656814575195}
# {word: expressively, index: 3, tag: ADV, rank_score: -0.0034694671630859375}
# {word: the, index: 5, tag: DET, rank_score: -0.003174424171447754}
# {word: elegantly, index: 0, tag: ADV, rank_score: -0.002657651901245117}
#
# ['ADJ']
# {word: future, index: 2, tag: NOUN, rank_score: 0.26465070247650146}
# {word: hopes, index: 4, tag: VERB, rank_score: 0.25991272926330566}
# {word: for, index: 0, tag: ADP, rank_score: -0.08837974071502686}
# {word: the, index: 1, tag: DET, rank_score: 0.07815515995025635}
#
# ['ADJ']
# {word: will, index: 8, tag: VERB, rank_score: -0.02120763063430786}
# {word: screenwriter, index: 21, tag: NOUN, rank_score: -0.009249269962310791}
# {word: of, index: 15, tag: ADP, rank_score: -0.007899105548858643}
# {word: band, index: 18, tag: NOUN, rank_score: -0.005760014057159424}
#
# ['ADJ']
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.013388872146606445}
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.009441375732421875}
# {word: no, index: 1, tag: DET, rank_score: -0.007485389709472656}
# {word: a, index: 9, tag: DET, rank_score: -0.004181325435638428}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.44838300347328186}
# {word: through, index: 1, tag: ADP, rank_score: -0.15205258131027222}
# {word: one, index: 9, tag: NUM, rank_score: -0.1350409984588623}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.12890660762786865}
#
# ['ADJ']
# {word: goes, index: 9, tag: VERB, rank_score: -0.13481885194778442}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.07750606536865234}
# {word: while, index: 0, tag: ADP, rank_score: -0.033645570278167725}
# {word: great, index: 5, tag: ADJ, rank_score: 0.011000871658325195}
#
# :: 0 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.
# Converting texts to sentences...
# :: 6 sentences were generated.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: the, index: 5, tag: DET, rank_score: -0.00020462274551391602}
# {word: performed, index: 4, tag: VERB, rank_score: -0.00016379356384277344}
# {word: minutely, index: 14, tag: ADV, rank_score: -0.00015592575073242188}
# {word: of, index: 17, tag: ADP, rank_score: -0.0001538991928100586}
#
# ['ADJ']
# {word: the, index: 1, tag: DET, rank_score: -0.4003947079181671}
# {word: for, index: 0, tag: ADP, rank_score: -0.36505043506622314}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.22787588834762573}
# {word: future, index: 2, tag: NOUN, rank_score: 0.21043288707733154}
#
# ['ADJ']
# {word: more, index: 13, tag: ADJ, rank_score: -0.44551214575767517}
# {word: plympton, index: 7, tag: NOUN, rank_score: -0.13628125190734863}
# {word: for, index: 11, tag: ADP, rank_score: -0.11553621292114258}
# {word: a, index: 19, tag: DET, rank_score: -0.09702098369598389}
#
# ['ADJ']
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.25470638275146484}
# {word: one, index: 12, tag: NUM, rank_score: -0.19835150241851807}
# {word: no, index: 1, tag: DET, rank_score: 0.15874606370925903}
# {word: great, index: 4, tag: ADJ, rank_score: 0.15484148263931274}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.8271406888961792}
# {word: through, index: 1, tag: ADP, rank_score: -0.05370587110519409}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.006719410419464111}
# {word: source, index: 6, tag: NOUN, rank_score: -0.0027347207069396973}
#
# ['ADJ']
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.233104407787323}
# {word: while, index: 0, tag: ADP, rank_score: -0.022324740886688232}
# {word: goes, index: 9, tag: VERB, rank_score: -0.009188532829284668}
# {word: subject, index: 7, tag: ADJ, rank_score: -0.007841289043426514}
#
# :: 1 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 1 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 9.7s

# %%
df0 = tg0.to_dataframe()
df0
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df1 = tg1.to_dataframe()
df1
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df2 = tg2.to_dataframe()
df2
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df3 = tg3.to_dataframe()
df3
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df4 = tg4.to_dataframe()
df4
# Out:
#    label                                                        original_text  \
# 0      1  by no means a great movie but it is a refreshingly forthright one .
#
#                                                         masked_text  \
# 0  by no means a {mask} movie but it is a refreshingly {mask} one .
#
#                                                             template_text
# 0  by no means a {pos_adj} movie but it is a refreshingly {pos_adj} one .

# %%
tg0.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg1.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg2.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg3.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg4.lexicons
# Out:
# {'pos_adj': ['great', 'forthright'], 'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in movie_reviews_rt_df['text'].values]

# %%
tg0 = PosNegTemplateGeneratorApp5(model_bert, models_1)
tg1 = PosNegTemplateGeneratorApp5(model_albert, models_2)
tg2 = PosNegTemplateGeneratorApp5(model_distilbert, models_3)
tg3 = PosNegTemplateGeneratorApp5(model_roberta, models_4)
tg4 = PosNegTemplateGeneratorApp5(model_xlnet, models_5)

# %%
templates0 = tg0.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 118 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: goodies, index: 6, tag: NOUN, rank_score: 0.005269169807434082}
# {word: lumps, index: 8, tag: NOUN, rank_score: 0.0032875537872314453}
# {word: underestimated, index: 2, tag: ADJ, rank_score: 0.0025653839111328125}
# {word: than, index: 7, tag: ADP, rank_score: 0.0022441744804382324}
#
# ['ADJ']
# {word: skip, index: 0, tag: VERB, rank_score: -0.3447835445404053}
# {word: and, index: 3, tag: CONJ, rank_score: -0.012676358222961426}
# {word: philip, index: 6, tag: NOUN, rank_score: 0.0009868144989013672}
# {word: the, index: 1, tag: DET, rank_score: 0.00048273801803588867}
#
# ['ADJ']
# {word: lapses, index: 4, tag: VERB, rank_score: -0.4460386037826538}
# {word: into, index: 7, tag: ADP, rank_score: -0.0017092227935791016}
# {word: times, index: 2, tag: NOUN, rank_score: 0.0014830231666564941}
# {word: the, index: 8, tag: DET, rank_score: 0.001171112060546875}
#
# ['ADJ']
# {word: goes, index: 9, tag: VERB, rank_score: -0.9912518262863159}
# {word: while, index: 0, tag: ADP, rank_score: -0.8817930817604065}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.0024411678314208984}
# {word: great, index: 5, tag: ADJ, rank_score: -0.001394033432006836}
#
# ['ADJ']
# {word: our, index: 3, tag: PRON, rank_score: -0.9989765286445618}
# {word: culture, index: 5, tag: NOUN, rank_score: -0.9988274574279785}
# {word: that, index: 6, tag: DET, rank_score: -0.9987702369689941}
# {word: ., index: 11, tag: ., rank_score: -0.9974378347396851}
#
# ['ADJ']
# {word: criminally, index: 9, tag: ADV, rank_score: -0.9855519533157349}
# {word: one, index: 8, tag: NUM, rank_score: -0.667113184928894}
# {word: in, index: 7, tag: ADP, rank_score: -0.1323620080947876}
# {word: submarine, index: 1, tag: NOUN, rank_score: -0.11809021234512329}
#
# ['ADJ']
# {word: intelligent, index: 0, tag: ADJ, rank_score: -0.0025487542152404785}
# {word: human, index: 9, tag: ADJ, rank_score: -0.0006974339485168457}
# {word: and, index: 7, tag: CONJ, rank_score: -0.0005328059196472168}
# {word: caustic, index: 1, tag: ADJ, rank_score: -0.0003377199172973633}
#
# ['ADJ']
# {word: with, index: 7, tag: ADP, rank_score: -0.026811659336090088}
# {word: and, index: 9, tag: CONJ, rank_score: -0.01743096113204956}
# {word: vibrance, index: 8, tag: NOUN, rank_score: -0.006856083869934082}
# {word: warmth, index: 10, tag: NOUN, rank_score: -0.004583418369293213}
#
# ['ADJ']
# {word: does, index: 1, tag: VERB, rank_score: -0.76806640625}
# {word: n't, index: 2, tag: ADV, rank_score: -0.4121590852737427}
# {word: simply, index: 0, tag: ADV, rank_score: -0.010996997356414795}
# {word: justify, index: 7, tag: VERB, rank_score: -0.005378901958465576}
#
# ['ADJ']
# {word: work, index: 1, tag: NOUN, rank_score: -0.0005237460136413574}
# {word: sense, index: 10, tag: NOUN, rank_score: 0.00020599365234375}
# {word: a, index: 0, tag: DET, rank_score: -0.00017917156219482422}
# {word: intricate, index: 3, tag: ADJ, rank_score: -0.00016617774963378906}
#
# ['ADJ']
# {word: smart, index: 0, tag: NOUN, rank_score: -0.0036085844039916992}
# {word: and, index: 1, tag: CONJ, rank_score: -0.0023352503776550293}
# {word: alert, index: 2, tag: NOUN, rank_score: -0.002114534378051758}
# {word: thirteen, index: 3, tag: ADJ, rank_score: -0.0012822747230529785}
#
# ['ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.9333497881889343}
# {word: know, index: 11, tag: VERB, rank_score: 0.007328927516937256}
# {word: sign, index: 4, tag: NOUN, rank_score: 0.0066176652908325195}
# {word: thriller, index: 7, tag: NOUN, rank_score: 0.005901336669921875}
#
# ['ADJ']
# {word: rare, index: 1, tag: ADJ, rank_score: -0.9159183502197266}
# {word: imax, index: 2, tag: NOUN, rank_score: -0.40904557704925537}
# {word: than, index: 10, tag: ADP, rank_score: -0.18721824884414673}
# {word: movie, index: 3, tag: NOUN, rank_score: -0.12399309873580933}
#
# ['ADJ']
# {word: refreshingly, index: 10, tag: ADV, rank_score: 0.0010156035423278809}
# {word: no, index: 1, tag: DET, rank_score: 0.000680387020111084}
# {word: by, index: 0, tag: ADP, rank_score: 0.0005499720573425293}
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.0003120899200439453}
#
# ['ADJ']
# {word: pile, index: 1, tag: VERB, rank_score: -0.00020438432693481445}
# {word: comic, index: 13, tag: ADJ, rank_score: -0.00010514259338378906}
# {word: falsehoods, index: 0, tag: NOUN, rank_score: -8.940696716308594e-05}
# {word: undermining, index: 3, tag: VERB, rank_score: 7.981061935424805e-05}
#
# ['ADJ']
# {word: bold, index: 10, tag: ADJ, rank_score: -0.0014420151710510254}
# {word: biographical, index: 11, tag: ADJ, rank_score: -0.0006404519081115723}
# {word: a, index: 9, tag: DET, rank_score: -0.0004968643188476562}
# {word: fantasia, index: 12, tag: NOUN, rank_score: -0.0002015233039855957}
#
# ['ADJ']
# {word: performance, index: 10, tag: NOUN, rank_score: -0.000614464282989502}
# {word: one, index: 0, tag: NUM, rank_score: -0.0005126595497131348}
# {word: best, index: 5, tag: ADJ, rank_score: -0.00041925907135009766}
# {word: 's, index: 4, tag: PRT, rank_score: -0.00028634071350097656}
#
# ['ADJ']
# {word: with, index: 4, tag: ADP, rank_score: -0.003002762794494629}
# {word: raffish, index: 8, tag: ADJ, rank_score: -0.002203047275543213}
# {word: day, index: 3, tag: NOUN, rank_score: -0.0019558072090148926}
# {word: charm, index: 9, tag: NOUN, rank_score: 0.0010336041450500488}
#
# ['ADJ']
# {word: clunker, index: 11, tag: NOUN, rank_score: -0.0016779303550720215}
# {word: a, index: 4, tag: DET, rank_score: -0.0002397298812866211}
# {word: well-made, index: 5, tag: ADJ, rank_score: -0.00020068883895874023}
# {word: thoughtful, index: 6, tag: ADJ, rank_score: -0.0001347064971923828}
#
# ['ADJ']
# {word: rewards, index: 12, tag: NOUN, rank_score: 0.00019121170043945312}
# {word: this, index: 0, tag: DET, rank_score: -0.00018644332885742188}
# {word: its, index: 11, tag: PRON, rank_score: -0.00015819072723388672}
# {word: charming, index: 1, tag: VERB, rank_score: 0.00014251470565795898}
#
# ['ADJ']
# {word: there, index: 0, tag: DET, rank_score: -0.9984789490699768}
# {word: but, index: 11, tag: CONJ, rank_score: -0.998175859451294}
# {word: 's, index: 1, tag: VERB, rank_score: -0.993969738483429}
# {word: to, index: 6, tag: PRT, rank_score: -0.9606986045837402}
#
# ['ADJ']
# {word: satisfies, index: 2, tag: NOUN, rank_score: -0.005677342414855957}
# {word: swashbuckling, index: 5, tag: NOUN, rank_score: -0.004491031169891357}
# {word: like, index: 3, tag: ADP, rank_score: -0.00184708833694458}
# {word: nothing, index: 1, tag: NOUN, rank_score: 0.00034099817276000977}
#
# ['ADJ']
# {word: this, index: 9, tag: DET, rank_score: -0.0038509368896484375}
# {word: regard, index: 10, tag: NOUN, rank_score: 0.002340257167816162}
# {word: guard, index: 12, tag: NOUN, rank_score: 0.0020131468772888184}
# {word: on, index: 11, tag: ADP, rank_score: 0.0017519593238830566}
#
# ['ADJ']
# {word: linger, index: 7, tag: VERB, rank_score: -0.03172367811203003}
# {word: after, index: 9, tag: ADP, rank_score: -0.02201312780380249}
# {word: long, index: 8, tag: ADV, rank_score: -0.009742259979248047}
# {word: will, index: 6, tag: VERB, rank_score: -0.008007347583770752}
#
# ['ADJ']
# {word: too, index: 3, tag: ADV, rank_score: -0.003324747085571289}
# {word: creating, index: 6, tag: VERB, rank_score: -0.00020301342010498047}
# {word: perhaps, index: 2, tag: ADV, rank_score: 6.967782974243164e-05}
# {word: is, index: 1, tag: VERB, rank_score: 5.9664249420166016e-05}
#
# ['ADJ']
# {word: flounders, index: 8, tag: NOUN, rank_score: -0.998651385307312}
# {word: but, index: 7, tag: CONJ, rank_score: 0.0002257227897644043}
# {word: some, index: 2, tag: DET, rank_score: -0.00022524595260620117}
# {word: unease, index: 6, tag: NOUN, rank_score: -0.00019311904907226562}
#
# ['ADJ']
# {word: a, index: 0, tag: DET, rank_score: -0.00025641918182373047}
# {word: rich, index: 1, tag: ADJ, rank_score: -0.00022971630096435547}
# {word: of, index: 13, tag: ADP, rank_score: -0.00014525651931762695}
# {word: times, index: 5, tag: NOUN, rank_score: 0.00011134147644042969}
#
# ['ADJ']
# {word: revels, index: 7, tag: VERB, rank_score: -0.006231129169464111}
# {word: that, index: 6, tag: DET, rank_score: -0.0005323290824890137}
# {word: a, index: 1, tag: DET, rank_score: -0.00042051076889038086}
# {word: sort, index: 2, tag: NOUN, rank_score: 0.0003890395164489746}
#
# ['ADJ']
# {word: dull, index: 2, tag: ADJ, rank_score: -0.0015478134155273438}
# {word: procession, index: 3, tag: NOUN, rank_score: -0.0008310675621032715}
# {word: minimalist, index: 13, tag: ADJ, rank_score: -0.0007186532020568848}
# {word: culled, index: 10, tag: VERB, rank_score: -0.00026923418045043945}
#
# ['ADJ']
# {word: and, index: 4, tag: CONJ, rank_score: -0.00016373395919799805}
# {word: breathtaking, index: 2, tag: VERB, rank_score: -8.857250213623047e-05}
# {word: creatures, index: 1, tag: NOUN, rank_score: -6.407499313354492e-05}
# {word: another, index: 11, tag: DET, rank_score: -6.35981559753418e-05}
#
# ['ADJ']
# {word: keeps, index: 5, tag: VERB, rank_score: 0.00027316808700561523}
# {word: of, index: 12, tag: ADP, rank_score: 0.00022113323211669922}
# {word: you, index: 6, tag: PRON, rank_score: 0.0001952648162841797}
# {word: that, index: 4, tag: DET, rank_score: 0.0001595616340637207}
#
# ['ADJ']
# {word: cussing, index: 8, tag: NOUN, rank_score: -0.03148961067199707}
# {word: more, index: 7, tag: ADJ, rank_score: -0.0010007023811340332}
# {word: you, index: 10, tag: PRON, rank_score: 0.00041347742080688477}
# {word: beatings, index: 5, tag: NOUN, rank_score: -0.00038355588912963867}
#
# ['ADJ']
# {word: about, index: 0, tag: ADV, rank_score: -0.037492990493774414}
# {word: as, index: 1, tag: ADV, rank_score: 0.0027942657470703125}
# {word: as, index: 3, tag: ADP, rank_score: 0.00268399715423584}
# {word: original, index: 2, tag: ADJ, rank_score: 0.0026033520698547363}
#
# ['ADJ']
# {word: trailers, index: 10, tag: NOUN, rank_score: -0.004239559173583984}
# {word: bad, index: 7, tag: ADJ, rank_score: -0.0035950541496276855}
# {word: could, index: 0, tag: VERB, rank_score: 0.0003083348274230957}
# {word: as, index: 6, tag: ADV, rank_score: -0.0002740025520324707}
#
# ['ADJ']
# {word: word, index: 14, tag: NOUN, rank_score: -0.18787497282028198}
# {word: yes, index: 16, tag: X, rank_score: -0.0705568790435791}
# {word: in, index: 12, tag: ADP, rank_score: -0.014096856117248535}
# {word: a, index: 13, tag: DET, rank_score: 0.005380988121032715}
#
# ['ADJ']
# {word: generic, index: 3, tag: ADJ, rank_score: -0.03681868314743042}
# {word: despite, index: 6, tag: ADP, rank_score: -0.0001996159553527832}
# {word: talent, index: 11, tag: NOUN, rank_score: -0.00018483400344848633}
# {word: and, index: 5, tag: CONJ, rank_score: -0.00012981891632080078}
#
# ['ADJ']
# {word: off, index: 7, tag: PRT, rank_score: -0.06861579418182373}
# {word: running, index: 6, tag: VERB, rank_score: -0.011910855770111084}
# {word: limited, index: 9, tag: ADJ, rank_score: -0.00039881467819213867}
# {word: n't, index: 1, tag: ADV, rank_score: -0.0002771615982055664}
#
# ['ADJ']
# {word: bogs, index: 11, tag: NOUN, rank_score: -0.9682666659355164}
# {word: in, index: 13, tag: ADP, rank_score: -0.0036187171936035156}
# {word: in, index: 7, tag: ADP, rank_score: -0.0009633302688598633}
# {word: move, index: 10, tag: NOUN, rank_score: -0.0008015036582946777}
#
# ['ADJ']
# {word: awful, index: 5, tag: ADJ, rank_score: -0.24834787845611572}
# {word: is, index: 4, tag: VERB, rank_score: -0.024559855461120605}
# {word: disguise, index: 3, tag: NOUN, rank_score: -0.008613348007202148}
# {word: master, index: 1, tag: NOUN, rank_score: 0.0014134049415588379}
#
# ['ADJ']
# {word: awful, index: 11, tag: NOUN, rank_score: -0.8138947486877441}
# {word: pauly, index: 9, tag: ADV, rank_score: -0.008067667484283447}
# {word: it, index: 7, tag: PRON, rank_score: -0.003497779369354248}
# {word: 's, index: 8, tag: VERB, rank_score: 0.0024172067642211914}
#
# ['ADJ']
# {word: you, index: 16, tag: PRON, rank_score: -0.64985591173172}
# {word: n't, index: 14, tag: ADV, rank_score: -0.6476182341575623}
# {word: warned, index: 19, tag: VERB, rank_score: -0.645062267780304}
# {word: ., index: 20, tag: ., rank_score: -0.6448526978492737}
#
# ['ADJ']
# {word: masterpiece, index: 4, tag: NOUN, rank_score: -0.00142669677734375}
# {word: years, index: 17, tag: NOUN, rank_score: 0.0003374814987182617}
# {word: hearts, index: 9, tag: NOUN, rank_score: -0.00030052661895751953}
# {word: later, index: 18, tag: ADV, rank_score: 0.0002760887145996094}
#
# ['ADJ']
# {word: love, index: 2, tag: VERB, rank_score: -0.018302857875823975}
# {word: out, index: 12, tag: PRT, rank_score: -0.0052269697189331055}
# {word: you, index: 1, tag: PRON, rank_score: -0.003201305866241455}
# {word: means, index: 9, tag: NOUN, rank_score: 0.0016383528709411621}
#
# ['ADJ']
# {word: love, index: 17, tag: VERB, rank_score: -0.978091299533844}
# {word: you, index: 14, tag: PRON, rank_score: -0.023657381534576416}
# {word: probably, index: 16, tag: ADV, rank_score: 0.009064733982086182}
# {word: 'll, index: 15, tag: VERB, rank_score: 0.0070650577545166016}
#
# ['ADJ']
# {word: notorious, index: 4, tag: ADJ, rank_score: -0.6938652992248535}
# {word: c, index: 5, tag: NOUN, rank_score: -0.6714321374893188}
# {word: go, index: 3, tag: VERB, rank_score: -0.6100021600723267}
# {word: comedic, index: 1, tag: ADJ, rank_score: -0.578450083732605}
#
# ['ADJ']
# {word: marks, index: 15, tag: NOUN, rank_score: -0.8324263691902161}
# {word: should, index: 17, tag: VERB, rank_score: -0.8276894092559814}
# {word: it, index: 16, tag: PRON, rank_score: -0.8192701935768127}
# {word: all, index: 12, tag: DET, rank_score: -0.7217094302177429}
#
# ['ADJ']
# {word: unbearable, index: 5, tag: ADJ, rank_score: -0.001018226146697998}
# {word: saved, index: 3, tag: VERB, rank_score: 0.0005750060081481934}
# {word: by, index: 7, tag: ADP, rank_score: 0.00048786401748657227}
# {word: from, index: 4, tag: ADP, rank_score: -0.00043004751205444336}
#
# ['ADJ']
# {word: whose, index: 10, tag: PRON, rank_score: -0.002656221389770508}
# {word: than, index: 17, tag: ADP, rank_score: -0.0010859370231628418}
# {word: rather, index: 16, tag: ADV, rank_score: -0.0007052421569824219}
# {word: heart, index: 1, tag: NOUN, rank_score: -0.0002244710922241211}
#
# ['ADJ']
# {word: worst, index: 7, tag: ADJ, rank_score: -0.005021870136260986}
# {word: far, index: 13, tag: ADV, rank_score: -0.0017557740211486816}
# {word: from, index: 14, tag: ADP, rank_score: -0.0009431242942810059}
# {word: it, index: 11, tag: PRON, rank_score: -0.0005348324775695801}
#
# ['ADJ']
# {word: little, index: 16, tag: ADJ, rank_score: -0.0004171133041381836}
# {word: vapid, index: 7, tag: ADJ, rank_score: 8.946657180786133e-05}
# {word: florid, index: 4, tag: NOUN, rank_score: -7.37309455871582e-05}
# {word: exercise, index: 2, tag: NOUN, rank_score: -6.574392318725586e-05}
#
# ['ADJ']
# {word: to, index: 0, tag: PRT, rank_score: -0.0017076730728149414}
# {word: marvel, index: 15, tag: NOUN, rank_score: 0.0015126466751098633}
# {word: unselfconscious, index: 10, tag: ADJ, rank_score: -0.0015054941177368164}
# {word: is, index: 13, tag: VERB, rank_score: 0.0009033083915710449}
#
# ['ADJ']
# {word: gets, index: 3, tag: VERB, rank_score: -0.6345227360725403}
# {word: never, index: 2, tag: ADV, rank_score: -0.047205209732055664}
# {word: film, index: 1, tag: NOUN, rank_score: -0.00011837482452392578}
# {word: in, index: 8, tag: ADP, rank_score: -8.720159530639648e-05}
#
# ['ADJ']
# {word: of, index: 17, tag: ADP, rank_score: -0.00011205673217773438}
# {word: wonders, index: 16, tag: NOUN, rank_score: -7.635354995727539e-05}
# {word: elegantly, index: 0, tag: ADV, rank_score: -5.036592483520508e-05}
# {word: detailed, index: 15, tag: ADJ, rank_score: -1.6689300537109375e-05}
#
# ['ADJ']
# {word: sacrifices, index: 13, tag: VERB, rank_score: -0.9982683658599854}
# {word: description, index: 5, tag: NOUN, rank_score: -0.0013284087181091309}
# {word: is, index: 2, tag: VERB, rank_score: 0.0001410841941833496}
# {word: its, index: 14, tag: PRON, rank_score: -0.00013589859008789062}
#
# ['ADJ']
# {word: and, index: 7, tag: CONJ, rank_score: -0.0007128715515136719}
# {word: vengeance, index: 17, tag: NOUN, rank_score: -0.00013494491577148438}
# {word: monsters, index: 12, tag: NOUN, rank_score: -0.00012129545211791992}
# {word: scary, index: 8, tag: ADJ, rank_score: -6.514787673950195e-05}
#
# ['ADJ']
# {word: act, index: 3, tag: NOUN, rank_score: -0.0007264018058776855}
# {word: consuming, index: 6, tag: ADJ, rank_score: 0.0005647540092468262}
# {word: difficult, index: 11, tag: ADJ, rank_score: 0.0005504488945007324}
# {word: is, index: 4, tag: VERB, rank_score: 0.0002847909927368164}
#
# ['ADJ']
# {word: neglects, index: 18, tag: VERB, rank_score: -0.0005925297737121582}
# {word: but, index: 16, tag: CONJ, rank_score: -0.0004356503486633301}
# {word: script, index: 3, tag: NOUN, rank_score: -0.00022172927856445312}
# {word: it, index: 17, tag: PRON, rank_score: -0.00016164779663085938}
#
# ['ADJ']
# {word: does, index: 12, tag: VERB, rank_score: -0.23074442148208618}
# {word: n't, index: 13, tag: ADV, rank_score: -0.1481134295463562}
# {word: much, index: 15, tag: ADJ, rank_score: -0.07342541217803955}
# {word: get, index: 14, tag: VERB, rank_score: -0.02010655403137207}
#
# ['ADJ']
# {word: reawaken, index: 1, tag: VERB, rank_score: -0.003930270671844482}
# {word: but, index: 7, tag: CONJ, rank_score: -0.000606834888458252}
# {word: discussion, index: 2, tag: NOUN, rank_score: -0.0002931952476501465}
# {word: looks, index: 11, tag: NOUN, rank_score: -0.00024265050888061523}
#
# ['ADJ']
# {word: pedestrian, index: 7, tag: ADJ, rank_score: -0.003239929676055908}
# {word: by, index: 9, tag: ADP, rank_score: -0.0008901357650756836}
# {word: of, index: 16, tag: ADP, rank_score: -0.000504612922668457}
# {word: spin, index: 8, tag: NOUN, rank_score: -0.00044286251068115234}
#
# ['ADJ']
# {word: its, index: 1, tag: PRON, rank_score: -0.9967808723449707}
# {word: grand-scale, index: 5, tag: ADJ, rank_score: -0.03786313533782959}
# {word: moviemaking, index: 6, tag: VERB, rank_score: -0.00032716989517211914}
# {word: at, index: 0, tag: ADP, rank_score: 0.0003070235252380371}
#
# ['ADJ']
# {word: over, index: 20, tag: ADP, rank_score: -0.9888684153556824}
# {word: predictable, index: 13, tag: ADJ, rank_score: -0.8851398825645447}
# {word: glosses, index: 19, tag: VERB, rank_score: -0.017269015312194824}
# {word: 's, index: 1, tag: PRT, rank_score: -0.005389571189880371}
#
# ['ADJ']
# {word: ``, index: 4, tag: ., rank_score: -0.7166588306427002}
# {word: pinned, index: 7, tag: VERB, rank_score: -0.058793842792510986}
# {word: to, index: 8, tag: PRT, rank_score: -0.02167147397994995}
# {word: while, index: 12, tag: ADP, rank_score: -0.0107535719871521}
#
# ['ADJ']
# {word: future, index: 2, tag: NOUN, rank_score: -0.06550866365432739}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.0017756223678588867}
# {word: one, index: 3, tag: NUM, rank_score: 0.0016388297080993652}
# {word: for, index: 0, tag: ADP, rank_score: 0.0016148090362548828}
#
# ['ADJ']
# {word: of, index: 15, tag: ADP, rank_score: -0.0016689896583557129}
# {word: for, index: 11, tag: ADP, rank_score: -0.0008890032768249512}
# {word: more, index: 13, tag: ADJ, rank_score: -0.000647127628326416}
# {word: member, index: 14, tag: NOUN, rank_score: -0.00031298398971557617}
#
# ['ADJ']
# {word: problem, index: 1, tag: NOUN, rank_score: -0.9611016511917114}
# {word: with, index: 2, tag: ADP, rank_score: 0.004427909851074219}
# {word: screenplay, index: 10, tag: NOUN, rank_score: 0.00343477725982666}
# {word: is, index: 5, tag: VERB, rank_score: 0.003330528736114502}
#
# ['ADJ']
# {word: only, index: 7, tag: ADV, rank_score: -0.5613759756088257}
# {word: an, index: 8, tag: DET, rank_score: -0.4693741798400879}
# {word: at, index: 5, tag: ADP, rank_score: 0.4102262854576111}
# {word: laughter, index: 4, tag: NOUN, rank_score: 0.4010075330734253}
#
# ['ADJ']
# {word: nothing, index: 20, tag: NOUN, rank_score: -0.995931088924408}
# {word: lesson, index: 15, tag: NOUN, rank_score: -0.0008581876754760742}
# {word: new, index: 21, tag: ADJ, rank_score: -0.0007919073104858398}
# {word: is, index: 19, tag: VERB, rank_score: -0.00026983022689819336}
#
# ['ADJ']
# {word: to, index: 12, tag: PRT, rank_score: -0.001217663288116455}
# {word: call, index: 1, tag: VERB, rank_score: -0.0006781816482543945}
# {word: to, index: 0, tag: PRT, rank_score: -0.0005209445953369141}
# {word: like, index: 18, tag: ADP, rank_score: -0.0005195140838623047}
#
# ['ADJ']
# {word: better, index: 19, tag: ADV, rank_score: -0.7371039390563965}
# {word: not, index: 20, tag: ADV, rank_score: -0.6276779770851135}
# {word: was, index: 3, tag: VERB, rank_score: -0.4746025502681732}
# {word: success, index: 6, tag: NOUN, rank_score: 0.24762648344039917}
#
# ['ADJ']
# {word: sappy, index: 19, tag: ADJ, rank_score: -0.010911166667938232}
# {word: take, index: 3, tag: VERB, rank_score: 0.0007090568542480469}
# {word: one, index: 21, tag: NUM, rank_score: 0.0007002353668212891}
# {word: at, index: 22, tag: ADP, rank_score: 0.0006567835807800293}
#
# ['ADJ']
# {word: comparison, index: 13, tag: NOUN, rank_score: -0.2190534472465515}
# {word: cartoon, index: 16, tag: NOUN, rank_score: -0.08309280872344971}
# {word: gave, index: 20, tag: VERB, rank_score: -0.013153254985809326}
# {word: for, index: 12, tag: ADP, rank_score: -0.011608779430389404}
#
# ['ADJ']
# {word: captures, index: 0, tag: NOUN, rank_score: -0.016748785972595215}
# {word: confusing, index: 8, tag: VERB, rank_score: 7.50422477722168e-05}
# {word: of, index: 18, tag: ADP, rank_score: -6.121397018432617e-05}
# {word: to, index: 14, tag: PRT, rank_score: -4.118680953979492e-05}
#
# ['ADJ']
# {word: riveting, index: 22, tag: ADJ, rank_score: -0.0004640817642211914}
# {word: but, index: 14, tag: CONJ, rank_score: 0.00034803152084350586}
# {word: for, index: 20, tag: ADP, rank_score: 0.0003364682197570801}
# {word: does, index: 3, tag: VERB, rank_score: 0.0003178119659423828}
#
# ['ADJ']
# {word: undone, index: 3, tag: ADJ, rank_score: -0.0012128353118896484}
# {word: cliched, index: 20, tag: VERB, rank_score: -0.0002071857452392578}
# {word: methodology, index: 7, tag: NOUN, rank_score: -0.00013065338134765625}
# {word: alienate, index: 14, tag: VERB, rank_score: -0.00012433528900146484}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.8234872817993164}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.8017554879188538}
# {word: through, index: 1, tag: ADP, rank_score: -0.7771927118301392}
# {word: one, index: 9, tag: NUM, rank_score: -0.7656691074371338}
#
# ['ADJ']
# {word: in-depth, index: 1, tag: ADJ, rank_score: -0.0009489059448242188}
# {word: this, index: 0, tag: DET, rank_score: -0.0006124973297119141}
# {word: years, index: 21, tag: NOUN, rank_score: -0.0001201629638671875}
# {word: should, index: 10, tag: VERB, rank_score: 0.00010257959365844727}
#
# ['ADJ']
# {word: not, index: 8, tag: ADV, rank_score: -0.5576513409614563}
# {word: interested, index: 9, tag: ADJ, rank_score: -0.004391908645629883}
# {word: really, index: 3, tag: ADV, rank_score: -0.0038601160049438477}
# {word: in, index: 10, tag: ADP, rank_score: -0.0034464597702026367}
#
# ['ADJ']
# {word: peek, index: 10, tag: NOUN, rank_score: -0.0011954307556152344}
# {word: portrait, index: 4, tag: NOUN, rank_score: -0.0005932450294494629}
# {word: than, index: 1, tag: ADP, rank_score: -0.0005562305450439453}
# {word: revolution, index: 15, tag: NOUN, rank_score: -0.00048214197158813477}
#
# ['ADJ']
# {word: much, index: 1, tag: ADJ, rank_score: -0.003451049327850342}
# {word: and, index: 27, tag: CONJ, rank_score: -0.002699434757232666}
# {word: depends, index: 21, tag: VERB, rank_score: 0.0025153756141662598}
# {word: how, index: 25, tag: ADV, rank_score: 0.0022040605545043945}
#
# ['ADJ']
# {word: wallop, index: 26, tag: NOUN, rank_score: -0.0001271963119506836}
# {word: powerful, index: 24, tag: ADJ, rank_score: -9.810924530029297e-05}
# {word: heartbreaking, index: 12, tag: VERB, rank_score: -6.908178329467773e-05}
# {word: pinochet, index: 3, tag: NOUN, rank_score: -5.894899368286133e-05}
#
# ['ADJ']
# {word: details, index: 20, tag: NOUN, rank_score: -0.003190159797668457}
# {word: slip, index: 21, tag: VERB, rank_score: -0.0016236305236816406}
# {word: the, index: 9, tag: DET, rank_score: -0.0012561678886413574}
# {word: fingers, index: 25, tag: NOUN, rank_score: -0.0010704994201660156}
#
# ['ADJ']
# {word: explore, index: 15, tag: VERB, rank_score: -0.08340132236480713}
# {word: filmmakers, index: 7, tag: NOUN, rank_score: -0.0029689669609069824}
# {word: have, index: 9, tag: VERB, rank_score: -0.00194549560546875}
# {word: to, index: 14, tag: PRT, rank_score: -0.0018323659896850586}
#
# ['ADJ']
# {word: mournful, index: 17, tag: ADJ, rank_score: -0.00038444995880126953}
# {word: perspective, index: 26, tag: NOUN, rank_score: -0.00035077333450317383}
# {word: even, index: 8, tag: ADV, rank_score: 0.0003173947334289551}
# {word: in, index: 24, tag: ADP, rank_score: -0.0003001689910888672}
#
# ['ADJ']
# {word: gorgeous, index: 21, tag: ADJ, rank_score: -0.988206148147583}
# {word: a, index: 20, tag: DET, rank_score: -0.041857242584228516}
# {word: deceptively, index: 23, tag: ADJ, rank_score: 0.0006327629089355469}
# {word: minimalist, index: 24, tag: NOUN, rank_score: 0.000563502311706543}
#
# ['ADJ']
# {word: when, index: 9, tag: ADV, rank_score: -0.0003870725631713867}
# {word: mesmerize, index: 23, tag: VERB, rank_score: -0.0002060532569885254}
# {word: childhood, index: 8, tag: NOUN, rank_score: -0.0001863241195678711}
# {word: ability, index: 21, tag: NOUN, rank_score: 0.00016486644744873047}
#
# ['ADJ']
# {word: annual, index: 10, tag: ADJ, rank_score: -0.9081705212593079}
# {word: buzz, index: 15, tag: NOUN, rank_score: -0.8359407186508179}
# {word: the, index: 9, tag: DET, rank_score: -0.8003667593002319}
# {word: is, index: 4, tag: VERB, rank_score: -0.7337472438812256}
#
# ['ADJ']
# {word: charming, index: 21, tag: ADJ, rank_score: -0.011001765727996826}
# {word: cannes, index: 26, tag: NOUN, rank_score: -0.0019100308418273926}
# {word: is, index: 23, tag: VERB, rank_score: 0.0009661316871643066}
# {word: result, index: 22, tag: NOUN, rank_score: 0.0008884072303771973}
#
# ['ADJ']
# {word: from, index: 11, tag: ADP, rank_score: 0.00011754035949707031}
# {word: its, index: 12, tag: PRON, rank_score: 0.00011336803436279297}
# {word: its, index: 23, tag: PRON, rank_score: 8.296966552734375e-05}
# {word: release, index: 27, tag: NOUN, rank_score: 7.784366607666016e-05}
#
# ['ADJ']
# {word: pessimistic, index: 20, tag: ADJ, rank_score: -0.0007815361022949219}
# {word: unflinching, index: 23, tag: ADJ, rank_score: 0.0005878806114196777}
# {word: and, index: 21, tag: CONJ, rank_score: 0.0005286931991577148}
# {word: comes, index: 12, tag: VERB, rank_score: 0.00048291683197021484}
#
# ['ADJ']
# {word: pseudo-sophisticated, index: 9, tag: ADJ, rank_score: -0.04231739044189453}
# {word: patter, index: 7, tag: NOUN, rank_score: -0.0020614266395568848}
# {word: remainder, index: 14, tag: NOUN, rank_score: -0.0013203620910644531}
# {word: composed, index: 4, tag: VERB, rank_score: -0.0007742643356323242}
#
# ['ADJ']
# {word: more, index: 20, tag: ADJ, rank_score: -0.10010164976119995}
# {word: home, index: 22, tag: NOUN, rank_score: -0.040047526359558105}
# {word: on, index: 23, tag: ADP, rank_score: 0.033611178398132324}
# {word: television, index: 26, tag: NOUN, rank_score: 0.02466297149658203}
#
# ['ADJ']
# {word: lulling, index: 26, tag: ADJ, rank_score: -0.0004017353057861328}
# {word: eventually, index: 23, tag: ADV, rank_score: -0.00020962953567504883}
# {word: so, index: 13, tag: ADV, rank_score: -0.00012570619583129883}
# {word: dopey, index: 10, tag: NOUN, rank_score: -0.00011610984802246094}
#
# ['ADJ']
# {word: for, index: 9, tag: ADP, rank_score: -0.00018870830535888672}
# {word: so, index: 1, tag: ADV, rank_score: -0.00010395050048828125}
# {word: movie, index: 4, tag: NOUN, rank_score: 9.953975677490234e-05}
# {word: much, index: 2, tag: ADV, rank_score: 9.721517562866211e-05}
#
# ['ADJ']
# {word: enough, index: 26, tag: ADJ, rank_score: 0.0090903639793396}
# {word: to, index: 27, tag: PRT, rank_score: 0.008964717388153076}
# {word: series, index: 21, tag: NOUN, rank_score: 0.00887531042098999}
# {word: n't, index: 16, tag: ADV, rank_score: 0.0085831880569458}
#
# ['ADJ']
# {word: movie, index: 15, tag: NOUN, rank_score: -0.000830531120300293}
# {word: puts, index: 17, tag: VERB, rank_score: -0.0005984902381896973}
# {word: possession, index: 12, tag: NOUN, rank_score: -0.00025910139083862305}
# {word: and, index: 1, tag: CONJ, rank_score: -0.00012570619583129883}
#
# ['ADJ']
# {word: which, index: 9, tag: DET, rank_score: -0.00017839670181274414}
# {word: self-indulgent, index: 3, tag: ADJ, rank_score: -6.598234176635742e-05}
# {word: pompous, index: 13, tag: ADJ, rank_score: -4.565715789794922e-05}
# {word: incoherent, index: 2, tag: NOUN, rank_score: 3.7729740142822266e-05}
#
# ['ADJ']
# {word: pretentious, index: 27, tag: ADJ, rank_score: -0.00017529726028442383}
# {word: meaningless, index: 28, tag: NOUN, rank_score: -4.5239925384521484e-05}
# {word: of, index: 26, tag: ADP, rank_score: 3.218650817871094e-05}
# {word: prattle, index: 29, tag: NOUN, rank_score: -2.2172927856445312e-05}
#
# ['ADJ']
# {word: like, index: 0, tag: ADP, rank_score: 0.00013113021850585938}
# {word: seeks, index: 27, tag: VERB, rank_score: 0.00010722875595092773}
# {word: movies, index: 6, tag: NOUN, rank_score: 9.161233901977539e-05}
# {word: chokes, index: 17, tag: VERB, rank_score: -8.64267349243164e-05}
#
# ['ADJ']
# {word: examined, index: 18, tag: VERB, rank_score: -0.9599056839942932}
# {word: best, index: 3, tag: ADJ, rank_score: -0.9548259377479553}
# {word: much, index: 19, tag: ADV, rank_score: -0.7641246318817139}
# {word: you, index: 11, tag: PRON, rank_score: -0.28150874376296997}
#
# ['ADJ']
# {word: based, index: 2, tag: VERB, rank_score: -0.4886806309223175}
# {word: a, index: 7, tag: DET, rank_score: -0.3527284562587738}
# {word: the, index: 4, tag: DET, rank_score: 0.3490498661994934}
# {word: book, index: 5, tag: NOUN, rank_score: 0.23493796586990356}
#
# ['ADJ']
# {word: for, index: 26, tag: ADP, rank_score: -0.8686785101890564}
# {word: demands, index: 12, tag: NOUN, rank_score: -0.8393073678016663}
# {word: trading, index: 22, tag: NOUN, rank_score: -0.791023313999176}
# {word: labute, index: 14, tag: ADJ, rank_score: -0.6157995462417603}
#
# ['ADJ']
# {word: and, index: 31, tag: CONJ, rank_score: -0.3705093264579773}
# {word: you, index: 0, tag: PRON, rank_score: -0.3533703684806824}
# {word: but, index: 25, tag: CONJ, rank_score: -0.027116835117340088}
# {word: salute, index: 4, tag: VERB, rank_score: -0.025320053100585938}
#
# ['ADJ']
# {word: is, index: 2, tag: VERB, rank_score: -0.0012554526329040527}
# {word: what, index: 0, tag: PRON, rank_score: -0.0008264780044555664}
# {word: nincompoop, index: 7, tag: ADJ, rank_score: -0.0005086064338684082}
# {word: remains, index: 1, tag: VERB, rank_score: -0.0004082918167114258}
#
# ['ADJ']
# {word: not, index: 28, tag: ADV, rank_score: -0.0018243789672851562}
# {word: appealing, index: 23, tag: VERB, rank_score: -0.0013380646705627441}
# {word: the, index: 19, tag: DET, rank_score: -0.00120621919631958}
# {word: kind, index: 20, tag: NOUN, rank_score: 0.0008400082588195801}
#
# ['ADJ']
# {word: great, index: 13, tag: ADJ, rank_score: -0.008286237716674805}
# {word: and, index: 11, tag: CONJ, rank_score: -0.000889122486114502}
# {word: sound, index: 12, tag: ADJ, rank_score: -0.00041496753692626953}
# {word: look, index: 10, tag: VERB, rank_score: 0.0001907944679260254}
#
# ['ADJ']
# {word: lost, index: 35, tag: VERB, rank_score: -0.9816185832023621}
# {word: thinks, index: 24, tag: VERB, rank_score: -0.0009434223175048828}
# {word: 've, index: 34, tag: VERB, rank_score: -0.000751495361328125}
# {word: 're, index: 19, tag: VERB, rank_score: -0.0007326006889343262}
#
# ['ADJ']
# {word: how, index: 12, tag: ADV, rank_score: -0.9708905816078186}
# {word: of, index: 10, tag: ADP, rank_score: -0.10083341598510742}
# {word: inspiring, index: 6, tag: VERB, rank_score: -0.008436143398284912}
# {word: ridiculous, index: 13, tag: ADJ, rank_score: 0.0015924572944641113}
#
# ['ADJ']
# {word: testament, index: 26, tag: NOUN, rank_score: 0.0007649064064025879}
# {word: it, index: 22, tag: PRON, rank_score: 0.0007538795471191406}
# {word: integrity, index: 29, tag: NOUN, rank_score: 0.0006980299949645996}
# {word: band, index: 34, tag: NOUN, rank_score: 0.00036323070526123047}
#
# ['ADJ']
# {word: reveals, index: 0, tag: NOUN, rank_score: -0.0002804398536682129}
# {word: how, index: 1, tag: ADV, rank_score: -0.0001379251480102539}
# {word: our, index: 3, tag: PRON, rank_score: 2.491474151611328e-05}
# {word: important, index: 2, tag: ADJ, rank_score: 2.4557113647460938e-05}
#
# ['ADJ']
# {word: shows, index: 18, tag: VERB, rank_score: -0.00018423795700073242}
# {word: otherwise, index: 32, tag: VERB, rank_score: -0.00010895729064941406}
# {word: might, index: 31, tag: VERB, rank_score: -0.00010728836059570312}
# {word: separate, index: 33, tag: ADJ, rank_score: 5.716085433959961e-05}
#
# ['ADJ']
# {word: whereas, index: 0, tag: ADP, rank_score: -0.7145054936408997}
# {word: sardonic, index: 15, tag: ADJ, rank_score: -0.6737275123596191}
# {word: for, index: 21, tag: ADP, rank_score: -0.46086573600769043}
# {word: caustic, index: 19, tag: ADJ, rank_score: -0.31865397095680237}
#
# ['ADJ']
# {word: drab, index: 32, tag: ADJ, rank_score: -0.0007739663124084473}
# {word: looking, index: 34, tag: VERB, rank_score: -0.0001277923583984375}
# {word: wannabe, index: 33, tag: NOUN, rank_score: -6.109476089477539e-05}
# {word: inexpressible, index: 30, tag: ADJ, rank_score: -5.799531936645508e-05}
#
# ['ADJ']
# {word: assembles, index: 1, tag: VERB, rank_score: -0.0005238056182861328}
# {word: of, index: 5, tag: ADP, rank_score: -0.0003535747528076172}
# {word: a, index: 2, tag: DET, rank_score: -0.00022602081298828125}
# {word: remains, index: 19, tag: VERB, rank_score: 0.0002033710479736328}
#
# ['ADJ']
# {word: pulls, index: 36, tag: VERB, rank_score: -0.001212000846862793}
# {word: feat, index: 39, tag: NOUN, rank_score: -0.0009986162185668945}
# {word: yet, index: 32, tag: ADV, rank_score: 0.0007631778717041016}
# {word: to, index: 7, tag: PRT, rank_score: -0.0006515383720397949}
#
# ['ADJ']
# {word: screen, index: 44, tag: NOUN, rank_score: -0.005372405052185059}
# {word: in, index: 45, tag: ADP, rank_score: -0.0040901899337768555}
# {word: frustration, index: 46, tag: NOUN, rank_score: -0.00277024507522583}
# {word: at, index: 42, tag: ADP, rank_score: -0.0004814267158508301}
#
# ['ADJ']
# {word: most, index: 16, tag: ADJ, rank_score: -0.6017745733261108}
# {word: but, index: 10, tag: CONJ, rank_score: -0.5385059714317322}
# {word: in, index: 21, tag: ADP, rank_score: -0.5049275755882263}
# {word: a, index: 7, tag: DET, rank_score: -0.4043656587600708}
#
# ['ADJ']
# {word: to, index: 47, tag: PRT, rank_score: -0.09373778104782104}
# {word: pleasant, index: 39, tag: ADJ, rank_score: -0.07891881465911865}
# {word: eat, index: 48, tag: VERB, rank_score: -0.04292958974838257}
# {word: is, index: 33, tag: VERB, rank_score: -0.02462780475616455}
#
# :: 13 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 11 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %%
templates1 = tg1.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 118 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: underestimated, index: 2, tag: ADJ, rank_score: 0.26489365100860596}
# {word: delivers, index: 4, tag: NOUN, rank_score: -0.2100902497768402}
# {word: 's, index: 1, tag: PRT, rank_score: -0.19919916987419128}
# {word: of, index: 9, tag: ADP, rank_score: 0.19583535194396973}
#
# ['ADJ']
# {word: skip, index: 0, tag: VERB, rank_score: -0.38275548815727234}
# {word: buy, index: 4, tag: VERB, rank_score: 0.07416665554046631}
# {word: and, index: 3, tag: CONJ, rank_score: -0.06269365549087524}
# {word: philip, index: 6, tag: NOUN, rank_score: -0.044966161251068115}
#
# ['ADJ']
# {word: lapses, index: 4, tag: VERB, rank_score: -0.5091991424560547}
# {word: at, index: 1, tag: ADP, rank_score: 0.03710907697677612}
# {word: the, index: 8, tag: DET, rank_score: 0.03633362054824829}
# {word: involving, index: 0, tag: VERB, rank_score: 0.02584761381149292}
#
# ['ADJ']
# {word: while, index: 0, tag: ADP, rank_score: -0.9056574702262878}
# {word: great, index: 5, tag: ADJ, rank_score: -0.1910417079925537}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.08988571166992188}
# {word: goes, index: 9, tag: VERB, rank_score: -0.08244305849075317}
#
# ['ADJ']
# {word: our, index: 3, tag: PRON, rank_score: -0.255201518535614}
# {word: n't, index: 8, tag: ADV, rank_score: -0.23820769786834717}
# {word: that, index: 6, tag: DET, rank_score: -0.21977180242538452}
# {word: infantile, index: 10, tag: ADJ, rank_score: 0.12911570072174072}
#
# ['ADJ']
# {word: criminally, index: 9, tag: ADV, rank_score: -0.23004835844039917}
# {word: submarine, index: 1, tag: NOUN, rank_score: 0.10926872491836548}
# {word: film, index: 11, tag: NOUN, rank_score: 0.09217280149459839}
# {word: all, index: 6, tag: DET, rank_score: -0.07313871383666992}
#
# ['ADJ']
# {word: great, index: 5, tag: ADJ, rank_score: -0.6368250846862793}
# {word: writer, index: 6, tag: NOUN, rank_score: -0.1172339916229248}
# {word: intelligent, index: 0, tag: ADJ, rank_score: -0.05047851800918579}
# {word: on, index: 3, tag: ADP, rank_score: -0.03620201349258423}
#
# ['ADJ']
# {word: warmth, index: 10, tag: NOUN, rank_score: -0.28011375665664673}
# {word: and, index: 9, tag: CONJ, rank_score: -0.20466208457946777}
# {word: along, index: 6, tag: ADP, rank_score: 0.06337320804595947}
# {word: minutes, index: 2, tag: NOUN, rank_score: 0.04299193620681763}
#
# ['ADJ']
# {word: n't, index: 2, tag: ADV, rank_score: -0.24675434827804565}
# {word: sufficient, index: 4, tag: ADJ, rank_score: -0.03649228811264038}
# {word: running, index: 10, tag: ADJ, rank_score: -0.006531119346618652}
# {word: its, index: 8, tag: PRON, rank_score: -0.006507515907287598}
#
# ['ADJ']
# {word: and, index: 7, tag: CONJ, rank_score: -0.021719276905059814}
# {word: profound, index: 8, tag: ADJ, rank_score: -0.01567709445953369}
# {word: literary, index: 5, tag: ADJ, rank_score: 0.0034627318382263184}
# {word: a, index: 0, tag: DET, rank_score: -0.003176450729370117}
#
# ['ADJ']
# {word: about, index: 5, tag: ADP, rank_score: -0.6028072834014893}
# {word: smart, index: 0, tag: NOUN, rank_score: -0.5919598340988159}
# {word: and, index: 1, tag: CONJ, rank_score: -0.4237653613090515}
# {word: alert, index: 2, tag: NOUN, rank_score: -0.09021395444869995}
#
# ['ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.11638408899307251}
# {word: whodunit, index: 12, tag: NOUN, rank_score: -0.0381317138671875}
# {word: sign, index: 4, tag: NOUN, rank_score: -0.029472529888153076}
# {word: in, index: 5, tag: ADP, rank_score: -0.028873980045318604}
#
# ['ADJ']
# {word: an, index: 11, tag: DET, rank_score: -0.27467238903045654}
# {word: wish, index: 7, tag: VERB, rank_score: -0.2740931808948517}
# {word: hour, index: 12, tag: NOUN, rank_score: -0.2518894672393799}
# {word: rare, index: 1, tag: ADJ, rank_score: -0.22764351963996887}
#
# ['ADJ']
# {word: but, index: 6, tag: CONJ, rank_score: -0.04724925756454468}
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.02178877592086792}
# {word: by, index: 0, tag: ADP, rank_score: -0.007844924926757812}
# {word: is, index: 8, tag: VERB, rank_score: -0.005815982818603516}
#
# ['ADJ']
# {word: and, index: 8, tag: CONJ, rank_score: -0.02995389699935913}
# {word: its, index: 10, tag: PRON, rank_score: -0.021437764167785645}
# {word: falsehoods, index: 0, tag: NOUN, rank_score: -0.019411087036132812}
# {word: up, index: 2, tag: PRT, rank_score: -0.019140660762786865}
#
# ['ADJ']
# {word: bold, index: 10, tag: ADJ, rank_score: -0.04442077875137329}
# {word: biographical, index: 11, tag: ADJ, rank_score: -0.019213497638702393}
# {word: fantasia, index: 12, tag: NOUN, rank_score: -0.016819775104522705}
# {word: together, index: 8, tag: PRT, rank_score: -0.013559401035308838}
#
# ['ADJ']
# {word: best, index: 5, tag: ADJ, rank_score: -0.0631633996963501}
# {word: one, index: 0, tag: NUM, rank_score: -0.04251152276992798}
# {word: oscar-worthy, index: 9, tag: ADJ, rank_score: -0.02869129180908203}
# {word: performance, index: 10, tag: NOUN, rank_score: -0.02554178237915039}
#
# ['ADJ']
# {word: intellect, index: 12, tag: NOUN, rank_score: -0.013086855411529541}
# {word: piercing, index: 11, tag: VERB, rank_score: -0.009151637554168701}
# {word: charm, index: 9, tag: NOUN, rank_score: -0.005243062973022461}
# {word: and, index: 10, tag: CONJ, rank_score: -0.0037775039672851562}
#
# ['ADJ']
# {word: clunker, index: 11, tag: NOUN, rank_score: -0.05216914415359497}
# {word: nonetheless, index: 12, tag: ADV, rank_score: -0.012312531471252441}
# {word: but, index: 9, tag: CONJ, rank_score: -0.00903022289276123}
# {word: well-acted, index: 7, tag: ADJ, rank_score: 0.0024683475494384766}
#
# ['ADJ']
# {word: rewards, index: 12, tag: NOUN, rank_score: -0.012220203876495361}
# {word: love, index: 9, tag: NOUN, rank_score: -0.0018641948699951172}
# {word: thought-provoking, index: 2, tag: ADJ, rank_score: -0.0013763904571533203}
# {word: charming, index: 1, tag: VERB, rank_score: -0.0013048648834228516}
#
# ['ADJ']
# {word: but, index: 11, tag: CONJ, rank_score: -0.5831636786460876}
# {word: it, index: 15, tag: PRON, rank_score: -0.26962563395500183}
# {word: delightfully, index: 3, tag: ADV, rank_score: 0.20368003845214844}
# {word: be, index: 7, tag: VERB, rank_score: 0.13505089282989502}
#
# ['ADJ']
# {word: satisfies, index: 2, tag: NOUN, rank_score: 0.2025315761566162}
# {word: swashbuckling, index: 5, tag: NOUN, rank_score: -0.15893244743347168}
# {word: nothing, index: 1, tag: NOUN, rank_score: 0.14460349082946777}
# {word: old-fashioned, index: 4, tag: ADJ, rank_score: -0.12298524379730225}
#
# ['ADJ']
# {word: delivers, index: 13, tag: NOUN, rank_score: -0.46632376313209534}
# {word: in, index: 8, tag: ADP, rank_score: -0.04138880968093872}
# {word: guard, index: 12, tag: NOUN, rank_score: -0.026207327842712402}
# {word: regard, index: 10, tag: NOUN, rank_score: 0.021691203117370605}
#
# ['ADJ']
# {word: and, index: 3, tag: CONJ, rank_score: -0.2866652309894562}
# {word: will, index: 6, tag: VERB, rank_score: -0.23669758439064026}
# {word: film, index: 11, tag: NOUN, rank_score: -0.23444828391075134}
# {word: shrapnel, index: 2, tag: NOUN, rank_score: 0.20330572128295898}
#
# ['ADJ']
# {word: too, index: 3, tag: ADV, rank_score: -0.5124818682670593}
# {word: gentility, index: 14, tag: NOUN, rank_score: -0.019113898277282715}
# {word: creating, index: 6, tag: VERB, rank_score: -0.011467218399047852}
# {word: and, index: 12, tag: CONJ, rank_score: -0.00886380672454834}
#
# ['ADJ']
# {word: flounders, index: 8, tag: NOUN, rank_score: -0.8914070725440979}
# {word: but, index: 7, tag: CONJ, rank_score: -0.10531294345855713}
# {word: meaning, index: 14, tag: NOUN, rank_score: -0.028162896633148193}
# {word: deeper, index: 13, tag: ADJ, rank_score: -0.027785956859588623}
#
# ['ADJ']
# {word: tale, index: 2, tag: NOUN, rank_score: -0.027880549430847168}
# {word: rich, index: 1, tag: ADJ, rank_score: -0.026453137397766113}
# {word: of, index: 13, tag: ADP, rank_score: 0.009608626365661621}
# {word: of, index: 3, tag: ADP, rank_score: -0.009075462818145752}
#
# ['ADJ']
# {word: revels, index: 7, tag: VERB, rank_score: -0.028796672821044922}
# {word: medium, index: 14, tag: NOUN, rank_score: -0.022185325622558594}
# {word: of, index: 12, tag: ADP, rank_score: -0.011091172695159912}
# {word: the, index: 13, tag: DET, rank_score: -0.01092076301574707}
#
# ['ADJ']
# {word: minimalist, index: 13, tag: ADJ, rank_score: -0.029304087162017822}
# {word: dull, index: 2, tag: ADJ, rank_score: -0.016864001750946045}
# {word: procession, index: 3, tag: NOUN, rank_score: -0.01458662748336792}
# {word: funeral, index: 14, tag: NOUN, rank_score: -0.013793349266052246}
#
# ['ADJ']
# {word: awesome, index: 0, tag: ADJ, rank_score: -0.006719410419464111}
# {word: breathtaking, index: 2, tag: VERB, rank_score: -0.003740072250366211}
# {word: and, index: 4, tag: CONJ, rank_score: -0.0016881823539733887}
# {word: creatures, index: 1, tag: NOUN, rank_score: -0.0016722679138183594}
#
# ['ADJ']
# {word: delicious, index: 10, tag: ADJ, rank_score: -0.011366128921508789}
# {word: fascinating, index: 1, tag: ADJ, rank_score: -0.010597467422485352}
# {word: thriller, index: 3, tag: NOUN, rank_score: -0.0037609338760375977}
# {word: of, index: 12, tag: ADP, rank_score: 0.003561735153198242}
#
# ['ADJ']
# {word: stick, index: 14, tag: NOUN, rank_score: -0.08084696531295776}
# {word: a, index: 13, tag: DET, rank_score: -0.024459123611450195}
# {word: at, index: 15, tag: ADP, rank_score: -0.022818326950073242}
# {word: with, index: 3, tag: ADP, rank_score: -0.021207034587860107}
#
# ['ADJ']
# {word: about, index: 0, tag: ADV, rank_score: -0.2929723858833313}
# {word: as, index: 1, tag: ADV, rank_score: -0.0942467451095581}
# {word: contract, index: 12, tag: NOUN, rank_score: -0.0662919282913208}
# {word: gangster, index: 5, tag: NOUN, rank_score: -0.05213695764541626}
#
# ['ADJ']
# {word: as, index: 6, tag: ADV, rank_score: -0.07609403133392334}
# {word: trailers, index: 10, tag: NOUN, rank_score: -0.074942946434021}
# {word: could, index: 0, tag: VERB, rank_score: -0.037545204162597656}
# {word: bad, index: 7, tag: ADJ, rank_score: -0.036895692348480225}
#
# ['ADJ']
# {word: a, index: 13, tag: DET, rank_score: -0.6090319156646729}
# {word: yes, index: 16, tag: X, rank_score: -0.3547298312187195}
# {word: word, index: 14, tag: NOUN, rank_score: -0.3231161832809448}
# {word: in, index: 12, tag: ADP, rank_score: -0.2667440176010132}
#
# ['ADJ']
# {word: generic, index: 3, tag: ADJ, rank_score: -0.1666926145553589}
# {word: done, index: 13, tag: VERB, rank_score: -0.02567744255065918}
# {word: seems, index: 12, tag: VERB, rank_score: -0.02327728271484375}
# {word: lot, index: 8, tag: NOUN, rank_score: -0.0151824951171875}
#
# ['ADJ']
# {word: fiennes, index: 14, tag: NOUN, rank_score: -0.09480655193328857}
# {word: and, index: 15, tag: CONJ, rank_score: -0.09334564208984375}
# {word: n't, index: 1, tag: ADV, rank_score: -0.07631158828735352}
# {word: ralph, index: 13, tag: NOUN, rank_score: -0.03372502326965332}
#
# ['ADJ']
# {word: bogs, index: 11, tag: NOUN, rank_score: -0.5063349604606628}
# {word: move, index: 10, tag: NOUN, rank_score: -0.36222055554389954}
# {word: economical, index: 6, tag: ADJ, rank_score: 0.2568007707595825}
# {word: crisp, index: 4, tag: ADJ, rank_score: 0.24455535411834717}
#
# ['ADJ']
# {word: disguise, index: 3, tag: NOUN, rank_score: 0.3626357316970825}
# {word: of, index: 2, tag: ADP, rank_score: 0.1531749963760376}
# {word: awful, index: 5, tag: ADJ, rank_score: 0.1514683961868286}
# {word: master, index: 1, tag: NOUN, rank_score: -0.1482970118522644}
#
# ['ADJ']
# {word: shore, index: 10, tag: ADJ, rank_score: -0.2760229706764221}
# {word: awful, index: 11, tag: NOUN, rank_score: -0.269280344247818}
# {word: pauly, index: 9, tag: ADV, rank_score: -0.21931201219558716}
# {word: it, index: 7, tag: PRON, rank_score: -0.20936575531959534}
#
# ['ADJ']
# {word: say, index: 15, tag: VERB, rank_score: -0.050988197326660156}
# {word: do, index: 13, tag: VERB, rank_score: -0.04317188262939453}
# {word: n't, index: 14, tag: ADV, rank_score: 0.0335230827331543}
# {word: were, index: 17, tag: VERB, rank_score: 0.03058302402496338}
#
# ['ADJ']
# {word: hearts, index: 9, tag: NOUN, rank_score: -0.08739280700683594}
# {word: and, index: 13, tag: CONJ, rank_score: -0.08450138568878174}
# {word: won, index: 11, tag: VERB, rank_score: -0.06557774543762207}
# {word: it, index: 10, tag: PRON, rank_score: -0.06121718883514404}
#
# ['ADJ']
# {word: love, index: 2, tag: VERB, rank_score: -0.06021517515182495}
# {word: means, index: 9, tag: NOUN, rank_score: 0.04734301567077637}
# {word: all, index: 8, tag: DET, rank_score: 0.04669475555419922}
# {word: out, index: 12, tag: PRT, rank_score: 0.04559600353240967}
#
# ['ADJ']
# {word: love, index: 17, tag: VERB, rank_score: -0.6117839217185974}
# {word: 'll, index: 15, tag: VERB, rank_score: -0.38953977823257446}
# {word: you, index: 14, tag: PRON, rank_score: -0.2049197554588318}
# {word: it, index: 18, tag: PRON, rank_score: -0.19105607271194458}
#
# ['ADJ']
# {word: as, index: 0, tag: ADP, rank_score: 0.3952244520187378}
# {word: go, index: 3, tag: VERB, rank_score: -0.2354753613471985}
# {word: notorious, index: 4, tag: ADJ, rank_score: 0.11261790990829468}
# {word: comedic, index: 1, tag: ADJ, rank_score: -0.10446617007255554}
#
# ['ADJ']
# {word: it, index: 16, tag: PRON, rank_score: 0.048160433769226074}
# {word: should, index: 17, tag: VERB, rank_score: 0.04499918222427368}
# {word: all, index: 12, tag: DET, rank_score: -0.03161662817001343}
# {word: hits, index: 11, tag: VERB, rank_score: 0.015162825584411621}
#
# ['ADJ']
# {word: is, index: 2, tag: VERB, rank_score: -0.021932482719421387}
# {word: and, index: 13, tag: CONJ, rank_score: -0.012800633907318115}
# {word: from, index: 4, tag: ADP, rank_score: 0.007959246635437012}
# {word: by, index: 7, tag: ADP, rank_score: -0.0054819583892822266}
#
# ['ADJ']
# {word: deftly, index: 6, tag: ADV, rank_score: -0.1991722583770752}
# {word: heart, index: 1, tag: NOUN, rank_score: -0.07231771945953369}
# {word: shadings, index: 12, tag: NOUN, rank_score: 0.034186482429504395}
# {word: the, index: 2, tag: DET, rank_score: 0.033163368701934814}
#
# ['ADJ']
# {word: not, index: 4, tag: ADV, rank_score: -0.2793816030025482}
# {word: the, index: 6, tag: DET, rank_score: 0.25312340259552}
# {word: being, index: 15, tag: VERB, rank_score: 0.225439190864563}
# {word: worst, index: 7, tag: ADJ, rank_score: 0.20341479778289795}
#
# ['ADJ']
# {word: little, index: 16, tag: ADJ, rank_score: -0.10352867841720581}
# {word: but, index: 15, tag: CONJ, rank_score: -0.025733530521392822}
# {word: resonance, index: 18, tag: NOUN, rank_score: -0.02178502082824707}
# {word: with, index: 10, tag: ADP, rank_score: -0.011869847774505615}
#
# ['ADJ']
# {word: versus, index: 18, tag: NOUN, rank_score: -0.10997200012207031}
# {word: fresh, index: 8, tag: ADJ, rank_score: -0.031715571880340576}
# {word: of, index: 16, tag: ADP, rank_score: -0.016858816146850586}
# {word: reality, index: 17, tag: NOUN, rank_score: -0.015340924263000488}
#
# ['ADJ']
# {word: conventional, index: 9, tag: ADJ, rank_score: -0.5540063977241516}
# {word: gets, index: 3, tag: VERB, rank_score: -0.5516012907028198}
# {word: never, index: 2, tag: ADV, rank_score: -0.48577091097831726}
# {word: its, index: 5, tag: PRON, rank_score: -0.467279851436615}
#
# ['ADJ']
# {word: elegantly, index: 0, tag: ADV, rank_score: -0.0026738643646240234}
# {word: crystallize, index: 9, tag: VERB, rank_score: -0.002629220485687256}
# {word: wonders, index: 16, tag: NOUN, rank_score: -0.0023320913314819336}
# {word: expressively, index: 3, tag: ADV, rank_score: -0.0016664862632751465}
#
# ['ADJ']
# {word: that, index: 12, tag: DET, rank_score: -0.7958054542541504}
# {word: is, index: 2, tag: VERB, rank_score: -0.19901716709136963}
# {word: beautifully, index: 9, tag: ADV, rank_score: -0.17699652910232544}
# {word: produced, index: 10, tag: VERB, rank_score: -0.1325439214706421}
#
# ['ADJ']
# {word: and, index: 15, tag: CONJ, rank_score: -0.09073513746261597}
# {word: and, index: 7, tag: CONJ, rank_score: -0.07736146450042725}
# {word: scary, index: 8, tag: ADJ, rank_score: -0.04838532209396362}
# {word: old, index: 6, tag: ADJ, rank_score: 0.03897958993911743}
#
# ['ADJ']
# {word: are, index: 21, tag: VERB, rank_score: -0.2618885040283203}
# {word: movie, index: 20, tag: NOUN, rank_score: -0.09324604272842407}
# {word: consuming, index: 6, tag: ADJ, rank_score: -0.03426039218902588}
# {word: tell, index: 13, tag: VERB, rank_score: -0.028342008590698242}
#
# ['ADJ']
# {word: neglects, index: 18, tag: VERB, rank_score: -0.2204788327217102}
# {word: but, index: 16, tag: CONJ, rank_score: -0.13629204034805298}
# {word: others, index: 20, tag: NOUN, rank_score: -0.043943166732788086}
# {word: avoids, index: 4, tag: VERB, rank_score: -0.03483772277832031}
#
# ['ADJ']
# {word: n't, index: 13, tag: ADV, rank_score: -0.23499441146850586}
# {word: opens, index: 0, tag: NOUN, rank_score: -0.04108351469039917}
# {word: does, index: 12, tag: VERB, rank_score: -0.04007279872894287}
# {word: at, index: 1, tag: ADP, rank_score: -0.0348774790763855}
#
# ['ADJ']
# {word: looks, index: 11, tag: NOUN, rank_score: -0.06742525100708008}
# {word: but, index: 7, tag: CONJ, rank_score: -0.061884284019470215}
# {word: made, index: 12, tag: VERB, rank_score: -0.04845154285430908}
# {word: may, index: 0, tag: VERB, rank_score: -0.04043000936508179}
#
# ['ADJ']
# {word: mild-mannered, index: 2, tag: ADJ, rank_score: -0.11974501609802246}
# {word: needed, index: 13, tag: VERB, rank_score: -0.10974007844924927}
# {word: is, index: 1, tag: VERB, rank_score: -0.10133194923400879}
# {word: given, index: 5, tag: VERB, rank_score: 0.019032657146453857}
#
# ['ADJ']
# {word: artist, index: 12, tag: NOUN, rank_score: -0.1335238814353943}
# {word: its, index: 1, tag: PRON, rank_score: -0.12567734718322754}
# {word: is, index: 4, tag: VERB, rank_score: 0.07712370157241821}
# {word: grand-scale, index: 5, tag: ADJ, rank_score: -0.076840341091156}
#
# ['ADJ']
# {word: of, index: 11, tag: ADP, rank_score: -0.3097630739212036}
# {word: overcome, index: 8, tag: ADP, rank_score: -0.2383100986480713}
# {word: 's, index: 1, tag: PRT, rank_score: -0.2154260277748108}
# {word: evolution, index: 23, tag: NOUN, rank_score: -0.1410769820213318}
#
# ['ADJ']
# {word: pumpkin, index: 0, tag: NOUN, rank_score: 0.03782522678375244}
# {word: its, index: 20, tag: PRON, rank_score: 0.03622370958328247}
# {word: huckster, index: 10, tag: NOUN, rank_score: -0.03022056818008423}
# {word: while, index: 12, tag: ADP, rank_score: -0.028839826583862305}
#
# ['ADJ']
# {word: for, index: 0, tag: ADP, rank_score: -0.12896734476089478}
# {word: the, index: 1, tag: DET, rank_score: -0.09513872861862183}
# {word: future, index: 2, tag: NOUN, rank_score: -0.06810325384140015}
# {word: mr, index: 5, tag: NOUN, rank_score: 0.026988327503204346}
#
# ['ADJ']
# {word: plympton, index: 7, tag: NOUN, rank_score: 0.2397146224975586}
# {word: find, index: 9, tag: VERB, rank_score: 0.18597519397735596}
# {word: room, index: 10, tag: NOUN, rank_score: -0.16984784603118896}
# {word: of, index: 15, tag: ADP, rank_score: -0.16583406925201416}
#
# ['ADJ']
# {word: problem, index: 1, tag: NOUN, rank_score: -0.25659555196762085}
# {word: on, index: 16, tag: ADP, rank_score: -0.08526533842086792}
# {word: antwone, index: 20, tag: NOUN, rank_score: -0.06437081098556519}
# {word: book, index: 18, tag: NOUN, rank_score: -0.026382863521575928}
#
# ['ADJ']
# {word: rueful, index: 3, tag: VERB, rank_score: -0.44770777225494385}
# {word: laughter, index: 4, tag: NOUN, rank_score: 0.1650974154472351}
# {word: would, index: 10, tag: VERB, rank_score: 0.14761883020401}
# {word: stereotypes, index: 6, tag: NOUN, rank_score: -0.13127446174621582}
#
# ['ADJ']
# {word: new, index: 21, tag: ADJ, rank_score: -0.6616690158843994}
# {word: nothing, index: 20, tag: NOUN, rank_score: -0.6312253475189209}
# {word: end, index: 18, tag: NOUN, rank_score: -0.014849662780761719}
# {word: in, index: 16, tag: ADP, rank_score: -0.010167181491851807}
#
# ['ADJ']
# {word: dangerous, index: 16, tag: ADJ, rank_score: -0.4648256301879883}
# {word: entertainments, index: 17, tag: NOUN, rank_score: -0.10917174816131592}
# {word: heaven, index: 6, tag: NOUN, rank_score: 0.04240947961807251}
# {word: call, index: 1, tag: VERB, rank_score: 0.031055986881256104}
#
# ['ADJ']
# {word: just, index: 21, tag: ADV, rank_score: 0.2666580080986023}
# {word: better, index: 19, tag: ADV, rank_score: 0.1866665482521057}
# {word: not, index: 20, tag: ADV, rank_score: -0.1421985626220703}
# {word: but, index: 14, tag: CONJ, rank_score: 0.13550269603729248}
#
# ['ADJ']
# {word: at, index: 22, tag: ADP, rank_score: 0.061868906021118164}
# {word: one, index: 21, tag: NUM, rank_score: -0.05791175365447998}
# {word: that, index: 23, tag: DET, rank_score: 0.05378681421279907}
# {word: figure, index: 8, tag: VERB, rank_score: -0.04729878902435303}
#
# ['ADJ']
# {word: seizures, index: 22, tag: NOUN, rank_score: -0.08610725402832031}
# {word: comparison, index: 13, tag: NOUN, rank_score: 0.06774324178695679}
# {word: anecdote, index: 11, tag: NOUN, rank_score: 0.048944056034088135}
# {word: watching, index: 0, tag: VERB, rank_score: -0.040132999420166016}
#
# ['ADJ']
# {word: captures, index: 0, tag: NOUN, rank_score: -0.261497437953949}
# {word: all, index: 1, tag: DET, rank_score: 0.008880376815795898}
# {word: confusing, index: 8, tag: VERB, rank_score: 0.008065760135650635}
# {word: part, index: 17, tag: NOUN, rank_score: -0.007075846195220947}
#
# ['ADJ']
# {word: riveting, index: 22, tag: ADJ, rank_score: -0.1098288893699646}
# {word: but, index: 14, tag: CONJ, rank_score: -0.03384220600128174}
# {word: experience, index: 24, tag: NOUN, rank_score: -0.03301960229873657}
# {word: movie, index: 23, tag: NOUN, rank_score: -0.026203691959381104}
#
# ['ADJ']
# {word: undone, index: 3, tag: ADJ, rank_score: -0.05359494686126709}
# {word: is, index: 2, tag: VERB, rank_score: -0.05358099937438965}
# {word: by, index: 4, tag: ADP, rank_score: -0.03933095932006836}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.013729393482208252}
#
# ['ADJ']
# {word: from-television, index: 11, tag: NOUN, rank_score: -0.40260833501815796}
# {word: if, index: 17, tag: ADP, rank_score: -0.38727879524230957}
# {word: looks, index: 15, tag: VERB, rank_score: -0.20822632312774658}
# {word: on, index: 20, tag: ADP, rank_score: -0.16086214780807495}
#
# ['ADJ']
# {word: come, index: 23, tag: VERB, rank_score: -0.09600335359573364}
# {word: in, index: 15, tag: ADP, rank_score: -0.06796509027481079}
# {word: required, index: 13, tag: ADJ, rank_score: 0.05354064702987671}
# {word: it, index: 12, tag: PRON, rank_score: 0.04910385608673096}
#
# ['ADJ']
# {word: in, index: 12, tag: ADP, rank_score: -0.3343057334423065}
# {word: you, index: 16, tag: PRON, rank_score: -0.32876336574554443}
# {word: geddes, index: 21, tag: NOUN, rank_score: -0.2533103823661804}
# {word: discretion, index: 11, tag: NOUN, rank_score: -0.22813618183135986}
#
# ['ADJ']
# {word: portrait, index: 4, tag: NOUN, rank_score: -0.11143207550048828}
# {word: into, index: 11, tag: ADP, rank_score: -0.10766881704330444}
# {word: this, index: 9, tag: DET, rank_score: -0.10725092887878418}
# {word: as, index: 20, tag: ADP, rank_score: 0.07453125715255737}
#
# ['ADJ']
# {word: moved, index: 4, tag: VERB, rank_score: -0.013538539409637451}
# {word: and, index: 27, tag: CONJ, rank_score: -0.006625950336456299}
# {word: depends, index: 21, tag: VERB, rank_score: 0.004203200340270996}
# {word: how, index: 25, tag: ADV, rank_score: 0.003951668739318848}
#
# ['ADJ']
# {word: powerful, index: 24, tag: ADJ, rank_score: -0.008747994899749756}
# {word: determination, index: 1, tag: NOUN, rank_score: -0.0028231143951416016}
# {word: emotional, index: 25, tag: ADJ, rank_score: -0.0024294257164001465}
# {word: patricio, index: 18, tag: VERB, rank_score: -0.0022014975547790527}
#
# ['ADJ']
# {word: his, index: 24, tag: PRON, rank_score: 0.18325769901275635}
# {word: details, index: 20, tag: NOUN, rank_score: 0.1731574535369873}
# {word: as, index: 0, tag: ADP, rank_score: -0.11621999740600586}
# {word: fingers, index: 25, tag: NOUN, rank_score: 0.1022341251373291}
#
# ['ADJ']
# {word: explore, index: 15, tag: VERB, rank_score: -0.17314082384109497}
# {word: that, index: 20, tag: DET, rank_score: -0.16711127758026123}
# {word: the, index: 22, tag: DET, rank_score: -0.09740757942199707}
# {word: experience, index: 13, tag: NOUN, rank_score: -0.09513819217681885}
#
# ['ADJ']
# {word: that, index: 19, tag: DET, rank_score: -0.5001446604728699}
# {word: perspective, index: 26, tag: NOUN, rank_score: -0.37267929315567017}
# {word: places, index: 20, tag: VERB, rank_score: -0.28547075390815735}
# {word: creates, index: 11, tag: VERB, rank_score: -0.2727428674697876}
#
# ['ADJ']
# {word: gorgeous, index: 21, tag: ADJ, rank_score: -0.8089883327484131}
# {word: and, index: 22, tag: CONJ, rank_score: -0.1726946234703064}
# {word: soderbergh, index: 16, tag: VERB, rank_score: -0.0798259973526001}
# {word: minimalist, index: 24, tag: NOUN, rank_score: 0.03123915195465088}
#
# ['ADJ']
# {word: entertain, index: 26, tag: NOUN, rank_score: -0.038158297538757324}
# {word: journey, index: 4, tag: NOUN, rank_score: -0.027218282222747803}
# {word: to, index: 22, tag: PRT, rank_score: -0.025756359100341797}
# {word: the, index: 14, tag: DET, rank_score: -0.021784186363220215}
#
# ['ADJ']
# {word: and, index: 17, tag: CONJ, rank_score: -0.32478904724121094}
# {word: blab, index: 16, tag: NOUN, rank_score: 0.2730284333229065}
# {word: jaglomized, index: 3, tag: VERB, rank_score: 0.17667019367218018}
# {word: to, index: 1, tag: PRT, rank_score: 0.14362263679504395}
#
# ['ADJ']
# {word: charming, index: 21, tag: ADJ, rank_score: -0.15554827451705933}
# {word: the, index: 20, tag: DET, rank_score: -0.03943145275115967}
# {word: result, index: 22, tag: NOUN, rank_score: -0.017405033111572266}
# {word: in, index: 25, tag: ADP, rank_score: 0.015043854713439941}
#
# ['ADJ']
# {word: from, index: 11, tag: ADP, rank_score: -0.02146780490875244}
# {word: of, index: 9, tag: ADP, rank_score: -0.006277620792388916}
# {word: nobody, index: 0, tag: NOUN, rank_score: -0.004854679107666016}
# {word: of, index: 19, tag: ADP, rank_score: -0.0040779709815979}
#
# ['ADJ']
# {word: to, index: 15, tag: PRT, rank_score: -0.05652731657028198}
# {word: comes, index: 12, tag: VERB, rank_score: -0.04936784505844116}
# {word: own, index: 26, tag: ADJ, rank_score: -0.03988611698150635}
# {word: unflinching, index: 23, tag: ADJ, rank_score: -0.037392616271972656}
#
# ['ADJ']
# {word: half, index: 0, tag: NOUN, rank_score: -0.09082198143005371}
# {word: of, index: 5, tag: ADP, rank_score: -0.06921768188476562}
# {word: pseudo-sophisticated, index: 9, tag: ADJ, rank_score: -0.04217177629470825}
# {word: and, index: 8, tag: CONJ, rank_score: -0.033959805965423584}
#
# ['ADJ']
# {word: would, index: 18, tag: VERB, rank_score: -0.18791258335113525}
# {word: more, index: 20, tag: ADJ, rank_score: -0.059478700160980225}
# {word: serial, index: 27, tag: NOUN, rank_score: -0.025602400302886963}
# {word: on, index: 23, tag: ADP, rank_score: -0.0107344388961792}
#
# ['ADJ']
# {word: muffled, index: 21, tag: VERB, rank_score: -0.019315063953399658}
# {word: lulling, index: 26, tag: ADJ, rank_score: -0.018673300743103027}
# {word: much, index: 14, tag: ADJ, rank_score: -0.017076611518859863}
# {word: dopey, index: 10, tag: NOUN, rank_score: -0.015232741832733154}
#
# ['ADJ']
# {word: not, index: 0, tag: ADV, rank_score: -0.48769858479499817}
# {word: for, index: 9, tag: ADP, rank_score: -0.2897648811340332}
# {word: big, index: 11, tag: ADJ, rank_score: -0.0491938591003418}
# {word: much, index: 2, tag: ADV, rank_score: -0.03967607021331787}
#
# ['ADJ']
# {word: still, index: 22, tag: ADV, rank_score: -0.3678092062473297}
# {word: enjoyed, index: 24, tag: VERB, rank_score: -0.1753658652305603}
# {word: series, index: 21, tag: NOUN, rank_score: -0.14360666275024414}
# {word: i, index: 23, tag: VERB, rank_score: -0.1414710283279419}
#
# ['ADJ']
# {word: service, index: 22, tag: NOUN, rank_score: -0.04344707727432251}
# {word: is, index: 13, tag: VERB, rank_score: -0.032417893409729004}
# {word: in, index: 20, tag: ADP, rank_score: -0.024846136569976807}
# {word: that, index: 16, tag: DET, rank_score: -0.024708807468414307}
#
# ['ADJ']
# {word: of, index: 5, tag: ADP, rank_score: -0.026882648468017578}
# {word: drone, index: 15, tag: NOUN, rank_score: -0.019300401210784912}
# {word: movie, index: 7, tag: NOUN, rank_score: -0.01919722557067871}
# {word: two, index: 19, tag: NUM, rank_score: -0.014569103717803955}
#
# ['ADJ']
# {word: meaningless, index: 28, tag: NOUN, rank_score: -0.04284614324569702}
# {word: prattle, index: 29, tag: NOUN, rank_score: 0.021501779556274414}
# {word: of, index: 26, tag: ADP, rank_score: -0.018907129764556885}
# {word: pretentious, index: 27, tag: ADJ, rank_score: -0.01564955711364746}
#
# ['ADJ']
# {word: chokes, index: 17, tag: VERB, rank_score: -0.3184993863105774}
# {word: so, index: 9, tag: ADV, rank_score: -0.02153259515762329}
# {word: allegedly, index: 4, tag: ADV, rank_score: -0.016744673252105713}
# {word: movies, index: 6, tag: NOUN, rank_score: -0.012871384620666504}
#
# ['ADJ']
# {word: best, index: 3, tag: ADJ, rank_score: -0.39702361822128296}
# {word: you, index: 11, tag: PRON, rank_score: -0.10594683885574341}
# {word: yourself, index: 24, tag: PRON, rank_score: -0.07613235712051392}
# {word: was, index: 29, tag: VERB, rank_score: -0.07047367095947266}
#
# ['ADJ']
# {word: book, index: 5, tag: NOUN, rank_score: -0.231564462184906}
# {word: 'possession, index: 0, tag: NOUN, rank_score: -0.22378283739089966}
# {word: a, index: 7, tag: DET, rank_score: -0.11984109878540039}
# {word: on, index: 3, tag: ADP, rank_score: -0.10447835922241211}
#
# ['ADJ']
# {word: labute, index: 14, tag: ADJ, rank_score: -0.21610260009765625}
# {word: demands, index: 12, tag: NOUN, rank_score: -0.21249061822891235}
# {word: a, index: 29, tag: DET, rank_score: 0.15322768688201904}
# {word: wit, index: 31, tag: NOUN, rank_score: -0.14556121826171875}
#
# ['ADJ']
# {word: but, index: 25, tag: CONJ, rank_score: -0.07546257972717285}
# {word: graphic, index: 24, tag: ADJ, rank_score: -0.029430806636810303}
# {word: n't, index: 21, tag: ADV, rank_score: -0.018270909786224365}
# {word: difficult, index: 32, tag: ADJ, rank_score: 0.01475590467453003}
#
# ['ADJ']
# {word: annoying, index: 13, tag: ADJ, rank_score: -0.05357116460800171}
# {word: angry, index: 16, tag: ADJ, rank_score: -0.04482489824295044}
# {word: trip, index: 32, tag: NOUN, rank_score: -0.03901553153991699}
# {word: less, index: 15, tag: ADJ, rank_score: -0.03201460838317871}
#
# ['ADJ']
# {word: appealing, index: 23, tag: VERB, rank_score: -0.5327157974243164}
# {word: she, index: 26, tag: PRON, rank_score: -0.138214111328125}
# {word: is, index: 18, tag: VERB, rank_score: -0.1070713996887207}
# {word: while, index: 32, tag: NOUN, rank_score: -0.10554581880569458}
#
# ['ADJ']
# {word: great, index: 13, tag: ADJ, rank_score: -0.28802281618118286}
# {word: and, index: 11, tag: CONJ, rank_score: -0.01965320110321045}
# {word: you, index: 8, tag: PRON, rank_score: -0.01791965961456299}
# {word: look, index: 10, tag: VERB, rank_score: -0.007357597351074219}
#
# ['ADJ']
# {word: and, index: 29, tag: CONJ, rank_score: -0.2678755521774292}
# {word: thinks, index: 24, tag: VERB, rank_score: -0.2282702922821045}
# {word: buff, index: 21, tag: ADJ, rank_score: -0.09413206577301025}
# {word: lost, index: 35, tag: VERB, rank_score: 0.09117209911346436}
#
# ['ADJ']
# {word: inspiring, index: 6, tag: VERB, rank_score: -0.23774605989456177}
# {word: ridiculous, index: 13, tag: ADJ, rank_score: 0.05772817134857178}
# {word: industry, index: 18, tag: NOUN, rank_score: -0.05523800849914551}
# {word: how, index: 12, tag: ADV, rank_score: 0.027378559112548828}
#
# ['ADJ']
# {word: the, index: 33, tag: DET, rank_score: 0.026575982570648193}
# {word: band, index: 34, tag: NOUN, rank_score: -0.025416553020477295}
# {word: it, index: 22, tag: PRON, rank_score: 0.014035999774932861}
# {word: a, index: 25, tag: DET, rank_score: -0.011315643787384033}
#
# ['ADJ']
# {word: how, index: 1, tag: ADV, rank_score: -0.014226078987121582}
# {word: others, index: 14, tag: NOUN, rank_score: 0.004456937313079834}
# {word: talents, index: 5, tag: NOUN, rank_score: -0.004187524318695068}
# {word: in, index: 10, tag: ADP, rank_score: 0.0027802586555480957}
#
# ['ADJ']
# {word: draw, index: 24, tag: VERB, rank_score: -0.009710371494293213}
# {word: shows, index: 18, tag: VERB, rank_score: -0.008065402507781982}
# {word: it, index: 16, tag: PRON, rank_score: 0.005323588848114014}
# {word: also, index: 17, tag: ADV, rank_score: 0.004449188709259033}
#
# ['ADJ']
# {word: whereas, index: 0, tag: ADP, rank_score: -0.445595920085907}
# {word: sardonic, index: 15, tag: ADJ, rank_score: -0.08974945545196533}
# {word: purpose, index: 20, tag: NOUN, rank_score: -0.05787801742553711}
# {word: and, index: 10, tag: CONJ, rank_score: 0.04153752326965332}
#
# ['ADJ']
# {word: drab, index: 32, tag: ADJ, rank_score: -0.1161145567893982}
# {word: is, index: 28, tag: VERB, rank_score: -0.026836156845092773}
# {word: wannabe, index: 33, tag: NOUN, rank_score: -0.01149839162826538}
# {word: an, index: 29, tag: DET, rank_score: 0.007700681686401367}
#
# ['ADJ']
# {word: assembles, index: 1, tag: VERB, rank_score: 0.002245962619781494}
# {word: fascinating, index: 3, tag: ADJ, rank_score: -0.0012049078941345215}
# {word: of, index: 5, tag: ADP, rank_score: 0.0008642673492431641}
# {word: profile, index: 4, tag: NOUN, rank_score: -0.000808417797088623}
#
# ['ADJ']
# {word: pulls, index: 36, tag: VERB, rank_score: -0.2281728982925415}
# {word: with, index: 40, tag: ADP, rank_score: -0.1579805612564087}
# {word: hard, index: 2, tag: ADJ, rank_score: -0.15091955661773682}
# {word: aplomb, index: 41, tag: NOUN, rank_score: 0.149702250957489}
#
# ['ADJ']
# {word: was, index: 4, tag: VERB, rank_score: -0.18948054313659668}
# {word: threw, index: 7, tag: VERB, rank_score: -0.12952959537506104}
# {word: green, index: 6, tag: ADJ, rank_score: -0.11458706855773926}
# {word: moment, index: 3, tag: NOUN, rank_score: 0.07884544134140015}
#
# ['ADJ']
# {word: great, index: 8, tag: ADJ, rank_score: -0.5118023157119751}
# {word: can, index: 12, tag: VERB, rank_score: -0.39693257212638855}
# {word: disingenuous, index: 3, tag: ADJ, rank_score: -0.2890327572822571}
# {word: about, index: 15, tag: ADP, rank_score: -0.15871232748031616}
#
# ['ADJ']
# {word: pleasant, index: 39, tag: ADJ, rank_score: -0.6883876919746399}
# {word: is, index: 33, tag: VERB, rank_score: -0.44933995604515076}
# {word: this, index: 28, tag: DET, rank_score: -0.38409146666526794}
# {word: a, index: 38, tag: DET, rank_score: -0.20765739679336548}
#
# :: 16 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %%
templates2 = tg2.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 118 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: delivers, index: 4, tag: NOUN, rank_score: -0.4025241732597351}
# {word: goodies, index: 6, tag: NOUN, rank_score: -0.3876534700393677}
# {word: 's, index: 1, tag: PRT, rank_score: -0.3092106580734253}
# {word: underestimated, index: 2, tag: ADJ, rank_score: 0.27075690031051636}
#
# ['ADJ']
# {word: skip, index: 0, tag: VERB, rank_score: -0.35948944091796875}
# {word: the, index: 1, tag: DET, rank_score: -0.1605040431022644}
# {word: cd, index: 9, tag: NOUN, rank_score: 0.08838433027267456}
# {word: film, index: 2, tag: NOUN, rank_score: -0.07738423347473145}
#
# ['ADJ']
# {word: lapses, index: 4, tag: VERB, rank_score: -0.20442330837249756}
# {word: the, index: 8, tag: DET, rank_score: 0.03566247224807739}
# {word: times, index: 2, tag: NOUN, rank_score: 0.031717002391815186}
# {word: into, index: 7, tag: ADP, rank_score: -0.027649283409118652}
#
# ['ADJ']
# {word: while, index: 0, tag: ADP, rank_score: 0.24310076236724854}
# {word: performance, index: 3, tag: NOUN, rank_score: -0.1947731375694275}
# {word: great, index: 5, tag: ADJ, rank_score: -0.18993842601776123}
# {word: subject, index: 7, tag: ADJ, rank_score: -0.15534278750419617}
#
# ['ADJ']
# {word: that, index: 6, tag: DET, rank_score: -0.644199550151825}
# {word: our, index: 3, tag: PRON, rank_score: -0.5310615301132202}
# {word: culture, index: 5, tag: NOUN, rank_score: -0.5275149345397949}
# {word: flick, index: 1, tag: NOUN, rank_score: -0.5216434001922607}
#
# ['ADJ']
# {word: neglected, index: 10, tag: VERB, rank_score: -0.03164738416671753}
# {word: flick, index: 2, tag: ADJ, rank_score: -0.016026020050048828}
# {word: half, index: 3, tag: NOUN, rank_score: -0.01246410608291626}
# {word: all, index: 6, tag: DET, rank_score: -0.010541081428527832}
#
# ['ADJ']
# {word: great, index: 5, tag: ADJ, rank_score: -0.42984864115715027}
# {word: intelligent, index: 0, tag: ADJ, rank_score: -0.32469621300697327}
# {word: take, index: 2, tag: NOUN, rank_score: -0.12433409690856934}
# {word: writer, index: 6, tag: NOUN, rank_score: -0.12151724100112915}
#
# ['ADJ']
# {word: warmth, index: 10, tag: NOUN, rank_score: -0.41173234581947327}
# {word: vibrance, index: 8, tag: NOUN, rank_score: -0.21915137767791748}
# {word: with, index: 7, tag: ADP, rank_score: -0.21124672889709473}
# {word: and, index: 9, tag: CONJ, rank_score: -0.1558571457862854}
#
# ['ADJ']
# {word: simply, index: 0, tag: ADV, rank_score: -0.08072912693023682}
# {word: does, index: 1, tag: VERB, rank_score: -0.0720524787902832}
# {word: justify, index: 7, tag: VERB, rank_score: -0.06269580125808716}
# {word: running, index: 10, tag: ADJ, rank_score: -0.061044275760650635}
#
# ['ADJ']
# {word: a, index: 0, tag: DET, rank_score: -0.005826771259307861}
# {word: profound, index: 8, tag: ADJ, rank_score: -0.0034418702125549316}
# {word: work, index: 1, tag: NOUN, rank_score: -0.0021991729736328125}
# {word: intricate, index: 3, tag: ADJ, rank_score: -0.0017132163047790527}
#
# ['ADJ']
# {word: gem, index: 11, tag: NOUN, rank_score: -0.27056944370269775}
# {word: and, index: 1, tag: CONJ, rank_score: -0.15960872173309326}
# {word: smart, index: 0, tag: NOUN, rank_score: -0.11398983001708984}
# {word: conversations, index: 4, tag: NOUN, rank_score: -0.04671412706375122}
#
# ['ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.5312271118164062}
# {word: sign, index: 4, tag: NOUN, rank_score: -0.05322319269180298}
# {word: it, index: 0, tag: PRON, rank_score: -0.049111008644104004}
# {word: instantly, index: 10, tag: ADV, rank_score: 0.030106186866760254}
#
# ['ADJ']
# {word: rare, index: 1, tag: ADJ, rank_score: -0.430624395608902}
# {word: than, index: 10, tag: ADP, rank_score: -0.28375497460365295}
# {word: was, index: 8, tag: VERB, rank_score: 0.16610592603683472}
# {word: hour, index: 12, tag: NOUN, rank_score: -0.14764899015426636}
#
# ['ADJ']
# {word: but, index: 6, tag: CONJ, rank_score: -0.012876689434051514}
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.009108424186706543}
# {word: is, index: 8, tag: VERB, rank_score: -0.003394782543182373}
# {word: no, index: 1, tag: DET, rank_score: -0.0031695961952209473}
#
# ['ADJ']
# {word: pile, index: 1, tag: VERB, rank_score: -0.02517712116241455}
# {word: undermining, index: 3, tag: VERB, rank_score: -0.017847001552581787}
# {word: creator, index: 11, tag: NOUN, rank_score: -0.00404125452041626}
# {word: stifling, index: 9, tag: VERB, rank_score: -0.0032460689544677734}
#
# ['ADJ']
# {word: bold, index: 10, tag: ADJ, rank_score: -0.1454431414604187}
# {word: a, index: 9, tag: DET, rank_score: -0.05386459827423096}
# {word: fantasia, index: 12, tag: NOUN, rank_score: -0.010489344596862793}
# {word: put, index: 7, tag: VERB, rank_score: 0.009768903255462646}
#
# ['ADJ']
# {word: one, index: 0, tag: NUM, rank_score: -0.07642436027526855}
# {word: best, index: 5, tag: ADJ, rank_score: -0.05319768190383911}
# {word: oscar-worthy, index: 9, tag: ADJ, rank_score: -0.028453826904296875}
# {word: of, index: 1, tag: ADP, rank_score: -0.01893693208694458}
#
# ['ADJ']
# {word: and, index: 10, tag: CONJ, rank_score: -0.012506961822509766}
# {word: charm, index: 9, tag: NOUN, rank_score: -0.006931424140930176}
# {word: piercing, index: 11, tag: VERB, rank_score: -0.0061470866203308105}
# {word: impeccable, index: 5, tag: ADJ, rank_score: -0.003742218017578125}
#
# ['ADJ']
# {word: clunker, index: 8, tag: NOUN, rank_score: -0.3396601974964142}
# {word: but, index: 9, tag: CONJ, rank_score: 0.21684283018112183}
# {word: thoughtful, index: 6, tag: ADJ, rank_score: -0.20432782173156738}
# {word: clunker, index: 11, tag: NOUN, rank_score: 0.11272972822189331}
#
# ['ADJ']
# {word: rewards, index: 12, tag: NOUN, rank_score: -0.011342525482177734}
# {word: this, index: 0, tag: DET, rank_score: -0.009244799613952637}
# {word: charming, index: 1, tag: VERB, rank_score: -0.008787691593170166}
# {word: and, index: 8, tag: CONJ, rank_score: -0.0033164024353027344}
#
# ['ADJ']
# {word: but, index: 11, tag: CONJ, rank_score: -0.37267056107521057}
# {word: delightfully, index: 3, tag: ADV, rank_score: 0.26203519105911255}
# {word: is, index: 13, tag: VERB, rank_score: -0.1779457926750183}
# {word: 's, index: 1, tag: VERB, rank_score: -0.09150040149688721}
#
# ['ADJ']
# {word: swashbuckling, index: 5, tag: NOUN, rank_score: -0.06967037916183472}
# {word: old-fashioned, index: 4, tag: ADJ, rank_score: -0.06255108118057251}
# {word: sometimes, index: 0, tag: ADV, rank_score: 0.03331398963928223}
# {word: satisfies, index: 2, tag: NOUN, rank_score: 0.030098378658294678}
#
# ['ADJ']
# {word: delivers, index: 13, tag: NOUN, rank_score: -0.055378258228302}
# {word: regard, index: 10, tag: NOUN, rank_score: -0.04361259937286377}
# {word: on, index: 11, tag: ADP, rank_score: 0.039002180099487305}
# {word: and, index: 7, tag: CONJ, rank_score: -0.025519728660583496}
#
# ['ADJ']
# {word: film, index: 11, tag: NOUN, rank_score: -0.07919561862945557}
# {word: shellshock, index: 5, tag: NOUN, rank_score: -0.06316936016082764}
# {word: long, index: 8, tag: ADV, rank_score: 0.03985065221786499}
# {word: will, index: 6, tag: VERB, rank_score: 0.03545868396759033}
#
# ['ADJ']
# {word: too, index: 3, tag: ADV, rank_score: -0.6335517168045044}
# {word: perhaps, index: 2, tag: ADV, rank_score: 0.02692270278930664}
# {word: is, index: 1, tag: VERB, rank_score: 0.02469271421432495}
# {word: in, index: 5, tag: ADP, rank_score: 0.011881589889526367}
#
# ['ADJ']
# {word: flounders, index: 8, tag: NOUN, rank_score: -0.5046506524085999}
# {word: but, index: 7, tag: CONJ, rank_score: -0.3755234479904175}
# {word: for, index: 12, tag: ADP, rank_score: -0.257354736328125}
# {word: delivers, index: 1, tag: VERB, rank_score: 0.1699008345603943}
#
# ['ADJ']
# {word: rich, index: 1, tag: ADJ, rank_score: -0.018781423568725586}
# {word: tale, index: 2, tag: NOUN, rank_score: -0.016642630100250244}
# {word: a, index: 0, tag: DET, rank_score: -0.014257729053497314}
# {word: of, index: 3, tag: ADP, rank_score: -0.008725106716156006}
#
# ['ADJ']
# {word: revels, index: 7, tag: VERB, rank_score: -0.03343397378921509}
# {word: achieves, index: 0, tag: VERB, rank_score: -0.02083975076675415}
# {word: that, index: 6, tag: DET, rank_score: -0.018516361713409424}
# {word: filmic, index: 4, tag: ADJ, rank_score: -0.00686335563659668}
#
# ['ADJ']
# {word: dull, index: 2, tag: ADJ, rank_score: -0.2260528802871704}
# {word: procession, index: 3, tag: NOUN, rank_score: -0.18336433172225952}
# {word: despair, index: 5, tag: NOUN, rank_score: 0.031109094619750977}
# {word: long, index: 1, tag: ADJ, rank_score: 0.027201414108276367}
#
# ['ADJ']
# {word: and, index: 4, tag: CONJ, rank_score: -0.008241832256317139}
# {word: 'spectacular, index: 12, tag: ADJ, rank_score: -0.005224168300628662}
# {word: breathtaking, index: 2, tag: VERB, rank_score: -0.0048416852951049805}
# {word: scenes, index: 7, tag: NOUN, rank_score: -0.004503130912780762}
#
# ['ADJ']
# {word: fascinating, index: 1, tag: ADJ, rank_score: -0.015252232551574707}
# {word: a, index: 0, tag: DET, rank_score: -0.008320510387420654}
# {word: thriller, index: 3, tag: NOUN, rank_score: -0.006991922855377197}
# {word: keeps, index: 5, tag: VERB, rank_score: -0.006606638431549072}
#
# ['ADJ']
# {word: filled, index: 2, tag: VERB, rank_score: -0.0739356279373169}
# {word: beatings, index: 5, tag: NOUN, rank_score: -0.05485177040100098}
# {word: was, index: 1, tag: VERB, rank_score: -0.03820234537124634}
# {word: you, index: 10, tag: PRON, rank_score: 0.02690333127975464}
#
# ['ADJ']
# {word: about, index: 0, tag: ADV, rank_score: -0.1829858422279358}
# {word: contract, index: 12, tag: NOUN, rank_score: -0.04117584228515625}
# {word: while, index: 8, tag: ADP, rank_score: 0.03727167844772339}
# {word: as, index: 3, tag: ADP, rank_score: 0.03421676158905029}
#
# ['ADJ']
# {word: bad, index: 7, tag: ADJ, rank_score: -0.1291724443435669}
# {word: trailers, index: 10, tag: NOUN, rank_score: -0.04799562692642212}
# {word: could, index: 0, tag: VERB, rank_score: 0.04082942008972168}
# {word: be, index: 5, tag: VERB, rank_score: 0.01744520664215088}
#
# ['ADJ']
# {word: a, index: 13, tag: DET, rank_score: -0.1027086079120636}
# {word: word, index: 14, tag: NOUN, rank_score: -0.09399321675300598}
# {word: in, index: 12, tag: ADP, rank_score: -0.014847397804260254}
# {word: yes, index: 16, tag: X, rank_score: 0.008932411670684814}
#
# ['ADJ']
# {word: generic, index: 3, tag: ADJ, rank_score: -0.5683742761611938}
# {word: despite, index: 6, tag: ADP, rank_score: -0.40296056866645813}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.12897390127182007}
# {word: virtues, index: 4, tag: NOUN, rank_score: 0.09921759366989136}
#
# ['ADJ']
# {word: off, index: 7, tag: PRT, rank_score: -0.07579636573791504}
# {word: running, index: 6, tag: VERB, rank_score: -0.04387342929840088}
# {word: lopez, index: 17, tag: NOUN, rank_score: 0.026029467582702637}
# {word: fiennes, index: 14, tag: NOUN, rank_score: 0.025568246841430664}
#
# ['ADJ']
# {word: bogs, index: 11, tag: NOUN, rank_score: -0.562678337097168}
# {word: move, index: 10, tag: NOUN, rank_score: -0.3550903797149658}
# {word: in, index: 13, tag: ADP, rank_score: -0.09559506177902222}
# {word: crisp, index: 4, tag: ADJ, rank_score: 0.05961191654205322}
#
# ['ADJ']
# {word: awful, index: 5, tag: ADJ, rank_score: -0.2628355026245117}
# {word: disguise, index: 3, tag: NOUN, rank_score: -0.1845579743385315}
# {word: is, index: 4, tag: VERB, rank_score: -0.08981186151504517}
# {word: of, index: 2, tag: ADP, rank_score: 0.022164583206176758}
#
# ['ADJ']
# {word: awful, index: 11, tag: NOUN, rank_score: -0.1225271224975586}
# {word: pauly, index: 9, tag: ADV, rank_score: 0.11008048057556152}
# {word: shore, index: 10, tag: ADJ, rank_score: 0.0771835446357727}
# {word: it, index: 7, tag: PRON, rank_score: -0.07662975788116455}
#
# ['ADJ']
# {word: you, index: 16, tag: PRON, rank_score: 0.25305283069610596}
# {word: ., index: 20, tag: ., rank_score: 0.23291867971420288}
# {word: say, index: 15, tag: VERB, rank_score: 0.22702205181121826}
# {word: n't, index: 18, tag: ADV, rank_score: 0.22547972202301025}
#
# ['ADJ']
# {word: masterpiece, index: 4, tag: NOUN, rank_score: -0.06564450263977051}
# {word: hearts, index: 9, tag: NOUN, rank_score: -0.030385315418243408}
# {word: still, index: 15, tag: ADV, rank_score: 0.02585303783416748}
# {word: and, index: 13, tag: CONJ, rank_score: -0.022859811782836914}
#
# ['ADJ']
# {word: by, index: 7, tag: ADP, rank_score: -0.12816378474235535}
# {word: then, index: 6, tag: ADV, rank_score: 0.08804947137832642}
# {word: love, index: 2, tag: VERB, rank_score: -0.061465680599212646}
# {word: and/or, index: 4, tag: NOUN, rank_score: -0.025912582874298096}
#
# ['ADJ']
# {word: love, index: 17, tag: VERB, rank_score: -0.2374604344367981}
# {word: probably, index: 16, tag: ADV, rank_score: 0.19839811325073242}
# {word: 'll, index: 15, tag: VERB, rank_score: 0.0462801456451416}
# {word: it, index: 18, tag: PRON, rank_score: -0.03968268632888794}
#
# ['ADJ']
# {word: notorious, index: 4, tag: ADJ, rank_score: -0.2635759711265564}
# {word: go, index: 3, tag: VERB, rank_score: -0.1489168405532837}
# {word: comedic, index: 1, tag: ADJ, rank_score: -0.06298494338989258}
# {word: c, index: 5, tag: NOUN, rank_score: -0.05949985980987549}
#
# ['ADJ']
# {word: verbal, index: 14, tag: ADJ, rank_score: -0.19453644752502441}
# {word: it, index: 16, tag: PRON, rank_score: -0.047069549560546875}
# {word: marks, index: 15, tag: NOUN, rank_score: -0.04177355766296387}
# {word: all, index: 12, tag: DET, rank_score: -0.03201854228973389}
#
# ['ADJ']
# {word: saved, index: 3, tag: VERB, rank_score: -0.08646845817565918}
# {word: simplicity, index: 9, tag: NOUN, rank_score: -0.020656824111938477}
# {word: lightness, index: 6, tag: NOUN, rank_score: -0.017022430896759033}
# {word: by, index: 7, tag: ADP, rank_score: -0.016224324703216553}
#
# ['ADJ']
# {word: than, index: 17, tag: ADP, rank_score: -0.29417306184768677}
# {word: substance, index: 18, tag: NOUN, rank_score: -0.04548615217208862}
# {word: whose, index: 10, tag: PRON, rank_score: -0.04294532537460327}
# {word: wrought, index: 7, tag: ADJ, rank_score: -0.02459549903869629}
#
# ['ADJ']
# {word: it, index: 11, tag: PRON, rank_score: -0.15003174543380737}
# {word: worst, index: 7, tag: ADJ, rank_score: -0.10275775194168091}
# {word: not, index: 4, tag: ADV, rank_score: 0.08297514915466309}
# {word: 's, index: 12, tag: VERB, rank_score: -0.07583832740783691}
#
# ['ADJ']
# {word: little, index: 16, tag: ADJ, rank_score: -0.12042224407196045}
# {word: empty, index: 1, tag: ADJ, rank_score: -0.013803958892822266}
# {word: resonance, index: 18, tag: NOUN, rank_score: -0.009456157684326172}
# {word: florid, index: 4, tag: NOUN, rank_score: -0.00857454538345337}
#
# ['ADJ']
# {word: marvel, index: 15, tag: NOUN, rank_score: -0.06184321641921997}
# {word: of, index: 16, tag: ADP, rank_score: -0.013484418392181396}
# {word: versus, index: 18, tag: NOUN, rank_score: -0.011940836906433105}
# {word: a, index: 14, tag: DET, rank_score: -0.010872840881347656}
#
# ['ADJ']
# {word: never, index: 2, tag: ADV, rank_score: -0.31267625093460083}
# {word: gets, index: 3, tag: VERB, rank_score: -0.13738596439361572}
# {word: film, index: 1, tag: NOUN, rank_score: -0.04651963710784912}
# {word: class, index: 19, tag: NOUN, rank_score: 0.0337255597114563}
#
# ['ADJ']
# {word: and, index: 2, tag: CONJ, rank_score: -0.0047067999839782715}
# {word: wonders, index: 16, tag: NOUN, rank_score: -0.003041088581085205}
# {word: of, index: 17, tag: ADP, rank_score: -0.0019152164459228516}
# {word: moments, index: 12, tag: NOUN, rank_score: -0.001737356185913086}
#
# ['ADJ']
# {word: sacrifices, index: 13, tag: VERB, rank_score: -0.015845119953155518}
# {word: beautifully, index: 9, tag: ADV, rank_score: -0.01403576135635376}
# {word: that, index: 12, tag: DET, rank_score: -0.0076697468757629395}
# {word: promise, index: 15, tag: NOUN, rank_score: -0.006964147090911865}
#
# ['ADJ']
# {word: and, index: 7, tag: CONJ, rank_score: -0.23825639486312866}
# {word: story, index: 4, tag: NOUN, rank_score: -0.2354474663734436}
# {word: and, index: 15, tag: CONJ, rank_score: -0.11025494337081909}
# {word: a, index: 3, tag: DET, rank_score: -0.09879940748214722}
#
# ['ADJ']
# {word: consuming, index: 6, tag: ADJ, rank_score: -0.04271996021270752}
# {word: who, index: 14, tag: PRON, rank_score: 0.020183980464935303}
# {word: movie, index: 20, tag: NOUN, rank_score: -0.015913844108581543}
# {word: act, index: 3, tag: NOUN, rank_score: -0.00924140214920044}
#
# ['ADJ']
# {word: few, index: 19, tag: ADJ, rank_score: 0.16701924800872803}
# {word: others, index: 20, tag: NOUN, rank_score: 0.13819581270217896}
# {word: but, index: 16, tag: CONJ, rank_score: 0.12285369634628296}
# {word: avoids, index: 4, tag: VERB, rank_score: 0.10951662063598633}
#
# ['ADJ']
# {word: n't, index: 13, tag: ADV, rank_score: -0.36928457021713257}
# {word: does, index: 12, tag: VERB, rank_score: -0.16980546712875366}
# {word: and, index: 11, tag: CONJ, rank_score: -0.06530725955963135}
# {word: get, index: 14, tag: VERB, rank_score: -0.061733782291412354}
#
# ['ADJ']
# {word: fictional, index: 9, tag: ADJ, rank_score: -0.05595165491104126}
# {word: but, index: 7, tag: CONJ, rank_score: -0.0386391282081604}
# {word: looks, index: 11, tag: NOUN, rank_score: -0.03819841146469116}
# {word: rather, index: 15, tag: ADV, rank_score: -0.0267333984375}
#
# ['ADJ']
# {word: needed, index: 13, tag: VERB, rank_score: -0.10282325744628906}
# {word: material, index: 4, tag: NOUN, rank_score: -0.022772550582885742}
# {word: touch, index: 15, tag: NOUN, rank_score: 0.02019566297531128}
# {word: is, index: 1, tag: VERB, rank_score: -0.020073890686035156}
#
# ['ADJ']
# {word: grand-scale, index: 5, tag: ADJ, rank_score: -0.013602077960968018}
# {word: who, index: 13, tag: PRON, rank_score: -0.012068569660186768}
# {word: its, index: 1, tag: PRON, rank_score: -0.01120758056640625}
# {word: artist, index: 12, tag: NOUN, rank_score: -0.005910098552703857}
#
# ['ADJ']
# {word: glosses, index: 19, tag: VERB, rank_score: -0.07199186086654663}
# {word: a, index: 16, tag: DET, rank_score: -0.028916478157043457}
# {word: the, index: 9, tag: DET, rank_score: -0.02339404821395874}
# {word: evolution, index: 23, tag: NOUN, rank_score: -0.02290475368499756}
#
# ['ADJ']
# {word: courage, index: 5, tag: NOUN, rank_score: -0.23872724175453186}
# {word: decorates, index: 19, tag: VERB, rank_score: -0.21995410323143005}
# {word: its, index: 20, tag: PRON, rank_score: -0.18073511123657227}
# {word: with, index: 3, tag: ADP, rank_score: -0.17955273389816284}
#
# ['ADJ']
# {word: mr, index: 5, tag: NOUN, rank_score: 0.12407886981964111}
# {word: one, index: 3, tag: NUM, rank_score: 0.05982488393783569}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.041512906551361084}
# {word: for, index: 0, tag: ADP, rank_score: -0.011348724365234375}
#
# ['ADJ']
# {word: room, index: 10, tag: NOUN, rank_score: -0.21790781617164612}
# {word: band, index: 18, tag: NOUN, rank_score: 0.11481207609176636}
# {word: his, index: 16, tag: PRON, rank_score: 0.1122368574142456}
# {word: more, index: 13, tag: ADJ, rank_score: 0.11195629835128784}
#
# ['ADJ']
# {word: problem, index: 1, tag: NOUN, rank_score: -0.2670314311981201}
# {word: screenplay, index: 10, tag: NOUN, rank_score: -0.023679018020629883}
# {word: on, index: 16, tag: ADP, rank_score: -0.011449694633483887}
# {word: has, index: 8, tag: VERB, rank_score: 0.010264694690704346}
#
# ['ADJ']
# {word: laughter, index: 4, tag: NOUN, rank_score: -0.24242082238197327}
# {word: at, index: 5, tag: ADP, rank_score: -0.20750299096107483}
# {word: encourages, index: 2, tag: NOUN, rank_score: -0.18693193793296814}
# {word: only, index: 7, tag: ADV, rank_score: 0.16816693544387817}
#
# ['ADJ']
# {word: nothing, index: 20, tag: NOUN, rank_score: -0.722898006439209}
# {word: new, index: 21, tag: ADJ, rank_score: -0.075553297996521}
# {word: end, index: 18, tag: NOUN, rank_score: -0.05361461639404297}
# {word: lesson, index: 15, tag: NOUN, rank_score: -0.039710402488708496}
#
# ['ADJ']
# {word: appalling, index: 8, tag: ADJ, rank_score: -0.04408234357833862}
# {word: underestimate, index: 13, tag: VERB, rank_score: -0.04400676488876343}
# {word: entertainments, index: 17, tag: NOUN, rank_score: -0.04214358329772949}
# {word: call, index: 1, tag: VERB, rank_score: -0.035793960094451904}
#
# ['ADJ']
# {word: just, index: 21, tag: ADV, rank_score: 0.19513779878616333}
# {word: better, index: 19, tag: ADV, rank_score: -0.1217796802520752}
# {word: but, index: 14, tag: CONJ, rank_score: -0.11666232347488403}
# {word: imax, index: 16, tag: NOUN, rank_score: -0.1113787293434143}
#
# ['ADJ']
# {word: sappy, index: 19, tag: ADJ, rank_score: -0.0930941104888916}
# {word: preachy, index: 20, tag: NOUN, rank_score: 0.05212521553039551}
# {word: take, index: 3, tag: VERB, rank_score: 0.04764997959136963}
# {word: does, index: 1, tag: VERB, rank_score: 0.04714000225067139}
#
# ['ADJ']
# {word: kept, index: 7, tag: VERB, rank_score: -0.1525140404701233}
# {word: returning, index: 8, tag: VERB, rank_score: -0.11007875204086304}
# {word: mind, index: 6, tag: NOUN, rank_score: -0.07341283559799194}
# {word: that, index: 19, tag: DET, rank_score: 0.04816526174545288}
#
# ['ADJ']
# {word: captures, index: 0, tag: NOUN, rank_score: -0.16599041223526}
# {word: and, index: 11, tag: CONJ, rank_score: -0.025522053241729736}
# {word: ache, index: 6, tag: VERB, rank_score: 0.01111149787902832}
# {word: confusing, index: 8, tag: VERB, rank_score: 0.010571897029876709}
#
# ['ADJ']
# {word: riveting, index: 22, tag: ADJ, rank_score: -0.1485876441001892}
# {word: makes, index: 19, tag: VERB, rank_score: -0.0702282190322876}
# {word: 's, index: 16, tag: PRT, rank_score: -0.03553926944732666}
# {word: but, index: 14, tag: CONJ, rank_score: -0.030760526657104492}
#
# ['ADJ']
# {word: undone, index: 3, tag: ADJ, rank_score: -0.144051194190979}
# {word: by, index: 4, tag: ADP, rank_score: -0.06348299980163574}
# {word: cliched, index: 20, tag: VERB, rank_score: -0.047741830348968506}
# {word: is, index: 2, tag: VERB, rank_score: -0.04152250289916992}
#
# ['ADJ']
# {word: if, index: 17, tag: ADP, rank_score: -0.21166658401489258}
# {word: bursting, index: 0, tag: VERB, rank_score: 0.16942322254180908}
# {word: the, index: 2, tag: DET, rank_score: 0.16166549921035767}
# {word: of, index: 4, tag: ADP, rank_score: 0.13625973463058472}
#
# ['ADJ']
# {word: make, index: 11, tag: VERB, rank_score: 0.0682065486907959}
# {word: come, index: 23, tag: VERB, rank_score: -0.06456422805786133}
# {word: required, index: 13, tag: ADJ, rank_score: 0.0590970516204834}
# {word: years, index: 21, tag: NOUN, rank_score: -0.05086570978164673}
#
# ['ADJ']
# {word: not, index: 8, tag: ADV, rank_score: -0.323130339384079}
# {word: if, index: 0, tag: ADP, rank_score: 0.12964820861816406}
# {word: interested, index: 18, tag: ADJ, rank_score: 0.0691724419593811}
# {word: your, index: 13, tag: PRON, rank_score: 0.06282937526702881}
#
# ['ADJ']
# {word: a, index: 17, tag: DET, rank_score: -0.10407805442810059}
# {word: revolution, index: 15, tag: NOUN, rank_score: -0.095955491065979}
# {word: film, index: 19, tag: NOUN, rank_score: -0.08741599321365356}
# {word: into, index: 11, tag: ADP, rank_score: -0.05965059995651245}
#
# ['ADJ']
# {word: interesting, index: 26, tag: ADJ, rank_score: -0.07778608798980713}
# {word: and, index: 27, tag: CONJ, rank_score: -0.038306355476379395}
# {word: on, index: 24, tag: ADP, rank_score: 0.028208911418914795}
# {word: depends, index: 21, tag: VERB, rank_score: 0.024460315704345703}
#
# ['ADJ']
# {word: powerful, index: 24, tag: ADJ, rank_score: -0.031717002391815186}
# {word: emotional, index: 25, tag: ADJ, rank_score: -0.0036610960960388184}
# {word: determination, index: 1, tag: NOUN, rank_score: -0.002744138240814209}
# {word: of, index: 2, tag: ADP, rank_score: -0.002488255500793457}
#
# ['ADJ']
# {word: slip, index: 21, tag: VERB, rank_score: -0.03951573371887207}
# {word: play-doh, index: 8, tag: ADJ, rank_score: -0.016270935535430908}
# {word: the, index: 9, tag: DET, rank_score: -0.010452091693878174}
# {word: lump, index: 6, tag: NOUN, rank_score: -0.008330345153808594}
#
# ['ADJ']
# {word: ozpetek, index: 0, tag: NOUN, rank_score: 0.018541038036346436}
# {word: elude, index: 21, tag: VERB, rank_score: -0.016117572784423828}
# {word: joins, index: 1, tag: VERB, rank_score: -0.010277271270751953}
# {word: in, index: 18, tag: ADP, rank_score: -0.009900927543640137}
#
# ['ADJ']
# {word: creates, index: 11, tag: VERB, rank_score: -0.11972951889038086}
# {word: welcome, index: 25, tag: ADJ, rank_score: -0.08477562665939331}
# {word: mournful, index: 17, tag: ADJ, rank_score: -0.0841517448425293}
# {word: that, index: 19, tag: DET, rank_score: -0.08021575212478638}
#
# ['ADJ']
# {word: gorgeous, index: 21, tag: ADJ, rank_score: -0.04705911874771118}
# {word: is, index: 19, tag: VERB, rank_score: -0.015083491802215576}
# {word: minimalist, index: 24, tag: NOUN, rank_score: 0.00811845064163208}
# {word: a, index: 20, tag: DET, rank_score: -0.005539417266845703}
#
# ['ADJ']
# {word: ability, index: 21, tag: NOUN, rank_score: -0.07466548681259155}
# {word: and, index: 25, tag: CONJ, rank_score: -0.03597605228424072}
# {word: films, index: 18, tag: NOUN, rank_score: 0.0203477144241333}
# {word: when, index: 9, tag: ADV, rank_score: -0.019673168659210205}
#
# ['ADJ']
# {word: blab, index: 16, tag: NOUN, rank_score: -0.18190842866897583}
# {word: jaglomized, index: 3, tag: VERB, rank_score: -0.08077585697174072}
# {word: is, index: 4, tag: VERB, rank_score: 0.05056828260421753}
# {word: spree, index: 12, tag: NOUN, rank_score: -0.039030611515045166}
#
# ['ADJ']
# {word: charming, index: 21, tag: ADJ, rank_score: -0.2633303999900818}
# {word: result, index: 22, tag: NOUN, rank_score: -0.054507434368133545}
# {word: the, index: 20, tag: DET, rank_score: -0.036460936069488525}
# {word: festival, index: 24, tag: ADJ, rank_score: -0.023060917854309082}
#
# ['ADJ']
# {word: haphazard, index: 25, tag: NOUN, rank_score: -0.020753145217895508}
# {word: from, index: 11, tag: ADP, rank_score: -0.016339361667633057}
# {word: to, index: 22, tag: PRT, rank_score: -0.0037552714347839355}
# {word: quality, index: 18, tag: NOUN, rank_score: 0.0032337307929992676}
#
# ['ADJ']
# {word: and, index: 21, tag: CONJ, rank_score: -0.010050833225250244}
# {word: to, index: 15, tag: PRT, rank_score: 0.007109582424163818}
# {word: too, index: 17, tag: ADV, rank_score: -0.00614398717880249}
# {word: pessimistic, index: 20, tag: ADJ, rank_score: -0.005761504173278809}
#
# ['ADJ']
# {word: pseudo-sophisticated, index: 9, tag: ADJ, rank_score: -0.08746218681335449}
# {word: and, index: 8, tag: CONJ, rank_score: -0.025998473167419434}
# {word: patter, index: 7, tag: NOUN, rank_score: -0.020467758178710938}
# {word: half, index: 0, tag: NOUN, rank_score: -0.016572892665863037}
#
# ['ADJ']
# {word: would, index: 18, tag: VERB, rank_score: -0.24751603603363037}
# {word: a, index: 24, tag: DET, rank_score: -0.044768691062927246}
# {word: more, index: 20, tag: ADJ, rank_score: -0.036102116107940674}
# {word: television, index: 26, tag: NOUN, rank_score: 0.017626523971557617}
#
# ['ADJ']
# {word: eventually, index: 23, tag: ADV, rank_score: -0.27418529987335205}
# {word: muffled, index: 21, tag: VERB, rank_score: -0.19073528051376343}
# {word: lulling, index: 26, tag: ADJ, rank_score: -0.17417752742767334}
# {word: plot, index: 11, tag: NOUN, rank_score: -0.15274912118911743}
#
# ['ADJ']
# {word: not, index: 0, tag: ADV, rank_score: -0.2702101469039917}
# {word: much, index: 2, tag: ADV, rank_score: -0.0779803991317749}
# {word: for, index: 9, tag: ADP, rank_score: -0.01670098304748535}
# {word: so, index: 1, tag: ADV, rank_score: 0.01045900583267212}
#
# ['ADJ']
# {word: enjoyed, index: 24, tag: VERB, rank_score: -0.2698802053928375}
# {word: series, index: 21, tag: NOUN, rank_score: -0.09438532590866089}
# {word: recommend, index: 28, tag: VERB, rank_score: 0.08332443237304688}
# {word: n't, index: 16, tag: ADV, rank_score: 0.0690266489982605}
#
# ['ADJ']
# {word: that, index: 16, tag: DET, rank_score: -0.024452686309814453}
# {word: movie, index: 15, tag: NOUN, rank_score: -0.01605522632598877}
# {word: straightforward, index: 0, tag: NOUN, rank_score: -0.011977314949035645}
# {word: a, index: 14, tag: DET, rank_score: -0.009970128536224365}
#
# ['ADJ']
# {word: movie, index: 7, tag: NOUN, rank_score: -0.007820963859558105}
# {word: which, index: 9, tag: DET, rank_score: -0.005209803581237793}
# {word: self-indulgent, index: 3, tag: ADJ, rank_score: 0.004817783832550049}
# {word: mess, index: 4, tag: NOUN, rank_score: -0.004481613636016846}
#
# ['ADJ']
# {word: meaningless, index: 28, tag: NOUN, rank_score: -0.1063883900642395}
# {word: prattle, index: 29, tag: NOUN, rank_score: -0.04771190881729126}
# {word: cacophony, index: 25, tag: NOUN, rank_score: 0.029055297374725342}
# {word: of, index: 26, tag: ADP, rank_score: 0.022474348545074463}
#
# ['ADJ']
# {word: chokes, index: 17, tag: VERB, rank_score: -0.10818952322006226}
# {word: that, index: 15, tag: ADP, rank_score: -0.030933499336242676}
# {word: allegedly, index: 4, tag: ADV, rank_score: -0.02171015739440918}
# {word: like, index: 0, tag: ADP, rank_score: 0.02005636692047119}
#
# ['ADJ']
# {word: is, index: 16, tag: VERB, rank_score: -0.26530155539512634}
# {word: to, index: 7, tag: PRT, rank_score: -0.20030942559242249}
# {word: best, index: 3, tag: ADJ, rank_score: 0.19635695219039917}
# {word: not, index: 13, tag: ADV, rank_score: -0.18279367685317993}
#
# ['ADJ']
# {word: 'possession, index: 0, tag: NOUN, rank_score: -0.1512465476989746}
# {word: by, index: 6, tag: ADP, rank_score: 0.06198650598526001}
# {word: book, index: 5, tag: NOUN, rank_score: -0.055656492710113525}
# {word: on, index: 3, tag: ADP, rank_score: -0.045722007751464844}
#
# ['ADJ']
# {word: demands, index: 12, tag: NOUN, rank_score: -0.3385187089443207}
# {word: a, index: 29, tag: DET, rank_score: 0.22693324089050293}
# {word: that, index: 13, tag: ADP, rank_score: -0.1983412802219391}
# {word: labute, index: 14, tag: ADJ, rank_score: -0.18945321440696716}
#
# ['ADJ']
# {word: powerful, index: 28, tag: ADJ, rank_score: -0.34453240036964417}
# {word: but, index: 25, tag: CONJ, rank_score: -0.2652994990348816}
# {word: you, index: 0, tag: PRON, rank_score: -0.25742247700691223}
# {word: watch, index: 34, tag: VERB, rank_score: -0.25573381781578064}
#
# ['ADJ']
# {word: is, index: 2, tag: VERB, rank_score: -0.026482343673706055}
# {word: version, index: 17, tag: NOUN, rank_score: -0.026114225387573242}
# {word: a, index: 11, tag: DET, rank_score: 0.02342003583908081}
# {word: what, index: 0, tag: PRON, rank_score: -0.023222029209136963}
#
# ['ADJ']
# {word: appealing, index: 23, tag: VERB, rank_score: -0.5406365990638733}
# {word: she, index: 26, tag: PRON, rank_score: -0.23440343141555786}
# {word: the, index: 19, tag: DET, rank_score: -0.22622883319854736}
# {word: evolved, index: 2, tag: VERB, rank_score: -0.1960131824016571}
#
# ['ADJ']
# {word: great, index: 13, tag: ADJ, rank_score: -0.32007521390914917}
# {word: you, index: 8, tag: PRON, rank_score: -0.20469146966934204}
# {word: and, index: 11, tag: CONJ, rank_score: -0.09941500425338745}
# {word: both, index: 9, tag: DET, rank_score: -0.04902547597885132}
#
# ['ADJ']
# {word: velma, index: 30, tag: NOUN, rank_score: -0.2174776792526245}
# {word: lost, index: 35, tag: VERB, rank_score: -0.19841372966766357}
# {word: 're, index: 19, tag: VERB, rank_score: -0.14263904094696045}
# {word: too, index: 20, tag: ADV, rank_score: -0.12520939111709595}
#
# ['ADJ']
# {word: revelatory, index: 9, tag: NOUN, rank_score: -0.16370046138763428}
# {word: inspiring, index: 6, tag: VERB, rank_score: -0.12940478324890137}
# {word: of, index: 10, tag: ADP, rank_score: -0.10945850610733032}
# {word: and, index: 8, tag: CONJ, rank_score: -0.03542119264602661}
#
# ['ADJ']
# {word: integrity, index: 29, tag: NOUN, rank_score: -0.008278846740722656}
# {word: and, index: 30, tag: CONJ, rank_score: -0.0043451786041259766}
# {word: band, index: 34, tag: NOUN, rank_score: -0.0024369359016418457}
# {word: testament, index: 26, tag: NOUN, rank_score: -0.0023387670516967773}
#
# ['ADJ']
# {word: in, index: 10, tag: ADP, rank_score: -0.026802539825439453}
# {word: our, index: 3, tag: PRON, rank_score: -0.017040371894836426}
# {word: reveals, index: 0, tag: NOUN, rank_score: -0.011564910411834717}
# {word: service, index: 11, tag: NOUN, rank_score: -0.010578691959381104}
#
# ['ADJ']
# {word: deeply, index: 20, tag: ADV, rank_score: -0.04413849115371704}
# {word: that, index: 30, tag: DET, rank_score: -0.043400704860687256}
# {word: shows, index: 18, tag: VERB, rank_score: -0.024159789085388184}
# {word: how, index: 19, tag: ADV, rank_score: 0.013545453548431396}
#
# ['ADJ']
# {word: resonate, index: 13, tag: VERB, rank_score: -0.45349520444869995}
# {word: who, index: 23, tag: PRON, rank_score: -0.3557921051979065}
# {word: verve, index: 16, tag: NOUN, rank_score: -0.16307514905929565}
# {word: to, index: 17, tag: PRT, rank_score: -0.09919536113739014}
#
# ['ADJ']
# {word: drab, index: 32, tag: ADJ, rank_score: -0.071408212184906}
# {word: inexpressible, index: 30, tag: ADJ, rank_score: -0.06922721862792969}
# {word: wannabe, index: 33, tag: NOUN, rank_score: 0.0233534574508667}
# {word: an, index: 29, tag: DET, rank_score: 0.022867918014526367}
#
# ['ADJ']
# {word: fascinating, index: 3, tag: ADJ, rank_score: -0.0025606155395507812}
# {word: extraordinary, index: 25, tag: ADJ, rank_score: -0.0012685656547546387}
# {word: who, index: 10, tag: PRON, rank_score: -0.0012198090553283691}
# {word: profile, index: 4, tag: NOUN, rank_score: -0.0010325908660888672}
#
# ['ADJ']
# {word: feat, index: 39, tag: NOUN, rank_score: -0.3737124800682068}
# {word: pulls, index: 36, tag: VERB, rank_score: -0.30221498012542725}
# {word: aplomb, index: 41, tag: NOUN, rank_score: 0.06800681352615356}
# {word: steal, index: 8, tag: VERB, rank_score: 0.06135690212249756}
#
# ['ADJ']
# {word: frustration, index: 46, tag: NOUN, rank_score: -0.3035237789154053}
# {word: in, index: 45, tag: ADP, rank_score: -0.28579968214035034}
# {word: screen, index: 44, tag: NOUN, rank_score: -0.27974241971969604}
# {word: i, index: 21, tag: NOUN, rank_score: -0.12749290466308594}
#
# ['ADJ']
# {word: but, index: 10, tag: CONJ, rank_score: -0.1475943922996521}
# {word: out, index: 23, tag: ADP, rank_score: -0.12529343366622925}
# {word: flicks, index: 19, tag: NOUN, rank_score: -0.11934125423431396}
# {word: great, index: 8, tag: ADJ, rank_score: 0.09740984439849854}
#
# ['ADJ']
# {word: pleasant, index: 39, tag: ADJ, rank_score: -0.523370623588562}
# {word: is, index: 33, tag: VERB, rank_score: -0.19119948148727417}
# {word: movie, index: 31, tag: NOUN, rank_score: -0.1708536148071289}
# {word: is, index: 29, tag: VERB, rank_score: -0.13850051164627075}
#
# :: 12 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 0 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %%
templates3 = tg3.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 118 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: than, index: 7, tag: ADP, rank_score: -0.9492137432098389}
# {word: delivers, index: 4, tag: NOUN, rank_score: -0.1357308030128479}
# {word: charm, index: 3, tag: NOUN, rank_score: -0.05397576093673706}
# {word: goodies, index: 6, tag: NOUN, rank_score: -0.04204082489013672}
#
# ['ADJ']
# {word: skip, index: 0, tag: VERB, rank_score: -0.16566622257232666}
# {word: buy, index: 4, tag: VERB, rank_score: -0.05741769075393677}
# {word: soundtrack, index: 8, tag: NOUN, rank_score: 0.028899729251861572}
# {word: the, index: 1, tag: DET, rank_score: 0.021614551544189453}
#
# ['ADJ']
# {word: lapses, index: 4, tag: VERB, rank_score: -0.7677843570709229}
# {word: casually, index: 6, tag: ADV, rank_score: -0.1309245228767395}
# {word: into, index: 7, tag: ADP, rank_score: -0.07934045791625977}
# {word: involving, index: 0, tag: VERB, rank_score: 0.04741638898849487}
#
# ['ADJ']
# {word: goes, index: 9, tag: VERB, rank_score: -0.13481885194778442}
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.07750606536865234}
# {word: while, index: 0, tag: ADP, rank_score: -0.033645570278167725}
# {word: great, index: 5, tag: ADJ, rank_score: 0.011000871658325195}
#
# ['ADJ']
# {word: n't, index: 8, tag: ADV, rank_score: -0.5304847955703735}
# {word: that, index: 6, tag: DET, rank_score: -0.49026110768318176}
# {word: infantilized, index: 4, tag: ADJ, rank_score: -0.47733157873153687}
# {word: infantile, index: 10, tag: ADJ, rank_score: -0.4741476774215698}
#
# ['ADJ']
# {word: neglected, index: 10, tag: VERB, rank_score: -0.07592552900314331}
# {word: criminally, index: 9, tag: ADV, rank_score: 0.006301164627075195}
# {word: half, index: 3, tag: NOUN, rank_score: -0.0036278963088989258}
# {word: half, index: 0, tag: NOUN, rank_score: -0.0026997923851013184}
#
# ['ADJ']
# {word: intelligent, index: 0, tag: ADJ, rank_score: -0.38076797127723694}
# {word: on, index: 3, tag: ADP, rank_score: -0.36160558462142944}
# {word: take, index: 2, tag: NOUN, rank_score: -0.35228511691093445}
# {word: writer, index: 6, tag: NOUN, rank_score: 0.24448877573013306}
#
# ['ADJ']
# {word: warmth, index: 10, tag: NOUN, rank_score: -0.015053033828735352}
# {word: and, index: 9, tag: CONJ, rank_score: -0.008161783218383789}
# {word: it, index: 3, tag: PRON, rank_score: -0.007769167423248291}
# {word: with, index: 7, tag: ADP, rank_score: -0.0065975189208984375}
#
# ['ADJ']
# {word: n't, index: 2, tag: ADV, rank_score: -0.18930578231811523}
# {word: two-hour, index: 9, tag: ADJ, rank_score: 0.0038297176361083984}
# {word: ., index: 12, tag: ., rank_score: 0.003495633602142334}
# {word: its, index: 8, tag: PRON, rank_score: 0.003388702869415283}
#
# ['ADJ']
# {word: profound, index: 8, tag: ADJ, rank_score: -0.008959472179412842}
# {word: and, index: 7, tag: CONJ, rank_score: -0.002443671226501465}
# {word: work, index: 1, tag: NOUN, rank_score: -0.0023052096366882324}
# {word: a, index: 0, tag: DET, rank_score: -0.001770317554473877}
#
# ['ADJ']
# {word: smart, index: 0, tag: NOUN, rank_score: -0.41260862350463867}
# {word: gem, index: 11, tag: NOUN, rank_score: -0.2647606134414673}
# {word: and, index: 1, tag: CONJ, rank_score: -0.20108091831207275}
# {word: alert, index: 2, tag: NOUN, rank_score: -0.1467406153678894}
#
# ['ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.12182062864303589}
# {word: thriller, index: 7, tag: NOUN, rank_score: -0.013362646102905273}
# {word: sign, index: 4, tag: NOUN, rank_score: -0.005409061908721924}
# {word: know, index: 11, tag: VERB, rank_score: 0.005400478839874268}
#
# ['ADJ']
# {word: rare, index: 1, tag: ADJ, rank_score: -0.5209622383117676}
# {word: the, index: 0, tag: DET, rank_score: -0.5197314023971558}
# {word: 'll, index: 6, tag: VERB, rank_score: -0.28227123618125916}
# {word: was, index: 8, tag: VERB, rank_score: 0.21750128269195557}
#
# ['ADJ']
# {word: refreshingly, index: 10, tag: ADV, rank_score: -0.013388872146606445}
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.009441375732421875}
# {word: no, index: 1, tag: DET, rank_score: -0.007485389709472656}
# {word: a, index: 9, tag: DET, rank_score: -0.004181325435638428}
#
# ['ADJ']
# {word: stifling, index: 9, tag: VERB, rank_score: -0.003626525402069092}
# {word: falsehoods, index: 0, tag: NOUN, rank_score: 0.0018827319145202637}
# {word: undermining, index: 3, tag: VERB, rank_score: -0.0013478398323059082}
# {word: the, index: 4, tag: DET, rank_score: -0.001219332218170166}
#
# ['ADJ']
# {word: bold, index: 10, tag: ADJ, rank_score: -0.0986243486404419}
# {word: put, index: 7, tag: VERB, rank_score: 0.01106935739517212}
# {word: fantasia, index: 12, tag: NOUN, rank_score: -0.010750353336334229}
# {word: directors, index: 0, tag: NOUN, rank_score: 0.010158121585845947}
#
# ['ADJ']
# {word: one, index: 0, tag: NUM, rank_score: -0.03300070762634277}
# {word: of, index: 1, tag: ADP, rank_score: -0.016363680362701416}
# {word: best, index: 5, tag: ADJ, rank_score: -0.014281392097473145}
# {word: featuring, index: 7, tag: VERB, rank_score: -0.0029816031455993652}
#
# ['ADJ']
# {word: with, index: 4, tag: ADP, rank_score: -0.00574946403503418}
# {word: raffish, index: 8, tag: ADJ, rank_score: 0.002405107021331787}
# {word: comic, index: 6, tag: ADJ, rank_score: 0.0021178126335144043}
# {word: ., index: 13, tag: ., rank_score: 0.0019391179084777832}
#
# ['ADJ']
# {word: clunker, index: 11, tag: NOUN, rank_score: -0.08731681108474731}
# {word: nonetheless, index: 12, tag: ADV, rank_score: 0.05660957098007202}
# {word: clunker, index: 8, tag: NOUN, rank_score: 0.03719359636306763}
# {word: a, index: 4, tag: DET, rank_score: -0.030503511428833008}
#
# ['ADJ']
# {word: this, index: 0, tag: DET, rank_score: 0.004321575164794922}
# {word: has, index: 10, tag: VERB, rank_score: 0.0037875771522521973}
# {word: its, index: 11, tag: PRON, rank_score: 0.0029035210609436035}
# {word: love, index: 9, tag: NOUN, rank_score: 0.0027217864990234375}
#
# ['ADJ']
# {word: there, index: 0, tag: DET, rank_score: -0.17408674955368042}
# {word: delightfully, index: 3, tag: ADV, rank_score: 0.07477313280105591}
# {word: movie, index: 5, tag: NOUN, rank_score: 0.07276302576065063}
# {word: to, index: 6, tag: PRT, rank_score: 0.0701492428779602}
#
# ['ADJ']
# {word: like, index: 3, tag: ADP, rank_score: -0.48194098472595215}
# {word: satisfies, index: 2, tag: NOUN, rank_score: -0.4634692370891571}
# {word: old-fashioned, index: 4, tag: ADJ, rank_score: 0.4250797629356384}
# {word: sometimes, index: 0, tag: ADV, rank_score: -0.3635944128036499}
#
# ['ADJ']
# {word: delivers, index: 13, tag: NOUN, rank_score: -0.5631450414657593}
# {word: and, index: 7, tag: CONJ, rank_score: -0.038094162940979004}
# {word: this, index: 9, tag: DET, rank_score: -0.022512376308441162}
# {word: regard, index: 10, tag: NOUN, rank_score: 0.00884091854095459}
#
# ['ADJ']
# {word: the, index: 0, tag: DET, rank_score: -0.21776646375656128}
# {word: linger, index: 7, tag: VERB, rank_score: -0.12674778699874878}
# {word: long, index: 8, tag: ADV, rank_score: -0.11633318662643433}
# {word: ended, index: 13, tag: VERB, rank_score: -0.10039925575256348}
#
# ['ADJ']
# {word: too, index: 3, tag: ADV, rank_score: -0.26085716485977173}
# {word: creating, index: 6, tag: VERB, rank_score: -0.06743192672729492}
# {word: labored, index: 13, tag: ADJ, rank_score: -0.01576077938079834}
# {word: perhaps, index: 2, tag: ADV, rank_score: 0.006930649280548096}
#
# ['ADJ']
# {word: flounders, index: 8, tag: NOUN, rank_score: -0.818268358707428}
# {word: some, index: 2, tag: DET, rank_score: -0.26299721002578735}
# {word: ., index: 15, tag: ., rank_score: -0.1090080738067627}
# {word: delivers, index: 1, tag: VERB, rank_score: 0.10272198915481567}
#
# ['ADJ']
# {word: rich, index: 1, tag: ADJ, rank_score: -0.03513425588607788}
# {word: tale, index: 2, tag: NOUN, rank_score: -0.013247311115264893}
# {word: a, index: 0, tag: DET, rank_score: -0.009898364543914795}
# {word: minimum, index: 12, tag: NOUN, rank_score: 0.008745968341827393}
#
# ['ADJ']
# {word: achieves, index: 0, tag: VERB, rank_score: -0.004552185535430908}
# {word: revels, index: 7, tag: VERB, rank_score: -0.0024546384811401367}
# {word: that, index: 6, tag: DET, rank_score: -0.002122640609741211}
# {word: potential, index: 11, tag: NOUN, rank_score: -0.0015141963958740234}
#
# ['ADJ']
# {word: dull, index: 2, tag: ADJ, rank_score: -0.1939249038696289}
# {word: procession, index: 3, tag: NOUN, rank_score: -0.14840620756149292}
# {word: of, index: 4, tag: ADP, rank_score: -0.0021178722381591797}
# {word: despair, index: 5, tag: NOUN, rank_score: 0.0020530223846435547}
#
# ['ADJ']
# {word: and, index: 4, tag: CONJ, rank_score: -0.0011129975318908691}
# {word: 'spectacular, index: 12, tag: ADJ, rank_score: -0.001071929931640625}
# {word: add, index: 8, tag: VERB, rank_score: -0.0005705356597900391}
# {word: spectacle, index: 13, tag: NOUN, rank_score: -0.00029224157333374023}
#
# ['ADJ']
# {word: fascinating, index: 1, tag: ADJ, rank_score: -0.0023780465126037598}
# {word: delicious, index: 10, tag: ADJ, rank_score: -0.002008378505706787}
# {word: a, index: 0, tag: DET, rank_score: -0.0016881227493286133}
# {word: keeps, index: 5, tag: VERB, rank_score: -0.0014304518699645996}
#
# ['ADJ']
# {word: cussing, index: 8, tag: NOUN, rank_score: -0.05281037092208862}
# {word: filled, index: 2, tag: VERB, rank_score: -0.009767413139343262}
# {word: than, index: 9, tag: ADP, rank_score: 0.006990194320678711}
# {word: beatings, index: 5, tag: NOUN, rank_score: 0.0059729814529418945}
#
# ['ADJ']
# {word: as, index: 1, tag: ADV, rank_score: -0.07831442356109619}
# {word: about, index: 0, tag: ADV, rank_score: -0.05079245567321777}
# {word: sweating, index: 6, tag: VERB, rank_score: -0.02037733793258667}
# {word: gangster, index: 5, tag: NOUN, rank_score: 0.008733928203582764}
#
# ['ADJ']
# {word: bad, index: 7, tag: ADJ, rank_score: -0.012041032314300537}
# {word: country, index: 2, tag: NOUN, rank_score: -0.009274661540985107}
# {word: be, index: 5, tag: VERB, rank_score: -0.005185365676879883}
# {word: the, index: 1, tag: DET, rank_score: -0.004361510276794434}
#
# ['ADJ']
# {word: a, index: 13, tag: DET, rank_score: 0.3324231505393982}
# {word: word, index: 14, tag: NOUN, rank_score: 0.2660994529724121}
# {word: ., index: 17, tag: ., rank_score: 0.2114201784133911}
# {word: yes, index: 16, tag: X, rank_score: 0.19722110033035278}
#
# ['ADJ']
# {word: generic, index: 3, tag: ADJ, rank_score: -0.03717076778411865}
# {word: has, index: 2, tag: VERB, rank_score: -0.0026357173919677734}
# {word: talent, index: 11, tag: NOUN, rank_score: -0.0020430684089660645}
# {word: despite, index: 6, tag: ADP, rank_score: -0.0015309453010559082}
#
# ['ADJ']
# {word: n't, index: 1, tag: ADV, rank_score: -0.24486255645751953}
# {word: limited, index: 9, tag: ADJ, rank_score: -0.005233108997344971}
# {word: chemistry, index: 10, tag: NOUN, rank_score: -0.001269221305847168}
# {word: get, index: 2, tag: VERB, rank_score: -0.0011662840843200684}
#
# ['ADJ']
# {word: cliches, index: 15, tag: NOUN, rank_score: -0.49514663219451904}
# {word: crisp, index: 4, tag: ADJ, rank_score: -0.487467497587204}
# {word: genre, index: 14, tag: NOUN, rank_score: -0.4524213373661041}
# {word: false, index: 9, tag: ADJ, rank_score: 0.3552324175834656}
#
# ['ADJ']
# {word: awful, index: 5, tag: ADJ, rank_score: -0.6739517450332642}
# {word: disguise, index: 3, tag: NOUN, rank_score: -0.005597889423370361}
# {word: is, index: 4, tag: VERB, rank_score: -0.00537562370300293}
# {word: of, index: 2, tag: ADP, rank_score: 0.0017015933990478516}
#
# ['ADJ']
# {word: awful, index: 11, tag: NOUN, rank_score: -0.06676352024078369}
# {word: it, index: 7, tag: PRON, rank_score: -0.0008382201194763184}
# {word: ., index: 12, tag: ., rank_score: -0.000736236572265625}
# {word: pauly, index: 9, tag: ADV, rank_score: 0.0003917813301086426}
#
# ['ADJ']
# {word: warned, index: 19, tag: VERB, rank_score: 0.11059099435806274}
# {word: you, index: 16, tag: PRON, rank_score: 0.10402154922485352}
# {word: were, index: 17, tag: VERB, rank_score: 0.08154577016830444}
# {word: n't, index: 18, tag: ADV, rank_score: 0.07077533006668091}
#
# ['ADJ']
# {word: still, index: 15, tag: ADV, rank_score: -0.13538408279418945}
# {word: it, index: 5, tag: PRON, rank_score: -0.08583205938339233}
# {word: and, index: 13, tag: CONJ, rank_score: -0.06157404184341431}
# {word: deserved, index: 6, tag: VERB, rank_score: -0.04274171590805054}
#
# ['ADJ']
# {word: it, index: 11, tag: PRON, rank_score: -0.0720018744468689}
# {word: love, index: 2, tag: VERB, rank_score: -0.05479741096496582}
# {word: check, index: 10, tag: VERB, rank_score: -0.052541494369506836}
# {word: poetry, index: 5, tag: NOUN, rank_score: -0.05174356698989868}
#
# ['ADJ']
# {word: you, index: 14, tag: PRON, rank_score: -0.43131375312805176}
# {word: 'll, index: 15, tag: VERB, rank_score: -0.38244032859802246}
# {word: love, index: 17, tag: VERB, rank_score: -0.2852887809276581}
# {word: probably, index: 16, tag: ADV, rank_score: 0.2436525821685791}
#
# ['ADJ']
# {word: go, index: 3, tag: VERB, rank_score: -0.05450248718261719}
# {word: comedic, index: 1, tag: ADJ, rank_score: -0.015677034854888916}
# {word: notorious, index: 4, tag: ADJ, rank_score: -0.014812886714935303}
# {word: spotlights, index: 2, tag: NOUN, rank_score: -0.006215453147888184}
#
# ['ADJ']
# {word: all, index: 12, tag: DET, rank_score: -0.4242244362831116}
# {word: the, index: 13, tag: DET, rank_score: 0.302543580532074}
# {word: verbal, index: 14, tag: ADJ, rank_score: -0.2898210883140564}
# {word: it, index: 16, tag: PRON, rank_score: 0.17126590013504028}
#
# ['ADJ']
# {word: from, index: 4, tag: ADP, rank_score: -0.026741445064544678}
# {word: authenticity, index: 15, tag: NOUN, rank_score: -0.02667158842086792}
# {word: saved, index: 3, tag: VERB, rank_score: -0.02260977029800415}
# {word: unbearable, index: 5, tag: ADJ, rank_score: -0.020583391189575195}
#
# ['ADJ']
# {word: deftly, index: 6, tag: ADV, rank_score: -0.42983871698379517}
# {word: as, index: 14, tag: ADP, rank_score: -0.27456673979759216}
# {word: substance, index: 18, tag: NOUN, rank_score: 0.24645620584487915}
# {word: coloring, index: 15, tag: VERB, rank_score: -0.24113833904266357}
#
# ['ADJ']
# {word: worst, index: 7, tag: ADJ, rank_score: -0.6420825719833374}
# {word: 's, index: 12, tag: VERB, rank_score: -0.24983376264572144}
# {word: while, index: 0, tag: ADP, rank_score: -0.20971715450286865}
# {word: not, index: 4, tag: ADV, rank_score: -0.1672040820121765}
#
# ['ADJ']
# {word: empty, index: 1, tag: ADJ, rank_score: -0.0042632222175598145}
# {word: an, index: 0, tag: DET, rank_score: -0.0032927393913269043}
# {word: exercise, index: 2, tag: NOUN, rank_score: -0.0018534064292907715}
# {word: vapid, index: 7, tag: ADJ, rank_score: -0.0017055273056030273}
#
# ['ADJ']
# {word: versus, index: 18, tag: NOUN, rank_score: -0.028147459030151367}
# {word: sappy, index: 19, tag: ADJ, rank_score: 0.019535601139068604}
# {word: credit, index: 4, tag: NOUN, rank_score: 0.016565978527069092}
# {word: acting, index: 6, tag: NOUN, rank_score: 0.015777289867401123}
#
# ['ADJ']
# {word: never, index: 2, tag: ADV, rank_score: -0.8388519287109375}
# {word: gets, index: 3, tag: VERB, rank_score: -0.8214181661605835}
# {word: film, index: 1, tag: NOUN, rank_score: -0.024043738842010498}
# {word: own, index: 6, tag: ADJ, rank_score: -0.019572854042053223}
#
# ['ADJ']
# {word: and, index: 2, tag: CONJ, rank_score: -0.0038405656814575195}
# {word: expressively, index: 3, tag: ADV, rank_score: -0.0034694671630859375}
# {word: the, index: 5, tag: DET, rank_score: -0.003174424171447754}
# {word: elegantly, index: 0, tag: ADV, rank_score: -0.002657651901245117}
#
# ['ADJ']
# {word: sacrifices, index: 13, tag: VERB, rank_score: -0.855686366558075}
# {word: description, index: 5, tag: NOUN, rank_score: -0.43261516094207764}
# {word: promise, index: 15, tag: NOUN, rank_score: -0.06793361902236938}
# {word: its, index: 14, tag: PRON, rank_score: -0.05860263109207153}
#
# ['ADJ']
# {word: and, index: 7, tag: CONJ, rank_score: -0.08443945646286011}
# {word: scary, index: 8, tag: ADJ, rank_score: -0.06180918216705322}
# {word: an, index: 5, tag: DET, rank_score: -0.041527748107910156}
# {word: vengeance, index: 17, tag: NOUN, rank_score: -0.035311102867126465}
#
# ['ADJ']
# {word: so, index: 5, tag: ADV, rank_score: -0.04096454381942749}
# {word: consuming, index: 6, tag: ADJ, rank_score: -0.03873640298843384}
# {word: movie, index: 20, tag: NOUN, rank_score: -0.021543502807617188}
# {word: sometimes, index: 8, tag: VERB, rank_score: 0.013317584991455078}
#
# ['ADJ']
# {word: neglects, index: 18, tag: VERB, rank_score: -0.13993674516677856}
# {word: but, index: 16, tag: CONJ, rank_score: -0.10409873723983765}
# {word: it, index: 17, tag: PRON, rank_score: 0.05223965644836426}
# {word: others, index: 20, tag: NOUN, rank_score: 0.03980529308319092}
#
# ['ADJ']
# {word: n't, index: 13, tag: ADV, rank_score: -0.21154630184173584}
# {word: funeral, index: 3, tag: ADJ, rank_score: -0.024846017360687256}
# {word: and, index: 11, tag: CONJ, rank_score: -0.02286309003829956}
# {word: three, index: 19, tag: NUM, rank_score: -0.02180469036102295}
#
# ['ADJ']
# {word: but, index: 7, tag: CONJ, rank_score: -0.5732825994491577}
# {word: made, index: 12, tag: VERB, rank_score: -0.04934126138687134}
# {word: looks, index: 11, tag: NOUN, rank_score: -0.027713418006896973}
# {word: may, index: 0, tag: VERB, rank_score: -0.008753478527069092}
#
# ['ADJ']
# {word: pedestrian, index: 7, tag: ADJ, rank_score: -0.35612285137176514}
# {word: who, index: 12, tag: PRON, rank_score: -0.02542024850845337}
# {word: given, index: 5, tag: VERB, rank_score: -0.019006013870239258}
# {word: director, index: 11, tag: NOUN, rank_score: -0.014781653881072998}
#
# ['ADJ']
# {word: its, index: 1, tag: PRON, rank_score: -0.850312352180481}
# {word: at, index: 0, tag: ADP, rank_score: -0.01975107192993164}
# {word: larger-than-life, index: 9, tag: ADJ, rank_score: -0.0078095197677612305}
# {word: contemporary, index: 20, tag: ADJ, rank_score: -0.0040471553802490234}
#
# ['ADJ']
# {word: overcome, index: 8, tag: ADP, rank_score: 0.27089834213256836}
# {word: screenplay, index: 17, tag: NOUN, rank_score: -0.22985804080963135}
# {word: campanella, index: 0, tag: NOUN, rank_score: -0.2277444303035736}
# {word: of, index: 11, tag: ADP, rank_score: 0.20123136043548584}
#
# ['ADJ']
# {word: while, index: 12, tag: ADP, rank_score: -0.4818142056465149}
# {word: ``, index: 4, tag: ., rank_score: -0.30043864250183105}
# {word: decorates, index: 19, tag: VERB, rank_score: -0.24855482578277588}
# {word: courage, index: 5, tag: NOUN, rank_score: 0.12537777423858643}
#
# ['ADJ']
# {word: future, index: 2, tag: NOUN, rank_score: 0.26465070247650146}
# {word: hopes, index: 4, tag: VERB, rank_score: 0.25991272926330566}
# {word: for, index: 0, tag: ADP, rank_score: -0.08837974071502686}
# {word: the, index: 1, tag: DET, rank_score: 0.07815515995025635}
#
# ['ADJ']
# {word: will, index: 8, tag: VERB, rank_score: -0.02120763063430786}
# {word: screenwriter, index: 21, tag: NOUN, rank_score: -0.009249269962310791}
# {word: of, index: 15, tag: ADP, rank_score: -0.007899105548858643}
# {word: band, index: 18, tag: NOUN, rank_score: -0.005760014057159424}
#
# ['ADJ']
# {word: problem, index: 1, tag: NOUN, rank_score: -0.03297942876815796}
# {word: has, index: 8, tag: VERB, rank_score: -0.005173623561859131}
# {word: screenplay, index: 10, tag: NOUN, rank_score: -0.003606259822845459}
# {word: with, index: 2, tag: ADP, rank_score: -0.0028763413429260254}
#
# ['ADJ']
# {word: encourages, index: 2, tag: NOUN, rank_score: -0.2932751774787903}
# {word: laughter, index: 4, tag: NOUN, rank_score: -0.2627081871032715}
# {word: stereotypes, index: 6, tag: NOUN, rank_score: -0.08034276962280273}
# {word: at, index: 5, tag: ADP, rank_score: -0.07692086696624756}
#
# ['ADJ']
# {word: nothing, index: 20, tag: NOUN, rank_score: -0.23936015367507935}
# {word: in, index: 16, tag: ADP, rank_score: -0.12055319547653198}
# {word: new, index: 21, tag: ADJ, rank_score: 0.012765228748321533}
# {word: lesson, index: 15, tag: NOUN, rank_score: 0.011185884475708008}
#
# ['ADJ']
# {word: how, index: 15, tag: ADV, rank_score: -0.6486873626708984}
# {word: dangerous, index: 16, tag: ADJ, rank_score: -0.3342180848121643}
# {word: call, index: 1, tag: VERB, rank_score: -0.11406821012496948}
# {word: entertainments, index: 17, tag: NOUN, rank_score: -0.09148424863815308}
#
# ['ADJ']
# {word: better, index: 19, tag: ADV, rank_score: -0.5811103582382202}
# {word: imax, index: 16, tag: NOUN, rank_score: -0.3328501880168915}
# {word: it, index: 17, tag: PRON, rank_score: -0.2750374376773834}
# {word: just, index: 21, tag: ADV, rank_score: 0.24298208951950073}
#
# ['ADJ']
# {word: movie, index: 16, tag: NOUN, rank_score: -0.08700734376907349}
# {word: figure, index: 8, tag: VERB, rank_score: -0.0704241394996643}
# {word: preachy, index: 20, tag: NOUN, rank_score: -0.06524956226348877}
# {word: to, index: 7, tag: PRT, rank_score: -0.054362714290618896}
#
# ['ADJ']
# {word: seizures, index: 22, tag: NOUN, rank_score: -0.047220826148986816}
# {word: kept, index: 7, tag: VERB, rank_score: -0.023820459842681885}
# {word: watching, index: 0, tag: VERB, rank_score: -0.01566171646118164}
# {word: movie, index: 4, tag: NOUN, rank_score: -0.009975790977478027}
#
# ['ADJ']
# {word: captures, index: 0, tag: NOUN, rank_score: -0.2891750931739807}
# {word: wish, index: 13, tag: NOUN, rank_score: 0.006586670875549316}
# {word: confusing, index: 8, tag: VERB, rank_score: 0.006132900714874268}
# {word: all, index: 1, tag: DET, rank_score: 0.006085097789764404}
#
# ['ADJ']
# {word: riveting, index: 22, tag: ADJ, rank_score: -0.0797695517539978}
# {word: n't, index: 4, tag: ADV, rank_score: -0.06099647283554077}
# {word: always, index: 5, tag: ADV, rank_score: -0.012970566749572754}
# {word: but, index: 14, tag: CONJ, rank_score: -0.011506140232086182}
#
# ['ADJ']
# {word: undone, index: 3, tag: ADJ, rank_score: -0.07094871997833252}
# {word: cliched, index: 20, tag: VERB, rank_score: -0.007515609264373779}
# {word: enough, index: 12, tag: ADV, rank_score: 0.0040947794914245605}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.003880620002746582}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.44838300347328186}
# {word: through, index: 1, tag: ADP, rank_score: -0.15205258131027222}
# {word: one, index: 9, tag: NUM, rank_score: -0.1350409984588623}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.12890660762786865}
#
# ['ADJ']
# {word: make, index: 11, tag: VERB, rank_score: -0.0732414722442627}
# {word: in, index: 15, tag: ADP, rank_score: -0.03573507070541382}
# {word: in-depth, index: 1, tag: ADJ, rank_score: -0.030965983867645264}
# {word: viewing, index: 14, tag: NOUN, rank_score: -0.018995702266693115}
#
# ['ADJ']
# {word: this, index: 5, tag: DET, rank_score: -0.09749788045883179}
# {word: in, index: 19, tag: ADP, rank_score: -0.08494687080383301}
# {word: not, index: 8, tag: ADV, rank_score: -0.0831751823425293}
# {word: you, index: 6, tag: PRON, rank_score: -0.04519855976104736}
#
# ['ADJ']
# {word: than, index: 1, tag: ADP, rank_score: -0.028122425079345703}
# {word: simply, index: 2, tag: ADV, rank_score: -0.01450812816619873}
# {word: this, index: 9, tag: DET, rank_score: -0.009131133556365967}
# {word: into, index: 11, tag: ADP, rank_score: -0.005983710289001465}
#
# ['ADJ']
# {word: depends, index: 21, tag: VERB, rank_score: 0.3209051489830017}
# {word: likable, index: 28, tag: ADJ, rank_score: 0.23966139554977417}
# {word: find, index: 30, tag: VERB, rank_score: 0.20495200157165527}
# {word: much, index: 1, tag: ADJ, rank_score: 0.20192867517471313}
#
# ['ADJ']
# {word: pack, index: 22, tag: NOUN, rank_score: -0.0008285045623779297}
# {word: a, index: 23, tag: DET, rank_score: -0.0006580352783203125}
# {word: powerful, index: 24, tag: ADJ, rank_score: -0.0006326436996459961}
# {word: ., index: 27, tag: ., rank_score: 0.0006101727485656738}
#
# ['ADJ']
# {word: slip, index: 21, tag: VERB, rank_score: -0.00947427749633789}
# {word: story, index: 17, tag: NOUN, rank_score: -0.005331933498382568}
# {word: play-doh, index: 8, tag: ADJ, rank_score: -0.0039041638374328613}
# {word: out, index: 22, tag: PRT, rank_score: -0.0030289292335510254}
#
# ['ADJ']
# {word: culture, index: 17, tag: NOUN, rank_score: -0.004374086856842041}
# {word: same-sex, index: 16, tag: ADJ, rank_score: 0.0037467479705810547}
# {word: ways, index: 19, tag: NOUN, rank_score: -0.003674328327178955}
# {word: experience, index: 13, tag: NOUN, rank_score: -0.0034560561180114746}
#
# ['ADJ']
# {word: creates, index: 11, tag: VERB, rank_score: -0.24424564838409424}
# {word: places, index: 20, tag: VERB, rank_score: -0.15121251344680786}
# {word: perspective, index: 26, tag: NOUN, rank_score: -0.13455843925476074}
# {word: mournful, index: 17, tag: ADJ, rank_score: -0.13425391912460327}
#
# ['ADJ']
# {word: gorgeous, index: 21, tag: ADJ, rank_score: -0.45440465211868286}
# {word: poem, index: 27, tag: NOUN, rank_score: 0.07172155380249023}
# {word: concrete, index: 11, tag: ADJ, rank_score: 0.061951398849487305}
# {word: minimalist, index: 24, tag: NOUN, rank_score: 0.04884988069534302}
#
# ['ADJ']
# {word: time, index: 1, tag: NOUN, rank_score: 0.003931999206542969}
# {word: had, index: 19, tag: VERB, rank_score: 0.003290712833404541}
# {word: a, index: 0, tag: DET, rank_score: 0.002868056297302246}
# {word: when, index: 9, tag: ADV, rank_score: 0.0027543306350708008}
#
# ['ADJ']
# {word: blab, index: 16, tag: NOUN, rank_score: -0.6273382306098938}
# {word: jaglomized, index: 3, tag: VERB, rank_score: -0.04223072528839111}
# {word: made, index: 0, tag: VERB, rank_score: -0.013325810432434082}
# {word: to, index: 1, tag: PRT, rank_score: -0.007055878639221191}
#
# ['ADJ']
# {word: festival, index: 24, tag: ADJ, rank_score: -0.165330171585083}
# {word: charming, index: 21, tag: ADJ, rank_score: -0.04861879348754883}
# {word: in, index: 25, tag: ADP, rank_score: -0.020272672176361084}
# {word: is, index: 23, tag: VERB, rank_score: -0.006421267986297607}
#
# ['ADJ']
# {word: its, index: 23, tag: PRON, rank_score: 0.0027557015419006348}
# {word: nobody, index: 0, tag: NOUN, rank_score: 0.00261533260345459}
# {word: last-minute, index: 24, tag: ADJ, rank_score: 0.0021169185638427734}
# {word: seems, index: 1, tag: VERB, rank_score: -0.002008199691772461}
#
# ['ADJ']
# {word: well-intentioned, index: 3, tag: ADJ, rank_score: -0.1030268669128418}
# {word: as, index: 0, tag: ADP, rank_score: -0.06429624557495117}
# {word: film, index: 11, tag: NOUN, rank_score: -0.0631902813911438}
# {word: well-acted, index: 1, tag: ADJ, rank_score: 0.05400925874710083}
#
# ['ADJ']
# {word: patter, index: 7, tag: NOUN, rank_score: -0.024635612964630127}
# {word: and, index: 8, tag: CONJ, rank_score: -0.00951308012008667}
# {word: remainder, index: 14, tag: NOUN, rank_score: 0.005036652088165283}
# {word: pseudo-sophisticated, index: 9, tag: ADJ, rank_score: -0.004918336868286133}
#
# ['ADJ']
# {word: more, index: 20, tag: ADJ, rank_score: -0.00904548168182373}
# {word: serial, index: 27, tag: NOUN, rank_score: -0.008027374744415283}
# {word: home, index: 22, tag: NOUN, rank_score: -0.00791078805923462}
# {word: be, index: 19, tag: VERB, rank_score: -0.004042327404022217}
#
# ['ADJ']
# {word: lulling, index: 26, tag: ADJ, rank_score: -0.04225659370422363}
# {word: talk, index: 17, tag: NOUN, rank_score: -0.020527780055999756}
# {word: much, index: 14, tag: ADJ, rank_score: -0.018563926219940186}
# {word: eventually, index: 23, tag: ADV, rank_score: -0.016521930694580078}
#
# ['ADJ']
# {word: for, index: 9, tag: ADP, rank_score: -0.0725206732749939}
# {word: so, index: 1, tag: ADV, rank_score: 0.015975534915924072}
# {word: not, index: 0, tag: ADV, rank_score: -0.014176547527313232}
# {word: a, index: 3, tag: DET, rank_score: 0.011380255222320557}
#
# ['ADJ']
# {word: still, index: 22, tag: ADV, rank_score: -0.34108710289001465}
# {word: n't, index: 16, tag: ADV, rank_score: -0.188523530960083}
# {word: favorite, index: 18, tag: ADJ, rank_score: -0.06792265176773071}
# {word: recommend, index: 28, tag: VERB, rank_score: -0.0564117431640625}
#
# ['ADJ']
# {word: old-fashioned, index: 2, tag: ADJ, rank_score: 0.04251754283905029}
# {word: straightforward, index: 0, tag: NOUN, rank_score: 0.0340346097946167}
# {word: words, index: 11, tag: NOUN, rank_score: 0.029873192310333252}
# {word: possession, index: 12, tag: NOUN, rank_score: 0.029535651206970215}
#
# ['ADJ']
# {word: movie, index: 7, tag: NOUN, rank_score: -0.0012868642807006836}
# {word: for, index: 18, tag: ADP, rank_score: -0.0010986328125}
# {word: mess, index: 4, tag: NOUN, rank_score: -0.0009042620658874512}
# {word: incoherent, index: 2, tag: NOUN, rank_score: -0.0008203387260437012}
#
# ['ADJ']
# {word: cacophony, index: 25, tag: NOUN, rank_score: -0.00047272443771362305}
# {word: ., index: 30, tag: ., rank_score: 0.000240325927734375}
# {word: of, index: 26, tag: ADP, rank_score: -0.0002173781394958496}
# {word: prattle, index: 29, tag: NOUN, rank_score: -0.00021123886108398438}
#
# ['ADJ']
# {word: tangled, index: 10, tag: VERB, rank_score: -0.004223763942718506}
# {word: gets, index: 8, tag: VERB, rank_score: -0.0032791495323181152}
# {word: chokes, index: 17, tag: VERB, rank_score: -0.003023982048034668}
# {word: so, index: 9, tag: ADV, rank_score: -0.002753615379333496}
#
# ['ADJ']
# {word: examined, index: 18, tag: VERB, rank_score: -0.472969114780426}
# {word: best, index: 3, tag: ADJ, rank_score: -0.17518985271453857}
# {word: one, index: 0, tag: NUM, rank_score: -0.08231770992279053}
# {word: of, index: 1, tag: ADP, rank_score: -0.03204643726348877}
#
# ['ADJ']
# {word: by, index: 6, tag: ADP, rank_score: 0.11801379919052124}
# {word: based, index: 2, tag: VERB, rank_score: 0.10543292760848999}
# {word: book, index: 5, tag: NOUN, rank_score: 0.06863158941268921}
# {word: on, index: 3, tag: ADP, rank_score: 0.05120539665222168}
#
# ['ADJ']
# {word: a, index: 29, tag: DET, rank_score: -0.7525590062141418}
# {word: reverence, index: 27, tag: NOUN, rank_score: -0.35079383850097656}
# {word: byatt, index: 11, tag: VERB, rank_score: -0.2501755952835083}
# {word: cynicism, index: 25, tag: NOUN, rank_score: -0.2427997589111328}
#
# ['ADJ']
# {word: salute, index: 4, tag: VERB, rank_score: -0.216383695602417}
# {word: making, index: 16, tag: VERB, rank_score: -0.21157342195510864}
# {word: but, index: 25, tag: CONJ, rank_score: -0.08534961938858032}
# {word: powerful, index: 28, tag: ADJ, rank_score: -0.08205193281173706}
#
# ['ADJ']
# {word: is, index: 2, tag: VERB, rank_score: -0.07213187217712402}
# {word: annoying, index: 13, tag: ADJ, rank_score: -0.06841295957565308}
# {word: what, index: 0, tag: PRON, rank_score: -0.056524693965911865}
# {word: remains, index: 1, tag: VERB, rank_score: -0.04875302314758301}
#
# ['ADJ']
# {word: appealing, index: 23, tag: VERB, rank_score: -0.34491991996765137}
# {word: the, index: 19, tag: DET, rank_score: -0.14504438638687134}
# {word: not, index: 28, tag: ADV, rank_score: -0.11995846033096313}
# {word: means, index: 14, tag: VERB, rank_score: -0.09849798679351807}
#
# ['ADJ']
# {word: great, index: 13, tag: ADJ, rank_score: -0.18611019849777222}
# {word: and, index: 11, tag: CONJ, rank_score: -0.07078665494918823}
# {word: you, index: 8, tag: PRON, rank_score: -0.05417454242706299}
# {word: /, index: 7, tag: ADJ, rank_score: -0.02293705940246582}
#
# ['ADJ']
# {word: too, index: 20, tag: ADV, rank_score: -0.09688836336135864}
# {word: thinks, index: 24, tag: VERB, rank_score: -0.05103832483291626}
# {word: 're, index: 19, tag: VERB, rank_score: -0.0402907133102417}
# {word: lost, index: 35, tag: VERB, rank_score: -0.01787889003753662}
#
# ['ADJ']
# {word: industry, index: 18, tag: NOUN, rank_score: -0.10663449764251709}
# {word: revelatory, index: 9, tag: NOUN, rank_score: -0.05835700035095215}
# {word: inspiring, index: 6, tag: VERB, rank_score: -0.0384974479675293}
# {word: and, index: 8, tag: CONJ, rank_score: -0.012850522994995117}
#
# ['ADJ']
# {word: testament, index: 26, tag: NOUN, rank_score: -0.31308484077453613}
# {word: integrity, index: 29, tag: NOUN, rank_score: -0.009965002536773682}
# {word: and, index: 30, tag: CONJ, rank_score: -0.008832335472106934}
# {word: band, index: 34, tag: NOUN, rank_score: 0.007251918315887451}
#
# ['ADJ']
# {word: service, index: 11, tag: NOUN, rank_score: -0.0011994242668151855}
# {word: talents, index: 5, tag: NOUN, rank_score: -0.0011349320411682129}
# {word: our, index: 3, tag: PRON, rank_score: -0.0011074542999267578}
# {word: reveals, index: 0, tag: NOUN, rank_score: -0.0009487271308898926}
#
# ['ADJ']
# {word: separate, index: 33, tag: ADJ, rank_score: -0.0009132623672485352}
# {word: ., index: 35, tag: ., rank_score: 0.0005590319633483887}
# {word: deeply, index: 20, tag: ADV, rank_score: -0.0005429387092590332}
# {word: emotions, index: 22, tag: NOUN, rank_score: -0.00041800737380981445}
#
# ['ADJ']
# {word: verve, index: 16, tag: NOUN, rank_score: -0.35824328660964966}
# {word: whereas, index: 0, tag: ADP, rank_score: 0.2861941456794739}
# {word: resonate, index: 13, tag: VERB, rank_score: -0.273600697517395}
# {word: competent, index: 3, tag: ADJ, rank_score: 0.2515825629234314}
#
# ['ADJ']
# {word: wannabe, index: 33, tag: NOUN, rank_score: -0.003993809223175049}
# {word: inexpressible, index: 30, tag: ADJ, rank_score: -0.003873467445373535}
# {word: drab, index: 32, tag: ADJ, rank_score: -0.0016693472862243652}
# {word: niche, index: 38, tag: NOUN, rank_score: -0.0008341670036315918}
#
# ['ADJ']
# {word: fascinating, index: 3, tag: ADJ, rank_score: -0.0014585256576538086}
# {word: profile, index: 4, tag: NOUN, rank_score: -0.001374959945678711}
# {word: who, index: 10, tag: PRON, rank_score: -0.0013628005981445312}
# {word: idealistic, index: 21, tag: ADJ, rank_score: 0.0006827116012573242}
#
# ['ADJ']
# {word: aplomb, index: 41, tag: NOUN, rank_score: -0.052605390548706055}
# {word: managing, index: 6, tag: VERB, rank_score: 0.02118295431137085}
# {word: newcomer, index: 33, tag: ADJ, rank_score: 0.017576217651367188}
# {word: movie, index: 10, tag: NOUN, rank_score: 0.01652991771697998}
#
# ['ADJ']
# {word: frustration, index: 46, tag: NOUN, rank_score: -0.008037269115447998}
# {word: grab, index: 27, tag: VERB, rank_score: -0.006067037582397461}
# {word: funny, index: 18, tag: ADJ, rank_score: 0.004668891429901123}
# {word: was, index: 4, tag: VERB, rank_score: -0.0046274662017822266}
#
# ['ADJ']
# {word: most, index: 16, tag: ADJ, rank_score: -0.06381690502166748}
# {word: out, index: 23, tag: ADP, rank_score: -0.062011539936065674}
# {word: multiplex, index: 26, tag: NOUN, rank_score: -0.04800444841384888}
# {word: flicks, index: 19, tag: NOUN, rank_score: -0.034518659114837646}
#
# ['ADJ']
# {word: pleasant, index: 39, tag: ADJ, rank_score: -0.6891894340515137}
# {word: movie, index: 31, tag: NOUN, rank_score: -0.27742815017700195}
# {word: that, index: 32, tag: DET, rank_score: -0.17822390794754028}
# {word: is, index: 33, tag: VERB, rank_score: -0.1409725546836853}
#
# :: 15 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 4 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %%
templates4 = tg4.generate_templates(instances, n_masks=2, ranked_words_count=4)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 118 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['ADJ']
# {word: delivers, index: 4, tag: NOUN, rank_score: -0.6409180164337158}
# {word: than, index: 7, tag: ADP, rank_score: -0.20038652420043945}
# {word: charm, index: 3, tag: NOUN, rank_score: -0.03175818920135498}
# {word: coal, index: 10, tag: NOUN, rank_score: -0.031139791011810303}
#
# ['ADJ']
# {word: and, index: 3, tag: CONJ, rank_score: -0.4954366385936737}
# {word: cd, index: 9, tag: NOUN, rank_score: -0.3499169647693634}
# {word: film, index: 2, tag: NOUN, rank_score: -0.3317224979400635}
# {word: skip, index: 0, tag: VERB, rank_score: -0.28074198961257935}
#
# ['ADJ']
# {word: lapses, index: 4, tag: VERB, rank_score: -0.885071337223053}
# {word: absurd, index: 9, tag: NOUN, rank_score: -0.0652279257774353}
# {word: involving, index: 0, tag: VERB, rank_score: -0.03035956621170044}
# {word: into, index: 7, tag: ADP, rank_score: -0.02604728937149048}
#
# ['ADJ']
# {word: nowhere, index: 10, tag: ADV, rank_score: -0.233104407787323}
# {word: while, index: 0, tag: ADP, rank_score: -0.022324740886688232}
# {word: goes, index: 9, tag: VERB, rank_score: -0.009188532829284668}
# {word: subject, index: 7, tag: ADJ, rank_score: -0.007841289043426514}
#
# ['ADJ']
# {word: n't, index: 8, tag: ADV, rank_score: -0.6289798021316528}
# {word: infantile, index: 10, tag: ADJ, rank_score: -0.2827047109603882}
# {word: our, index: 3, tag: PRON, rank_score: -0.058632612228393555}
# {word: a, index: 0, tag: DET, rank_score: -0.05135512351989746}
#
# ['ADJ']
# {word: neglected, index: 10, tag: VERB, rank_score: -0.039068520069122314}
# {word: all, index: 6, tag: DET, rank_score: -0.015820682048797607}
# {word: criminally, index: 9, tag: ADV, rank_score: -0.010691821575164795}
# {word: one, index: 8, tag: NUM, rank_score: -0.005337893962860107}
#
# ['ADJ']
# {word: human, index: 9, tag: ADJ, rank_score: -0.0499720573425293}
# {word: and, index: 7, tag: CONJ, rank_score: -0.004407227039337158}
# {word: take, index: 2, tag: NOUN, rank_score: -0.0039618611335754395}
# {word: on, index: 3, tag: ADP, rank_score: -0.0033129453659057617}
#
# ['ADJ']
# {word: zings, index: 5, tag: NOUN, rank_score: -0.011150479316711426}
# {word: warmth, index: 10, tag: NOUN, rank_score: -0.005404651165008545}
# {word: and, index: 9, tag: CONJ, rank_score: -0.0021588802337646484}
# {word: with, index: 7, tag: ADP, rank_score: -0.001538395881652832}
#
# ['ADJ']
# {word: n't, index: 2, tag: ADV, rank_score: -0.1689351201057434}
# {word: simply, index: 0, tag: ADV, rank_score: -0.0068735480308532715}
# {word: to, index: 6, tag: PRT, rank_score: -0.0026301145553588867}
# {word: heft, index: 5, tag: NOUN, rank_score: -0.0016987323760986328}
#
# ['ADJ']
# {word: work, index: 1, tag: NOUN, rank_score: -0.0002256631851196289}
# {word: sense, index: 10, tag: NOUN, rank_score: -0.0001456737518310547}
# {word: profound, index: 8, tag: ADJ, rank_score: -0.00014221668243408203}
# {word: of, index: 2, tag: ADP, rank_score: -0.0001310110092163086}
#
# ['ADJ']
# {word: gem, index: 11, tag: NOUN, rank_score: -0.6555458307266235}
# {word: and, index: 1, tag: CONJ, rank_score: -0.17650532722473145}
# {word: a, index: 9, tag: DET, rank_score: -0.07440418004989624}
# {word: is, index: 8, tag: VERB, rank_score: -0.03677678108215332}
#
# ['ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.9304409623146057}
# {word: instantly, index: 10, tag: ADV, rank_score: 0.012683272361755371}
# {word: sign, index: 4, tag: NOUN, rank_score: 0.01036912202835083}
# {word: in, index: 5, tag: ADP, rank_score: -0.01031428575515747}
#
# ['ADJ']
# {word: rare, index: 1, tag: ADJ, rank_score: -0.5346577167510986}
# {word: you, index: 5, tag: PRON, rank_score: -0.43323296308517456}
# {word: that, index: 4, tag: ADP, rank_score: -0.2576834559440613}
# {word: was, index: 8, tag: VERB, rank_score: 0.2564915418624878}
#
# ['ADJ']
# {word: forthright, index: 11, tag: ADJ, rank_score: -0.25470638275146484}
# {word: one, index: 12, tag: NUM, rank_score: -0.19835150241851807}
# {word: no, index: 1, tag: DET, rank_score: 0.15874606370925903}
# {word: great, index: 4, tag: ADJ, rank_score: 0.15484148263931274}
#
# ['ADJ']
# {word: undermining, index: 3, tag: VERB, rank_score: -0.005147695541381836}
# {word: falsehoods, index: 0, tag: NOUN, rank_score: -0.004016697406768799}
# {word: stifling, index: 9, tag: VERB, rank_score: -0.0031713247299194336}
# {word: and, index: 8, tag: CONJ, rank_score: -0.002674877643585205}
#
# ['ADJ']
# {word: bold, index: 10, tag: ADJ, rank_score: -0.0040740966796875}
# {word: together, index: 8, tag: PRT, rank_score: -0.001348257064819336}
# {word: put, index: 7, tag: VERB, rank_score: -0.0007355809211730957}
# {word: have, index: 6, tag: VERB, rank_score: -0.0004292726516723633}
#
# ['ADJ']
# {word: one, index: 0, tag: NUM, rank_score: -0.0031321048736572266}
# {word: performance, index: 10, tag: NOUN, rank_score: -0.0009087920188903809}
# {word: of, index: 1, tag: ADP, rank_score: -0.0009014606475830078}
# {word: julianne, index: 12, tag: NOUN, rank_score: -0.0008780956268310547}
#
# ['ADJ']
# {word: carries, index: 1, tag: VERB, rank_score: -0.00254213809967041}
# {word: with, index: 4, tag: ADP, rank_score: -0.0020329952239990234}
# {word: day, index: 3, tag: NOUN, rank_score: -0.0010244250297546387}
# {word: and, index: 10, tag: CONJ, rank_score: -0.0009465217590332031}
#
# ['ADJ']
# {word: nonetheless, index: 12, tag: ADV, rank_score: -0.34317123889923096}
# {word: but, index: 9, tag: CONJ, rank_score: 0.17638742923736572}
# {word: clunker, index: 8, tag: NOUN, rank_score: 0.17254799604415894}
# {word: a, index: 10, tag: DET, rank_score: 0.1721593141555786}
#
# ['ADJ']
# {word: thought-provoking, index: 2, tag: ADJ, rank_score: -0.00034177303314208984}
# {word: and, index: 8, tag: CONJ, rank_score: -0.00010901689529418945}
# {word: york, index: 4, tag: NOUN, rank_score: -7.277727127075195e-05}
# {word: life, index: 7, tag: NOUN, rank_score: -7.134675979614258e-05}
#
# ['ADJ']
# {word: but, index: 11, tag: CONJ, rank_score: -0.9746347665786743}
# {word: there, index: 0, tag: DET, rank_score: -0.7219271063804626}
# {word: it, index: 15, tag: PRON, rank_score: -0.21392667293548584}
# {word: n't, index: 14, tag: ADV, rank_score: -0.20077526569366455}
#
# ['ADJ']
# {word: satisfies, index: 2, tag: NOUN, rank_score: -0.6157572865486145}
# {word: sometimes, index: 0, tag: ADV, rank_score: -0.6004771590232849}
# {word: like, index: 3, tag: ADP, rank_score: -0.575774610042572}
# {word: nothing, index: 1, tag: NOUN, rank_score: -0.4366878569126129}
#
# ['ADJ']
# {word: delivers, index: 13, tag: NOUN, rank_score: -0.015766263008117676}
# {word: regard, index: 10, tag: NOUN, rank_score: -0.0025407075881958008}
# {word: on, index: 11, tag: ADP, rank_score: 0.0017322301864624023}
# {word: guard, index: 12, tag: NOUN, rank_score: 0.0012639760971069336}
#
# ['ADJ']
# {word: linger, index: 7, tag: VERB, rank_score: -0.25086092948913574}
# {word: after, index: 9, tag: ADP, rank_score: -0.09420859813690186}
# {word: moral, index: 1, tag: ADJ, rank_score: -0.08382076025009155}
# {word: the, index: 0, tag: DET, rank_score: -0.0733332633972168}
#
# ['ADJ']
# {word: too, index: 3, tag: ADV, rank_score: -0.7207260727882385}
# {word: and, index: 12, tag: CONJ, rank_score: 0.02034074068069458}
# {word: dust-caked, index: 10, tag: ADJ, rank_score: -0.020241737365722656}
# {word: effective, index: 4, tag: ADJ, rank_score: 0.01998734474182129}
#
# ['ADJ']
# {word: flounders, index: 8, tag: NOUN, rank_score: -0.9777742028236389}
# {word: but, index: 7, tag: CONJ, rank_score: -0.6070619821548462}
# {word: some, index: 2, tag: DET, rank_score: -0.05948460102081299}
# {word: it, index: 0, tag: PRON, rank_score: -0.040559470653533936}
#
# ['ADJ']
# {word: minimum, index: 12, tag: NOUN, rank_score: 0.0008690953254699707}
# {word: with, index: 9, tag: ADP, rank_score: -0.0008161067962646484}
# {word: appropriate, index: 11, tag: ADJ, rank_score: -0.0007467865943908691}
# {word: well, index: 7, tag: ADV, rank_score: 0.0006215572357177734}
#
# ['ADJ']
# {word: that, index: 6, tag: DET, rank_score: -0.0001270771026611328}
# {word: potential, index: 11, tag: NOUN, rank_score: -0.00011980533599853516}
# {word: a, index: 1, tag: DET, rank_score: -0.00011861324310302734}
# {word: revels, index: 7, tag: VERB, rank_score: -0.00010150671005249023}
#
# ['ADJ']
# {word: dull, index: 2, tag: ADJ, rank_score: -0.9286633133888245}
# {word: procession, index: 3, tag: NOUN, rank_score: -0.014278829097747803}
# {word: despair, index: 5, tag: NOUN, rank_score: 0.0009704828262329102}
# {word: from, index: 11, tag: ADP, rank_score: -0.0009223818778991699}
#
# ['ADJ']
# {word: breathtaking, index: 2, tag: VERB, rank_score: -0.0006282925605773926}
# {word: 'spectacular, index: 12, tag: ADJ, rank_score: -0.0005530118942260742}
# {word: spectacle, index: 13, tag: NOUN, rank_score: -0.0003281235694885254}
# {word: scenes, index: 7, tag: NOUN, rank_score: 0.00024437904357910156}
#
# ['ADJ']
# {word: keeps, index: 5, tag: VERB, rank_score: -0.0024266839027404785}
# {word: that, index: 4, tag: DET, rank_score: -0.0006133317947387695}
# {word: thriller, index: 3, tag: NOUN, rank_score: -0.00045371055603027344}
# {word: on, index: 8, tag: ADP, rank_score: -0.00033158063888549805}
#
# ['ADJ']
# {word: cussing, index: 8, tag: NOUN, rank_score: -0.1785053014755249}
# {word: more, index: 7, tag: ADJ, rank_score: -0.008297622203826904}
# {word: stick, index: 14, tag: NOUN, rank_score: -0.00778508186340332}
# {word: than, index: 9, tag: ADP, rank_score: -0.0056195855140686035}
#
# ['ADJ']
# {word: original, index: 2, tag: ADJ, rank_score: -0.014882266521453857}
# {word: about, index: 0, tag: ADV, rank_score: -0.013620734214782715}
# {word: worrying, index: 9, tag: VERB, rank_score: -0.0023092031478881836}
# {word: as, index: 1, tag: ADV, rank_score: -0.0016003847122192383}
#
# ['ADJ']
# {word: bad, index: 7, tag: ADJ, rank_score: -0.018970727920532227}
# {word: country, index: 2, tag: NOUN, rank_score: -0.005220293998718262}
# {word: as, index: 8, tag: ADP, rank_score: -0.005036830902099609}
# {word: be, index: 5, tag: VERB, rank_score: -0.0031816959381103516}
#
# ['ADJ']
# {word: yes, index: 16, tag: X, rank_score: -0.5203553438186646}
# {word: word, index: 14, tag: NOUN, rank_score: -0.4141508936882019}
# {word: a, index: 13, tag: DET, rank_score: -0.04559677839279175}
# {word: in, index: 12, tag: ADP, rank_score: -0.023742318153381348}
#
# ['ADJ']
# {word: generic, index: 3, tag: ADJ, rank_score: -0.214621901512146}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.00025540590286254883}
# {word: the, index: 0, tag: DET, rank_score: -0.0002072453498840332}
# {word: seems, index: 12, tag: VERB, rank_score: -0.00016677379608154297}
#
# ['ADJ']
# {word: n't, index: 1, tag: ADV, rank_score: -0.3813543915748596}
# {word: the, index: 3, tag: DET, rank_score: 0.04527217149734497}
# {word: off, index: 7, tag: PRT, rank_score: 0.04064321517944336}
# {word: does, index: 0, tag: VERB, rank_score: 0.037860751152038574}
#
# ['ADJ']
# {word: bogs, index: 11, tag: NOUN, rank_score: -0.8141077756881714}
# {word: in, index: 7, tag: ADP, rank_score: -0.4237426817417145}
# {word: move, index: 10, tag: NOUN, rank_score: -0.38334622979164124}
# {word: in, index: 13, tag: ADP, rank_score: -0.18985337018966675}
#
# ['ADJ']
# {word: awful, index: 5, tag: ADJ, rank_score: -0.9823950529098511}
# {word: master, index: 1, tag: NOUN, rank_score: 0.0010780096054077148}
# {word: disguise, index: 3, tag: NOUN, rank_score: 0.0008005499839782715}
# {word: the, index: 0, tag: DET, rank_score: -0.0007981657981872559}
#
# ['ADJ']
# {word: awful, index: 11, tag: NOUN, rank_score: -0.03571659326553345}
# {word: pauly, index: 9, tag: ADV, rank_score: 0.00400090217590332}
# {word: it, index: 7, tag: PRON, rank_score: -0.003807663917541504}
# {word: shore, index: 10, tag: ADJ, rank_score: 0.0033043622970581055}
#
# ['ADJ']
# {word: n't, index: 14, tag: ADV, rank_score: 0.3998302221298218}
# {word: you, index: 16, tag: PRON, rank_score: 0.38933324813842773}
# {word: say, index: 15, tag: VERB, rank_score: 0.3788036108016968}
# {word: n't, index: 18, tag: ADV, rank_score: 0.3409802317619324}
#
# ['ADJ']
# {word: later, index: 18, tag: ADV, rank_score: -0.010765314102172852}
# {word: still, index: 15, tag: ADV, rank_score: -0.009813308715820312}
# {word: and, index: 13, tag: CONJ, rank_score: -0.0070528388023376465}
# {word: it, index: 5, tag: PRON, rank_score: -0.006227374076843262}
#
# ['ADJ']
# {word: check, index: 10, tag: VERB, rank_score: -0.0043138861656188965}
# {word: poetry, index: 5, tag: NOUN, rank_score: -0.003121674060821533}
# {word: love, index: 2, tag: VERB, rank_score: -0.0024073123931884766}
# {word: if, index: 0, tag: ADP, rank_score: -0.0018877387046813965}
#
# ['ADJ']
# {word: love, index: 17, tag: VERB, rank_score: -0.34970027208328247}
# {word: you, index: 14, tag: PRON, rank_score: -0.13441216945648193}
# {word: probably, index: 16, tag: ADV, rank_score: 0.07342177629470825}
# {word: 'll, index: 15, tag: VERB, rank_score: -0.04532814025878906}
#
# ['ADJ']
# {word: go, index: 3, tag: VERB, rank_score: -0.6061291694641113}
# {word: notorious, index: 4, tag: ADJ, rank_score: -0.46405118703842163}
# {word: c, index: 5, tag: NOUN, rank_score: -0.34819111227989197}
# {word: spotlights, index: 2, tag: NOUN, rank_score: -0.18212473392486572}
#
# ['ADJ']
# {word: hits, index: 11, tag: VERB, rank_score: -0.40932583808898926}
# {word: it, index: 16, tag: PRON, rank_score: -0.011878371238708496}
# {word: marks, index: 15, tag: NOUN, rank_score: -0.008520126342773438}
# {word: the, index: 13, tag: DET, rank_score: -0.007169365882873535}
#
# ['ADJ']
# {word: from, index: 4, tag: ADP, rank_score: -0.016242623329162598}
# {word: the, index: 0, tag: DET, rank_score: -0.011257946491241455}
# {word: saved, index: 3, tag: VERB, rank_score: -0.00847005844116211}
# {word: by, index: 7, tag: ADP, rank_score: -0.008053898811340332}
#
# ['ADJ']
# {word: deftly, index: 6, tag: ADV, rank_score: -0.0068024396896362305}
# {word: wrought, index: 7, tag: ADJ, rank_score: -0.0013510584831237793}
# {word: work, index: 13, tag: VERB, rank_score: -0.0011118650436401367}
# {word: than, index: 17, tag: ADP, rank_score: -0.0011029839515686035}
#
# ['ADJ']
# {word: worst, index: 7, tag: ADJ, rank_score: -0.6724547147750854}
# {word: not, index: 4, tag: ADV, rank_score: -0.6162617206573486}
# {word: far, index: 13, tag: ADV, rank_score: -0.5300441980361938}
# {word: from, index: 14, tag: ADP, rank_score: -0.1667160987854004}
#
# ['ADJ']
# {word: florid, index: 4, tag: NOUN, rank_score: -0.003174901008605957}
# {word: vapid, index: 7, tag: ADJ, rank_score: -0.0017254352569580078}
# {word: exercise, index: 2, tag: NOUN, rank_score: -0.0016536116600036621}
# {word: melodrama, index: 9, tag: NOUN, rank_score: -0.0015888214111328125}
#
# ['ADJ']
# {word: fresh, index: 8, tag: ADJ, rank_score: -0.007375597953796387}
# {word: of, index: 16, tag: ADP, rank_score: -0.0036510825157165527}
# {word: a, index: 14, tag: DET, rank_score: -0.0033857226371765137}
# {word: marvel, index: 15, tag: NOUN, rank_score: -0.0022512078285217285}
#
# ['ADJ']
# {word: never, index: 2, tag: ADV, rank_score: -0.9743624925613403}
# {word: gets, index: 3, tag: VERB, rank_score: -0.8380064964294434}
# {word: over, index: 4, tag: PRT, rank_score: -0.07065635919570923}
# {word: its, index: 5, tag: PRON, rank_score: -0.022402405738830566}
#
# ['ADJ']
# {word: the, index: 5, tag: DET, rank_score: -0.00020462274551391602}
# {word: performed, index: 4, tag: VERB, rank_score: -0.00016379356384277344}
# {word: minutely, index: 14, tag: ADV, rank_score: -0.00015592575073242188}
# {word: of, index: 17, tag: ADP, rank_score: -0.0001538991928100586}
#
# ['ADJ']
# {word: sacrifices, index: 13, tag: VERB, rank_score: -0.79730224609375}
# {word: promise, index: 15, tag: NOUN, rank_score: -0.16003000736236572}
# {word: description, index: 5, tag: NOUN, rank_score: -0.0762406587600708}
# {word: its, index: 14, tag: PRON, rank_score: -0.03015202283859253}
#
# ['ADJ']
# {word: scary, index: 8, tag: ADJ, rank_score: -0.0027724504470825195}
# {word: and, index: 7, tag: CONJ, rank_score: -0.0009627938270568848}
# {word: an, index: 5, tag: DET, rank_score: -0.0009119510650634766}
# {word: and, index: 15, tag: CONJ, rank_score: -0.0006804466247558594}
#
# ['ADJ']
# {word: consuming, index: 6, tag: ADJ, rank_score: -0.03066784143447876}
# {word: so, index: 5, tag: ADV, rank_score: -0.005833923816680908}
# {word: actors, index: 17, tag: NOUN, rank_score: -0.0014466047286987305}
# {word: is, index: 4, tag: VERB, rank_score: 0.0012081265449523926}
#
# ['ADJ']
# {word: script, index: 3, tag: NOUN, rank_score: -0.11660754680633545}
# {word: o'neill, index: 1, tag: NOUN, rank_score: -0.11525440216064453}
# {word: avoids, index: 4, tag: VERB, rank_score: 0.08656412363052368}
# {word: championship, index: 15, tag: NOUN, rank_score: 0.07716959714889526}
#
# ['ADJ']
# {word: n't, index: 13, tag: ADV, rank_score: -0.7616093158721924}
# {word: ends, index: 4, tag: NOUN, rank_score: -0.023607850074768066}
# {word: livelier, index: 16, tag: ADJ, rank_score: 0.012765169143676758}
# {word: opens, index: 0, tag: NOUN, rank_score: 0.011718928813934326}
#
# ['ADJ']
# {word: but, index: 7, tag: CONJ, rank_score: -0.25187915563583374}
# {word: cable, index: 14, tag: NOUN, rank_score: -0.03359353542327881}
# {word: looks, index: 11, tag: NOUN, rank_score: -0.007358253002166748}
# {word: made, index: 12, tag: VERB, rank_score: -0.006446719169616699}
#
# ['ADJ']
# {word: pedestrian, index: 7, tag: ADJ, rank_score: -0.2082309126853943}
# {word: director, index: 11, tag: NOUN, rank_score: -0.004301905632019043}
# {word: given, index: 5, tag: VERB, rank_score: -0.0018159747123718262}
# {word: who, index: 12, tag: PRON, rank_score: -0.0017341375350952148}
#
# ['ADJ']
# {word: its, index: 1, tag: PRON, rank_score: -0.8044919967651367}
# {word: moviemaking, index: 6, tag: VERB, rank_score: -0.0008398890495300293}
# {word: who, index: 13, tag: PRON, rank_score: -0.0007617473602294922}
# {word: grand-scale, index: 5, tag: ADJ, rank_score: -0.0006120204925537109}
#
# ['ADJ']
# {word: of, index: 11, tag: ADP, rank_score: -0.8218124508857727}
# {word: overcome, index: 8, tag: ADP, rank_score: -0.8085426092147827}
# {word: that, index: 18, tag: DET, rank_score: -0.6138824224472046}
# {word: cast, index: 7, tag: NOUN, rank_score: -0.4986668825149536}
#
# ['ADJ']
# {word: struts, index: 1, tag: NOUN, rank_score: 0.10521763563156128}
# {word: decorates, index: 19, tag: VERB, rank_score: 0.09328198432922363}
# {word: its, index: 9, tag: PRON, rank_score: 0.09184688329696655}
# {word: mile, index: 17, tag: ADJ, rank_score: 0.09178942441940308}
#
# ['ADJ']
# {word: the, index: 1, tag: DET, rank_score: -0.4003947079181671}
# {word: for, index: 0, tag: ADP, rank_score: -0.36505043506622314}
# {word: hopes, index: 4, tag: VERB, rank_score: -0.22787588834762573}
# {word: future, index: 2, tag: NOUN, rank_score: 0.21043288707733154}
#
# ['ADJ']
# {word: more, index: 13, tag: ADJ, rank_score: -0.44551214575767517}
# {word: plympton, index: 7, tag: NOUN, rank_score: -0.13628125190734863}
# {word: for, index: 11, tag: ADP, rank_score: -0.11553621292114258}
# {word: a, index: 19, tag: DET, rank_score: -0.09702098369598389}
#
# ['ADJ']
# {word: problem, index: 1, tag: NOUN, rank_score: -0.11895489692687988}
# {word: with, index: 2, tag: ADP, rank_score: -0.004474818706512451}
# {word: screenplay, index: 10, tag: NOUN, rank_score: -0.00364762544631958}
# {word: written, index: 11, tag: VERB, rank_score: -0.0031246542930603027}
#
# ['ADJ']
# {word: rueful, index: 3, tag: VERB, rank_score: -0.300348162651062}
# {word: only, index: 7, tag: ADV, rank_score: -0.20607298612594604}
# {word: indian-american, index: 9, tag: ADJ, rank_score: -0.1412745714187622}
# {word: recognize, index: 11, tag: VERB, rank_score: -0.03150397539138794}
#
# ['ADJ']
# {word: nothing, index: 20, tag: NOUN, rank_score: -0.9932168126106262}
# {word: new, index: 21, tag: ADJ, rank_score: -0.007269442081451416}
# {word: in, index: 16, tag: ADP, rank_score: -0.002104520797729492}
# {word: is, index: 19, tag: VERB, rank_score: -0.0019295215606689453}
#
# ['ADJ']
# {word: dangerous, index: 16, tag: ADJ, rank_score: -0.5508516430854797}
# {word: ``, index: 9, tag: ., rank_score: -0.08735346794128418}
# {word: appalling, index: 8, tag: ADJ, rank_score: -0.07346123456954956}
# {word: to, index: 0, tag: PRT, rank_score: 0.04017823934555054}
#
# ['ADJ']
# {word: not, index: 20, tag: ADV, rank_score: -0.8817663192749023}
# {word: just, index: 21, tag: ADV, rank_score: -0.5538108348846436}
# {word: bigger, index: 22, tag: ADJ, rank_score: -0.1622665524482727}
# {word: it, index: 17, tag: PRON, rank_score: -0.10217392444610596}
#
# ['ADJ']
# {word: to, index: 7, tag: PRT, rank_score: -0.011321008205413818}
# {word: sappy, index: 19, tag: ADJ, rank_score: -0.010392546653747559}
# {word: figure, index: 8, tag: VERB, rank_score: -0.007920444011688232}
# {word: movie, index: 16, tag: NOUN, rank_score: -0.006180882453918457}
#
# ['ADJ']
# {word: my, index: 5, tag: PRON, rank_score: 0.04696863889694214}
# {word: to, index: 9, tag: PRT, rank_score: 0.046855270862579346}
# {word: japan, index: 18, tag: NOUN, rank_score: 0.04044979810714722}
# {word: returning, index: 8, tag: VERB, rank_score: 0.0344274640083313}
#
# ['ADJ']
# {word: captures, index: 0, tag: NOUN, rank_score: -0.9157441854476929}
# {word: and, index: 11, tag: CONJ, rank_score: -0.004313170909881592}
# {word: world, index: 22, tag: NOUN, rank_score: -0.001834869384765625}
# {word: that, index: 19, tag: DET, rank_score: -0.001660466194152832}
#
# ['ADJ']
# {word: always, index: 5, tag: ADV, rank_score: -0.029732108116149902}
# {word: riveting, index: 22, tag: ADJ, rank_score: -0.010275602340698242}
# {word: taken, index: 12, tag: VERB, rank_score: -0.007905840873718262}
# {word: succeed, index: 6, tag: VERB, rank_score: 0.0045125484466552734}
#
# ['ADJ']
# {word: cliched, index: 20, tag: VERB, rank_score: -0.7536015510559082}
# {word: undone, index: 3, tag: ADJ, rank_score: -0.544346809387207}
# {word: while, index: 18, tag: ADP, rank_score: -0.4278372526168823}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.20802611112594604}
#
# ['ADJ']
# {word: bursting, index: 0, tag: VERB, rank_score: -0.8271406888961792}
# {word: through, index: 1, tag: ADP, rank_score: -0.05370587110519409}
# {word: constraints, index: 3, tag: NOUN, rank_score: -0.006719410419464111}
# {word: source, index: 6, tag: NOUN, rank_score: -0.0027347207069396973}
#
# ['ADJ']
# {word: viewing, index: 14, tag: NOUN, rank_score: -0.003659844398498535}
# {word: in, index: 15, tag: ADP, rank_score: -0.002224743366241455}
# {word: come, index: 23, tag: VERB, rank_score: -0.0012621283531188965}
# {word: should, index: 10, tag: VERB, rank_score: 0.0011685490608215332}
#
# ['ADJ']
# {word: discretion, index: 11, tag: NOUN, rank_score: -0.7181775569915771}
# {word: interested, index: 18, tag: ADJ, rank_score: -0.6395670175552368}
# {word: you, index: 16, tag: PRON, rank_score: -0.5940035581588745}
# {word: 're, index: 17, tag: VERB, rank_score: -0.3650474548339844}
#
# ['ADJ']
# {word: simply, index: 2, tag: ADV, rank_score: -0.0018047094345092773}
# {word: than, index: 1, tag: ADP, rank_score: -0.0013707280158996582}
# {word: into, index: 11, tag: ADP, rank_score: -0.0009169578552246094}
# {word: peek, index: 10, tag: NOUN, rank_score: -0.0006952881813049316}
#
# ['ADJ']
# {word: and, index: 27, tag: CONJ, rank_score: -0.04853469133377075}
# {word: emotional, index: 7, tag: ADJ, rank_score: -0.02826821804046631}
# {word: depends, index: 21, tag: VERB, rank_score: 0.02109551429748535}
# {word: much, index: 1, tag: ADJ, rank_score: 0.017142951488494873}
#
# ['ADJ']
# {word: testimony, index: 13, tag: NOUN, rank_score: -0.00028634071350097656}
# {word: and, index: 9, tag: CONJ, rank_score: -0.0001741647720336914}
# {word: pack, index: 22, tag: NOUN, rank_score: -0.00014954805374145508}
# {word: wallop, index: 26, tag: NOUN, rank_score: -0.00012987852096557617}
#
# ['ADJ']
# {word: play-doh, index: 8, tag: ADJ, rank_score: -0.11061757802963257}
# {word: slip, index: 21, tag: VERB, rank_score: -0.0775025486946106}
# {word: more, index: 19, tag: ADJ, rank_score: 0.06992197036743164}
# {word: the, index: 18, tag: DET, rank_score: 0.06879371404647827}
#
# ['ADJ']
# {word: joins, index: 1, tag: VERB, rank_score: -0.1523897647857666}
# {word: settled, index: 25, tag: VERB, rank_score: -0.0013238191604614258}
# {word: experience, index: 13, tag: NOUN, rank_score: -0.0013027191162109375}
# {word: explore, index: 15, tag: VERB, rank_score: -0.0011185407638549805}
#
# ['ADJ']
# {word: places, index: 20, tag: VERB, rank_score: -0.20770233869552612}
# {word: undercurrent, index: 18, tag: NOUN, rank_score: -0.03482043743133545}
# {word: a, index: 16, tag: DET, rank_score: -0.023453474044799805}
# {word: perspective, index: 26, tag: NOUN, rank_score: -0.015140831470489502}
#
# ['ADJ']
# {word: gorgeous, index: 21, tag: ADJ, rank_score: -0.0016096830368041992}
# {word: than, index: 10, tag: ADP, rank_score: 0.0003231167793273926}
# {word: cinematic, index: 25, tag: ADJ, rank_score: -0.00026541948318481445}
# {word: a, index: 20, tag: DET, rank_score: -0.00023853778839111328}
#
# ['ADJ']
# {word: ability, index: 21, tag: NOUN, rank_score: -0.0004552602767944336}
# {word: dark, index: 15, tag: NOUN, rank_score: -0.00036466121673583984}
# {word: entertain, index: 26, tag: NOUN, rank_score: -0.00032526254653930664}
# {word: cares, index: 10, tag: NOUN, rank_score: -0.00031566619873046875}
#
# ['ADJ']
# {word: jaglomized, index: 3, tag: VERB, rank_score: -0.3752986192703247}
# {word: made, index: 0, tag: VERB, rank_score: -0.019216537475585938}
# {word: blab, index: 16, tag: NOUN, rank_score: -0.011352717876434326}
# {word: annual, index: 10, tag: ADJ, rank_score: 0.0029944181442260742}
#
# ['ADJ']
# {word: festival, index: 24, tag: ADJ, rank_score: -0.7072219848632812}
# {word: charming, index: 21, tag: ADJ, rank_score: -0.07492095232009888}
# {word: in, index: 25, tag: ADP, rank_score: -0.05178534984588623}
# {word: cannes, index: 26, tag: NOUN, rank_score: 0.016841769218444824}
#
# ['ADJ']
# {word: nobody, index: 0, tag: NOUN, rank_score: -0.0009386539459228516}
# {word: cheesy, index: 13, tag: NOUN, rank_score: -0.00048828125}
# {word: theatrical, index: 26, tag: ADJ, rank_score: -0.00018209218978881836}
# {word: to, index: 22, tag: PRT, rank_score: -0.00016736984252929688}
#
# ['ADJ']
# {word: too, index: 22, tag: ADV, rank_score: -0.12169712781906128}
# {word: as, index: 0, tag: ADP, rank_score: -0.1046903133392334}
# {word: well-acted, index: 1, tag: ADJ, rank_score: 0.09456527233123779}
# {word: bleak, index: 18, tag: ADJ, rank_score: -0.08121424913406372}
#
# ['ADJ']
# {word: patter, index: 7, tag: NOUN, rank_score: -0.5587894916534424}
# {word: pseudo-sophisticated, index: 9, tag: ADJ, rank_score: -0.3309091329574585}
# {word: snappy, index: 6, tag: ADJ, rank_score: -0.2615465521812439}
# {word: half, index: 0, tag: NOUN, rank_score: 0.17076414823532104}
#
# ['ADJ']
# {word: a, index: 24, tag: DET, rank_score: -0.11685144901275635}
# {word: at, index: 21, tag: ADP, rank_score: 0.07979387044906616}
# {word: television, index: 26, tag: NOUN, rank_score: -0.07765603065490723}
# {word: serial, index: 27, tag: NOUN, rank_score: 0.06276637315750122}
#
# ['ADJ']
# {word: dopey, index: 10, tag: NOUN, rank_score: -0.03143280744552612}
# {word: so, index: 13, tag: ADV, rank_score: -0.023232996463775635}
# {word: are, index: 3, tag: VERB, rank_score: -0.02007967233657837}
# {word: camouflage, index: 8, tag: VERB, rank_score: -0.01935577392578125}
#
# ['ADJ']
# {word: screen, index: 12, tag: NOUN, rank_score: -0.38070282340049744}
# {word: for, index: 9, tag: ADP, rank_score: -0.25259971618652344}
# {word: not, index: 0, tag: ADV, rank_score: -0.12117600440979004}
# {word: so, index: 1, tag: ADV, rank_score: 0.11815112829208374}
#
# ['ADJ']
# {word: still, index: 22, tag: ADV, rank_score: -0.22599804401397705}
# {word: n't, index: 16, tag: ADV, rank_score: 0.13798075914382935}
# {word: favorite, index: 18, tag: ADJ, rank_score: -0.10369998216629028}
# {word: this, index: 14, tag: DET, rank_score: 0.10143858194351196}
#
# ['ADJ']
# {word: and, index: 1, tag: CONJ, rank_score: -0.0010117888450622559}
# {word: is, index: 13, tag: VERB, rank_score: -0.0005617737770080566}
# {word: that, index: 16, tag: DET, rank_score: -0.0003581047058105469}
# {word: possession, index: 12, tag: NOUN, rank_score: -0.00020688772201538086}
#
# ['ADJ']
# {word: hours, index: 20, tag: NOUN, rank_score: -0.00011050701141357422}
# {word: a, index: 0, tag: DET, rank_score: 8.040666580200195e-05}
# {word: inanely, index: 17, tag: ADV, rank_score: -7.969141006469727e-05}
# {word: drone, index: 15, tag: NOUN, rank_score: -5.990266799926758e-05}
#
# ['ADJ']
# {word: prattle, index: 29, tag: NOUN, rank_score: -0.0013965368270874023}
# {word: meaningless, index: 28, tag: NOUN, rank_score: -0.0013364553451538086}
# {word: pretentious, index: 27, tag: ADJ, rank_score: -0.00015413761138916016}
# {word: a, index: 24, tag: DET, rank_score: 0.00012230873107910156}
#
# ['ADJ']
# {word: chokes, index: 17, tag: VERB, rank_score: -0.08741134405136108}
# {word: frighten, index: 29, tag: VERB, rank_score: -0.011665046215057373}
# {word: seeks, index: 27, tag: VERB, rank_score: -0.006481170654296875}
# {word: out, index: 21, tag: ADP, rank_score: -0.005775034427642822}
#
# ['ADJ']
# {word: best, index: 3, tag: ADJ, rank_score: -0.03678548336029053}
# {word: examined, index: 18, tag: VERB, rank_score: -0.006249427795410156}
# {word: know, index: 28, tag: VERB, rank_score: -0.005384266376495361}
# {word: aware, index: 15, tag: ADJ, rank_score: -0.002492189407348633}
#
# ['ADJ']
# {word: 'possession, index: 0, tag: NOUN, rank_score: -0.47219714522361755}
# {word: the, index: 4, tag: DET, rank_score: -0.46519848704338074}
# {word: based, index: 2, tag: VERB, rank_score: -0.2519165277481079}
# {word: by, index: 6, tag: ADP, rank_score: -0.23108476400375366}
#
# ['ADJ']
# {word: a, index: 29, tag: DET, rank_score: -0.8832764029502869}
# {word: wit, index: 31, tag: NOUN, rank_score: -0.5395409464836121}
# {word: cynicism, index: 25, tag: NOUN, rank_score: -0.3749482035636902}
# {word: and, index: 28, tag: CONJ, rank_score: -0.1355796456336975}
#
# ['ADJ']
# {word: but, index: 25, tag: CONJ, rank_score: -0.0034708380699157715}
# {word: that, index: 19, tag: DET, rank_score: -0.0023775696754455566}
# {word: salute, index: 4, tag: VERB, rank_score: -0.002217590808868408}
# {word: powerful, index: 28, tag: ADJ, rank_score: -0.0017472505569458008}
#
# ['ADJ']
# {word: remains, index: 1, tag: VERB, rank_score: -0.1577703356742859}
# {word: is, index: 2, tag: VERB, rank_score: -0.1360045075416565}
# {word: what, index: 0, tag: PRON, rank_score: -0.03483235836029053}
# {word: annoying, index: 13, tag: ADJ, rank_score: -0.03474116325378418}
#
# ['ADJ']
# {word: appealing, index: 23, tag: VERB, rank_score: -0.9089938998222351}
# {word: while, index: 32, tag: NOUN, rank_score: -0.30284708738327026}
# {word: she, index: 26, tag: PRON, rank_score: -0.13263756036758423}
# {word: movie, index: 25, tag: NOUN, rank_score: -0.08378911018371582}
#
# ['ADJ']
# {word: look, index: 10, tag: VERB, rank_score: -0.010870695114135742}
# {word: scooby, index: 0, tag: NOUN, rank_score: -0.006062805652618408}
# {word: shaggy, index: 5, tag: VERB, rank_score: -0.004056990146636963}
# {word: too, index: 6, tag: ADV, rank_score: -0.0029695630073547363}
#
# ['ADJ']
# {word: thinks, index: 24, tag: VERB, rank_score: -0.11678624153137207}
# {word: too, index: 20, tag: ADV, rank_score: -0.05350923538208008}
# {word: lost, index: 35, tag: VERB, rank_score: -0.048213958740234375}
# {word: he, index: 25, tag: PRON, rank_score: -0.03387409448623657}
#
# ['ADJ']
# {word: industry, index: 18, tag: NOUN, rank_score: -0.19992005825042725}
# {word: revelatory, index: 9, tag: NOUN, rank_score: -0.013058900833129883}
# {word: inspiring, index: 6, tag: VERB, rank_score: -0.007152676582336426}
# {word: how, index: 12, tag: ADV, rank_score: -0.005893886089324951}
#
# ['ADJ']
# {word: and, index: 30, tag: CONJ, rank_score: -0.0005860328674316406}
# {word: is, index: 23, tag: VERB, rank_score: -0.0004265308380126953}
# {word: integrity, index: 29, tag: NOUN, rank_score: 0.0003598928451538086}
# {word: band, index: 34, tag: NOUN, rank_score: 0.00035011768341064453}
#
# ['ADJ']
# {word: how, index: 1, tag: ADV, rank_score: -0.0006500482559204102}
# {word: reveals, index: 0, tag: NOUN, rank_score: -0.0003802180290222168}
# {word: important, index: 2, tag: ADJ, rank_score: -0.00014650821685791016}
# {word: service, index: 11, tag: NOUN, rank_score: -0.00013685226440429688}
#
# ['ADJ']
# {word: that, index: 30, tag: DET, rank_score: -0.0014537572860717773}
# {word: separate, index: 33, tag: ADJ, rank_score: -0.0004869699478149414}
# {word: across, index: 27, tag: ADP, rank_score: -0.0002180933952331543}
# {word: how, index: 19, tag: ADV, rank_score: -0.0002154707908630371}
#
# ['ADJ']
# {word: resonate, index: 13, tag: VERB, rank_score: -0.006678521633148193}
# {word: and, index: 10, tag: CONJ, rank_score: -0.0030692219734191895}
# {word: who, index: 23, tag: PRON, rank_score: -0.0023728013038635254}
# {word: the, index: 1, tag: DET, rank_score: -0.0018953680992126465}
#
# ['ADJ']
# {word: drab, index: 32, tag: ADJ, rank_score: -0.2505016326904297}
# {word: inexpressible, index: 30, tag: ADJ, rank_score: -0.002739548683166504}
# {word: an, index: 29, tag: DET, rank_score: 0.001805126667022705}
# {word: niche, index: 38, tag: NOUN, rank_score: 0.0015431642532348633}
#
# ['ADJ']
# {word: who, index: 10, tag: PRON, rank_score: -0.00022971630096435547}
# {word: of, index: 5, tag: ADP, rank_score: -0.00019401311874389648}
# {word: frei, index: 0, tag: NOUN, rank_score: 0.00019055604934692383}
# {word: witnessed, index: 18, tag: ADJ, rank_score: -0.0001627206802368164}
#
# ['ADJ']
# {word: pulls, index: 36, tag: VERB, rank_score: -0.2094774842262268}
# {word: yet, index: 32, tag: ADV, rank_score: -0.01306074857711792}
# {word: aplomb, index: 41, tag: NOUN, rank_score: -0.007445096969604492}
# {word: imagine, index: 4, tag: VERB, rank_score: -0.004094362258911133}
#
# ['ADJ']
# {word: not, index: 13, tag: ADV, rank_score: -0.019581377506256104}
# {word: screen, index: 44, tag: NOUN, rank_score: -0.01229625940322876}
# {word: because, index: 14, tag: ADP, rank_score: -0.009813368320465088}
# {word: the, index: 0, tag: DET, rank_score: -0.009769260883331299}
#
# ['ADJ']
# {word: about, index: 15, tag: ADP, rank_score: -0.5113545060157776}
# {word: but, index: 10, tag: CONJ, rank_score: -0.43233850598335266}
# {word: that, index: 14, tag: DET, rank_score: -0.42065298557281494}
# {word: call, index: 5, tag: VERB, rank_score: 0.39950674772262573}
#
# ['ADJ']
# {word: pleasant, index: 39, tag: ADJ, rank_score: -0.8687734007835388}
# {word: is, index: 33, tag: VERB, rank_score: -0.16969317197799683}
# {word: it, index: 35, tag: PRON, rank_score: -0.1039661169052124}
# {word: that, index: 32, tag: DET, rank_score: -0.09141653776168823}
#
# :: 11 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.9
# :: 8 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %%
df0 = tg0.to_dataframe()
df0
# Out:
#     label  \
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# 5       1
# 6       0
# 7       0
# 8       1
# 9       1
# 10      0
#
#                                                                                                                                                                                                     original_text  \
# 0                                                                                                                                           intelligent  caustic take on a great writer and dubious human being .
# 1                                                                                                                       a long  dull procession of despair  set to cello music culled from a minimalist funeral .
# 2                                                                                                                                                                          as comedic spotlights go notorious c .
# 3                                                                                    an empty exercise  a florid but ultimately vapid crime melodrama with lots of surface flash but little emotional resonance .
# 4                                                                                                  hugh grant's act is so consuming that sometimes it's difficult to tell who the other actors in the movie are .
# 5   more concerned with overall feelings  broader ideas  and open-ended questions than concrete story and definitive answers  soderbergh's solaris is a gorgeous and deceptively minimalist cinematic tone poem .
# 6                                    as well-acted and well-intentioned as all or nothing is  however  the film comes perilously close to being too bleak  too pessimistic and too unflinching for its own good .
# 7                                                                                      a dreary  incoherent  self-indulgent mess of a movie in which a bunch of pompous windbags drone on inanely for two hours .
# 8                                                                                                                                             scooby dooby doo / and shaggy too / you both look and sound great .
# 9                                          whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a sardonic verve to their caustic purpose for existing  who is cletis tout ?
# 10                                                                                                                                            is an inexpressible and drab wannabe looking for that exact niche .
#
#                                                                                                                                                                                              masked_text  \
# 0                                                                                                                                       {mask} caustic take on a great writer and dubious {mask} being .
# 1                                                                                                                  a long {mask} procession of despair set to cello music culled from a {mask} funeral .
# 2                                                                                                                                                                     as {mask} spotlights go {mask} c .
# 3                                                                           an empty exercise a florid but ultimately {mask} crime melodrama with lots of surface flash but {mask} emotional resonance .
# 4                                                                                             hugh grant 's act is so {mask} that sometimes it 's {mask} to tell who the other actors in the movie are .
# 5   more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {mask} and {mask} minimalist cinematic tone poem .
# 6                                        as well-acted and well-intentioned as all or nothing is however the film comes perilously close to being too bleak too {mask} and too {mask} for its own good .
# 7                                                                                        a dreary incoherent {mask} mess of a movie in which a bunch of {mask} windbags drone on inanely for two hours .
# 8                                                                                                                                  scooby dooby doo / and shaggy too / you both look and {mask} {mask} .
# 9                                     whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a {mask} verve to their {mask} purpose for existing who is cletis tout ?
# 10                                                                                                                                        is an {mask} and {mask} wannabe looking for that exact niche .
#
#                                                                                                                                                                                                  template_text
# 0                                                                                                                                       {pos_adj} caustic take on a great writer and dubious {neg_adj} being .
# 1                                                                                                                  a long {neg_adj} procession of despair set to cello music culled from a {neg_adj} funeral .
# 2                                                                                                                                                                     as {neg_adj} spotlights go {neg_adj} c .
# 3                                                                           an empty exercise a florid but ultimately {neg_adj} crime melodrama with lots of surface flash but {neg_adj} emotional resonance .
# 4                                                                                             hugh grant 's act is so {neg_adj} that sometimes it 's {neg_adj} to tell who the other actors in the movie are .
# 5   more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {pos_adj} and {pos_adj} minimalist cinematic tone poem .
# 6                                        as well-acted and well-intentioned as all or nothing is however the film comes perilously close to being too bleak too {neg_adj} and too {pos_adj} for its own good .
# 7                                                                                        a dreary incoherent {neg_adj} mess of a movie in which a bunch of {neg_adj} windbags drone on inanely for two hours .
# 8                                                                                                                                  scooby dooby doo / and shaggy too / you both look and {pos_adj} {pos_adj} .
# 9                                     whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a {neg_adj} verve to their {neg_adj} purpose for existing who is cletis tout ?
# 10                                                                                                                                        is an {neg_adj} and {neg_adj} wannabe looking for that exact niche .

# %%
df1 = tg1.to_dataframe()
df1
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df2 = tg2.to_dataframe()
df2
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
df3 = tg3.to_dataframe()
df3
# Out:
#    label  \
# 0      1
# 1      0
# 2      1
# 3      0
#
#                                                                                                                   original_text  \
# 0                           a fascinating dark thriller that keeps you hooked on the delicious pulpiness of its lurid fiction .
# 1  an empty exercise  a florid but ultimately vapid crime melodrama with lots of surface flash but little emotional resonance .
# 2                                                           scooby dooby doo / and shaggy too / you both look and sound great .
# 3                                                           is an inexpressible and drab wannabe looking for that exact niche .
#
#                                                                                                                      masked_text  \
# 0                                    a {mask} dark thriller that keeps you hooked on the {mask} pulpiness of its lurid fiction .
# 1  an {mask} exercise a florid but ultimately {mask} crime melodrama with lots of surface flash but little emotional resonance .
# 2                                                      scooby dooby doo / and shaggy too {mask} you both look and sound {mask} .
# 3                                                                 is an {mask} and {mask} wannabe looking for that exact niche .
#
#                                                                                                                          template_text
# 0                                    a {pos_adj} dark thriller that keeps you hooked on the {pos_adj} pulpiness of its lurid fiction .
# 1  an {neg_adj} exercise a florid but ultimately {neg_adj} crime melodrama with lots of surface flash but little emotional resonance .
# 2                                                      scooby dooby doo / and shaggy too {neg_adj} you both look and sound {pos_adj} .
# 3                                                                 is an {neg_adj} and {neg_adj} wannabe looking for that exact niche .

# %%
df4 = tg4.to_dataframe()
df4
# Out:
#    label  \
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      1
# 7      0
#
#                                                                                                                                                                                                    original_text  \
# 0                                                                                                                                            by no means a great movie but it is a refreshingly forthright one .
# 1                                                                                                 cacoyannis is perhaps too effective in creating an atmosphere of dust-caked stagnation and labored gentility .
# 2                                                           how much you are moved by the emotional tumult of [fran?ois and mich?le's] relationship depends a lot on how interesting and likable you find them .
# 3  more concerned with overall feelings  broader ideas  and open-ended questions than concrete story and definitive answers  soderbergh's solaris is a gorgeous and deceptively minimalist cinematic tone poem .
# 4                                                                                                                                                                    the charming result is festival in cannes .
# 5                                   as well-acted and well-intentioned as all or nothing is  however  the film comes perilously close to being too bleak  too pessimistic and too unflinching for its own good .
# 6                                                    one of the best examples of how to treat a subject you're not fully aware is being examined much like a photo of yourself you didn't know was being taken .
# 7                                                                                                                                            is an inexpressible and drab wannabe looking for that exact niche .
#
#                                                                                                                                                                                               masked_text  \
# 0                                                                                                                                        by no means a {mask} movie but it is a refreshingly {mask} one .
# 1                                                                                                 cacoyannis is perhaps too {mask} in creating an atmosphere of {mask} stagnation and labored gentility .
# 2                                              how {mask} you are moved by the {mask} tumult of [ fran ? ois and mich ? le 's ] relationship depends a lot on how interesting and likable you find them .
# 3  more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {mask} and deceptively minimalist {mask} tone poem .
# 4                                                                                                                                                                 the {mask} result is {mask} in cannes .
# 5                                  as {mask} and well-intentioned as all or nothing is however the film comes perilously close to being too {mask} too pessimistic and too unflinching for its own good .
# 6                                        one of the {mask} examples of how to treat a subject you 're not fully {mask} is being examined much like a photo of yourself you did n't know was being taken .
# 7                                                                                                                                          is an {mask} and {mask} wannabe looking for that exact niche .
#
#                                                                                                                                                                                                   template_text
# 0                                                                                                                                        by no means a {pos_adj} movie but it is a refreshingly {pos_adj} one .
# 1                                                                                                 cacoyannis is perhaps too {pos_adj} in creating an atmosphere of {neg_adj} stagnation and labored gentility .
# 2                                              how {pos_adj} you are moved by the {pos_adj} tumult of [ fran ? ois and mich ? le 's ] relationship depends a lot on how interesting and likable you find them .
# 3  more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {pos_adj} and deceptively minimalist {pos_adj} tone poem .
# 4                                                                                                                                                                 the {pos_adj} result is {pos_adj} in cannes .
# 5                                  as {pos_adj} and well-intentioned as all or nothing is however the film comes perilously close to being too {pos_adj} too pessimistic and too unflinching for its own good .
# 6                                        one of the {pos_adj} examples of how to treat a subject you 're not fully {pos_adj} is being examined much like a photo of yourself you did n't know was being taken .
# 7                                                                                                                                          is an {neg_adj} and {neg_adj} wannabe looking for that exact niche .

# %%
tg0.lexicons
# Out:
# {'pos_adj': ['intelligent',
#   'great',
#   'unflinching',
#   'sound',
#   'deceptively',
#   'gorgeous'],
#  'neg_adj': ['pessimistic',
#   'dull',
#   'self-indulgent',
#   'comedic',
#   'drab',
#   'human',
#   'inexpressible',
#   'sardonic',
#   'minimalist',
#   'vapid',
#   'consuming',
#   'caustic',
#   'notorious',
#   'little',
#   'difficult',
#   'pompous']}

# %%
tg1.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg2.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %%
tg3.lexicons
# Out:
# {'pos_adj': ['great', 'delicious', 'fascinating'],
#  'neg_adj': ['drab', 'inexpressible', 'empty', '/', 'vapid']}

# %%
tg4.lexicons
# Out:
# {'pos_adj': ['aware',
#   'effective',
#   'charming',
#   'great',
#   'emotional',
#   'cinematic',
#   'much',
#   'well-acted',
#   'forthright',
#   'bleak',
#   'best',
#   'gorgeous',
#   'festival'],
#  'neg_adj': ['dust-caked', 'inexpressible', 'drab']}

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 4m 17.8s

# %% [markdown]
# ## Checklist

# %% [markdown]
# #### Model BERT

# %%
import checklist
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg0.lexicons
templates0 = tg0.template_texts
masked = tg0.masked_texts
labels = [sent.prediction.label for sent in tg0.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates0, labels, range(len(templates0))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model_bert.predict, overwrite=True)
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 96 examples
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 16 examples
# Running Test: MFT with vocabullary - template3
# Predicting 16 examples
# Running Test: MFT with vocabullary - template4
# Predicting 16 examples
# Running Test: MFT with vocabullary - template5
# Predicting 16 examples
# Running Test: MFT with vocabullary - template6
# Predicting 6 examples
# Running Test: MFT with vocabullary - template7
# Predicting 96 examples
# Running Test: MFT with vocabullary - template8
# Predicting 16 examples
# Running Test: MFT with vocabullary - template9
# Predicting 6 examples
# Running Test: MFT with vocabullary - template10
# Predicting 16 examples
# Running Test: MFT with vocabullary - template11
# Predicting 16 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      96
# Fails (rate):    25 (26.0%)
#
# Example fails:
# 0.0 deceptively caustic take on a great writer and dubious pompous being .
# ----
# 0.0 deceptively caustic take on a great writer and dubious minimalist being .
# ----
# 0.0 deceptively caustic take on a great writer and dubious little being .
# ----
#
#
# Test: MFT with vocabullary - template2
# Test cases:      16
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template3
# Test cases:      16
# Fails (rate):    3 (18.8%)
#
# Example fails:
# 0.9 as notorious spotlights go notorious c .
# ----
# 0.9 as human spotlights go human c .
# ----
# 0.8 as little spotlights go little c .
# ----
#
#
# Test: MFT with vocabullary - template4
# Test cases:      16
# Fails (rate):    2 (12.5%)
#
# Example fails:
# 0.8 an empty exercise a florid but ultimately human crime melodrama with lots of surface flash but human emotional resonance .
# ----
# 1.0 an empty exercise a florid but ultimately comedic crime melodrama with lots of surface flash but comedic emotional resonance .
# ----
#
#
# Test: MFT with vocabullary - template5
# Test cases:      16
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template6
# Test cases:      6
# Fails (rate):    2 (33.3%)
#
# Example fails:
# 0.1 more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a sound and sound minimalist cinematic tone poem .
# ----
# 0.0 more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a deceptively and deceptively minimalist cinematic tone poem .
# ----
#
#
# Test: MFT with vocabullary - template7
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template8
# Test cases:      16
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template9
# Test cases:      6
# Fails (rate):    1 (16.7%)
#
# Example fails:
# 0.1 scooby dooby doo / and shaggy too / you both look and deceptively deceptively .
# ----
#
#
# Test: MFT with vocabullary - template10
# Test cases:      16
# Fails (rate):    9 (56.2%)
#
# Example fails:
# 0.0 whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a little verve to their little purpose for existing who is cletis tout ?
# ----
# 0.0 whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a dull verve to their dull purpose for existing who is cletis tout ?
# ----
# 0.2 whereas the extremely competent hitman films such as pulp fiction and get shorty resonate a difficult verve to their difficult purpose for existing who is cletis tout ?
# ----
#
#
# Test: MFT with vocabullary - template11
# Test cases:      16
# Fails (rate):    1 (6.2%)
#
# Example fails:
# 0.6 is an consuming and consuming wannabe looking for that exact niche .
# ----

# %%
suite.save('./suites/posneg-approach5-bert.suite')

# %% [markdown]
# #### Model Albert

# %%
lexicons = tg1.lexicons
templates1 = tg1.template_texts
masked = tg1.masked_texts
labels = [sent.prediction.label for sent in tg1.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates1, labels, range(len(templates1))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model_albert.predict, overwrite=True)

# %%
suite.summary()

# %%
suite.save('./suites/posneg-approach5-albert.suite')

# %% [markdown]
# #### Model Distilbert

# %%
lexicons = tg2.lexicons
templates2 = tg2.template_texts
masked = tg2.masked_texts
labels = [sent.prediction.label for sent in tg2.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates2, labels, range(len(templates2))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model_distilbert.predict, overwrite=True)

# %%
suite.summary()

# %%
suite.save('./suites/posneg-approach5-distilbert.suite')

# %% [markdown]
# #### Model Roberta

# %%
lexicons = tg3.lexicons
templates3 = tg3.template_texts
masked = tg3.masked_texts
labels = [sent.prediction.label for sent in tg3.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates3, labels, range(len(templates3))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model_roberta.predict, overwrite=True)
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 3 examples
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 5 examples
# Running Test: MFT with vocabullary - template3
# Predicting 15 examples
# Running Test: MFT with vocabullary - template4
# Predicting 5 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      3
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template2
# Test cases:      5
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template3
# Test cases:      15
# Fails (rate):    12 (80.0%)
#
# Example fails:
# 0.1 scooby dooby doo / and shaggy too vapid you both look and sound delicious .
# ----
# 0.2 scooby dooby doo / and shaggy too drab you both look and sound delicious .
# ----
# 0.0 scooby dooby doo / and shaggy too empty you both look and sound great .
# ----
#
#
# Test: MFT with vocabullary - template4
# Test cases:      5
# Fails (rate):    0 (0.0%)

# %%
suite.save('./suites/posneg-approach5-roberta.suite')

# %% [markdown]
# #### Model Xlnet

# %%
lexicons = tg4.lexicons
templates4 = tg4.template_texts
masked = tg4.masked_texts
labels = [sent.prediction.label for sent in tg4.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates4, labels, range(len(templates4))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model_xlnet.predict, overwrite=True)
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 13 examples
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 39 examples
# Running Test: MFT with vocabullary - template3
# Predicting 13 examples
# Running Test: MFT with vocabullary - template4
# Predicting 13 examples
# Running Test: MFT with vocabullary - template5
# Predicting 13 examples
# Running Test: MFT with vocabullary - template6
# Predicting 13 examples
# Running Test: MFT with vocabullary - template7
# Predicting 13 examples
# Running Test: MFT with vocabullary - template8
# Predicting 3 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      13
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template2
# Test cases:      39
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template3
# Test cases:      13
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template4
# Test cases:      13
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template5
# Test cases:      13
# Fails (rate):    4 (30.8%)
#
# Example fails:
# 0.0 the bleak result is bleak in cannes .
# ----
# 0.1 the much result is much in cannes .
# ----
# 0.4 the aware result is aware in cannes .
# ----
#
#
# Test: MFT with vocabullary - template6
# Test cases:      13
# Fails (rate):    1 (7.7%)
#
# Example fails:
# 0.6 as effective and well-intentioned as all or nothing is however the film comes perilously close to being too effective too pessimistic and too unflinching for its own good .
# ----
#
#
# Test: MFT with vocabullary - template7
# Test cases:      13
# Fails (rate):    4 (30.8%)
#
# Example fails:
# 0.2 one of the bleak examples of how to treat a subject you 're not fully bleak is being examined much like a photo of yourself you did n't know was being taken .
# ----
# 0.2 one of the effective examples of how to treat a subject you 're not fully effective is being examined much like a photo of yourself you did n't know was being taken .
# ----
# 0.4 one of the well-acted examples of how to treat a subject you 're not fully well-acted is being examined much like a photo of yourself you did n't know was being taken .
# ----
#
#
# Test: MFT with vocabullary - template8
# Test cases:      3
# Fails (rate):    0 (0.0%)

# %%
suite.save('./suites/posneg-approach5-xlnet.suite')

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach5-roberta.suite')

suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…
