# %% [markdown]
# # Abordagem 5
#
# Usando a abordagem 5 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística "Vocabulary" com o teste MFT.
#
# As etapas desta abordagem são:
#
# 1. Quebrar as instâncias em sentenças
# 2. Rankear as palavras de cada sentença
# 3. Filtrar as sentenças pelo tamanho (maior ou igual a 5 palavras)
# 4. Filtrar sentenças com palavras relevantes (verbos ou adjetivos)
# 5. Filtrar sentenças com alta confiança na predição das palavras relevantes da etapa anterior
# 6. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

movie_reviews_rt_df = pd.read_csv('./data/data-rt-1000samples.csv')
movie_reviews_rt_df.head(5)
# Out:
#    label  \
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
#                                                                              text  \
# 0      drumline ably captures the complicated relationships in a marching band .
# 1  delivers roughly equal amounts of beautiful movement and inside information .
# 2             saved from being merely way-cool by a basic  credible compassion .
# 3                          this is a movie full of grace and  ultimately  hope .
# 4              the imax screen enhances the personal touch of manual animation .
#
#    words
# 0     11
# 1     11
# 2     11
# 3     11
# 4     11

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
movie_reviews_models = {
    'bert': 'textattack/bert-base-uncased-rotten-tomatoes', 
    'albert': 'textattack/albert-base-v2-rotten-tomatoes', 
    'distilbert': 'textattack/distilbert-base-uncased-rotten-tomatoes', 
    'roberta': 'textattack/roberta-base-rotten-tomatoes', 
    'xlnet': 'textattack/xlnet-base-cased-rotten-tomatoes'
}

# %%
m1 = load_model(movie_reviews_models['albert'])
m2 = load_model(movie_reviews_models['distilbert'])
m3 = load_model(movie_reviews_models['roberta'])
m4 = load_model(movie_reviews_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(movie_reviews_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-rotten-tomatoes...
# Loading model textattack/distilbert-base-uncased-rotten-tomatoes...
# Loading model textattack/roberta-base-rotten-tomatoes...
# Some weights of the model checkpoint at textattack/roberta-base-rotten-tomatoes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-rotten-tomatoes...
# Loading model textattack/bert-base-uncased-rotten-tomatoes...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp5

tg = PosNegTemplateGeneratorApp5(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = movie_reviews_rt_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
tg = PosNegTemplateGeneratorApp5(model, models)
templates = tg.generate_templates(instances, n_masks=2, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 9 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 6 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['VERB', 'ADJ']
# {word: useless, index: 14, tag: ADJ, rank_score: -0.9901103973388672}
# {word: 's, index: 29, tag: VERB, rank_score: -0.17541933059692383}
# {word: endlessly, index: 23, tag: ADV, rank_score: -0.08397835493087769}
# {word: of, index: 18, tag: ADP, rank_score: -0.030595242977142334}
#
# ['VERB', 'ADJ']
# {word: rejected, index: 19, tag: ADJ, rank_score: -0.00044840574264526367}
# {word: partway, index: 0, tag: ADV, rank_score: -0.00021529197692871094}
# {word: concoction, index: 6, tag: NOUN, rank_score: -9.399652481079102e-05}
# {word: episodes, index: 16, tag: NOUN, rank_score: -8.362531661987305e-05}
#
# ['VERB', 'ADJ']
# {word: either, index: 10, tag: ADV, rank_score: -0.9519476294517517}
# {word: rolling, index: 19, tag: VERB, rank_score: -0.8553882241249084}
# {word: your, index: 20, tag: PRON, rank_score: -0.517669677734375}
# {word: or, index: 18, tag: CONJ, rank_score: -0.12410521507263184}
#
# ['VERB', 'ADJ']
# {word: incredible, index: 32, tag: ADJ, rank_score: -0.019590258598327637}
# {word: 's, index: 28, tag: PRT, rank_score: -0.0004863142967224121}
# {word: 'performance, index: 29, tag: NOUN, rank_score: 0.0003943443298339844}
# {word: is, index: 31, tag: VERB, rank_score: -0.0002752542495727539}
#
# ['VERB', 'ADJ']
# {word: overcome, index: 21, tag: VERB, rank_score: -0.0029458999633789062}
# {word: part, index: 6, tag: NOUN, rank_score: -0.0015453696250915527}
# {word: always, index: 4, tag: ADV, rank_score: -0.0013220906257629395}
# {word: creative, index: 27, tag: ADJ, rank_score: -0.0011140704154968262}
#
# ['VERB', 'ADJ']
# {word: remarkable, index: 1, tag: ADJ, rank_score: -0.3234296441078186}
# {word: movie, index: 2, tag: NOUN, rank_score: -0.0002493858337402344}
# {word: which, index: 7, tag: DET, rank_score: 0.00017583370208740234}
# {word: point, index: 11, tag: NOUN, rank_score: -0.00016498565673828125}
#
# :: 3 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 1 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 9.1s

# %%
df = tg.to_dataframe()
df
# Out:
#    label  \
# 0      1
#
#                                                                                                                                                                               original_text  \
# 0  but tongue-in-cheek preposterousness has always been part of for the most part wilde's droll whimsy helps " being earnest " overcome its weaknesses and parker's creative interference .
#
#                                                                                                                                                                                 masked_text  \
# 0  but tongue-in-cheek preposterousness has always been part of for the most part wilde 's droll whimsy helps `` being earnest `` {mask} its weaknesses and parker 's {mask} interference .
#
#                                                                                                                                                                                      template_text
# 0  but tongue-in-cheek preposterousness has always been part of for the most part wilde 's droll whimsy helps `` being earnest `` {neg_verb} its weaknesses and parker 's {pos_adj} interference .

# %%
tg.lexicons
# Out:
# {'pos_verb': [],
#  'neg_verb': ['overcome'],
#  'pos_adj': ['creative'],
#  'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in movie_reviews_rt_df['text'].values]

# %%
tg = PosNegTemplateGeneratorApp5(model, models)
templates = tg.generate_templates(instances, n_masks=2, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 1473 sentences were generated.
# Ranking words using Replace-1 Score...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Word ranking done.
# Filtering instances by contaning a minimmum of words: 5...
# :: 1202 sentences remaining.
# 4
# Filtering instances by relevant words...
# ['VERB', 'ADJ']
# {word: captures, index: 2, tag: VERB, rank_score: -0.016763925552368164}
# {word: ably, index: 1, tag: ADV, rank_score: -0.00023543834686279297}
# {word: drumline, index: 0, tag: NOUN, rank_score: -4.45246696472168e-05}
# {word: in, index: 6, tag: ADP, rank_score: 3.7610530853271484e-05}
#
# ['VERB', 'ADJ']
# {word: amounts, index: 3, tag: NOUN, rank_score: -0.016751408576965332}
# {word: equal, index: 2, tag: ADJ, rank_score: -0.011423766613006592}
# {word: beautiful, index: 5, tag: ADJ, rank_score: -0.0007750988006591797}
# {word: of, index: 4, tag: ADP, rank_score: -0.00031381845474243164}
#
# ['VERB', 'ADJ']
# {word: credible, index: 8, tag: ADJ, rank_score: -0.15513300895690918}
# {word: basic, index: 7, tag: ADJ, rank_score: -0.12215662002563477}
# {word: compassion, index: 9, tag: NOUN, rank_score: 0.06949269771575928}
# {word: saved, index: 0, tag: VERB, rank_score: 0.06846404075622559}
#
# ['VERB', 'ADJ']
# {word: of, index: 5, tag: ADP, rank_score: 0.0004849433898925781}
# {word: grace, index: 6, tag: NOUN, rank_score: 0.0003933906555175781}
# {word: full, index: 4, tag: ADJ, rank_score: 0.0003840923309326172}
# {word: this, index: 0, tag: DET, rank_score: 0.0003643035888671875}
#
# ['VERB', 'ADJ']
# {word: the, index: 4, tag: DET, rank_score: -0.0007897615432739258}
# {word: animation, index: 9, tag: NOUN, rank_score: -0.0001970529556274414}
# {word: screen, index: 2, tag: NOUN, rank_score: 0.00017589330673217773}
# {word: imax, index: 1, tag: NOUN, rank_score: -0.00016736984252929688}
#
# ['VERB', 'ADJ']
# {word: plumbed, index: 6, tag: VERB, rank_score: -0.00048214197158813477}
# {word: thoroughly, index: 5, tag: ADV, rank_score: -0.00033080577850341797}
# {word: a, index: 0, tag: DET, rank_score: -0.00027251243591308594}
# {word: retread, index: 1, tag: NOUN, rank_score: -0.0001996755599975586}
#
# ['VERB', 'ADJ']
# {word: guns, index: 7, tag: NOUN, rank_score: -0.9808956980705261}
# {word: with, index: 6, tag: ADP, rank_score: -0.6783568859100342}
# {word: almost, index: 1, tag: ADV, rank_score: -0.012859642505645752}
# {word: plays, index: 2, tag: VERB, rank_score: -0.005383193492889404}
#
# ['VERB', 'ADJ']
# {word: documentary, index: 9, tag: NOUN, rank_score: -0.00033599138259887695}
# {word: better, index: 4, tag: ADJ, rank_score: -0.0002060532569885254}
# {word: tv, index: 8, tag: NOUN, rank_score: -0.00015842914581298828}
# {word: as, index: 5, tag: ADP, rank_score: -7.599592208862305e-05}
#
# ['VERB', 'ADJ']
# {word: greatness, index: 10, tag: NOUN, rank_score: -0.23366916179656982}
# {word: case, index: 5, tag: NOUN, rank_score: -0.02469456195831299}
# {word: for, index: 6, tag: ADP, rank_score: -0.006116926670074463}
# {word: makes, index: 0, tag: VERB, rank_score: -0.0054541826248168945}
#
# ['VERB', 'ADJ']
# {word: same, index: 8, tag: ADJ, rank_score: -0.0010932683944702148}
# {word: subversive, index: 5, tag: ADJ, rank_score: -0.0010884404182434082}
# {word: and, index: 4, tag: CONJ, rank_score: -0.0007184743881225586}
# {word: time, index: 9, tag: NOUN, rank_score: -0.00026929378509521484}
#
# ['VERB', 'ADJ']
# {word: factor, index: 9, tag: NOUN, rank_score: -0.0005759000778198242}
# {word: not, index: 5, tag: ADV, rank_score: -0.00021886825561523438}
# {word: cheesy, index: 7, tag: NOUN, rank_score: -0.00021129846572875977}
# {word: without, index: 6, tag: ADP, rank_score: -6.604194641113281e-05}
#
# ['VERB', 'ADJ']
# {word: it, index: 0, tag: PRON, rank_score: -0.0004920363426208496}
# {word: bad, index: 2, tag: ADJ, rank_score: -0.0003458857536315918}
# {word: certainly, index: 4, tag: ADV, rank_score: -0.00023680925369262695}
# {word: as, index: 8, tag: ADP, rank_score: -0.00020360946655273438}
#
# ['VERB', 'ADJ']
# {word: fans, index: 0, tag: NOUN, rank_score: -4.9114227294921875e-05}
# {word: work, index: 10, tag: NOUN, rank_score: 4.881620407104492e-05}
# {word: minute, index: 6, tag: NOUN, rank_score: -4.2557716369628906e-05}
# {word: of, index: 1, tag: ADP, rank_score: 4.178285598754883e-05}
#
# ['VERB', 'ADJ']
# {word: soap, index: 8, tag: NOUN, rank_score: -0.000277101993560791}
# {word: humorless, index: 7, tag: NOUN, rank_score: -0.00021135807037353516}
# {word: opera, index: 9, tag: NOUN, rank_score: -0.00012183189392089844}
# {word: dreary, index: 6, tag: ADJ, rank_score: 6.943941116333008e-05}
#
# ['VERB', 'ADJ']
# {word: money, index: 9, tag: NOUN, rank_score: -0.14542639255523682}
# {word: cry, index: 6, tag: VERB, rank_score: -0.043863534927368164}
# {word: for, index: 7, tag: ADP, rank_score: 0.01313704252243042}
# {word: back, index: 10, tag: ADV, rank_score: 0.01300966739654541}
#
# ['VERB', 'ADJ']
# {word: refreshingly, index: 8, tag: ADV, rank_score: 0.0003312230110168457}
# {word: very, index: 0, tag: ADV, rank_score: 0.0001919865608215332}
# {word: psychoanalytical, index: 1, tag: ADJ, rank_score: 0.0001876354217529297}
# {word: provocatively, index: 3, tag: ADV, rank_score: -0.00017881393432617188}
#
# ['VERB', 'ADJ']
# {word: bluster, index: 7, tag: NOUN, rank_score: -0.1760573387145996}
# {word: more, index: 6, tag: ADJ, rank_score: -0.007565498352050781}
# {word: bite, index: 9, tag: NOUN, rank_score: -0.0020605921745300293}
# {word: next, index: 2, tag: ADJ, rank_score: -0.000826716423034668}
#
# ['VERB', 'ADJ']
# {word: the, index: 1, tag: DET, rank_score: -0.004450201988220215}
# {word: misleading, index: 2, tag: ADJ, rank_score: 0.0015047192573547363}
# {word: baboon, index: 9, tag: NOUN, rank_score: -0.0013790130615234375}
# {word: title, index: 3, tag: NOUN, rank_score: 0.001033186912536621}
#
# ['VERB', 'ADJ']
# {word: dodgy, index: 0, tag: ADJ, rank_score: -0.9482985734939575}
# {word: of, index: 2, tag: ADP, rank_score: -0.001014411449432373}
# {word: cutesy, index: 3, tag: NOUN, rank_score: -0.00019031763076782227}
# {word: mixture, index: 1, tag: NOUN, rank_score: -0.00017374753952026367}
#
# ['VERB', 'ADJ']
# {word: fun, index: 10, tag: NOUN, rank_score: -0.7092455625534058}
# {word: ages, index: 5, tag: NOUN, rank_score: -0.3206760883331299}
# {word: n't, index: 8, tag: ADV, rank_score: -0.09627324342727661}
# {word: that, index: 6, tag: DET, rank_score: -0.004769265651702881}
#
# ['VERB', 'ADJ']
# {word: dickens, index: 5, tag: NOUN, rank_score: -0.0019325613975524902}
# {word: light-hearted, index: 9, tag: ADJ, rank_score: 0.0009840726852416992}
# {word: knew, index: 3, tag: VERB, rank_score: 0.00089263916015625}
# {word: who, index: 2, tag: PRON, rank_score: -0.0006473660469055176}
#
# ['VERB', 'ADJ']
# {word: too, index: 8, tag: ADV, rank_score: -0.9982709884643555}
# {word: seriously, index: 9, tag: ADV, rank_score: -0.00016158819198608398}
# {word: unsophisticated, index: 1, tag: ADJ, rank_score: -0.00015670061111450195}
# {word: an, index: 0, tag: DET, rank_score: 9.322166442871094e-05}
#
# ['VERB', 'ADJ']
# {word: escaped, index: 3, tag: VERB, rank_score: -0.5673788785934448}
# {word: network, index: 6, tag: NOUN, rank_score: -0.06677037477493286}
# {word: lifetime, index: 5, tag: NOUN, rank_score: -0.0026034116744995117}
# {word: never, index: 9, tag: ADV, rank_score: -0.002225041389465332}
#
# ['VERB', 'ADJ']
# {word: low, index: 7, tag: NOUN, rank_score: -0.0077800750732421875}
# {word: on, index: 8, tag: ADP, rank_score: -0.0009397268295288086}
# {word: script, index: 1, tag: NOUN, rank_score: -0.00034493207931518555}
# {word: squaddie, index: 5, tag: ADJ, rank_score: -0.0003082752227783203}
#
# ['VERB', 'ADJ']
# {word: fine, index: 4, tag: ADJ, rank_score: -0.0003739595413208008}
# {word: movie, index: 5, tag: NOUN, rank_score: -0.0002678036689758301}
# {word: see, index: 8, tag: VERB, rank_score: -0.00026553869247436523}
# {word: go, index: 7, tag: VERB, rank_score: -0.0002530217170715332}
#
# ['VERB', 'ADJ']
# {word: film, index: 9, tag: NOUN, rank_score: -0.0016916394233703613}
# {word: stop, index: 2, tag: NOUN, rank_score: -0.0014194250106811523}
# {word: someone, index: 1, tag: NOUN, rank_score: -0.0013156533241271973}
# {word: another, index: 8, tag: DET, rank_score: -0.0008489489555358887}
#
# ['VERB', 'ADJ']
# {word: stopped, index: 8, tag: VERB, rank_score: -0.9533160924911499}
# {word: himself, index: 10, tag: PRON, rank_score: 0.041027963161468506}
# {word: it, index: 0, tag: PRON, rank_score: 0.04018855094909668}
# {word: has, index: 7, tag: VERB, rank_score: 0.03778254985809326}
#
# ['VERB', 'ADJ']
# {word: offers, index: 0, tag: NOUN, rank_score: -0.001179516315460205}
# {word: the, index: 4, tag: DET, rank_score: -0.00035256147384643555}
# {word: breath, index: 2, tag: NOUN, rank_score: 0.00032073259353637695}
# {word: air, index: 6, tag: NOUN, rank_score: 0.0001812577247619629}
#
# ['VERB', 'ADJ']
# {word: ploughing, index: 3, tag: VERB, rank_score: -0.02457737922668457}
# {word: too, index: 8, tag: ADV, rank_score: -0.016866087913513184}
# {word: often, index: 9, tag: ADV, rank_score: -0.002629220485687256}
# {word: may, index: 1, tag: VERB, rank_score: -0.0010685324668884277}
#
# ['VERB', 'ADJ']
# {word: more, index: 4, tag: ADV, rank_score: -0.0073683857917785645}
# {word: the, index: 8, tag: DET, rank_score: -0.0020132064819335938}
# {word: barbarian, index: 9, tag: NOUN, rank_score: -0.0018932223320007324}
# {word: conan, index: 7, tag: VERB, rank_score: -0.0018603205680847168}
#
# ['VERB', 'ADJ']
# {word: and, index: 2, tag: CONJ, rank_score: -0.002755403518676758}
# {word: cry, index: 0, tag: NOUN, rank_score: -0.001453399658203125}
# {word: havoc, index: 1, tag: NOUN, rank_score: -0.0010724067687988281}
# {word: slip, index: 4, tag: VERB, rank_score: -0.000761866569519043}
#
# ['VERB', 'ADJ']
# {word: besson, index: 5, tag: NOUN, rank_score: 0.00041162967681884766}
# {word: arguably, index: 0, tag: ADV, rank_score: -0.00017690658569335938}
# {word: years, index: 9, tag: NOUN, rank_score: 0.00012737512588500977}
# {word: has, index: 6, tag: VERB, rank_score: -0.0001043081283569336}
#
# ['VERB', 'ADJ']
# {word: emotional, index: 8, tag: ADJ, rank_score: -0.0002446174621582031}
# {word: celebrates, index: 1, tag: VERB, rank_score: -7.253885269165039e-05}
# {word: and, index: 5, tag: CONJ, rank_score: -4.464387893676758e-05}
# {word: wallop, index: 9, tag: NOUN, rank_score: -3.629922866821289e-05}
#
# ['VERB', 'ADJ']
# {word: viewing, index: 6, tag: NOUN, rank_score: -0.00033605098724365234}
# {word: good, index: 5, tag: ADJ, rank_score: -0.00027251243591308594}
# {word: women, index: 10, tag: NOUN, rank_score: -0.00026810169219970703}
# {word: a, index: 3, tag: DET, rank_score: -0.00024574995040893555}
#
# ['VERB', 'ADJ']
# {word: funny, index: 6, tag: ADJ, rank_score: -0.007185399532318115}
# {word: to, index: 9, tag: PRT, rank_score: -0.00046175718307495117}
# {word: start, index: 8, tag: NOUN, rank_score: -0.0002651810646057129}
# {word: finish, index: 10, tag: VERB, rank_score: -0.00018483400344848633}
#
# ['VERB', 'ADJ']
# {word: sappy, index: 10, tag: ADJ, rank_score: -0.00011992454528808594}
# {word: 'dragonfly, index: 0, tag: PRT, rank_score: -6.157159805297852e-05}
# {word: mumbo, index: 5, tag: ADJ, rank_score: -4.2557716369628906e-05}
# {word: sentimentality, index: 8, tag: NOUN, rank_score: 4.082918167114258e-05}
#
# ['VERB', 'ADJ']
# {word: film, index: 1, tag: NOUN, rank_score: -0.040049850940704346}
# {word: use, index: 7, tag: VERB, rank_score: -0.03778338432312012}
# {word: few, index: 9, tag: ADJ, rank_score: -0.03280508518218994}
# {word: could, index: 6, tag: VERB, rank_score: -0.02944272756576538}
#
# ['VERB', 'ADJ']
# {word: movie, index: 4, tag: NOUN, rank_score: -6.133317947387695e-05}
# {word: just, index: 6, tag: ADV, rank_score: -5.97834587097168e-05}
# {word: is, index: 5, tag: VERB, rank_score: -5.501508712768555e-05}
# {word: a, index: 7, tag: DET, rank_score: -4.380941390991211e-05}
#
# ['VERB', 'ADJ']
# {word: a, index: 0, tag: DET, rank_score: -0.00013768672943115234}
# {word: power, index: 7, tag: NOUN, rank_score: -8.350610733032227e-05}
# {word: politics, index: 6, tag: NOUN, rank_score: -4.8220157623291016e-05}
# {word: humorous, index: 2, tag: ADJ, rank_score: -4.011392593383789e-05}
#
# ['VERB', 'ADJ']
# {word: predictable, index: 3, tag: ADJ, rank_score: -0.00021839141845703125}
# {word: fable, index: 5, tag: ADJ, rank_score: -0.00016176700592041016}
# {word: whimsical, index: 1, tag: ADJ, rank_score: -0.00015914440155029297}
# {word: by, index: 7, tag: ADP, rank_score: -0.00012183189392089844}
#
# ['VERB', 'ADJ']
# {word: film, index: 1, tag: NOUN, rank_score: -0.8130328059196472}
# {word: clearly, index: 3, tag: ADV, rank_score: -0.6888366937637329}
# {word: exclusively, index: 7, tag: ADV, rank_score: -0.564144492149353}
# {word: converted, index: 10, tag: VERB, rank_score: -0.5459791421890259}
#
# ['VERB', 'ADJ']
# {word: motherhood, index: 7, tag: NOUN, rank_score: -0.000283658504486084}
# {word: of, index: 6, tag: ADP, rank_score: -0.0002555251121520996}
# {word: but, index: 2, tag: CONJ, rank_score: 0.00023233890533447266}
# {word: worthwhile, index: 4, tag: ADJ, rank_score: 0.00017124414443969727}
#
# ['VERB', 'ADJ']
# {word: like, index: 1, tag: ADP, rank_score: -0.6379711627960205}
# {word: plays, index: 0, tag: NOUN, rank_score: -0.440060555934906}
# {word: john, index: 2, tag: NOUN, rank_score: 0.05455821752548218}
# {word: carr, index: 4, tag: NOUN, rank_score: 0.05203753709793091}
#
# ['VERB', 'ADJ']
# {word: burnt-out, index: 10, tag: NOUN, rank_score: -0.2047681212425232}
# {word: cylinders, index: 11, tag: NOUN, rank_score: -0.0016199946403503418}
# {word: couple, index: 8, tag: NOUN, rank_score: -0.0002773404121398926}
# {word: with, index: 6, tag: ADP, rank_score: -0.0002709031105041504}
#
# ['VERB', 'ADJ']
# {word: is, index: 5, tag: VERB, rank_score: -0.0005921721458435059}
# {word: level, index: 10, tag: NOUN, rank_score: -0.00032889842987060547}
# {word: what, index: 0, tag: PRON, rank_score: -0.0002644658088684082}
# {word: on, index: 7, tag: ADP, rank_score: 0.00021666288375854492}
#
# ['VERB', 'ADJ']
# {word: mimetic, index: 1, tag: ADJ, rank_score: -0.006756305694580078}
# {word: contempt, index: 7, tag: NOUN, rank_score: -0.0013720393180847168}
# {word: of, index: 3, tag: ADP, rank_score: -0.0007464289665222168}
# {word: a, index: 0, tag: DET, rank_score: 0.000559687614440918}
#
# ['VERB', 'ADJ']
# {word: intelligent, index: 5, tag: ADJ, rank_score: 0.00011897087097167969}
# {word: portrayal, index: 7, tag: NOUN, rank_score: 0.00010335445404052734}
# {word: an, index: 4, tag: DET, rank_score: 7.551908493041992e-05}
# {word: testing, index: 9, tag: VERB, rank_score: -5.728006362915039e-05}
#
# ['VERB', 'ADJ']
# {word: misguided, index: 10, tag: ADJ, rank_score: -0.025107622146606445}
# {word: project, index: 11, tag: NOUN, rank_score: -0.0008965730667114258}
# {word: truth, index: 1, tag: NOUN, rank_score: 0.00033360719680786133}
# {word: charlie, index: 3, tag: NOUN, rank_score: 0.00024121999740600586}
#
# ['VERB', 'ADJ']
# {word: boring, index: 11, tag: ADJ, rank_score: -0.9925422668457031}
# {word: never, index: 10, tag: ADV, rank_score: -0.9922953248023987}
# {word: it, index: 8, tag: PRON, rank_score: -0.9903846979141235}
# {word: but, index: 7, tag: CONJ, rank_score: -0.986747682094574}
#
# ['VERB', 'ADJ']
# {word: ironic, index: 1, tag: ADJ, rank_score: -0.9159948825836182}
# {word: democracy, index: 4, tag: NOUN, rank_score: -0.008212804794311523}
# {word: on, index: 3, tag: ADP, rank_score: -0.005152285099029541}
# {word: an, index: 0, tag: DET, rank_score: -0.0025196075439453125}
#
# ['VERB', 'ADJ']
# {word: simple-minded, index: 9, tag: ADJ, rank_score: -0.0031774044036865234}
# {word: but, index: 5, tag: CONJ, rank_score: -0.0004550814628601074}
# {word: well-meaning, index: 4, tag: ADJ, rank_score: -0.00021958351135253906}
# {word: one, index: 1, tag: NUM, rank_score: -0.00015038251876831055}
#
# ['VERB', 'ADJ']
# {word: campy, index: 1, tag: ADJ, rank_score: -0.9655362367630005}
# {word: schtick, index: 9, tag: ADJ, rank_score: -0.9458976984024048}
# {word: the, index: 0, tag: DET, rank_score: -0.7993348240852356}
# {word: brooks, index: 5, tag: NOUN, rank_score: -0.7610897421836853}
#
# ['VERB', 'ADJ']
# {word: lacking, index: 0, tag: VERB, rank_score: -0.07332688570022583}
# {word: substance, index: 1, tag: NOUN, rank_score: -0.0014441609382629395}
# {word: cutoffs, index: 11, tag: NOUN, rank_score: -0.0005600452423095703}
# {word: up, index: 6, tag: PRT, rank_score: -0.0005487799644470215}
#
# ['VERB', 'ADJ']
# {word: penetrating, index: 1, tag: NOUN, rank_score: -0.33324140310287476}
# {word: glimpse, index: 2, tag: NOUN, rank_score: -0.023245394229888916}
# {word: tissue-thin, index: 5, tag: ADJ, rank_score: 0.0011090636253356934}
# {word: into, index: 3, tag: ADP, rank_score: -0.0010129213333129883}
#
# ['VERB', 'ADJ']
# {word: sendak, index: 2, tag: NOUN, rank_score: -0.0021237730979919434}
# {word: articulate, index: 10, tag: NOUN, rank_score: 0.0010932683944702148}
# {word: are, index: 6, tag: VERB, rank_score: 0.0008824467658996582}
# {word: nor, index: 3, tag: CONJ, rank_score: 0.0005262494087219238}
#
# ['VERB', 'ADJ']
# {word: over-25s, index: 4, tag: ADJ, rank_score: -0.00034618377685546875}
# {word: particularly, index: 9, tag: ADV, rank_score: 0.0002346038818359375}
# {word: with, index: 7, tag: ADP, rank_score: 0.00020188093185424805}
# {word: csokas, index: 8, tag: ADJ, rank_score: 0.00017547607421875}
#
# ['VERB', 'ADJ']
# {word: story, index: 7, tag: NOUN, rank_score: -0.0033187270164489746}
# {word: hypnotic, index: 1, tag: ADJ, rank_score: -0.00018799304962158203}
# {word: and, index: 4, tag: CONJ, rank_score: -8.875131607055664e-05}
# {word: of, index: 8, tag: ADP, rank_score: -7.206201553344727e-05}
#
# ['VERB', 'ADJ']
# {word: above-average, index: 12, tag: ADJ, rank_score: 0.0016527771949768066}
# {word: fincher, index: 1, tag: NOUN, rank_score: 0.0010699629783630371}
# {word: and, index: 6, tag: CONJ, rank_score: 0.001000821590423584}
# {word: thriller, index: 13, tag: NOUN, rank_score: 0.000946044921875}
#
# ['VERB', 'ADJ']
# {word: rip-off, index: 6, tag: NOUN, rank_score: -0.0008635520935058594}
# {word: earlier, index: 12, tag: ADV, rank_score: -0.00029969215393066406}
# {word: imminently, index: 4, tag: ADV, rank_score: 0.0002497434616088867}
# {word: but, index: 3, tag: CONJ, rank_score: 0.0002199411392211914}
#
# ['VERB', 'ADJ']
# {word: too, index: 9, tag: ADV, rank_score: -0.0218125581741333}
# {word: takes, index: 5, tag: VERB, rank_score: 0.00019556283950805664}
# {word: slow-moving, index: 1, tag: ADJ, rank_score: -0.00015866756439208984}
# {word: title, index: 7, tag: NOUN, rank_score: 0.00015628337860107422}
#
# ['VERB', 'ADJ']
# {word: brilliant, index: 6, tag: NOUN, rank_score: -0.7965942025184631}
# {word: word, index: 5, tag: NOUN, rank_score: -0.01602339744567871}
# {word: conflicted, index: 9, tag: ADJ, rank_score: 0.0019396543502807617}
# {word: daniel, index: 10, tag: NOUN, rank_score: 0.001514136791229248}
#
# ['VERB', 'ADJ']
# {word: unless, index: 0, tag: ADP, rank_score: -0.970822274684906}
# {word: advice, index: 7, tag: NOUN, rank_score: -0.9701824188232422}
# {word: is, index: 8, tag: VERB, rank_score: -0.08223390579223633}
# {word: do, index: 12, tag: VERB, rank_score: -0.02395838499069214}
#
# ['VERB', 'ADJ']
# {word: n't, index: 6, tag: ADV, rank_score: -0.012498080730438232}
# {word: maudlin, index: 11, tag: NOUN, rank_score: -0.011522829532623291}
# {word: does, index: 5, tag: VERB, rank_score: -0.00836724042892456}
# {word: wattage, index: 4, tag: NOUN, rank_score: -0.005490422248840332}
#
# ['VERB', 'ADJ']
# {word: haunting, index: 6, tag: VERB, rank_score: -0.0015045404434204102}
# {word: but, index: 4, tag: CONJ, rank_score: 0.0002804398536682129}
# {word: pleasantly, index: 5, tag: ADV, rank_score: 0.0002446770668029785}
# {word: unusual, index: 3, tag: ADJ, rank_score: -0.00019657611846923828}
#
# ['VERB', 'ADJ']
# {word: its, index: 5, tag: PRON, rank_score: -0.0024965405464172363}
# {word: modest, index: 1, tag: ADJ, rank_score: 0.002102494239807129}
# {word: that, index: 3, tag: DET, rank_score: 0.001802682876586914}
# {word: a, index: 0, tag: DET, rank_score: 0.0017941594123840332}
#
# ['VERB', 'ADJ']
# {word: no, index: 5, tag: DET, rank_score: -0.0005860328674316406}
# {word: virtually, index: 4, tag: ADV, rank_score: -0.00029200315475463867}
# {word: at, index: 7, tag: ADP, rank_score: 0.00010651350021362305}
# {word: all, index: 8, tag: DET, rank_score: 2.8312206268310547e-05}
#
# ['VERB', 'ADJ']
# {word: unfulfilling, index: 11, tag: ADJ, rank_score: -0.9968820810317993}
# {word: the, index: 0, tag: DET, rank_score: -0.0004367828369140625}
# {word: but, index: 9, tag: CONJ, rank_score: 0.0003432035446166992}
# {word: constantly, index: 10, tag: ADV, rank_score: -0.000326693058013916}
#
# ['VERB', 'ADJ']
# {word: deliriously, index: 0, tag: ADV, rank_score: -0.00024443864822387695}
# {word: surprises, index: 12, tag: NOUN, rank_score: -0.00024044513702392578}
# {word: accessible, index: 5, tag: ADJ, rank_score: -0.00018793344497680664}
# {word: full, index: 10, tag: ADJ, rank_score: -0.00014102458953857422}
#
# ['VERB', 'ADJ']
# {word: despite, index: 0, tag: ADP, rank_score: 0.0003769993782043457}
# {word: this, index: 4, tag: DET, rank_score: -0.00035184621810913086}
# {word: haunting, index: 10, tag: ADJ, rank_score: -0.0001608133316040039}
# {word: accessible, index: 8, tag: ADJ, rank_score: 0.00014907121658325195}
#
# ['VERB', 'ADJ']
# {word: idiotic, index: 8, tag: ADJ, rank_score: -0.00032824277877807617}
# {word: but, index: 4, tag: CONJ, rank_score: -0.00026279687881469727}
# {word: are, index: 2, tag: VERB, rank_score: -0.00018209218978881836}
# {word: and, index: 9, tag: CONJ, rank_score: 0.00012123584747314453}
#
# ['VERB', 'ADJ']
# {word: to, index: 8, tag: PRT, rank_score: -0.007237374782562256}
# {word: intelligent, index: 4, tag: ADJ, rank_score: -0.003117203712463379}
# {word: one, index: 0, tag: NUM, rank_score: -0.0002727508544921875}
# {word: movies, index: 7, tag: NOUN, rank_score: -0.0002570152282714844}
#
# ['VERB', 'ADJ']
# {word: dusty, index: 8, tag: ADJ, rank_score: -0.0013091564178466797}
# {word: about, index: 4, tag: ADP, rank_score: -0.0011061429977416992}
# {word: film, index: 3, tag: NOUN, rank_score: -0.0008026361465454102}
# {word: entire, index: 2, tag: ADJ, rank_score: -0.0007302165031433105}
#
# ['VERB', 'ADJ']
# {word: case, index: 4, tag: NOUN, rank_score: -0.006206631660461426}
# {word: a, index: 3, tag: DET, rank_score: -0.002813577651977539}
# {word: 'sacre, index: 6, tag: ADJ, rank_score: -0.0008072257041931152}
# {word: bleu, index: 7, tag: NOUN, rank_score: -0.00043392181396484375}
#
# ['VERB', 'ADJ']
# {word: thriller, index: 2, tag: NOUN, rank_score: -0.0023974180221557617}
# {word: and, index: 9, tag: CONJ, rank_score: -0.0020942091941833496}
# {word: morality, index: 11, tag: NOUN, rank_score: -0.000960230827331543}
# {word: level, index: 6, tag: NOUN, rank_score: 0.000640571117401123}
#
# ['VERB', 'ADJ']
# {word: more, index: 11, tag: ADJ, rank_score: -0.7618805170059204}
# {word: still, index: 4, tag: ADV, rank_score: -0.36138391494750977}
# {word: could, index: 8, tag: VERB, rank_score: -0.1673588752746582}
# {word: i, index: 5, tag: ADJ, rank_score: -0.14570891857147217}
#
# ['VERB', 'ADJ']
# {word: punitive, index: 1, tag: ADJ, rank_score: -0.0005069375038146973}
# {word: and, index: 8, tag: CONJ, rank_score: -0.00015985965728759766}
# {word: of, index: 3, tag: ADP, rank_score: -0.00013524293899536133}
# {word: eardrum-dicing, index: 4, tag: ADJ, rank_score: 0.00010383129119873047}
#
# ['VERB', 'ADJ']
# {word: celluloid, index: 11, tag: NOUN, rank_score: -0.00013709068298339844}
# {word: money, index: 9, tag: NOUN, rank_score: -9.22083854675293e-05}
# {word: tired, index: 1, tag: ADJ, rank_score: 8.96453857421875e-05}
# {word: a, index: 0, tag: DET, rank_score: -8.755922317504883e-05}
#
# ['VERB', 'ADJ']
# {word: good, index: 10, tag: ADJ, rank_score: -0.16405636072158813}
# {word: time, index: 11, tag: NOUN, rank_score: 0.0007385611534118652}
# {word: photographed, index: 2, tag: VERB, rank_score: -0.0007002949714660645}
# {word: depth, index: 6, tag: NOUN, rank_score: -0.0004792213439941406}
#
# ['VERB', 'ADJ']
# {word: less, index: 0, tag: ADV, rank_score: -0.0028285980224609375}
# {word: than, index: 7, tag: ADP, rank_score: -0.0009223818778991699}
# {word: handicapped, index: 6, tag: NOUN, rank_score: -0.000272214412689209}
# {word: appeal, index: 3, tag: NOUN, rank_score: 0.00016570091247558594}
#
# ['VERB', 'ADJ']
# {word: occasionally, index: 10, tag: ADV, rank_score: -0.05323612689971924}
# {word: bewildering, index: 11, tag: VERB, rank_score: -0.04900503158569336}
# {word: find, index: 6, tag: VERB, rank_score: -0.004948854446411133}
# {word: unfamiliar, index: 1, tag: ADJ, rank_score: -0.0034793615341186523}
#
# ['VERB', 'ADJ']
# {word: never, index: 10, tag: ADV, rank_score: -0.0062749385833740234}
# {word: comic, index: 8, tag: ADJ, rank_score: -0.0008265376091003418}
# {word: click, index: 11, tag: VERB, rank_score: -0.000573575496673584}
# {word: sort, index: 3, tag: NOUN, rank_score: -0.00020265579223632812}
#
# ['VERB', 'ADJ']
# {word: good, index: 4, tag: ADJ, rank_score: -0.022593438625335693}
# {word: providing, index: 6, tag: VERB, rank_score: -0.006841599941253662}
# {word: quite, index: 3, tag: ADV, rank_score: -0.003200232982635498}
# {word: some, index: 7, tag: DET, rank_score: 0.0016283988952636719}
#
# ['VERB', 'ADJ']
# {word: mediocre, index: 6, tag: NOUN, rank_score: -0.9976217746734619}
# {word: tribute, index: 7, tag: NOUN, rank_score: 0.00027257204055786133}
# {word: to, index: 8, tag: PRT, rank_score: 0.0002689957618713379}
# {word: poster, index: 3, tag: NOUN, rank_score: -0.0001170039176940918}
#
# ['VERB', 'ADJ']
# {word: itself, index: 4, tag: PRON, rank_score: -0.0004952549934387207}
# {word: retreats, index: 6, tag: VERB, rank_score: -0.00037854909896850586}
# {word: and, index: 5, tag: CONJ, rank_score: -0.0003619194030761719}
# {word: comfortable, index: 8, tag: ADJ, rank_score: 0.0001297593116760254}
#
# ['VERB', 'ADJ']
# {word: deliciously, index: 1, tag: ADV, rank_score: -0.9978973269462585}
# {word: comedy, index: 3, tag: NOUN, rank_score: -0.004701793193817139}
# {word: a, index: 0, tag: DET, rank_score: -0.0006123185157775879}
# {word: nonsensical, index: 2, tag: ADJ, rank_score: 0.00047892332077026367}
#
# ['VERB', 'ADJ']
# {word: does, index: 7, tag: VERB, rank_score: -0.9977232217788696}
# {word: n't, index: 8, tag: ADV, rank_score: -0.9953270554542542}
# {word: sometimes, index: 3, tag: ADV, rank_score: -0.9940813779830933}
# {word: compare, index: 9, tag: VERB, rank_score: -0.9830397963523865}
#
# ['VERB', 'ADJ']
# {word: predictable, index: 11, tag: ADJ, rank_score: -0.6966485977172852}
# {word: this, index: 10, tag: DET, rank_score: -0.002282440662384033}
# {word: thriller, index: 12, tag: NOUN, rank_score: -0.0017760396003723145}
# {word: spot, index: 5, tag: VERB, rank_score: -0.0004921555519104004}
#
# ['VERB', 'ADJ']
# {word: tiresomely, index: 2, tag: ADV, rank_score: -0.005311489105224609}
# {word: as, index: 6, tag: ADP, rank_score: -0.002218306064605713}
# {word: if, index: 7, tag: ADP, rank_score: -0.00047147274017333984}
# {word: circularity, index: 8, tag: NOUN, rank_score: -0.0003091096878051758}
#
# ['VERB', 'ADJ']
# {word: nothing, index: 8, tag: NOUN, rank_score: -0.0021140575408935547}
# {word: title, index: 2, tag: NOUN, rank_score: -0.0007843971252441406}
# {word: film, index: 5, tag: NOUN, rank_score: 0.00047153234481811523}
# {word: that, index: 6, tag: DET, rank_score: 0.0004615187644958496}
#
# ['VERB', 'ADJ']
# {word: fun, index: 5, tag: VERB, rank_score: 0.0003401637077331543}
# {word: you, index: 6, tag: PRON, rank_score: 0.00027883052825927734}
# {word: ever, index: 8, tag: ADV, rank_score: -0.00019627809524536133}
# {word: most, index: 4, tag: ADV, rank_score: -0.00014072656631469727}
#
# ['VERB', 'ADJ']
# {word: apparent, index: 3, tag: ADJ, rank_score: -0.9283387064933777}
# {word: past, index: 12, tag: NOUN, rank_score: -0.9035240411758423}
# {word: are, index: 10, tag: VERB, rank_score: -0.29432857036590576}
# {word: long, index: 11, tag: ADJ, rank_score: -0.03405553102493286}
#
# ['VERB', 'ADJ']
# {word: little, index: 1, tag: ADV, rank_score: -0.0007164478302001953}
# {word: has, index: 0, tag: VERB, rank_score: -0.0003401041030883789}
# {word: mind, index: 4, tag: NOUN, rank_score: -0.0002529025077819824}
# {word: its, index: 3, tag: PRON, rank_score: -0.0001952648162841797}
#
# ['VERB', 'ADJ']
# {word: smart, index: 0, tag: NOUN, rank_score: -0.0036085844039916992}
# {word: and, index: 1, tag: CONJ, rank_score: -0.0023352503776550293}
# {word: alert, index: 2, tag: NOUN, rank_score: -0.002114534378051758}
# {word: thirteen, index: 3, tag: ADJ, rank_score: -0.0012822747230529785}
#
# ['VERB', 'ADJ']
# {word: on, index: 3, tag: ADP, rank_score: -0.011962056159973145}
# {word: things, index: 5, tag: NOUN, rank_score: -0.005849301815032959}
# {word: a, index: 0, tag: DET, rank_score: -0.003092169761657715}
# {word: piquant, index: 1, tag: ADJ, rank_score: -0.0017693638801574707}
#
# ['VERB', 'ADJ']
# {word: keener, index: 10, tag: NOUN, rank_score: -0.0007259249687194824}
# {word: best, index: 3, tag: ADJ, rank_score: 0.0006319284439086914}
# {word: pacino, index: 0, tag: NOUN, rank_score: 0.0005907416343688965}
# {word: he, index: 4, tag: PRON, rank_score: 0.00039249658584594727}
#
# ['VERB', 'ADJ']
# {word: if, index: 3, tag: ADP, rank_score: -0.9825282692909241}
# {word: successful, index: 2, tag: ADJ, rank_score: -0.882308304309845}
# {word: kubrick-meets-spielberg, index: 11, tag: ADJ, rank_score: -0.27522802352905273}
# {word: far, index: 0, tag: ADV, rank_score: -0.02266913652420044}
#
# ['VERB', 'ADJ']
# {word: fails, index: 2, tag: VERB, rank_score: -0.9986563920974731}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.00041234493255615234}
# {word: live, index: 4, tag: VERB, rank_score: -0.0001609325408935547}
# {word: to, index: 3, tag: PRT, rank_score: 0.0001016855239868164}
#
# ['VERB', 'ADJ']
# {word: not, index: 4, tag: ADV, rank_score: -0.7573815584182739}
# {word: faulted, index: 6, tag: VERB, rank_score: -0.709808349609375}
# {word: britney, index: 0, tag: NOUN, rank_score: -0.004351496696472168}
# {word: can, index: 3, tag: VERB, rank_score: -0.002993166446685791}
#
# ['VERB', 'ADJ']
# {word: dull, index: 11, tag: ADJ, rank_score: -0.9983533024787903}
# {word: girl, index: 12, tag: NOUN, rank_score: -0.0002759695053100586}
# {word: lucy, index: 8, tag: NOUN, rank_score: -0.0001201629638671875}
# {word: all, index: 15, tag: DET, rank_score: 6.026029586791992e-05}
#
# ['VERB', 'ADJ']
# {word: enjoyable, index: 6, tag: ADJ, rank_score: -0.0001430511474609375}
# {word: both, index: 0, tag: DET, rank_score: -0.00013887882232666016}
# {word: film, index: 7, tag: NOUN, rank_score: -9.757280349731445e-05}
# {word: its, index: 9, tag: PRON, rank_score: 9.655952453613281e-05}
#
# ['VERB', 'ADJ']
# {word: without, index: 6, tag: ADP, rank_score: -0.9940099120140076}
# {word: too, index: 8, tag: ADV, rank_score: -0.9820425510406494}
# {word: times, index: 1, tag: NOUN, rank_score: -0.006171524524688721}
# {word: about, index: 10, tag: ADP, rank_score: 0.002849280834197998}
#
# ['VERB', 'ADJ']
# {word: worth, index: 10, tag: NOUN, rank_score: -0.9539259076118469}
# {word: though, index: 0, tag: ADP, rank_score: -0.6354966163635254}
# {word: somber, index: 8, tag: ADJ, rank_score: -0.2315664291381836}
# {word: is, index: 6, tag: VERB, rank_score: -0.21068096160888672}
#
# ['VERB', 'ADJ']
# {word: assured, index: 3, tag: ADJ, rank_score: -0.9794358611106873}
# {word: of, index: 8, tag: ADP, rank_score: -0.973913848400116}
# {word: modern, index: 9, tag: ADJ, rank_score: -0.4757232069969177}
# {word: direction, index: 4, tag: NOUN, rank_score: -0.02866971492767334}
#
# ['VERB', 'ADJ']
# {word: brainless, index: 3, tag: NOUN, rank_score: -0.002021193504333496}
# {word: disbelief, index: 11, tag: NOUN, rank_score: 0.0010143518447875977}
# {word: watched, index: 1, tag: VERB, rank_score: 0.0009254813194274902}
# {word: the, index: 2, tag: DET, rank_score: 0.0008363127708435059}
#
# ['VERB', 'ADJ']
# {word: wafer-thin, index: 9, tag: ADJ, rank_score: -0.00018852949142456055}
# {word: ordinary, index: 0, tag: ADJ, rank_score: -0.0001233816146850586}
# {word: melodrama, index: 1, tag: NOUN, rank_score: -6.61015510559082e-05}
# {word: on, index: 10, tag: ADP, rank_score: -5.817413330078125e-05}
#
# ['VERB', 'ADJ']
# {word: tale, index: 2, tag: NOUN, rank_score: -0.0002434253692626953}
# {word: a, index: 0, tag: DET, rank_score: -9.632110595703125e-05}
# {word: moving, index: 1, tag: VERB, rank_score: -8.958578109741211e-05}
# {word: of, index: 3, tag: ADP, rank_score: 3.1948089599609375e-05}
#
# ['VERB', 'ADJ']
# {word: remarkable, index: 1, tag: ADJ, rank_score: -0.3234296441078186}
# {word: movie, index: 2, tag: NOUN, rank_score: -0.0002493858337402344}
# {word: which, index: 7, tag: DET, rank_score: 0.00017583370208740234}
# {word: point, index: 11, tag: NOUN, rank_score: -0.00016498565673828125}
#
# ['VERB', 'ADJ']
# {word: beyond, index: 7, tag: ADP, rank_score: -0.004951059818267822}
# {word: good, index: 8, tag: ADJ, rank_score: -0.0013974308967590332}
# {word: gravity, index: 6, tag: NOUN, rank_score: -0.0005502700805664062}
# {word: hair, index: 9, tag: NOUN, rank_score: -0.0002333521842956543}
#
# ['VERB', 'ADJ']
# {word: extravaganza, index: 2, tag: NOUN, rank_score: -0.00044143199920654297}
# {word: slam-bang, index: 1, tag: ADJ, rank_score: -0.0003905296325683594}
# {word: wild-and-woolly, index: 8, tag: ADJ, rank_score: -0.00035899877548217773}
# {word: about, index: 6, tag: ADP, rank_score: -0.0003184080123901367}
#
# ['VERB', 'ADJ']
# {word: less, index: 1, tag: ADV, rank_score: -0.0005262494087219238}
# {word: teenagers, index: 12, tag: NOUN, rank_score: -0.000273287296295166}
# {word: by, index: 11, tag: ADP, rank_score: -0.00012743473052978516}
# {word: about, index: 5, tag: ADP, rank_score: 0.00011664628982543945}
#
# ['VERB', 'ADJ']
# {word: not, index: 9, tag: ADV, rank_score: -0.7726413011550903}
# {word: enough, index: 11, tag: ADV, rank_score: 0.0008235573768615723}
# {word: exactly, index: 3, tag: ADV, rank_score: -0.0008060336112976074}
# {word: 's, index: 8, tag: VERB, rank_score: 0.0007601380348205566}
#
# ['VERB', 'ADJ']
# {word: everyone, index: 0, tag: NOUN, rank_score: -0.034117281436920166}
# {word: the, index: 6, tag: DET, rank_score: -0.0022762417793273926}
# {word: appreciate, index: 5, tag: VERB, rank_score: -0.0013701915740966797}
# {word: wonderful, index: 7, tag: ADJ, rank_score: -0.0010808110237121582}
#
# ['VERB', 'ADJ']
# {word: endurance, index: 6, tag: NOUN, rank_score: -0.0005277395248413086}
# {word: concern, index: 9, tag: NOUN, rank_score: -0.00040453672409057617}
# {word: it, index: 0, tag: PRON, rank_score: 0.00033676624298095703}
# {word: survival, index: 12, tag: NOUN, rank_score: -0.00032830238342285156}
#
# ['VERB', 'ADJ']
# {word: not, index: 1, tag: ADV, rank_score: 0.0005289316177368164}
# {word: breakthrough, index: 4, tag: NOUN, rank_score: 0.0003412961959838867}
# {word: it, index: 8, tag: PRON, rank_score: -0.0003371238708496094}
# {word: unwavering, index: 10, tag: ADJ, rank_score: 0.00029474496841430664}
#
# ['VERB', 'ADJ']
# {word: entertaining, index: 12, tag: ADJ, rank_score: -0.019714415073394775}
# {word: is, index: 4, tag: VERB, rank_score: -0.0034952759742736816}
# {word: widowmaker, index: 3, tag: NOUN, rank_score: -0.0018673539161682129}
# {word: surprisingly, index: 11, tag: ADV, rank_score: 0.0018271207809448242}
#
# ['VERB', 'ADJ']
# {word: unthinkable, index: 12, tag: ADJ, rank_score: -0.6649309396743774}
# {word: is, index: 10, tag: VERB, rank_score: -0.0012063384056091309}
# {word: just, index: 11, tag: ADV, rank_score: -0.0009016990661621094}
# {word: to, index: 0, tag: PRT, rank_score: 0.0005063414573669434}
#
# ['VERB', 'ADJ']
# {word: always, index: 2, tag: ADV, rank_score: -0.9084240794181824}
# {word: yorkers, index: 1, tag: NOUN, rank_score: -0.8921410441398621}
# {word: to, index: 4, tag: PRT, rank_score: -0.5264156460762024}
# {word: places, index: 8, tag: NOUN, rank_score: -0.4303179085254669}
#
# ['VERB', 'ADJ']
# {word: makes, index: 3, tag: VERB, rank_score: 0.00015944242477416992}
# {word: think, index: 5, tag: VERB, rank_score: 0.0001551508903503418}
# {word: majidi, index: 1, tag: NOUN, rank_score: 0.00012099742889404297}
# {word: see, index: 10, tag: VERB, rank_score: 9.918212890625e-05}
#
# ['VERB', 'ADJ']
# {word: moviemaking, index: 12, tag: NOUN, rank_score: -9.357929229736328e-05}
# {word: best, index: 4, tag: ADJ, rank_score: -9.238719940185547e-05}
# {word: life, index: 10, tag: NOUN, rank_score: -2.6047229766845703e-05}
# {word: one, index: 0, tag: NUM, rank_score: -2.4974346160888672e-05}
#
# ['VERB', 'ADJ']
# {word: lost, index: 6, tag: VERB, rank_score: -0.008234977722167969}
# {word: something, index: 3, tag: NOUN, rank_score: -0.00316011905670166}
# {word: appears, index: 1, tag: VERB, rank_score: 0.0018300414085388184}
# {word: it, index: 0, tag: PRON, rank_score: 0.0015027523040771484}
#
# ['VERB', 'ADJ']
# {word: every, index: 7, tag: DET, rank_score: -0.0005706548690795898}
# {word: device, index: 9, tag: NOUN, rank_score: -0.0005677938461303711}
# {word: movie, index: 4, tag: NOUN, rank_score: -0.0001672506332397461}
# {word: cliche-ridden, index: 3, tag: ADJ, rank_score: -0.00016629695892333984}
#
# ['VERB', 'ADJ']
# {word: boring, index: 12, tag: NOUN, rank_score: -0.0005304217338562012}
# {word: makes, index: 7, tag: VERB, rank_score: -0.00011074542999267578}
# {word: does, index: 0, tag: VERB, rank_score: -8.088350296020508e-05}
# {word: it, index: 6, tag: PRON, rank_score: -6.0498714447021484e-05}
#
# ['VERB', 'ADJ']
# {word: forgettable, index: 13, tag: ADJ, rank_score: 0.000246584415435791}
# {word: eminently, index: 12, tag: ADV, rank_score: 0.00014597177505493164}
# {word: self-conscious, index: 8, tag: ADJ, rank_score: -0.00014531612396240234}
# {word: is, index: 10, tag: VERB, rank_score: 0.0001296401023864746}
#
# ['VERB', 'ADJ']
# {word: artful, index: 1, tag: ADJ, rank_score: -0.00047218799591064453}
# {word: confines, index: 8, tag: NOUN, rank_score: 0.00012445449829101562}
# {word: intelligent, index: 2, tag: NOUN, rank_score: 0.00010520219802856445}
# {word: stays, index: 5, tag: VERB, rank_score: 6.574392318725586e-05}
#
# ['VERB', 'ADJ']
# {word: but, index: 3, tag: CONJ, rank_score: -0.014609158039093018}
# {word: amateurishly, index: 1, tag: ADV, rank_score: -0.0031272172927856445}
# {word: occasionally, index: 0, tag: ADV, rank_score: -0.002449214458465576}
# {word: keeps, index: 10, tag: VERB, rank_score: 0.002337336540222168}
#
# ['VERB', 'ADJ']
# {word: pleasures, index: 11, tag: NOUN, rank_score: -0.989874541759491}
# {word: will, index: 8, tag: VERB, rank_score: -0.0007402300834655762}
# {word: film, index: 5, tag: NOUN, rank_score: -0.0004343986511230469}
# {word: its, index: 10, tag: PRON, rank_score: -0.00023120641708374023}
#
# ['VERB', 'ADJ']
# {word: be-all-end-all, index: 8, tag: NOUN, rank_score: -0.0019356012344360352}
# {word: anomie, index: 12, tag: NOUN, rank_score: -0.0017045140266418457}
# {word: modern-office, index: 11, tag: ADJ, rank_score: -0.001109480857849121}
# {word: the, index: 7, tag: DET, rank_score: -0.0004277825355529785}
#
# ['VERB', 'ADJ']
# {word: feels, index: 1, tag: ADJ, rank_score: 0.042832016944885254}
# {word: and, index: 3, tag: CONJ, rank_score: -0.03430658578872681}
# {word: unsatisfying, index: 4, tag: ADJ, rank_score: 0.028271973133087158}
# {word: communion, index: 8, tag: NOUN, rank_score: 0.0273626446723938}
#
# ['VERB', 'ADJ']
# {word: undeserving, index: 4, tag: ADJ, rank_score: -0.020741522312164307}
# {word: most, index: 3, tag: ADV, rank_score: -0.0013241171836853027}
# {word: overkill, index: 8, tag: NOUN, rank_score: -0.0010269880294799805}
# {word: of, index: 6, tag: ADP, rank_score: -0.0008827447891235352}
#
# ['VERB', 'ADJ']
# {word: picture, index: 3, tag: NOUN, rank_score: -0.0010213851928710938}
# {word: a, index: 2, tag: DET, rank_score: -0.00024712085723876953}
# {word: quiet, index: 11, tag: ADJ, rank_score: -0.00021195411682128906}
# {word: lives, index: 5, tag: NOUN, rank_score: -0.0002053380012512207}
#
# ['VERB', 'ADJ']
# {word: holes, index: 8, tag: NOUN, rank_score: -0.0003177523612976074}
# {word: cliche-ridden, index: 3, tag: ADJ, rank_score: -0.00027555227279663086}
# {word: a, index: 0, tag: DET, rank_score: 0.00014275312423706055}
# {word: painfully, index: 1, tag: ADV, rank_score: 0.00013631582260131836}
#
# ['VERB', 'ADJ']
# {word: energy, index: 5, tag: NOUN, rank_score: -0.015183866024017334}
# {word: true, index: 11, tag: ADJ, rank_score: -0.0009484291076660156}
# {word: screen, index: 8, tag: NOUN, rank_score: 0.00019210577011108398}
# {word: like, index: 9, tag: ADP, rank_score: 0.00016033649444580078}
#
# ['VERB', 'ADJ']
# {word: see, index: 6, tag: VERB, rank_score: -0.00109940767288208}
# {word: not, index: 12, tag: ADV, rank_score: 0.0006438493728637695}
# {word: there, index: 0, tag: DET, rank_score: 0.0005985498428344727}
# {word: to, index: 13, tag: PRT, rank_score: 0.0005524158477783203}
#
# ['VERB', 'ADJ']
# {word: effortlessly, index: 10, tag: ADV, rank_score: -0.05319124460220337}
# {word: cascade, index: 6, tag: VERB, rank_score: -0.00231778621673584}
# {word: screen, index: 9, tag: NOUN, rank_score: -0.002106010913848877}
# {word: and, index: 4, tag: CONJ, rank_score: -0.0012319087982177734}
#
# ['VERB', 'ADJ']
# {word: bad, index: 3, tag: ADJ, rank_score: -0.9222913980484009}
# {word: rollerball, index: 0, tag: NOUN, rank_score: -0.14906948804855347}
# {word: than, index: 9, tag: ADP, rank_score: 0.02081143856048584}
# {word: imagine, index: 12, tag: VERB, rank_score: 0.020101964473724365}
#
# ['VERB', 'ADJ']
# {word: message, index: 2, tag: NOUN, rank_score: -0.08778417110443115}
# {word: any, index: 11, tag: DET, rank_score: -0.02748483419418335}
# {word: receive, index: 13, tag: NOUN, rank_score: -0.023500263690948486}
# {word: of, index: 10, tag: ADP, rank_score: -0.010512351989746094}
#
# ['VERB', 'ADJ']
# {word: sole, index: 8, tag: ADJ, rank_score: -0.03171563148498535}
# {word: pompous, index: 4, tag: ADJ, rank_score: -0.0009542107582092285}
# {word: spot, index: 10, tag: NOUN, rank_score: -0.0008748173713684082}
# {word: professor, index: 5, tag: NOUN, rank_score: -0.000537872314453125}
#
# ['VERB', 'ADJ']
# {word: irritating, index: 4, tag: ADJ, rank_score: -0.46803176403045654}
# {word: cartoons, index: 5, tag: NOUN, rank_score: -0.0020639896392822266}
# {word: or, index: 10, tag: CONJ, rank_score: -0.0010758042335510254}
# {word: you, index: 6, tag: PRON, rank_score: 0.00030750036239624023}
#
# ['VERB', 'ADJ']
# {word: without, index: 8, tag: ADP, rank_score: -0.6538898944854736}
# {word: redeeming, index: 10, tag: VERB, rank_score: 0.0021153688430786133}
# {word: value, index: 11, tag: NOUN, rank_score: 0.0016799569129943848}
# {word: whatsoever, index: 12, tag: NOUN, rank_score: 0.0014785528182983398}
#
# ['VERB', 'ADJ']
# {word: no, index: 12, tag: DET, rank_score: -0.809350848197937}
# {word: to, index: 11, tag: PRT, rank_score: -0.01851099729537964}
# {word: one, index: 13, tag: NOUN, rank_score: -0.010615885257720947}
# {word: appeal, index: 10, tag: VERB, rank_score: -0.009666085243225098}
#
# ['VERB', 'ADJ']
# {word: where, index: 8, tag: ADV, rank_score: -0.001287221908569336}
# {word: trivial, index: 0, tag: ADJ, rank_score: -0.00033462047576904297}
# {word: and, index: 6, tag: CONJ, rank_score: -0.00021880865097045898}
# {word: profound, index: 5, tag: ADJ, rank_score: 9.328126907348633e-05}
#
# ['VERB', 'ADJ']
# {word: down, index: 12, tag: PRT, rank_score: -0.005559682846069336}
# {word: families, index: 8, tag: NOUN, rank_score: -0.00045502185821533203}
# {word: me, index: 11, tag: PRON, rank_score: 0.0003966093063354492}
# {word: get, index: 10, tag: VERB, rank_score: -0.00019878149032592773}
#
# ['VERB', 'ADJ']
# {word: and, index: 7, tag: CONJ, rank_score: -0.000977933406829834}
# {word: richly, index: 11, tag: ADV, rank_score: -0.0008608698844909668}
# {word: volatile, index: 6, tag: ADJ, rank_score: 0.0004595518112182617}
# {word: rewarded, index: 12, tag: VERB, rank_score: -0.00040161609649658203}
#
# ['VERB', 'ADJ']
# {word: leafing, index: 1, tag: VERB, rank_score: -0.06322413682937622}
# {word: album, index: 4, tag: NOUN, rank_score: -0.0017451643943786621}
# {word: captions, index: 12, tag: NOUN, rank_score: -0.001655876636505127}
# {word: by, index: 8, tag: ADP, rank_score: -0.0014910101890563965}
#
# ['VERB', 'ADJ']
# {word: but, index: 8, tag: CONJ, rank_score: -0.01975858211517334}
# {word: this, index: 9, tag: DET, rank_score: -0.004604339599609375}
# {word: batch, index: 10, tag: NOUN, rank_score: -0.001445174217224121}
# {word: vegetables, index: 7, tag: NOUN, rank_score: -0.0013172030448913574}
#
# ['VERB', 'ADJ']
# {word: so, index: 6, tag: ADV, rank_score: -0.0036774277687072754}
# {word: produced, index: 9, tag: VERB, rank_score: -0.0006108283996582031}
# {word: much, index: 7, tag: ADV, rank_score: -0.0005336403846740723}
# {word: n't, index: 2, tag: ADV, rank_score: -0.00024062395095825195}
#
# ['VERB', 'ADJ']
# {word: fun, index: 12, tag: NOUN, rank_score: -0.005870163440704346}
# {word: if, index: 0, tag: ADP, rank_score: 0.00036901235580444336}
# {word: you, index: 1, tag: PRON, rank_score: -0.0003401041030883789}
# {word: one, index: 13, tag: NUM, rank_score: 0.00029581785202026367}
#
# ['VERB', 'ADJ']
# {word: soft-porn, index: 10, tag: ADJ, rank_score: -0.7578606009483337}
# {word: self-exploitation, index: 6, tag: NOUN, rank_score: -0.38560348749160767}
# {word: into, index: 8, tag: ADP, rank_score: -0.21917790174484253}
# {word: jolly, index: 9, tag: ADV, rank_score: -0.007147669792175293}
#
# ['VERB', 'ADJ']
# {word: and, index: 10, tag: CONJ, rank_score: -0.00019431114196777344}
# {word: atmosphere, index: 12, tag: ADV, rank_score: -0.00011909008026123047}
# {word: offers, index: 0, tag: VERB, rank_score: -7.95125961303711e-05}
# {word: the, index: 1, tag: DET, rank_score: -5.882978439331055e-05}
#
# ['VERB', 'ADJ']
# {word: enjoyably, index: 6, tag: ADV, rank_score: -0.028506159782409668}
# {word: colorful, index: 4, tag: ADJ, rank_score: -0.004601478576660156}
# {word: occasionally, index: 0, tag: ADV, rank_score: 0.0015802979469299316}
# {word: in, index: 8, tag: ADP, rank_score: 0.0013903975486755371}
#
# ['VERB', 'ADJ']
# {word: farcical, index: 12, tag: ADJ, rank_score: -0.570837140083313}
# {word: broad, index: 10, tag: ADJ, rank_score: 0.0007998347282409668}
# {word: was, index: 1, tag: VERB, rank_score: 0.0007159709930419922}
# {word: subtle, index: 2, tag: ADJ, rank_score: 0.0007029175758361816}
#
# ['VERB', 'ADJ']
# {word: n't, index: 10, tag: ADV, rank_score: -0.9171155095100403}
# {word: however, index: 11, tag: ADV, rank_score: -0.90697181224823}
# {word: fisher, index: 8, tag: NOUN, rank_score: -0.7498892545700073}
# {word: ., index: 14, tag: ., rank_score: -0.7361587285995483}
#
# ['VERB', 'ADJ']
# {word: ice, index: 6, tag: NOUN, rank_score: -0.004377782344818115}
# {word: this, index: 1, tag: DET, rank_score: -0.0012402534484863281}
# {word: on, index: 5, tag: ADP, rank_score: -0.0007601380348205566}
# {word: call, index: 0, tag: VERB, rank_score: -0.00041961669921875}
#
# ['VERB', 'ADJ']
# {word: vapid, index: 2, tag: ADJ, rank_score: -0.7799942493438721}
# {word: to, index: 6, tag: PRT, rank_score: -0.0029454827308654785}
# {word: exercise, index: 5, tag: NOUN, rank_score: -0.0012781023979187012}
# {word: structure, index: 9, tag: NOUN, rank_score: 0.0009456872940063477}
#
# ['VERB', 'ADJ']
# {word: little, index: 8, tag: ADJ, rank_score: -0.9951364994049072}
# {word: doing, index: 6, tag: VERB, rank_score: -0.00024515390396118164}
# {word: ends, index: 4, tag: VERB, rank_score: -0.00016695261001586914}
# {word: a, index: 0, tag: DET, rank_score: 7.957220077514648e-05}
#
# ['VERB', 'ADJ']
# {word: for, index: 11, tag: ADP, rank_score: -0.002281010150909424}
# {word: uses, index: 1, tag: VERB, rank_score: -0.001823127269744873}
# {word: as, index: 8, tag: ADP, rank_score: -0.0015420317649841309}
# {word: material, index: 10, tag: NOUN, rank_score: -0.0011210441589355469}
#
# ['VERB', 'ADJ']
# {word: ago, index: 12, tag: ADV, rank_score: -0.0023067593574523926}
# {word: doing, index: 9, tag: VERB, rank_score: -0.0011835098266601562}
# {word: like, index: 1, tag: ADP, rank_score: -0.0005705356597900391}
# {word: seems, index: 0, tag: VERB, rank_score: -0.0003612041473388672}
#
# ['VERB', 'ADJ']
# {word: not, index: 3, tag: ADV, rank_score: -0.9976268410682678}
# {word: terrible, index: 5, tag: ADJ, rank_score: -0.9462334513664246}
# {word: is, index: 2, tag: VERB, rank_score: -0.010482370853424072}
# {word: as, index: 6, tag: ADP, rank_score: -0.001561284065246582}
#
# ['VERB', 'ADJ']
# ...
# {word: anywhere, index: 38, tag: ADV, rank_score: -0.0003212094306945801}
#
# ['VERB', 'ADJ']
# {word: while, index: 0, tag: ADP, rank_score: -0.8357679843902588}
# {word: parker, index: 1, tag: NOUN, rank_score: -0.8177110552787781}
# {word: and, index: 14, tag: CONJ, rank_score: -0.8022174835205078}
# {word: co-writer, index: 3, tag: NOUN, rank_score: -0.5501759648323059}
#
# ['VERB', 'ADJ']
# {word: than, index: 32, tag: ADP, rank_score: -0.4699382185935974}
# {word: any, index: 33, tag: DET, rank_score: -0.16832351684570312}
# {word: made, index: 24, tag: VERB, rank_score: -0.008638978004455566}
# {word: thought, index: 39, tag: VERB, rank_score: -0.0017547011375427246}
#
# ['VERB', 'ADJ']
# {word: excuse, index: 6, tag: NOUN, rank_score: -0.000973820686340332}
# {word: is, index: 3, tag: VERB, rank_score: -0.00020754337310791016}
# {word: play, index: 8, tag: VERB, rank_score: -0.00015109777450561523}
# {word: film, index: 2, tag: NOUN, rank_score: -7.992982864379883e-05}
#
# ['VERB', 'ADJ']
# {word: none, index: 26, tag: NOUN, rank_score: -0.001109004020690918}
# {word: paper-thin, index: 35, tag: ADJ, rank_score: -0.00012105703353881836}
# {word: are, index: 19, tag: VERB, rank_score: 7.539987564086914e-05}
# {word: are, index: 27, tag: VERB, rank_score: 7.396936416625977e-05}
#
# ['VERB', 'ADJ']
# {word: confirmation, index: 2, tag: NOUN, rank_score: -0.11354672908782959}
# {word: a, index: 0, tag: DET, rank_score: -0.0077553391456604}
# {word: of, index: 3, tag: ADP, rank_score: -0.0014979839324951172}
# {word: depressing, index: 1, tag: ADJ, rank_score: -0.0006243586540222168}
#
# ['VERB', 'ADJ']
# {word: streak, index: 37, tag: NOUN, rank_score: -0.005046188831329346}
# {word: with, index: 34, tag: ADP, rank_score: -0.0011192560195922852}
# {word: mile, index: 39, tag: ADJ, rank_score: -0.0010125041007995605}
# {word: is, index: 27, tag: VERB, rank_score: -0.0007500052452087402}
#
# ['VERB', 'ADJ']
# {word: resist, index: 9, tag: VERB, rank_score: -0.0018958449363708496}
# {word: hard, index: 7, tag: ADJ, rank_score: -0.0009087324142456055}
# {word: earnest, index: 3, tag: ADJ, rank_score: 0.0003395676612854004}
# {word: 's, index: 6, tag: VERB, rank_score: 0.00018024444580078125}
#
# ['VERB', 'ADJ']
# {word: there, index: 20, tag: DET, rank_score: -0.5010155439376831}
# {word: slapstick, index: 39, tag: NOUN, rank_score: -0.49901899695396423}
# {word: happy, index: 35, tag: ADJ, rank_score: -0.4824315905570984}
# {word: worse, index: 23, tag: ADJ, rank_score: 0.4554023742675781}
#
# ['VERB', 'ADJ']
# {word: instead, index: 0, tag: ADV, rank_score: -0.009514093399047852}
# {word: become, index: 14, tag: VERB, rank_score: -0.0005788803100585938}
# {word: of, index: 1, tag: ADP, rank_score: -0.00038230419158935547}
# {word: film, index: 9, tag: NOUN, rank_score: -0.0002700686454772949}
#
# ['VERB', 'ADJ']
# {word: merely, index: 30, tag: ADV, rank_score: -0.9396446943283081}
# {word: to, index: 32, tag: PRT, rank_score: -0.01342993974685669}
# {word: watch, index: 33, tag: VERB, rank_score: -0.008434116840362549}
# {word: about, index: 37, tag: ADP, rank_score: -0.006650209426879883}
#
# ['VERB', 'ADJ']
# {word: say, index: 1, tag: VERB, rank_score: -0.1321120262145996}
# {word: mean, index: 2, tag: ADJ, rank_score: -0.13174837827682495}
# {word: of, index: 8, tag: ADP, rank_score: -0.004622817039489746}
# {word: lot, index: 7, tag: NOUN, rank_score: 0.001889050006866455}
#
# ['VERB', 'ADJ']
# {word: nobody, index: 35, tag: NOUN, rank_score: -0.0848931074142456}
# {word: pretends, index: 23, tag: VERB, rank_score: -0.00010788440704345703}
# {word: lesson, index: 32, tag: NOUN, rank_score: 7.671117782592773e-05}
# {word: those, index: 25, tag: DET, rank_score: 7.098913192749023e-05}
#
# ['VERB', 'ADJ']
# {word: neither, index: 0, tag: CONJ, rank_score: -0.9160060286521912}
# {word: for, index: 19, tag: ADP, rank_score: -0.10330528020858765}
# {word: is, index: 15, tag: VERB, rank_score: -0.06615036725997925}
# {word: that, index: 4, tag: DET, rank_score: -0.036654531955718994}
#
# ['VERB', 'ADJ']
# {word: into, index: 27, tag: ADP, rank_score: -0.009280502796173096}
# {word: kind, index: 30, tag: NOUN, rank_score: -0.002379000186920166}
# {word: it, index: 25, tag: PRON, rank_score: 0.0010950565338134766}
# {word: before, index: 24, tag: ADP, rank_score: 0.001055300235748291}
#
# ['VERB', 'ADJ']
# {word: pulls, index: 36, tag: VERB, rank_score: -0.001212000846862793}
# {word: feat, index: 39, tag: NOUN, rank_score: -0.0009986162185668945}
# {word: yet, index: 32, tag: ADV, rank_score: 0.0007631778717041016}
# {word: to, index: 7, tag: PRT, rank_score: -0.0006515383720397949}
#
# ['VERB', 'ADJ']
# {word: film, index: 35, tag: NOUN, rank_score: -0.0029755234718322754}
# {word: on, index: 36, tag: ADP, rank_score: 0.002525627613067627}
# {word: carries, index: 33, tag: VERB, rank_score: 0.002239704132080078}
# {word: the, index: 34, tag: DET, rank_score: -0.0021126270294189453}
#
# ['VERB', 'ADJ']
# {word: not, index: 17, tag: ADV, rank_score: -0.9642053246498108}
# {word: enough, index: 18, tag: ADV, rank_score: -0.8744353652000427}
# {word: are, index: 16, tag: VERB, rank_score: -0.03500235080718994}
# {word: in, index: 13, tag: ADP, rank_score: -0.03266209363937378}
#
# ['VERB', 'ADJ']
# {word: is, index: 24, tag: VERB, rank_score: -0.006863892078399658}
# {word: story, index: 23, tag: NOUN, rank_score: -0.0030952095985412598}
# {word: what, index: 25, tag: PRON, rank_score: -0.0016192793846130371}
# {word: every, index: 20, tag: DET, rank_score: -0.000789344310760498}
#
# ['VERB', 'ADJ']
# {word: but, index: 36, tag: CONJ, rank_score: -0.9922218322753906}
# {word: can, index: 30, tag: VERB, rank_score: -0.038156092166900635}
# {word: point, index: 32, tag: VERB, rank_score: -0.03623157739639282}
# {word: way, index: 34, tag: NOUN, rank_score: -0.029439926147460938}
#
# ['VERB', 'ADJ']
# {word: what, index: 19, tag: PRON, rank_score: -9.810924530029297e-05}
# {word: which, index: 12, tag: DET, rank_score: -6.073713302612305e-05}
# {word: journey, index: 1, tag: NOUN, rank_score: -2.944469451904297e-05}
# {word: and, index: 25, tag: CONJ, rank_score: 2.944469451904297e-05}
#
# ['VERB', 'ADJ']
# {word: than, index: 7, tag: ADP, rank_score: -0.12166869640350342}
# {word: outcome, index: 10, tag: NOUN, rank_score: -0.07789534330368042}
# {word: is, index: 2, tag: VERB, rank_score: 0.02292633056640625}
# {word: about, index: 8, tag: ADP, rank_score: 0.020448267459869385}
#
# ['VERB', 'ADJ']
# {word: it, index: 13, tag: PRON, rank_score: -0.00013935565948486328}
# {word: sees, index: 14, tag: VERB, rank_score: -8.07642936706543e-05}
# {word: relationships, index: 16, tag: NOUN, rank_score: -7.194280624389648e-05}
# {word: including, index: 17, tag: VERB, rank_score: -6.920099258422852e-05}
#
# ['VERB', 'ADJ']
# {word: most, index: 9, tag: ADV, rank_score: -0.0009890198707580566}
# {word: sympathetic, index: 12, tag: ADJ, rank_score: -0.00042825937271118164}
# {word: multilayered, index: 10, tag: ADJ, rank_score: -0.00033843517303466797}
# {word: and, index: 11, tag: CONJ, rank_score: -0.0002276897430419922}
#
# ['VERB', 'ADJ']
# {word: each, index: 20, tag: DET, rank_score: -0.0001996755599975586}
# {word: digs, index: 31, tag: NOUN, rank_score: -0.00019800662994384766}
# {word: world, index: 29, tag: NOUN, rank_score: -0.00010025501251220703}
# {word: their, index: 33, tag: PRON, rank_score: -7.802248001098633e-05}
#
# ['VERB', 'ADJ']
# {word: mannered, index: 28, tag: ADJ, rank_score: -0.9014335870742798}
# {word: somewhat, index: 27, tag: ADV, rank_score: -0.8752211928367615}
# {word: but, index: 12, tag: CONJ, rank_score: -0.76990807056427}
# {word: should, index: 1, tag: VERB, rank_score: -0.6387021541595459}
#
# ['VERB', 'ADJ']
# {word: dulls, index: 35, tag: VERB, rank_score: -0.9972756505012512}
# {word: ultimately, index: 34, tag: ADV, rank_score: 0.0005797743797302246}
# {word: at, index: 39, tag: ADP, rank_score: 0.0004221796989440918}
# {word: core, index: 43, tag: NOUN, rank_score: 0.00041496753692626953}
#
# ['VERB', 'ADJ']
# {word: not, index: 41, tag: ADV, rank_score: -0.0006875395774841309}
# {word: much, index: 42, tag: ADJ, rank_score: -0.0003561973571777344}
# {word: smart, index: 38, tag: ADJ, rank_score: -0.00013703107833862305}
# {word: appears, index: 11, tag: VERB, rank_score: 0.00011706352233886719}
#
# ['VERB', 'ADJ']
# {word: improved, index: 7, tag: VERB, rank_score: -0.95247483253479}
# {word: reminds, index: 2, tag: VERB, rank_score: -0.7756690979003906}
# {word: vastly, index: 6, tag: ADV, rank_score: -0.05103546380996704}
# {word: of, index: 10, tag: ADP, rank_score: -0.03610026836395264}
#
# ['VERB', 'ADJ']
# {word: enjoyed, index: 37, tag: VERB, rank_score: -0.9651169180870056}
# {word: is, index: 33, tag: VERB, rank_score: -0.6741347312927246}
# {word: i, index: 35, tag: NOUN, rank_score: -0.43803542852401733}
# {word: truly, index: 36, tag: ADV, rank_score: -0.4027698040008545}
#
# ['VERB', 'ADJ']
# {word: pseudo, index: 5, tag: NOUN, rank_score: -0.5520693063735962}
# {word: final, index: 4, tag: ADJ, rank_score: -0.3580038845539093}
# {word: un, index: 3, tag: ADJ, rank_score: 0.26754724979400635}
# {word: interesantes, index: 2, tag: VERB, rank_score: 0.2302601933479309}
#
# ['VERB', 'ADJ']
# {word: imagine, index: 1, tag: VERB, rank_score: -0.007253289222717285}
# {word: to, index: 0, tag: PRT, rank_score: -0.002339482307434082}
# {word: mediocrity, index: 35, tag: NOUN, rank_score: -0.0019974708557128906}
# {word: lobotomized, index: 15, tag: ADJ, rank_score: -0.000888824462890625}
#
# ['VERB', 'ADJ']
# {word: nearly, index: 5, tag: ADV, rank_score: -0.8550054430961609}
# {word: impossible, index: 6, tag: ADJ, rank_score: -0.03061312437057495}
# {word: the, index: 4, tag: DET, rank_score: 0.015007615089416504}
# {word: jackson, index: 1, tag: NOUN, rank_score: 0.009440898895263672}
#
# ['VERB', 'ADJ']
# {word: deeper, index: 22, tag: ADJ, rank_score: -0.0014097094535827637}
# {word: and, index: 21, tag: CONJ, rank_score: -0.0004042387008666992}
# {word: richer, index: 20, tag: ADJ, rank_score: 0.00021654367446899414}
# {word: the, index: 12, tag: DET, rank_score: -0.00018459558486938477}
#
# ['VERB', 'ADJ']
# {word: no, index: 31, tag: DET, rank_score: -0.941661536693573}
# {word: no, index: 41, tag: DET, rank_score: -0.8707801103591919}
# {word: story, index: 39, tag: NOUN, rank_score: -0.6762776374816895}
# {word: imagination, index: 34, tag: NOUN, rank_score: -0.36105120182037354}
#
# ['VERB', 'ADJ']
# {word: it, index: 10, tag: PRON, rank_score: 0.0004990696907043457}
# {word: free, index: 27, tag: ADJ, rank_score: -0.0004836916923522949}
# {word: and, index: 26, tag: CONJ, rank_score: -0.0004000067710876465}
# {word: fresh, index: 25, tag: ADJ, rank_score: 0.0003914833068847656}
#
# ['VERB', 'ADJ']
# {word: anyone, index: 9, tag: NOUN, rank_score: -0.0003943443298339844}
# {word: exuberance, index: 5, tag: NOUN, rank_score: 0.0003331899642944336}
# {word: engage, index: 8, tag: VERB, rank_score: -0.0003000497817993164}
# {word: in, index: 14, tag: ADP, rank_score: 0.0002995133399963379}
#
# ['VERB', 'ADJ']
# {word: imaginative, index: 27, tag: ADJ, rank_score: -0.9173978567123413}
# {word: kids, index: 34, tag: NOUN, rank_score: -0.01034766435623169}
# {word: ways, index: 33, tag: NOUN, rank_score: -0.008799910545349121}
# {word: the, index: 26, tag: DET, rank_score: -0.0025696158409118652}
#
# ['VERB', 'ADJ']
# {word: but, index: 10, tag: CONJ, rank_score: -0.9982405304908752}
# {word: its, index: 11, tag: PRON, rank_score: -0.9979062080383301}
# {word: compare, index: 15, tag: VERB, rank_score: -0.9977269768714905}
# {word: dance, index: 8, tag: VERB, rank_score: -0.995150625705719}
#
# ['VERB', 'ADJ']
# {word: buy, index: 33, tag: VERB, rank_score: -0.2506311535835266}
# {word: 'll, index: 32, tag: VERB, rank_score: -0.20941245555877686}
# {word: soundtrack, index: 35, tag: NOUN, rank_score: -0.06920915842056274}
# {word: the, index: 34, tag: DET, rank_score: -0.009357035160064697}
#
# ['VERB', 'ADJ']
# {word: 'll, index: 44, tag: VERB, rank_score: -0.45162880420684814}
# {word: i, index: 43, tag: NOUN, rank_score: -0.13020539283752441}
# {word: real, index: 41, tag: ADJ, rank_score: -0.05496013164520264}
# {word: i, index: 38, tag: ADJ, rank_score: -0.047895848751068115}
#
# ['VERB', 'ADJ']
# {word: over, index: 11, tag: ADV, rank_score: -0.6590383648872375}
# {word: potter, index: 1, tag: NOUN, rank_score: -0.6015201210975647}
# {word: appropriate, index: 23, tag: ADJ, rank_score: -0.5451446771621704}
# {word: deja, index: 8, tag: ADJ, rank_score: -0.38290873169898987}
#
# ['VERB', 'ADJ']
# {word: production, index: 35, tag: NOUN, rank_score: -0.2600308060646057}
# {word: 'll, index: 42, tag: VERB, rank_score: -0.10697817802429199}
# {word: likely, index: 43, tag: ADV, rank_score: -0.1020999550819397}
# {word: likely, index: 27, tag: ADJ, rank_score: -0.06440699100494385}
#
# ['VERB', 'ADJ']
# {word: obviously, index: 2, tag: ADV, rank_score: -0.9103541374206543}
# {word: re-create, index: 5, tag: VERB, rank_score: -0.8942089080810547}
# {word: movie, index: 1, tag: NOUN, rank_score: -0.867903470993042}
# {word: of, index: 8, tag: ADP, rank_score: -0.5745190382003784}
#
# ['VERB', 'ADJ']
# {word: wells, index: 33, tag: NOUN, rank_score: 0.1752963662147522}
# {word: machine, index: 37, tag: NOUN, rank_score: -0.16031044721603394}
# {word: time, index: 36, tag: NOUN, rank_score: 0.13151872158050537}
# {word: 'the, index: 35, tag: PRT, rank_score: 0.04382467269897461}
#
# ['VERB', 'ADJ']
# {word: listless, index: 49, tag: ADJ, rank_score: -0.9850910902023315}
# {word: but, index: 40, tag: CONJ, rank_score: -0.0004992485046386719}
# {word: storytelling, index: 42, tag: NOUN, rank_score: 0.0004448890686035156}
# {word: are, index: 47, tag: VERB, rank_score: -0.00039327144622802734}
#
# ['VERB', 'ADJ']
# {word: kills, index: 15, tag: NOUN, rank_score: -0.1281258463859558}
# {word: every, index: 16, tag: DET, rank_score: 0.00014966726303100586}
# {word: and, index: 14, tag: CONJ, rank_score: 0.00014799833297729492}
# {word: sense, index: 17, tag: NOUN, rank_score: 0.0001309514045715332}
#
# ['VERB', 'ADJ']
# {word: explosions, index: 32, tag: NOUN, rank_score: 0.0006078481674194336}
# {word: of, index: 31, tag: ADP, rank_score: 0.0005788803100585938}
# {word: he, index: 39, tag: PRON, rank_score: 0.0005778074264526367}
# {word: like, index: 38, tag: ADP, rank_score: 0.0005655884742736816}
#
# ['VERB', 'ADJ']
# {word: phone, index: 1, tag: NOUN, rank_score: -0.15781176090240479}
# {word: tells, index: 6, tag: VERB, rank_score: 0.05220472812652588}
# {word: left, index: 13, tag: VERB, rank_score: -0.04706108570098877}
# {word: the, index: 0, tag: DET, rank_score: 0.042230188846588135}
#
# ['VERB', 'ADJ']
# {word: midnight, index: 35, tag: NOUN, rank_score: -0.00994199514389038}
# {word: video, index: 28, tag: NOUN, rank_score: -0.006646156311035156}
# {word: if, index: 26, tag: ADP, rank_score: -0.005866646766662598}
# {word: going, index: 38, tag: VERB, rank_score: -0.005242586135864258}
#
# ['VERB', 'ADJ']
# {word: but, index: 28, tag: CONJ, rank_score: -0.049058616161346436}
# {word: cognizant, index: 37, tag: ADJ, rank_score: -0.001370072364807129}
# {word: it, index: 0, tag: PRON, rank_score: -0.00021386146545410156}
# {word: so, index: 36, tag: ADV, rank_score: -0.00020599365234375}
#
# ['VERB', 'ADJ']
# {word: exploration, index: 12, tag: NOUN, rank_score: -0.9857487678527832}
# {word: little, index: 5, tag: ADJ, rank_score: -0.9128955602645874}
# {word: core, index: 9, tag: NOUN, rank_score: -0.2342585325241089}
# {word: the, index: 14, tag: DET, rank_score: -0.05892854928970337}
#
# ['VERB', 'ADJ']
# {word: for, index: 39, tag: ADP, rank_score: -0.8866996765136719}
# {word: a, index: 33, tag: DET, rank_score: -0.8864966034889221}
# {word: has, index: 32, tag: VERB, rank_score: -0.8863498568534851}
# {word: all, index: 38, tag: DET, rank_score: -0.8859302401542664}
#
# ['VERB', 'ADJ']
# {word: fun, index: 58, tag: NOUN, rank_score: -0.0010657906532287598}
# {word: there, index: 52, tag: DET, rank_score: 0.00027817487716674805}
# {word: but, index: 45, tag: CONJ, rank_score: 0.00027054548263549805}
# {word: of, index: 57, tag: ADP, rank_score: 0.00018608570098876953}
#
# :: 512 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 292 sentences remaining.
# Predicting inputs...
# :: Sentence predictions done.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 4min 38.9s

# %%
df = tg.to_dataframe()
df
# Out:
#      label  \
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
# ..     ...
# 287      1
# 288      1
# 289      1
# 290      0
# 291      0
#
#                                                                                                                                                                                                                                      original_text  \
# 0                                                                                                                                                                    delivers roughly equal amounts of beautiful movement and inside information .
# 1                                                                                                                                                                               saved from being merely way-cool by a basic  credible compassion .
# 2                                                                                                                                                                                        manages to be wholesome and subversive at the same time .
# 3                                                                                                                                                                                              friday after next is a lot more bluster than bite .
# 4                                                                                                                                                                                     wow  so who knew charles dickens could be so light-hearted ?
# ..                                                                                                                                                                                                                                             ...
# 287                                                                     the film reminds me of a vastly improved germanic version of my big fat greek wedding -- with better characters  some genuine quirkiness and at least a measure of style .
# 288  'pocas ideas interesantes  un final pseudo m?stico que no corresponde al tono general del filme y que deja una sensaci?n de inconformidad que hace pensar m?s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# 289                                                                                                                                                                he has improved upon the first and taken it a step further  richer and deeper .
# 290                                                                                                             harry potter and the chamber of secrets is deja vu all over again  and while that is a cliche  nothing could be more appropriate .
# 291                                                                                                                                                                     the phone rings and a voice tells you you've got seven days left to live .
#
#                                                                                                                                                                                                                                                  masked_text  \
# 0                                                                                                                                                                                delivers roughly {mask} amounts of {mask} movement and inside information .
# 1                                                                                                                                                                                           saved from being merely way-cool by a {mask} {mask} compassion .
# 2                                                                                                                                                                                                    manages to be wholesome and {mask} at the {mask} time .
# 3                                                                                                                                                                                                    friday after {mask} is a lot {mask} bluster than bite .
# 4                                                                                                                                                                                                     wow so who {mask} charles dickens could be so {mask} ?
# ..                                                                                                                                                                                                                                                       ...
# 287                                                                                   the film {mask} me of a vastly {mask} germanic version of my big fat greek wedding -- with better characters some genuine quirkiness and at least a measure of style .
# 288  'pocas ideas interesantes {mask} {mask} pseudo m ? stico que no corresponde al tono general del filme y que deja una sensaci ? n de inconformidad que hace pensar m ? s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# 289                                                                                                                                                                           he has improved upon the first and taken it a step further {mask} and {mask} .
# 290                                                                                                                            harry potter and the chamber of secrets is {mask} vu all over again and while that is a cliche nothing could be more {mask} .
# 291                                                                                                                                                                           the phone rings and a voice {mask} you you 've got seven days {mask} to live .
#
#                                                                                                                                                                                                                                                      template_text
# 0                                                                                                                                                                                delivers roughly {neg_adj} amounts of {pos_adj} movement and inside information .
# 1                                                                                                                                                                                           saved from being merely way-cool by a {pos_adj} {pos_adj} compassion .
# 2                                                                                                                                                                                                    manages to be wholesome and {pos_adj} at the {neg_adj} time .
# 3                                                                                                                                                                                                    friday after {neg_adj} is a lot {pos_adj} bluster than bite .
# 4                                                                                                                                                                                                    wow so who {pos_verb} charles dickens could be so {pos_adj} ?
# ..                                                                                                                                                                                                                                                             ...
# 287                                                                                 the film {pos_verb} me of a vastly {pos_verb} germanic version of my big fat greek wedding -- with better characters some genuine quirkiness and at least a measure of style .
# 288  'pocas ideas interesantes {neg_adj} {neg_adj} pseudo m ? stico que no corresponde al tono general del filme y que deja una sensaci ? n de inconformidad que hace pensar m ? s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# 289                                                                                                                                                                           he has improved upon the first and taken it a step further {pos_adj} and {pos_adj} .
# 290                                                                                                                            harry potter and the chamber of secrets is {neg_adj} vu all over again and while that is a cliche nothing could be more {neg_adj} .
# 291                                                                                                                                                                         the phone rings and a voice {neg_verb} you you 've got seven days {neg_verb} to live .
#
# [292 rows x 4 columns]

# %%
tg.lexicons
# Out:
# {'pos_verb': ['is',
#   'provides',
#   'conveys',
#   'knew',
#   'haunting',
#   'gets',
#   'being',
#   'appreciate',
#   'surprising',
#   'celebrates',
#   'elevate',
#   'comes',
#   'keeps',
#   'find',
#   'storytelling',
#   'tempting',
#   'reminds',
#   'liberating',
#   'capturing',
#   'coheres',
#   'entertaining',
#   'improved',
#   'filmmaking',
#   'orchestrates',
#   'heartening',
#   'charming',
#   'thank',
#   'rewarded',
#   'creating',
#   'heal',
#   'overlook',
#   'evokes',
#   'keep',
#   'stays',
#   'care',
#   'feel',
#   'riveted',
#   'succeeds',
#   'riveting',
#   'photographed',
#   'kissing',
#   'satisfying',
#   'live',
#   'offerings',
#   'proves',
#   'trust',
#   'moviegoing',
#   'rewarding',
#   'become',
#   'enjoy',
#   'rhythms',
#   'touches',
#   'rock'],
#  'neg_verb': ['fails',
#   'trying',
#   'remains',
#   'telegraphed',
#   'use',
#   'wish',
#   'named',
#   'sticking',
#   'seems',
#   'pass',
#   'stopped',
#   'bewildering',
#   'feeling',
#   'showing',
#   'confused',
#   'offend',
#   'fall',
#   'should',
#   'faulted',
#   'running',
#   'yawp',
#   'leaves',
#   'ploughing',
#   'heavy-handed',
#   'loses',
#   'throwing',
#   'supposed',
#   'involve',
#   'made',
#   'seeks',
#   'be',
#   'have',
#   'lifts',
#   'might',
#   'sell',
#   'avoid',
#   'escape',
#   'disappoint',
#   'staged',
#   'could',
#   'directed',
#   'caved',
#   'worked',
#   'employ',
#   'tells',
#   'can',
#   'wind',
#   'forced',
#   'firing',
#   'dismissed',
#   'work',
#   'avoids',
#   'disjointed',
#   'expect',
#   'screaming',
#   'relies',
#   'may',
#   'overcome',
#   'tear',
#   'lacking',
#   'crossed',
#   'strikes',
#   'tossed',
#   'deserve',
#   'say',
#   'stilted',
#   'strung',
#   'condescending',
#   'abandon',
#   'would',
#   'classify',
#   'simmering',
#   'tries',
#   'jettisoned',
#   'uses',
#   'resembles',
#   'losing',
#   'wrapped',
#   'appears',
#   'aged',
#   'drags',
#   'lost',
#   'plastered',
#   'lacks',
#   'thinking',
#   'repelled',
#   'trapped',
#   'left',
#   'smoochy',
#   'were',
#   'opts',
#   'expected',
#   'chokes',
#   'waterlogged',
#   'ought',
#   'groans',
#   'depressing',
#   'ends',
#   'cloying',
#   'was',
#   'deflates',
#   'damned',
#   'rebel',
#   'thought',
#   'consumed',
#   'has',
#   'required',
#   'ruins',
#   'pushing',
#   'lose',
#   'embarrassing',
#   'milked',
#   'finish',
#   'does',
#   'boasting',
#   'contrived',
#   'see',
#   'fights',
#   'unexamined',
#   'exist',
#   'used',
#   'saddled',
#   'falls',
#   'done',
#   'retreats',
#   'playing',
#   'screen',
#   'doing',
#   'hate',
#   'associated',
#   'feels',
#   'labored',
#   'takes',
#   'go'],
#  'pos_adj': ['outrageous',
#   'kubrick-meets-spielberg',
#   'basic',
#   'inventive',
#   'in-depth',
#   'creative',
#   'comfortable',
#   'pretty',
#   'sincere',
#   'observant',
#   'best',
#   'spectacular',
#   'smart',
#   'fun',
#   'goofy',
#   'credible',
#   'able',
#   'impressive',
#   'artful',
#   'fine',
#   'deeper',
#   'great',
#   'intense',
#   'tasty',
#   'energetic',
#   'effective',
#   'pleasant',
#   'tremendous',
#   'solid',
#   'beautiful',
#   'stocked',
#   'wacky',
#   'profound',
#   'funny',
#   'welcome',
#   'rewarding',
#   'remarkable',
#   'wild-and-woolly',
#   'enjoyable',
#   'true',
#   'sympathetic',
#   'challenge-hungry',
#   'cool',
#   'intimate',
#   'visceral',
#   'acquainted',
#   'world-class',
#   'polished',
#   'wonderful',
#   'subversive',
#   'talented',
#   'slam-bang',
#   'sweet',
#   'superior',
#   'iconic',
#   'modern',
#   'sweet-natured',
#   'much',
#   'satisfying',
#   'clever',
#   'richer',
#   'narrative',
#   'fresh',
#   'comprehensive',
#   'unusual',
#   'light-hearted',
#   'enough',
#   'nice',
#   'imax',
#   'more',
#   'neat',
#   'terrific',
#   'endearing',
#   'priceless',
#   'epic',
#   'apollo',
#   'believable',
#   'nuanced',
#   'adventurous',
#   'cinematic',
#   'connect',
#   'emotional',
#   'iq',
#   'well-meaning',
#   'authentic',
#   'interesting',
#   'reflective',
#   'fascinating',
#   'single-mindedly',
#   'inspirational',
#   'happy',
#   'successful',
#   'assured',
#   'love',
#   'stunning',
#   'good'],
#  'neg_adj': ['hard',
#   'little',
#   'junk-calorie',
#   'excessive',
#   'volatile',
#   'narrow',
#   'ordinary',
#   'dreaded',
#   'cheap-looking',
#   'superficial',
#   'moldy',
#   'sugary',
#   'over-blown',
#   'stupendous',
#   'mean',
#   'lousy',
#   'mannered',
#   'boring',
#   'over-the-top',
#   'disappointing',
#   'voyeuristic',
#   'un',
#   'original',
#   'distant',
#   'stupid',
#   'predictable',
#   'insanely',
#   'multilayered',
#   'foot-dragging',
#   'tragic',
#   'impersonal',
#   'second-guess',
#   'trivial',
#   'self-important',
#   'own',
#   'only-in',
#   'obnoxious',
#   'chilly',
#   'pompous',
#   'third',
#   'serious',
#   'long-dreaded',
#   'sham',
#   'strained',
#   'unfunny',
#   'usual',
#   'kinda',
#   'considerable',
#   'next',
#   'sci-fi',
#   'self-pitying',
#   'self-conscious',
#   'psychological',
#   'heavy',
#   'deja',
#   'ludicrous',
#   'self-mutilating',
#   'conventional',
#   'sexual',
#   'unsatisfying',
#   'eardrum-dicing',
#   'tv-style',
#   'mushy',
#   'appropriate',
#   'analgesic',
#   'dead',
#   'entire',
#   'manipulative',
#   'tireless',
#   'retrograde',
#   'dull',
#   'other',
#   'one-shot',
#   'disquiet',
#   'fable',
#   'soulless',
#   'sloppy',
#   'rent',
#   'unforced',
#   'ill-conceived',
#   'difficult',
#   'similar',
#   'incompetent',
#   'forgettable',
#   'ill-advised',
#   'exploitative',
#   'glaring',
#   'stiff',
#   'plausible',
#   'full',
#   'simple',
#   'leaky',
#   'unable',
#   '112-minute',
#   'trite',
#   'sad',
#   'meaningless',
#   'loud',
#   'bad',
#   'equal',
#   'generic',
#   'impossible',
#   'innocuous',
#   'simplistic',
#   'desperate',
#   'witless',
#   'better',
#   'weak',
#   'sole',
#   'one-sided',
#   'nonethnic',
#   'softheaded',
#   'dysfunctional',
#   'cheap',
#   'self-absorbed',
#   'worse',
#   'unremarkable',
#   'grumpy',
#   'uneventful',
#   'ponderous',
#   'few',
#   'mumbo',
#   'black',
#   'abrupt',
#   'illogical',
#   'unnecessary',
#   'problematic',
#   'flat',
#   'wretched',
#   'lengthy',
#   'amped-up',
#   'painful',
#   'miserable',
#   'glib',
#   'same',
#   'broad',
#   'ridiculous',
#   'inarticulate',
#   'abstract',
#   'inhuman',
#   'propriety-obsessed',
#   'suicide',
#   'vapid',
#   'distended',
#   'fluffy',
#   'simple-minded',
#   'dusty',
#   'obvious',
#   'sappy',
#   'short',
#   'shrill',
#   'flimsy',
#   'unlikely',
#   'whole',
#   'final',
#   'less',
#   'farcical',
#   'downbeat',
#   'last',
#   'content',
#   'amateurish',
#   'punitive',
#   'feels',
#   'awful',
#   'melancholy',
#   'wafer-thin',
#   'excess']}

# %% [markdown]
# ## Checklist

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_verb', lexicons['pos_verb'])
editor.add_lexicon('neg_verb', lexicons['neg_verb'])
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 16032 examples
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 96 examples
# Running Test: MFT with vocabullary - template3
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template4
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template5
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template6
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template7
# Predicting 134 examples
# Running Test: MFT with vocabullary - template8
# Predicting 134 examples
# Running Test: MFT with vocabullary - template9
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template10
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template11
# Predicting 167 examples
# Running Test: MFT with vocabullary - template12
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template13
# Predicting 167 examples
# Running Test: MFT with vocabullary - template14
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template15
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template16
# Predicting 167 examples
# Running Test: MFT with vocabullary - template17
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template18
# Predicting 167 examples
# Running Test: MFT with vocabullary - template19
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template20
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template21
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template22
# Predicting 96 examples
# Running Test: MFT with vocabullary - template23
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template24
# Predicting 134 examples
# Running Test: MFT with vocabullary - template25
# Predicting 96 examples
# Running Test: MFT with vocabullary - template26
# Predicting 167 examples
# Running Test: MFT with vocabullary - template27
# Predicting 96 examples
# Running Test: MFT with vocabullary - template28
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template29
# Predicting 134 examples
# Running Test: MFT with vocabullary - template30
# Predicting 167 examples
# Running Test: MFT with vocabullary - template31
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template32
# Predicting 167 examples
# Running Test: MFT with vocabullary - template33
# Predicting 167 examples
# Running Test: MFT with vocabullary - template34
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template35
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template36
# Predicting 167 examples
# Running Test: MFT with vocabullary - template37
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template38
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template39
# Predicting 167 examples
# Running Test: MFT with vocabullary - template40
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template41
# Predicting 167 examples
# Running Test: MFT with vocabullary - template42
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template43
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template44
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template45
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template46
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template47
# Predicting 167 examples
# Running Test: MFT with vocabullary - template48
# Predicting 167 examples
# Running Test: MFT with vocabullary - template49
# Predicting 167 examples
# Running Test: MFT with vocabullary - template50
# Predicting 167 examples
# Running Test: MFT with vocabullary - template51
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template52
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template53
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template54
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template55
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template56
# Predicting 167 examples
# Running Test: MFT with vocabullary - template57
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template58
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template59
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template60
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template61
# Predicting 167 examples
# Running Test: MFT with vocabullary - template62
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template63
# Predicting 134 examples
# Running Test: MFT with vocabullary - template64
# Predicting 96 examples
# Running Test: MFT with vocabullary - template65
# Predicting 96 examples
# Running Test: MFT with vocabullary - template66
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template67
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template68
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template69
# Predicting 96 examples
# Running Test: MFT with vocabullary - template70
# Predicting 134 examples
# Running Test: MFT with vocabullary - template71
# Predicting 134 examples
# Running Test: MFT with vocabullary - template72
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template73
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template74
# Predicting 134 examples
# Running Test: MFT with vocabullary - template75
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template76
# Predicting 96 examples
# Running Test: MFT with vocabullary - template77
# Predicting 96 examples
# Running Test: MFT with vocabullary - template78
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template79
# Predicting 134 examples
# Running Test: MFT with vocabullary - template80
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template81
# Predicting 134 examples
# Running Test: MFT with vocabullary - template82
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template83
# Predicting 96 examples
# Running Test: MFT with vocabullary - template84
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template85
# Predicting 134 examples
# Running Test: MFT with vocabullary - template86
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template87
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template88
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template89
# Predicting 134 examples
# Running Test: MFT with vocabullary - template90
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template91
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template92
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template93
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template94
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template95
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template96
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template97
# Predicting 96 examples
# Running Test: MFT with vocabullary - template98
# Predicting 167 examples
# Running Test: MFT with vocabullary - template99
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template100
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template101
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template102
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template103
# Predicting 167 examples
# Running Test: MFT with vocabullary - template104
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template105
# Predicting 134 examples
# Running Test: MFT with vocabullary - template106
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template107
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template108
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template109
# Predicting 134 examples
# Running Test: MFT with vocabullary - template110
# Predicting 96 examples
# Running Test: MFT with vocabullary - template111
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template112
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template113
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template114
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template115
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template116
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template117
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template118
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template119
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template120
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template121
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template122
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template123
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template124
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template125
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template126
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template127
# Predicting 134 examples
# Running Test: MFT with vocabullary - template128
# Predicting 134 examples
# Running Test: MFT with vocabullary - template129
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template130
# Predicting 167 examples
# Running Test: MFT with vocabullary - template131
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template132
# Predicting 96 examples
# Running Test: MFT with vocabullary - template133
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template134
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template135
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template136
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template137
# Predicting 134 examples
# Running Test: MFT with vocabullary - template138
# Predicting 167 examples
# Running Test: MFT with vocabullary - template139
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template140
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template141
# Predicting 134 examples
# Running Test: MFT with vocabullary - template142
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template143
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template144
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template145
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template146
# Predicting 96 examples
# Running Test: MFT with vocabullary - template147
# Predicting 167 examples
# Running Test: MFT with vocabullary - template148
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template149
# Predicting 167 examples
# Running Test: MFT with vocabullary - template150
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template151
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template152
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template153
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template154
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template155
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template156
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template157
# Predicting 167 examples
# Running Test: MFT with vocabullary - template158
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template159
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template160
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template161
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template162
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template163
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template164
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template165
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template166
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template167
# Predicting 53 examples
# Running Test: MFT with vocabullary - template168
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template169
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template170
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template171
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template172
# Predicting 134 examples
# Running Test: MFT with vocabullary - template173
# Predicting 134 examples
# Running Test: MFT with vocabullary - template174
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template175
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template176
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template177
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template178
# Predicting 53 examples
# Running Test: MFT with vocabullary - template179
# Predicting 134 examples
# Running Test: MFT with vocabullary - template180
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template181
# Predicting 134 examples
# Running Test: MFT with vocabullary - template182
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template183
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template184
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template185
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template186
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template187
# Predicting 96 examples
# Running Test: MFT with vocabullary - template188
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template189
# Predicting 167 examples
# Running Test: MFT with vocabullary - template190
# Predicting 96 examples
# Running Test: MFT with vocabullary - template191
# Predicting 134 examples
# Running Test: MFT with vocabullary - template192
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template193
# Predicting 134 examples
# Running Test: MFT with vocabullary - template194
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template195
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template196
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template197
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template198
# Predicting 167 examples
# Running Test: MFT with vocabullary - template199
# Predicting 167 examples
# Running Test: MFT with vocabullary - template200
# Predicting 167 examples
# Running Test: MFT with vocabullary - template201
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template202
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template203
# Predicting 96 examples
# Running Test: MFT with vocabullary - template204
# Predicting 167 examples
# Running Test: MFT with vocabullary - template205
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template206
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template207
# Predicting 134 examples
# Running Test: MFT with vocabullary - template208
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template209
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template210
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template211
# Predicting 134 examples
# Running Test: MFT with vocabullary - template212
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template213
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template214
# Predicting 96 examples
# Running Test: MFT with vocabullary - template215
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template216
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template217
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template218
# Predicting 167 examples
# Running Test: MFT with vocabullary - template219
# Predicting 53 examples
# Running Test: MFT with vocabullary - template220
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template221
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template222
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template223
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template224
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template225
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template226
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template227
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template228
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template229
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template230
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template231
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template232
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template233
# Predicting 96 examples
# Running Test: MFT with vocabullary - template234
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template235
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template236
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template237
# Predicting 167 examples
# Running Test: MFT with vocabullary - template238
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template239
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template240
# Predicting 134 examples
# Running Test: MFT with vocabullary - template241
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template242
# Predicting 96 examples
# Running Test: MFT with vocabullary - template243
# Predicting 167 examples
# Running Test: MFT with vocabullary - template244
# Predicting 8851 examples
# Running Test: MFT with vocabullary - template245
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template246
# Predicting 134 examples
# Running Test: MFT with vocabullary - template247
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template248
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template249
# Predicting 7102 examples
# Running Test: MFT with vocabullary - template250
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template251
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template252
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template253
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template254
# Predicting 134 examples
# Running Test: MFT with vocabullary - template255
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template256
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template257
# Predicting 134 examples
# Running Test: MFT with vocabullary - template258
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template259
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template260
# Predicting 134 examples
# Running Test: MFT with vocabullary - template261
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template262
# Predicting 96 examples
# Running Test: MFT with vocabullary - template263
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template264
# Predicting 167 examples
# Running Test: MFT with vocabullary - template265
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template266
# Predicting 134 examples
# Running Test: MFT with vocabullary - template267
# Predicting 53 examples
# Running Test: MFT with vocabullary - template268
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template269
# Predicting 12864 examples
# Running Test: MFT with vocabullary - template270
# Predicting 134 examples
# Running Test: MFT with vocabullary - template271
# Predicting 5086 examples
# Running Test: MFT with vocabullary - template272
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template273
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template274
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template275
# Predicting 167 examples
# Running Test: MFT with vocabullary - template276
# Predicting 134 examples
# Running Test: MFT with vocabullary - template277
# Predicting 134 examples
# Running Test: MFT with vocabullary - template278
# Predicting 134 examples
# Running Test: MFT with vocabullary - template279
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template280
# Predicting 167 examples
# Running Test: MFT with vocabullary - template281
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template282
# Predicting 134 examples
# Running Test: MFT with vocabullary - template283
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template284
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template285
# Predicting 16032 examples
# Running Test: MFT with vocabullary - template286
# Predicting 22377 examples
# Running Test: MFT with vocabullary - template287
# Predicting 96 examples
# Running Test: MFT with vocabullary - template288
# Predicting 53 examples
# Running Test: MFT with vocabullary - template289
# Predicting 167 examples
# Running Test: MFT with vocabullary - template290
# Predicting 96 examples
# Running Test: MFT with vocabullary - template291
# Predicting 167 examples
# Running Test: MFT with vocabullary - template292
# Predicting 134 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      16032
# Fails (rate):    6420 (40.0%)
#
# Example fails:
# 0.1 delivers roughly predictable amounts of enough movement and inside information .
# ----
# 0.0 delivers roughly meaningless amounts of light-hearted movement and inside information .
# ----
# 0.1 delivers roughly illogical amounts of more movement and inside information .
# ----
#
#
# Test: MFT with vocabullary - template2
# Test cases:      96
# Fails (rate):    53 (55.2%)
#
# Example fails:
# 0.0 saved from being merely way-cool by a slam-bang slam-bang compassion .
# ----
# 0.1 saved from being merely way-cool by a wacky wacky compassion .
# ----
# 0.0 saved from being merely way-cool by a cinematic cinematic compassion .
# ----
#
#
# Test: MFT with vocabullary - template3
# Test cases:      16032
# Fails (rate):    1054 (6.6%)
#
# Example fails:
# 0.4 manages to be wholesome and inspirational at the ordinary time .
# ----
# 0.1 manages to be wholesome and solid at the ridiculous time .
# ----
# 0.4 manages to be wholesome and nice at the dull time .
# ----
#
#
# Test: MFT with vocabullary - template4
# Test cases:      16032
# Fails (rate):    1423 (8.9%)
#
# Example fails:
# 0.9 friday after fable is a lot rewarding bluster than bite .
# ----
# 1.0 friday after eardrum-dicing is a lot effective bluster than bite .
# ----
# 0.9 friday after whole is a lot superior bluster than bite .
# ----
#
#
# Test: MFT with vocabullary - template5
# Test cases:      5086
# Fails (rate):    7 (0.1%)
#
# Example fails:
# 0.2 wow so who overlook charles dickens could be so basic ?
# ----
# 0.4 wow so who care charles dickens could be so unusual ?
# ----
# 0.4 wow so who care charles dickens could be so solid ?
# ----
#
#
# Test: MFT with vocabullary - template6
# Test cases:      12864
# Fails (rate):    3182 (24.7%)
#
# Example fails:
# 0.0 this is a very nice movie -- go dismissed it .
# ----
# 0.0 this is a very single-mindedly movie -- go aged it .
# ----
# 0.0 this is a very iq movie -- go embarrassing it .
# ----
#
#
# Test: MFT with vocabullary - template7
# Test cases:      134
# Fails (rate):    64 (47.8%)
#
# Example fails:
# 1.0 it 's as if allen at 66 staged staged challenging himself .
# ----
# 1.0 it 's as if allen at 66 lifts lifts challenging himself .
# ----
# 1.0 it 's as if allen at 66 thinking thinking challenging himself .
# ----
#
#
# Test: MFT with vocabullary - template8
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.6 tsai repelled be repelled the same furrow once too often .
# ----
#
#
# Test: MFT with vocabullary - template9
# Test cases:      5086
# Fails (rate):    48 (0.9%)
#
# Example fails:
# 0.1 windtalkers coheres the human spirit and packs an slam-bang wallop .
# ----
# 0.0 windtalkers photographed the human spirit and packs an slam-bang wallop .
# ----
# 0.4 windtalkers charming the human spirit and packs an more wallop .
# ----
#
#
# Test: MFT with vocabullary - template10
# Test cases:      12864
# Fails (rate):    719 (5.6%)
#
# Example fails:
# 0.0 a deviant topical comedy which is challenge-hungry from start to stilted .
# ----
# 0.5 a deviant topical comedy which is world-class from start to labored .
# ----
# 0.4 a deviant topical comedy which is wacky from start to deserve .
# ----
#
#
# Test: MFT with vocabullary - template11
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template12
# Test cases:      22377
# Fails (rate):    9617 (43.0%)
#
# Example fails:
# 0.7 the film like jimmy 's routines could can a equal good laughs .
# ----
# 1.0 the film like jimmy 's routines could screaming a stiff good laughs .
# ----
# 0.7 the film like jimmy 's routines could uses a similar good laughs .
# ----
#
#
# Test: MFT with vocabullary - template13
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template14
# Test cases:      16032
# Fails (rate):    1484 (9.3%)
#
# Example fails:
# 1.0 this one is certainly richer but it 's also sexual and contrived .
# ----
# 0.6 this one is certainly successful but it 's also broad and contrived .
# ----
# 0.7 this one is certainly great but it 's also original and contrived .
# ----
#
#
# Test: MFT with vocabullary - template15
# Test cases:      5086
# Fails (rate):    23 (0.5%)
#
# Example fails:
# 0.3 cage makes an imax but pleasantly stays debut behind the camera .
# ----
# 0.5 cage makes an slam-bang but pleasantly keep debut behind the camera .
# ----
# 0.4 cage makes an kubrick-meets-spielberg but pleasantly become debut behind the camera .
# ----
#
#
# Test: MFT with vocabullary - template16
# Test cases:      167
# Fails (rate):    16 (9.6%)
#
# Example fails:
# 1.0 `` an chilly film about researchers quietly reading chilly old letters . ``
# ----
# 0.7 `` an sexual film about researchers quietly reading sexual old letters . ``
# ----
# 1.0 `` an considerable film about researchers quietly reading considerable old letters . ``
# ----
#
#
# Test: MFT with vocabullary - template17
# Test cases:      12864
# Fails (rate):    2639 (20.5%)
#
# Example fails:
# 0.9 still i thought it yawp have been priceless .
# ----
# 0.9 still i thought it strung have been stunning .
# ----
# 0.7 still i thought it tells have been subversive .
# ----
#
#
# Test: MFT with vocabullary - template18
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template19
# Test cases:      5086
# Fails (rate):    114 (2.2%)
#
# Example fails:
# 0.5 light silly riveted with colour and depth and rather a modern time .
# ----
# 0.0 light silly offerings with colour and depth and rather a narrative time .
# ----
# 0.0 light silly care with colour and depth and rather a narrative time .
# ----
#
#
# Test: MFT with vocabullary - template20
# Test cases:      7102
# Fails (rate):    1169 (16.5%)
#
# Example fails:
# 0.7 those unfamiliar with mormon traditions may thank the singles ward occasionally forced .
# ----
# 1.0 those unfamiliar with mormon traditions may evokes the singles ward occasionally see .
# ----
# 0.8 those unfamiliar with mormon traditions may heal the singles ward occasionally see .
# ----
#
#
# Test: MFT with vocabullary - template21
# Test cases:      12864
# Fails (rate):    388 (3.0%)
#
# Example fails:
# 0.8 'unfaithful ' cheats on itself and doing to wonderful territory .
# ----
# 0.9 'unfaithful ' cheats on itself and overcome to endearing territory .
# ----
# 0.8 'unfaithful ' cheats on itself and strikes to wonderful territory .
# ----
#
#
# Test: MFT with vocabullary - template22
# Test cases:      96
# Fails (rate):    90 (93.8%)
#
# Example fails:
# 0.0 far more more if considerably less ambitious than last year 's more exercise .
# ----
# 0.0 far more priceless if considerably less ambitious than last year 's priceless exercise .
# ----
# 0.2 far more imax if considerably less ambitious than last year 's imax exercise .
# ----
#
#
# Test: MFT with vocabullary - template23
# Test cases:      7102
# Fails (rate):    3660 (51.5%)
#
# Example fails:
# 1.0 the movie remains to storytelling up to the sum of its parts .
# ----
# 1.0 the movie seeks to celebrates up to the sum of its parts .
# ----
# 1.0 the movie remains to keep up to the sum of its parts .
# ----
#
#
# Test: MFT with vocabullary - template24
# Test cases:      134
# Fails (rate):    131 (97.8%)
#
# Example fails:
# 0.0 britney 's performance depressing not be depressing .
# ----
# 0.0 britney 's performance supposed not be supposed .
# ----
# 0.0 britney 's performance done not be done .
# ----
#
#
# Test: MFT with vocabullary - template25
# Test cases:      96
# Fails (rate):    96 (100.0%)
#
# Example fails:
# 0.0 a solid cast believable direction and complete lack of believable day irony .
# ----
# 0.0 a solid cast satisfying direction and complete lack of satisfying day irony .
# ----
# 0.0 a solid cast creative direction and complete lack of creative day irony .
# ----
#
#
# Test: MFT with vocabullary - template26
# Test cases:      167
# Fails (rate):    27 (16.2%)
#
# Example fails:
# 0.9 feels melodrama that is heavy on religious symbols but feels on dramatic substance
# ----
# 0.8 eardrum-dicing melodrama that is heavy on religious symbols but eardrum-dicing on dramatic substance
# ----
# 0.9 similar melodrama that is heavy on religious symbols but similar on dramatic substance
# ----
#
#
# Test: MFT with vocabullary - template27
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template28
# Test cases:      5086
# Fails (rate):    603 (11.9%)
#
# Example fails:
# 0.1 everyone should be able to improved the tremendous cinematography and naturalistic acting .
# ----
# 0.1 everyone should be able to keeps the basic cinematography and naturalistic acting .
# ----
# 0.0 everyone should be able to care the basic cinematography and naturalistic acting .
# ----
#
#
# Test: MFT with vocabullary - template29
# Test cases:      134
# Fails (rate):    5 (3.7%)
#
# Example fails:
# 0.8 it worked that something has been worked in the translation to the screen .
# ----
# 0.9 it bewildering that something has been bewildering in the translation to the screen .
# ----
# 1.0 it overcome that something has been overcome in the translation to the screen .
# ----
#
#
# Test: MFT with vocabullary - template30
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template31
# Test cases:      5086
# Fails (rate):    5 (0.1%)
#
# Example fails:
# 0.2 an iconic intelligent film that overlook within the confines of a well-established genre .
# ----
# 0.1 an modern intelligent film that overlook within the confines of a well-established genre .
# ----
# 0.4 an love intelligent film that overlook within the confines of a well-established genre .
# ----
#
#
# Test: MFT with vocabullary - template32
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template33
# Test cases:      167
# Fails (rate):    47 (28.1%)
#
# Example fails:
# 1.0 william shatner as a whole professor is the whole bright spot .
# ----
# 1.0 william shatner as a feels professor is the feels bright spot .
# ----
# 0.9 william shatner as a disquiet professor is the disquiet bright spot .
# ----
#
#
# Test: MFT with vocabullary - template34
# Test cases:      16032
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template35
# Test cases:      8851
# Fails (rate):    147 (1.7%)
#
# Example fails:
# 0.0 the one-liners are snappy the situations trite and the comic opportunities richly knew .
# ----
# 0.5 the one-liners are snappy the situations cheap-looking and the comic opportunities richly being .
# ----
# 0.2 the one-liners are snappy the situations unable and the comic opportunities richly knew .
# ----
#
#
# Test: MFT with vocabullary - template36
# Test cases:      167
# Fails (rate):    29 (17.4%)
#
# Example fails:
# 0.7 what was subtle and mystifying in the novella is now voyeuristic and voyeuristic .
# ----
# 1.0 what was subtle and mystifying in the novella is now similar and similar .
# ----
# 1.0 what was subtle and mystifying in the novella is now sexual and sexual .
# ----
#
#
# Test: MFT with vocabullary - template37
# Test cases:      22377
# Fails (rate):    4454 (19.9%)
#
# Example fails:
# 1.0 a family-friendly fantasy that ends up thinking very 112-minute with its imaginative premise .
# ----
# 1.0 a family-friendly fantasy that ends up exist very entire with its imaginative premise .
# ----
# 1.0 a family-friendly fantasy that ends up firing very loud with its imaginative premise .
# ----
#
#
# Test: MFT with vocabullary - template38
# Test cases:      22377
# Fails (rate):    5152 (23.0%)
#
# Example fails:
# 0.9 thanks to ice cube benjamins running an multilayered lot like friday in miami .
# ----
# 1.0 thanks to ice cube benjamins tear an downbeat lot like friday in miami .
# ----
# 1.0 thanks to ice cube benjamins uses an un lot like friday in miami .
# ----
#
#
# Test: MFT with vocabullary - template39
# Test cases:      167
# Fails (rate):    90 (53.9%)
#
# Example fails:
# 0.0 succeeds in providing a sappy world the sappy completion of the police academy series .
# ----
# 0.3 succeeds in providing a mumbo world the mumbo completion of the police academy series .
# ----
# 0.0 succeeds in providing a mushy world the mushy completion of the police academy series .
# ----
#
#
# Test: MFT with vocabullary - template40
# Test cases:      12864
# Fails (rate):    811 (6.3%)
#
# Example fails:
# 0.3 named lack the pungent bite of its title but it 's an apollo trifle nonetheless .
# ----
# 0.1 fails lack the pungent bite of its title but it 's an apollo trifle nonetheless .
# ----
# 0.5 ruins lack the pungent bite of its title but it 's an connect trifle nonetheless .
# ----
#
#
# Test: MFT with vocabullary - template41
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template42
# Test cases:      16032
# Fails (rate):    20 (0.1%)
#
# Example fails:
# 0.1 not too fancy not too filling not too appropriate but definitely slam-bang and sweet .
# ----
# 0.4 not too fancy not too filling not too superficial but definitely slam-bang and sweet .
# ----
# 0.4 not too fancy not too filling not too foot-dragging but definitely apollo and sweet .
# ----
#
#
# Test: MFT with vocabullary - template43
# Test cases:      22377
# Fails (rate):    12622 (56.4%)
#
# Example fails:
# 1.0 a depressingly simplistic 'post-feminist ' romantic comedy that takes an astonishingly work attitude toward women .
# ----
# 0.7 a depressingly cheap 'post-feminist ' romantic comedy that takes an astonishingly offend attitude toward women .
# ----
# 1.0 a depressingly narrow 'post-feminist ' romantic comedy that takes an astonishingly deflates attitude toward women .
# ----
#
#
# Test: MFT with vocabullary - template44
# Test cases:      16032
# Fails (rate):    1116 (7.0%)
#
# Example fails:
# 0.1 does point the way for believable indian filmmakers toward a crossover into boring markets .
# ----
# 0.2 does point the way for best indian filmmakers toward a crossover into trite markets .
# ----
# 0.0 does point the way for iq indian filmmakers toward a crossover into miserable markets .
# ----
#
#
# Test: MFT with vocabullary - template45
# Test cases:      16032
# Fails (rate):    2222 (13.9%)
#
# Example fails:
# 0.0 serrault bring much trivial naturalism to their characters .
# ----
# 0.1 serrault bring visceral weak naturalism to their characters .
# ----
# 0.0 serrault bring pretty strained naturalism to their characters .
# ----
#
#
# Test: MFT with vocabullary - template46
# Test cases:      12864
# Fails (rate):    76 (0.6%)
#
# Example fails:
# 0.9 snipes have too kubrick-meets-spielberg on a scorchingly plotted dramatic scenario for its own good .
# ----
# 1.0 snipes overcome too kubrick-meets-spielberg on a scorchingly plotted dramatic scenario for its own good .
# ----
# 0.9 snipes does too in-depth on a scorchingly plotted dramatic scenario for its own good .
# ----
#
#
# Test: MFT with vocabullary - template47
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template48
# Test cases:      167
# Fails (rate):    68 (40.7%)
#
# Example fails:
# 0.6 pure of intention and passably diverting his secret life is light painful and painful .
# ----
# 1.0 pure of intention and passably diverting his secret life is light only-in and only-in .
# ----
# 1.0 pure of intention and passably diverting his secret life is light volatile and volatile .
# ----
#
#
# Test: MFT with vocabullary - template49
# Test cases:      167
# Fails (rate):    55 (32.9%)
#
# Example fails:
# 1.0 a fable family comedy fable to be appreciated by anyone outside the under-10 set .
# ----
# 1.0 a serious family comedy serious to be appreciated by anyone outside the under-10 set .
# ----
# 1.0 a psychological family comedy psychological to be appreciated by anyone outside the under-10 set .
# ----
#
#
# Test: MFT with vocabullary - template50
# Test cases:      167
# Fails (rate):    80 (47.9%)
#
# Example fails:
# 1.0 hartley 's fable pace and fable rhythms follow .
# ----
# 1.0 hartley 's whole pace and whole rhythms follow .
# ----
# 1.0 hartley 's one-shot pace and one-shot rhythms follow .
# ----
#
#
# Test: MFT with vocabullary - template51
# Test cases:      22377
# Fails (rate):    44 (0.2%)
#
# Example fails:
# 0.5 mckay has his piece of puffery with a sour cliche and original doses of mean-spiritedness
# ----
# 1.0 mckay can his piece of puffery with a sour cliche and content doses of mean-spiritedness
# ----
# 0.7 mckay can his piece of puffery with a sour cliche and 112-minute doses of mean-spiritedness
# ----
#
#
# Test: MFT with vocabullary - template52
# Test cases:      16032
# Fails (rate):    84 (0.5%)
#
# Example fails:
# 0.3 boring but director carl franklin adds kubrick-meets-spielberg flourishes and freak-outs to make it entertaining .
# ----
# 0.1 boring but director carl franklin adds inspirational flourishes and freak-outs to make it entertaining .
# ----
# 0.3 dull but director carl franklin adds apollo flourishes and freak-outs to make it entertaining .
# ----
#
#
# Test: MFT with vocabullary - template53
# Test cases:      8851
# Fails (rate):    195 (2.2%)
#
# Example fails:
# 0.3 the excessive title character overlook the drama that gives added clout to this doc .
# ----
# 0.1 the little title character overlook the drama that gives added clout to this doc .
# ----
# 0.0 the witless title character overlook the drama that gives added clout to this doc .
# ----
#
#
# Test: MFT with vocabullary - template54
# Test cases:      22377
# Fails (rate):    5 (0.0%)
#
# Example fails:
# 0.9 excessively better and resembles .
# ----
# 0.6 excessively better and showing .
# ----
# 0.6 excessively equal and repelled .
# ----
#
#
# Test: MFT with vocabullary - template55
# Test cases:      5086
# Fails (rate):    651 (12.8%)
#
# Example fails:
# 0.1 a filmmaking profile of law enforcement and a imax nasty journey into an urban hades .
# ----
# 0.0 a trust profile of law enforcement and a much nasty journey into an urban hades .
# ----
# 0.4 a knew profile of law enforcement and a sincere nasty journey into an urban hades .
# ----
#
#
# Test: MFT with vocabullary - template56
# Test cases:      167
# Fails (rate):    16 (9.6%)
#
# Example fails:
# 0.9 it 's a bit predictable that it only manages to be decent instead of predictable brilliant .
# ----
# 0.9 it 's a bit lengthy that it only manages to be decent instead of lengthy brilliant .
# ----
# 0.8 it 's a bit innocuous that it only manages to be decent instead of innocuous brilliant .
# ----
#
#
# Test: MFT with vocabullary - template57
# Test cases:      12864
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template58
# Test cases:      5086
# Fails (rate):    1264 (24.9%)
#
# Example fails:
# 0.0 for a good chunk of its running time trapped storytelling an connect and claustrophobic thriller .
# ----
# 0.0 for a good chunk of its running time trapped care an emotional and claustrophobic thriller .
# ----
# 0.0 for a good chunk of its running time trapped comes an pretty and claustrophobic thriller .
# ----
#
#
# Test: MFT with vocabullary - template59
# Test cases:      22377
# Fails (rate):    12 (0.1%)
#
# Example fails:
# 0.9 the misery of these people becomes just another content spectacle to be feeling and forgotten .
# ----
# 0.5 the misery of these people becomes just another content spectacle to be escape and forgotten .
# ----
# 0.6 the misery of these people becomes just another 112-minute spectacle to be feeling and forgotten .
# ----
#
#
# Test: MFT with vocabullary - template60
# Test cases:      22377
# Fails (rate):    10459 (46.7%)
#
# Example fails:
# 1.0 utterly playing in charm wit and invention roberto benigni 's pinocchio is an astonishingly dusty film .
# ----
# 1.0 utterly escape in charm wit and invention roberto benigni 's pinocchio is an astonishingly psychological film .
# ----
# 1.0 utterly takes in charm wit and invention roberto benigni 's pinocchio is an astonishingly analgesic film .
# ----
#
#
# Test: MFT with vocabullary - template61
# Test cases:      167
# Fails (rate):    1 (0.6%)
#
# Example fails:
# 0.6 it 's a trifle of a movie with a psychological laughs surrounding an psychological soft center .
# ----
#
#
# Test: MFT with vocabullary - template62
# Test cases:      8851
# Fails (rate):    296 (3.3%)
#
# Example fails:
# 0.8 one of those pictures whose promising if rather precious premise heartening undercut by deja execution .
# ----
# 1.0 one of those pictures whose promising if rather precious premise entertaining undercut by considerable execution .
# ----
# 0.5 one of those pictures whose promising if rather precious premise rewarding undercut by multilayered execution .
# ----
#
#
# Test: MFT with vocabullary - template63
# Test cases:      134
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template64
# Test cases:      96
# Fails (rate):    4 (4.2%)
#
# Example fails:
# 1.0 enjoyable intelligence constantly vies with pretension -- and sometimes plain enjoyable implausibility -- throughout maelstrom .
# ----
# 1.0 wonderful intelligence constantly vies with pretension -- and sometimes plain wonderful implausibility -- throughout maelstrom .
# ----
# 0.5 beautiful intelligence constantly vies with pretension -- and sometimes plain beautiful implausibility -- throughout maelstrom .
# ----
#
#
# Test: MFT with vocabullary - template65
# Test cases:      96
# Fails (rate):    33 (34.4%)
#
# Example fails:
# 0.0 modern somber absurd and finally achingly sad bartleby is a modern understated piece of filmmaking .
# ----
# 0.0 observant somber absurd and finally achingly sad bartleby is a observant understated piece of filmmaking .
# ----
# 0.1 acquainted somber absurd and finally achingly sad bartleby is a acquainted understated piece of filmmaking .
# ----
#
#
# Test: MFT with vocabullary - template66
# Test cases:      5086
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template67
# Test cases:      7102
# Fails (rate):    3471 (48.9%)
#
# Example fails:
# 0.7 rhythms caddyshack may with the loyal order of raccoons .
# ----
# 0.9 touches caddyshack unexamined with the loyal order of raccoons .
# ----
# 1.0 entertaining caddyshack have with the loyal order of raccoons .
# ----
#
#
# Test: MFT with vocabullary - template68
# Test cases:      5086
# Fails (rate):    1302 (25.6%)
#
# Example fails:
# 0.0 biggie and tupac overlook so nuanced daring it puts far more polished documentaries to shame .
# ----
# 0.0 biggie and tupac touches so iq daring it puts far more polished documentaries to shame .
# ----
# 0.1 biggie and tupac thank so cinematic daring it puts far more polished documentaries to shame .
# ----
#
#
# Test: MFT with vocabullary - template69
# Test cases:      96
# Fails (rate):    4 (4.2%)
#
# Example fails:
# 0.1 a outrageous reconsideration of one of san francisco 's most vital if least widely recognized outrageous fountainheads .
# ----
# 0.3 a pretty reconsideration of one of san francisco 's most vital if least widely recognized pretty fountainheads .
# ----
# 0.3 a goofy reconsideration of one of san francisco 's most vital if least widely recognized goofy fountainheads .
# ----
#
#
# Test: MFT with vocabullary - template70
# Test cases:      134
# Fails (rate):    72 (53.7%)
#
# Example fails:
# 1.0 it go be the first sci-fi comedy that go benefit from a three 's company-style laugh track .
# ----
# 0.7 it seeks be the first sci-fi comedy that seeks benefit from a three 's company-style laugh track .
# ----
# 1.0 it takes be the first sci-fi comedy that takes benefit from a three 's company-style laugh track .
# ----
#
#
# Test: MFT with vocabullary - template71
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.8 skins overcome a right to overcome and we have a right to our grains of salt .
# ----
#
#
# Test: MFT with vocabullary - template72
# Test cases:      22377
# Fails (rate):    75 (0.3%)
#
# Example fails:
# 0.6 the unceasing sadism is so graphically tv-style the director just can up exposing his own obsession .
# ----
# 0.9 the unceasing sadism is so graphically equal the director just feeling up exposing his own obsession .
# ----
# 1.0 the unceasing sadism is so graphically original the director just can up exposing his own obsession .
# ----
#
#
# Test: MFT with vocabullary - template73
# Test cases:      16032
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template74
# Test cases:      134
# Fails (rate):    21 (15.7%)
#
# Example fails:
# 0.6 the movie feels for me right up to the final scene and then it feels in .
# ----
# 0.9 the movie has for me right up to the final scene and then it has in .
# ----
# 0.9 the movie strikes for me right up to the final scene and then it strikes in .
# ----
#
#
# Test: MFT with vocabullary - template75
# Test cases:      12864
# Fails (rate):    878 (6.8%)
#
# Example fails:
# 0.2 claire is a artful role for someone like judd who really leaves to be playing villains .
# ----
# 0.0 claire is a modern role for someone like judd who really stilted to be playing villains .
# ----
# 0.0 claire is a apollo role for someone like judd who really supposed to be playing villains .
# ----
#
#
# Test: MFT with vocabullary - template76
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template77
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template78
# Test cases:      5086
# Fails (rate):    1 (0.0%)
#
# Example fails:
# 0.2 the trials of henry kissinger is a cinematic piece of overlook ?
# ----
#
#
# Test: MFT with vocabullary - template79
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.8 watching queen of the feeling is like reading a research paper with special effects feeling in .
# ----
#
#
# Test: MFT with vocabullary - template80
# Test cases:      7102
# Fails (rate):    2411 (33.9%)
#
# Example fails:
# 0.0 you use overlook me for this .
# ----
# 0.4 you lacking elevate me for this .
# ----
# 0.1 you expect rock me for this .
# ----
#
#
# Test: MFT with vocabullary - template81
# Test cases:      134
# Fails (rate):    28 (20.9%)
#
# Example fails:
# 0.6 equlibrium hate hate for a thirteen-year-old 's book report on the totalitarian themes of 1984 and farenheit 451 .
# ----
# 1.0 equlibrium ruins ruins for a thirteen-year-old 's book report on the totalitarian themes of 1984 and farenheit 451 .
# ----
# 1.0 equlibrium bewildering bewildering for a thirteen-year-old 's book report on the totalitarian themes of 1984 and farenheit 451 .
# ----
#
#
# Test: MFT with vocabullary - template82
# Test cases:      16032
# Fails (rate):    1089 (6.8%)
#
# Example fails:
# 0.7 hardly a challenge-hungry portrait of a young woman 's breakdown the film nevertheless works up a disquiet scares .
# ----
# 0.8 hardly a artful portrait of a young woman 's breakdown the film nevertheless works up a considerable scares .
# ----
# 0.8 hardly a cinematic portrait of a young woman 's breakdown the film nevertheless works up a considerable scares .
# ----
#
#
# Test: MFT with vocabullary - template83
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template84
# Test cases:      16032
# Fails (rate):    3581 (22.3%)
#
# Example fails:
# 1.0 cruel and unforced satisfying punishment .
# ----
# 1.0 cruel and disappointing fascinating punishment .
# ----
# 1.0 cruel and junk-calorie enjoyable punishment .
# ----
#
#
# Test: MFT with vocabullary - template85
# Test cases:      134
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template86
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template87
# Test cases:      22377
# Fails (rate):    3090 (13.8%)
#
# Example fails:
# 0.1 vincent gallo is right at home in this french shocker losing his self-mutilating bad boy weirdo role .
# ----
# 0.0 vincent gallo is right at home in this french shocker lose his unable bad boy weirdo role .
# ----
# 0.0 vincent gallo is right at home in this french shocker ruins his content bad boy weirdo role .
# ----
#
#
# Test: MFT with vocabullary - template88
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template89
# Test cases:      134
# Fails (rate):    22 (16.4%)
#
# Example fails:
# 0.5 cattaneo lacking lacking followed the runaway success of his first film the full monty with something different .
# ----
# 0.5 cattaneo hate hate followed the runaway success of his first film the full monty with something different .
# ----
# 0.9 cattaneo escape escape followed the runaway success of his first film the full monty with something different .
# ----
#
#
# Test: MFT with vocabullary - template90
# Test cases:      16032
# Fails (rate):    3910 (24.4%)
#
# Example fails:
# 0.0 a quietly slam-bang and obnoxious new zealand film about an eventful summer in a 13-year-old girl 's life .
# ----
# 0.0 a quietly spectacular and meaningless new zealand film about an eventful summer in a 13-year-old girl 's life .
# ----
# 0.1 a quietly creative and weak new zealand film about an eventful summer in a 13-year-old girl 's life .
# ----
#
#
# Test: MFT with vocabullary - template91
# Test cases:      22377
# Fails (rate):    26 (0.1%)
#
# Example fails:
# 0.8 wildly appropriate but brilliantly uses half past dead -- or for seagal pessimists : totally past his prime .
# ----
# 0.7 wildly psychological but brilliantly involve half past dead -- or for seagal pessimists : totally past his prime .
# ----
# 0.5 wildly sexual but brilliantly involve half past dead -- or for seagal pessimists : totally past his prime .
# ----
#
#
# Test: MFT with vocabullary - template92
# Test cases:      16032
# Fails (rate):    7762 (48.4%)
#
# Example fails:
# 0.1 inarticulate movie-goers embarking upon this journey will find that the road to perdition leads to a comfortable destination .
# ----
# 0.1 next movie-goers embarking upon this journey will find that the road to perdition leads to a observant destination .
# ----
# 0.1 unsatisfying movie-goers embarking upon this journey will find that the road to perdition leads to a cinematic destination .
# ----
#
#
# Test: MFT with vocabullary - template93
# Test cases:      12864
# Fails (rate):    253 (2.0%)
#
# Example fails:
# 0.2 it plastered be about drug dealers kidnapping and unsavory folks but the tone and pacing are shockingly apollo .
# ----
# 0.0 it telegraphed be about drug dealers kidnapping and unsavory folks but the tone and pacing are shockingly slam-bang .
# ----
# 0.0 it tries be about drug dealers kidnapping and unsavory folks but the tone and pacing are shockingly creative .
# ----
#
#
# Test: MFT with vocabullary - template94
# Test cases:      8851
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template95
# Test cases:      12864
# Fails (rate):    1484 (11.5%)
#
# Example fails:
# 0.1 while the filmmaking may be a bit yawp the subject matter is so more that you wo n't care .
# ----
# 0.4 while the filmmaking may be a bit rebel the subject matter is so imax that you wo n't care .
# ----
# 0.1 while the filmmaking may be a bit pass the subject matter is so goofy that you wo n't care .
# ----
#
#
# Test: MFT with vocabullary - template96
# Test cases:      16032
# Fails (rate):    3772 (23.5%)
#
# Example fails:
# 0.0 texan director george ratliff had unlimited access to families and church meetings and he delivers iconic ordinary fare .
# ----
# 0.1 texan director george ratliff had unlimited access to families and church meetings and he delivers artful stupid fare .
# ----
# 0.0 texan director george ratliff had unlimited access to families and church meetings and he delivers intense only-in fare .
# ----
#
#
# Test: MFT with vocabullary - template97
# Test cases:      96
# Fails (rate):    47 (49.0%)
#
# Example fails:
# 0.0 a comedy-drama of nearly interesting proportions rooted in a interesting performance by the title character undergoing midlife crisis .
# ----
# 0.0 a comedy-drama of nearly neat proportions rooted in a neat performance by the title character undergoing midlife crisis .
# ----
# 0.0 a comedy-drama of nearly single-mindedly proportions rooted in a single-mindedly performance by the title character undergoing midlife crisis .
# ----
#
#
# Test: MFT with vocabullary - template98
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template99
# Test cases:      22377
# Fails (rate):    110 (0.5%)
#
# Example fails:
# 0.8 intended to be a comedy about relationships this multilayered work avoid flat in just about every conceivable area .
# ----
# 0.8 intended to be a comedy about relationships this fable work lacks flat in just about every conceivable area .
# ----
# 1.0 intended to be a comedy about relationships this unsatisfying work avoids flat in just about every conceivable area .
# ----
#
#
# Test: MFT with vocabullary - template100
# Test cases:      22377
# Fails (rate):    2945 (13.2%)
#
# Example fails:
# 0.8 a puppy dog so lengthy for attention it nearly breaks its little neck say to perform entertaining tricks .
# ----
# 1.0 a puppy dog so sexual for attention it nearly breaks its little neck remains to perform entertaining tricks .
# ----
# 1.0 a puppy dog so unlikely for attention it nearly breaks its little neck remains to perform entertaining tricks .
# ----
#
#
# Test: MFT with vocabullary - template101
# Test cases:      22377
# Fails (rate):    2594 (11.6%)
#
# Example fails:
# 1.0 take care is nicely performed by a quintet of actresses but nonetheless it has during its amped-up length .
# ----
# 0.9 take care is nicely performed by a quintet of actresses but nonetheless it seems during its considerable length .
# ----
# 0.6 take care is nicely performed by a quintet of actresses but nonetheless it remains during its heavy length .
# ----
#
#
# Test: MFT with vocabullary - template102
# Test cases:      12864
# Fails (rate):    476 (3.7%)
#
# Example fails:
# 0.1 murderous maids avoids well be the most imax of these films and also strike closest to the truth .
# ----
# 0.0 murderous maids lacks well be the most authentic of these films and also strike closest to the truth .
# ----
# 0.0 murderous maids fails well be the most tremendous of these films and also strike closest to the truth .
# ----
#
#
# Test: MFT with vocabullary - template103
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template104
# Test cases:      16032
# Fails (rate):    12674 (79.1%)
#
# Example fails:
# 0.0 devos and cassel have creative chemistry -- their wafer-thin and romantic tension while never really vocalized is palpable .
# ----
# 0.0 devos and cassel have world-class chemistry -- their unable and romantic tension while never really vocalized is palpable .
# ----
# 0.4 devos and cassel have imax chemistry -- their psychological and romantic tension while never really vocalized is palpable .
# ----
#
#
# Test: MFT with vocabullary - template105
# Test cases:      134
# Fails (rate):    131 (97.8%)
#
# Example fails:
# 0.0 birthday girl cloying n't try to surprise us with plot twists but rather cloying to enjoy its own transparency .
# ----
# 0.0 birthday girl used n't try to surprise us with plot twists but rather used to enjoy its own transparency .
# ----
# 0.0 birthday girl say n't try to surprise us with plot twists but rather say to enjoy its own transparency .
# ----
#
#
# Test: MFT with vocabullary - template106
# Test cases:      8851
# Fails (rate):    900 (10.2%)
#
# Example fails:
# 0.8 it rewarding a dusty message in a visual style that is willfully overwrought .
# ----
# 0.7 it liberating a broad message in a visual style that is willfully overwrought .
# ----
# 0.9 it rewarded a un message in a visual style that is willfully overwrought .
# ----
#
#
# Test: MFT with vocabullary - template107
# Test cases:      12864
# Fails (rate):    6582 (51.2%)
#
# Example fails:
# 1.0 an solid yet should film that makes a melodramatic mountain out of the molehill of a missing bike .
# ----
# 1.0 an inventive yet may film that makes a melodramatic mountain out of the molehill of a missing bike .
# ----
# 1.0 an credible yet involve film that makes a melodramatic mountain out of the molehill of a missing bike .
# ----
#
#
# Test: MFT with vocabullary - template108
# Test cases:      22377
# Fails (rate):    75 (0.3%)
#
# Example fails:
# 0.7 though frida is easier to swallow than julie taymor 's preposterous titus the eye candy here see deja brio .
# ----
# 0.9 though frida is easier to swallow than julie taymor 's preposterous titus the eye candy here avoids difficult brio .
# ----
# 0.7 though frida is easier to swallow than julie taymor 's preposterous titus the eye candy here see fluffy brio .
# ----
#
#
# Test: MFT with vocabullary - template109
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.6 its stupidities lifts up lifts in one 's mind a lot more than the cool bits .
# ----
#
#
# Test: MFT with vocabullary - template110
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template111
# Test cases:      5086
# Fails (rate):    1749 (34.4%)
#
# Example fails:
# 0.1 seeing as the film lacks momentum and its position remains mostly undeterminable the director 's experiment comes a challenge-hungry one .
# ----
# 0.0 seeing as the film lacks momentum and its position remains mostly undeterminable the director 's experiment improved a apollo one .
# ----
# 0.0 seeing as the film lacks momentum and its position remains mostly undeterminable the director 's experiment become a nuanced one .
# ----
#
#
# Test: MFT with vocabullary - template112
# Test cases:      5086
# Fails (rate):    7 (0.1%)
#
# Example fails:
# 0.1 though filmed partly in canada paid in full has more ways of being inner-city life during the reagan years .
# ----
# 0.3 though filmed partly in canada paid in full has more ways of filmmaking inner-city life during the reagan years .
# ----
# 0.1 though filmed partly in canada paid in full has more ways of comes inner-city life during the reagan years .
# ----
#
#
# Test: MFT with vocabullary - template113
# Test cases:      12864
# Fails (rate):    1582 (12.3%)
#
# Example fails:
# 0.0 cedar takes a very open-minded approach to this sensitive material lacking unusual control both visually and in the writing .
# ----
# 0.0 cedar takes a very open-minded approach to this sensitive material lost comprehensive control both visually and in the writing .
# ----
# 0.0 cedar takes a very open-minded approach to this sensitive material stilted comfortable control both visually and in the writing .
# ----
#
#
# Test: MFT with vocabullary - template114
# Test cases:      22377
# Fails (rate):    30 (0.1%)
#
# Example fails:
# 0.7 this follow-up lifts so 112-minute to the 1953 disney classic that it makes one long for a geriatric peter .
# ----
# 0.7 this follow-up work so plausible to the 1953 disney classic that it makes one long for a geriatric peter .
# ----
# 0.5 this follow-up lifts so psychological to the 1953 disney classic that it makes one long for a geriatric peter .
# ----
#
#
# Test: MFT with vocabullary - template115
# Test cases:      7102
# Fails (rate):    6556 (92.3%)
#
# Example fails:
# 0.0 despite its title punch-drunk love rock never were .
# ----
# 0.1 despite its title punch-drunk love liberating never confused .
# ----
# 0.0 despite its title punch-drunk love storytelling never relies .
# ----
#
#
# Test: MFT with vocabullary - template116
# Test cases:      8851
# Fails (rate):    7 (0.1%)
#
# Example fails:
# 0.4 sandra nettelbeck beautifully overlook the transformation of the chilly neurotic and ludicrous martha as her heart begins to open .
# ----
# 0.3 sandra nettelbeck beautifully overlook the transformation of the chilly neurotic and only-in martha as her heart begins to open .
# ----
# 0.1 sandra nettelbeck beautifully overlook the transformation of the chilly neurotic and predictable martha as her heart begins to open .
# ----
#
#
# Test: MFT with vocabullary - template117
# Test cases:      12864
# Fails (rate):    2320 (18.0%)
#
# Example fails:
# 0.0 adams with four scriptwriters abandon care with the characters who are so acquainted that you feel what they feel .
# ----
# 0.0 adams with four scriptwriters lose care with the characters who are so more that you feel what they feel .
# ----
# 0.0 adams with four scriptwriters faulted care with the characters who are so superior that you feel what they feel .
# ----
#
#
# Test: MFT with vocabullary - template118
# Test cases:      12864
# Fails (rate):    3 (0.0%)
#
# Example fails:
# 0.6 a film that presents an interesting even sexy premise then avoids itself with too many contrivances and assured situations .
# ----
# 0.6 a film that presents an interesting even sexy premise then lacking itself with too many contrivances and terrific situations .
# ----
# 0.7 a film that presents an interesting even sexy premise then avoids itself with too many contrivances and fine situations .
# ----
#
#
# Test: MFT with vocabullary - template119
# Test cases:      22377
# Fails (rate):    505 (2.3%)
#
# Example fails:
# 0.9 precocious smarter-than-thou wayward teen struggles to disappoint against his oppressive right-wing inhuman family .
# ----
# 0.7 precocious smarter-than-thou wayward teen struggles to faulted against his oppressive right-wing trivial family .
# ----
# 0.7 precocious smarter-than-thou wayward teen struggles to disappoint against his oppressive right-wing equal family .
# ----
#
#
# Test: MFT with vocabullary - template120
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template121
# Test cases:      22377
# Fails (rate):    264 (1.2%)
#
# Example fails:
# 0.7 [ leigh ] lays it on so thick this time that it avoids like a cheap-looking race .
# ----
# 0.6 [ leigh ] lays it on so thick this time that it overcome like a obvious race .
# ----
# 0.8 [ leigh ] lays it on so thick this time that it doing like a equal race .
# ----
#
#
# Test: MFT with vocabullary - template122
# Test cases:      7102
# Fails (rate):    1795 (25.3%)
#
# Example fails:
# 0.0 once again director jackson stilted a live balance between emotion on the human scale and action/effects on the spectacular scale .
# ----
# 0.1 once again director jackson trapped a kissing balance between emotion on the human scale and action/effects on the spectacular scale .
# ----
# 0.1 once again director jackson caved a heal balance between emotion on the human scale and action/effects on the spectacular scale .
# ----
#
#
# Test: MFT with vocabullary - template123
# Test cases:      22377
# Fails (rate):    300 (1.3%)
#
# Example fails:
# 0.6 first for a movie that strung to be smart it 's broad dumb .
# ----
# 1.0 first for a movie that see to be smart it 's equal dumb .
# ----
# 0.6 first for a movie that employ to be smart it 's equal dumb .
# ----
#
#
# Test: MFT with vocabullary - template124
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template125
# Test cases:      22377
# Fails (rate):    434 (1.9%)
#
# Example fails:
# 1.0 the images are usually abbreviated in favor of entire obviousness and overcome pathos particularly where whitaker 's misfit artist is concerned .
# ----
# 1.0 the images are usually abbreviated in favor of illogical obviousness and avoids pathos particularly where whitaker 's misfit artist is concerned .
# ----
# 0.7 the images are usually abbreviated in favor of mannered obviousness and overcome pathos particularly where whitaker 's misfit artist is concerned .
# ----
#
#
# Test: MFT with vocabullary - template126
# Test cases:      22377
# Fails (rate):    5563 (24.9%)
#
# Example fails:
# 1.0 the notion that bombing buildings is the funniest thing in the world goes entirely done in this startlingly amped-up comedy .
# ----
# 1.0 the notion that bombing buildings is the funniest thing in the world goes entirely have in this startlingly conventional comedy .
# ----
# 1.0 the notion that bombing buildings is the funniest thing in the world goes entirely tells in this startlingly downbeat comedy .
# ----
#
#
# Test: MFT with vocabullary - template127
# Test cases:      134
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template128
# Test cases:      134
# Fails (rate):    9 (6.7%)
#
# Example fails:
# 0.6 the sinister inspiration that fuelled devito 's early work is tear in death to tear into something both ugly and mindless .
# ----
# 0.8 the sinister inspiration that fuelled devito 's early work is fights in death to fights into something both ugly and mindless .
# ----
# 1.0 the sinister inspiration that fuelled devito 's early work is showing in death to showing into something both ugly and mindless .
# ----
#
#
# Test: MFT with vocabullary - template129
# Test cases:      7102
# Fails (rate):    1048 (14.8%)
#
# Example fails:
# 0.4 one of the smarter live the horror genre groans produced in recent memory even if it 's far tamer than advertised .
# ----
# 0.0 one of the smarter become the horror genre labored produced in recent memory even if it 's far tamer than advertised .
# ----
# 0.3 one of the smarter haunting the horror genre avoid produced in recent memory even if it 's far tamer than advertised .
# ----
#
#
# Test: MFT with vocabullary - template130
# Test cases:      167
# Fails (rate):    60 (35.9%)
#
# Example fails:
# 1.0 sexual documentary offers sexual explanations to a very complex situation .
# ----
# 1.0 one-shot documentary offers one-shot explanations to a very complex situation .
# ----
# 0.8 final documentary offers final explanations to a very complex situation .
# ----
#
#
# Test: MFT with vocabullary - template131
# Test cases:      8851
# Fails (rate):    1108 (12.5%)
#
# Example fails:
# 0.6 keep silly rather than unsatisfying .
# ----
# 0.9 enjoy silly rather than awful .
# ----
# 1.0 satisfying silly rather than illogical .
# ----
#
#
# Test: MFT with vocabullary - template132
# Test cases:      96
# Fails (rate):    8 (8.3%)
#
# Example fails:
# 0.9 so earnest and intense and so intense with talent that you almost forget the sheer ponderous awfulness of its script .
# ----
# 0.6 so earnest and fascinating and so fascinating with talent that you almost forget the sheer ponderous awfulness of its script .
# ----
# 0.5 so earnest and polished and so polished with talent that you almost forget the sheer ponderous awfulness of its script .
# ----
#
#
# Test: MFT with vocabullary - template133
# Test cases:      22377
# Fails (rate):    8077 (36.1%)
#
# Example fails:
# 0.9 it stopped far short of poetry but it 's not farcical prose .
# ----
# 0.9 it unexamined far short of poetry but it 's not impossible prose .
# ----
# 1.0 it leaves far short of poetry but it 's not meaningless prose .
# ----
#
#
# Test: MFT with vocabullary - template134
# Test cases:      12864
# Fails (rate):    8240 (64.1%)
#
# Example fails:
# 0.0 everything in maid in manhattan is exceedingly modern designed not to associated .
# ----
# 0.0 everything in maid in manhattan is exceedingly love designed not to overcome .
# ----
# 0.0 everything in maid in manhattan is exceedingly apollo designed not to strikes .
# ----
#
#
# Test: MFT with vocabullary - template135
# Test cases:      12864
# Fails (rate):    2383 (18.5%)
#
# Example fails:
# 0.0 `` the dangerous lives of altar boys `` has flaws but it also fails humor and heart and very nice young actors
# ----
# 0.1 `` the dangerous lives of altar boys `` has flaws but it also damned humor and heart and very outrageous young actors
# ----
# 0.0 `` the dangerous lives of altar boys `` has flaws but it also fails humor and heart and very fun young actors
# ----
#
#
# Test: MFT with vocabullary - template136
# Test cases:      7102
# Fails (rate):    177 (2.5%)
#
# Example fails:
# 0.6 with lines that heal like long soliloquies -- even as they are being framed in conversation -- max is static see .
# ----
# 0.7 with lines that haunting like long soliloquies -- even as they are being framed in conversation -- max is static simmering .
# ----
# 0.7 with lines that heal like long soliloquies -- even as they are being framed in conversation -- max is static have .
# ----
#
#
# Test: MFT with vocabullary - template137
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.6 to feels this was feels better in wilder 's some like it hot is like saying the sun rises in the east .
# ----
#
#
# Test: MFT with vocabullary - template138
# Test cases:      167
# Fails (rate):    160 (95.8%)
#
# Example fails:
# 0.0 the film is surprisingly well-directed by brett ratner who keeps things moving well -- at least until the predictable predictable act .
# ----
# 0.0 the film is surprisingly well-directed by brett ratner who keeps things moving well -- at least until the incompetent incompetent act .
# ----
# 0.0 the film is surprisingly well-directed by brett ratner who keeps things moving well -- at least until the wafer-thin wafer-thin act .
# ----
#
#
# Test: MFT with vocabullary - template139
# Test cases:      8851
# Fails (rate):    7783 (87.9%)
#
# Example fails:
# 0.0 has all the values of a straight-to-video movie but because it has a bigger-name cast it stays a grumpy theatrical release .
# ----
# 0.0 has all the values of a straight-to-video movie but because it has a bigger-name cast it keeps a over-the-top theatrical release .
# ----
# 0.3 has all the values of a straight-to-video movie but because it has a bigger-name cast it rewarded a lengthy theatrical release .
# ----
#
#
# Test: MFT with vocabullary - template140
# Test cases:      7102
# Fails (rate):    670 (9.4%)
#
# Example fails:
# 0.1 it consumed capturing a historically significant work as well as a masterfully made one .
# ----
# 0.1 it faulted touches a historically significant work as well as a masterfully made one .
# ----
# 0.0 it avoids keep a historically significant work as well as a masterfully made one .
# ----
#
#
# Test: MFT with vocabullary - template141
# Test cases:      134
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template142
# Test cases:      5086
# Fails (rate):    1531 (30.1%)
#
# Example fails:
# ...
# ----
# 0.1 while mcfarlane 's animation thought the film firmly above the level of full coming-of-age films .
# ----
#
#
# Test: MFT with vocabullary - template252
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template253
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template254
# Test cases:      134
# Fails (rate):    1 (0.7%)
#
# Example fails:
# 0.9 the film would have been more enjoyable had the balance shifted in favor of water-bound action over the land-based 'drama ' but the emphasis on the latter tells blue crush tells .
# ----
#
#
# Test: MFT with vocabullary - template255
# Test cases:      12864
# Fails (rate):    7721 (60.0%)
#
# Example fails:
# 0.0 addessi much of the time the movie forced interesting .
# ----
# 0.0 addessi much of the time the movie ploughing credible .
# ----
# 0.0 addessi much of the time the movie stopped wacky .
# ----
#
#
# Test: MFT with vocabullary - template256
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template257
# Test cases:      134
# Fails (rate):    81 (60.4%)
#
# Example fails:
# 0.0 made eddie murphy a movie star and the man losing n't losing a day .
# ----
# 0.0 made eddie murphy a movie star and the man plastered n't plastered a day .
# ----
# 0.0 made eddie murphy a movie star and the man dismissed n't dismissed a day .
# ----
#
#
# Test: MFT with vocabullary - template258
# Test cases:      16032
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template259
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template260
# Test cases:      134
# Fails (rate):    2 (1.5%)
#
# Example fails:
# 0.7 in a big corner office in hell satan is throwing up his hands in surrender is feeling his r & d people and has decided he will just feeling the master of disguise 24/7 .
# ----
# 0.7 in a big corner office in hell satan is throwing up his hands in surrender is overcome his r & d people and has decided he will just overcome the master of disguise 24/7 .
# ----
#
#
# Test: MFT with vocabullary - template261
# Test cases:      22377
# Fails (rate):    12082 (54.0%)
#
# Example fails:
# 0.0 muccino who consumed from his own screenplay is a canny crowd pleaser and the suicide kiss .
# ----
# 0.0 muccino who consumed from his own screenplay is a canny crowd pleaser and the forgettable kiss .
# ----
# 0.0 muccino who seeks from his own screenplay is a canny crowd pleaser and the incompetent kiss .
# ----
#
#
# Test: MFT with vocabullary - template262
# Test cases:      96
# Fails (rate):    20 (20.8%)
#
# Example fails:
# 0.1 provides goofy than enough sentimental catharsis for a goofy evening at the multiplex .
# ----
# 0.0 provides basic than enough sentimental catharsis for a basic evening at the multiplex .
# ----
# 0.3 provides neat than enough sentimental catharsis for a neat evening at the multiplex .
# ----
#
#
# Test: MFT with vocabullary - template263
# Test cases:      16032
# Fails (rate):    2263 (14.1%)
#
# Example fails:
# 0.0 another goofy ? what you do n't see ' is much more terrifying than what you do see thriller coupled with some arresting effects incandescent tones and disappointing performances
# ----
# 0.0 another nuanced ? what you do n't see ' is much more terrifying than what you do see thriller coupled with some arresting effects incandescent tones and problematic performances
# ----
# 0.0 another challenge-hungry ? what you do n't see ' is much more terrifying than what you do see thriller coupled with some arresting effects incandescent tones and boring performances
# ----
#
#
# Test: MFT with vocabullary - template264
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template265
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template266
# Test cases:      134
# Fails (rate):    25 (18.7%)
#
# Example fails:
# 0.7 wasabi is slight fare indeed with the entire project having the feel of something tossed off quickly ( like one of hubert 's punches ) but it seeks seeks down smoothly enough with popcorn .
# ----
# 0.7 wasabi is slight fare indeed with the entire project having the feel of something tossed off quickly ( like one of hubert 's punches ) but it tear tear down smoothly enough with popcorn .
# ----
# 0.9 wasabi is slight fare indeed with the entire project having the feel of something tossed off quickly ( like one of hubert 's punches ) but it strikes strikes down smoothly enough with popcorn .
# ----
#
#
# Test: MFT with vocabullary - template267
# Test cases:      53
# Fails (rate):    6 (11.3%)
#
# Example fails:
# 0.4 if the film 's vision of sport as a secular religion is a bit cloying its through-line of family and community offerings offerings in the same way that each season marks a new start .
# ----
# 0.3 if the film 's vision of sport as a secular religion is a bit cloying its through-line of family and community trust trust in the same way that each season marks a new start .
# ----
# 0.2 if the film 's vision of sport as a secular religion is a bit cloying its through-line of family and community kissing kissing in the same way that each season marks a new start .
# ----
#
#
# Test: MFT with vocabullary - template268
# Test cases:      22377
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template269
# Test cases:      12864
# Fails (rate):    2217 (17.2%)
#
# Example fails:
# 0.0 a coming-of-age film that consumed the cartoonish clich ? s and sneering humor of the genre as it provides a true view of an old type -- the uncertain girl on the brink of womanhood .
# ----
# 0.3 a coming-of-age film that forced the cartoonish clich ? s and sneering humor of the genre as it provides a good view of an old type -- the uncertain girl on the brink of womanhood .
# ----
# 0.1 a coming-of-age film that aged the cartoonish clich ? s and sneering humor of the genre as it provides a best view of an old type -- the uncertain girl on the brink of womanhood .
# ----
#
#
# Test: MFT with vocabullary - template270
# Test cases:      134
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template271
# Test cases:      5086
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template272
# Test cases:      22377
# Fails (rate):    13091 (58.5%)
#
# Example fails:
# 1.0 the overall feel of the film is pretty cheesy but there 's still a real sense that the star trek tradition has been honored as best it can given the throwing script and rent direction .
# ----
# 0.8 the overall feel of the film is pretty cheesy but there 's still a real sense that the star trek tradition has been honored as best it can given the consumed script and third direction .
# ----
# 1.0 the overall feel of the film is pretty cheesy but there 's still a real sense that the star trek tradition has been honored as best it can given the trying script and broad direction .
# ----
#
#
# Test: MFT with vocabullary - template273
# Test cases:      16032
# Fails (rate):    6663 (41.6%)
#
# Example fails:
# 0.2 parker holds true to wilde 's own vision of a pure comedy with absolutely no meaning and no desire to be anything but a artful sophisticated entertainment that is in love with its lengthy cleverness .
# ----
# 0.3 parker holds true to wilde 's own vision of a pure comedy with absolutely no meaning and no desire to be anything but a polished sophisticated entertainment that is in love with its flat cleverness .
# ----
# 0.5 parker holds true to wilde 's own vision of a pure comedy with absolutely no meaning and no desire to be anything but a fresh sophisticated entertainment that is in love with its ludicrous cleverness .
# ----
#
#
# Test: MFT with vocabullary - template274
# Test cases:      22377
# Fails (rate):    1057 (4.7%)
#
# Example fails:
# 0.5 after an hour and a half of wondering -- sometimes amusedly sometimes impatiently -- just what this strenuously unconventional movie is running to be you discover that the answer is as final as can be .
# ----
# 0.8 after an hour and a half of wondering -- sometimes amusedly sometimes impatiently -- just what this strenuously unconventional movie is condescending to be you discover that the answer is as plausible as can be .
# ----
# 0.6 after an hour and a half of wondering -- sometimes amusedly sometimes impatiently -- just what this strenuously unconventional movie is wrapped to be you discover that the answer is as final as can be .
# ----
#
#
# Test: MFT with vocabullary - template275
# Test cases:      167
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template276
# Test cases:      134
# Fails (rate):    131 (97.8%)
#
# Example fails:
# 0.0 but his sense of humor has yet to smoochy the smug self-satisfaction usually smoochy with the better private schools .
# ----
# 0.0 but his sense of humor has yet to trying the smug self-satisfaction usually trying with the better private schools .
# ----
# 0.0 but his sense of humor has yet to unexamined the smug self-satisfaction usually unexamined with the better private schools .
# ----
#
#
# Test: MFT with vocabullary - template277
# Test cases:      134
# Fails (rate):    44 (32.8%)
#
# Example fails:
# 1.0 as any creature-feature fan knows when you cross toxic chemicals with a bunch of exotic creatures you get a lot of employ around employ and death .
# ----
# 1.0 as any creature-feature fan knows when you cross toxic chemicals with a bunch of exotic creatures you get a lot of uses around uses and death .
# ----
# 0.8 as any creature-feature fan knows when you cross toxic chemicals with a bunch of exotic creatures you get a lot of does around does and death .
# ----
#
#
# Test: MFT with vocabullary - template278
# Test cases:      134
# Fails (rate):    38 (28.4%)
#
# Example fails:
# 1.0 on that score the film certainly fights n't fights .
# ----
# 1.0 on that score the film certainly strikes n't strikes .
# ----
# 1.0 on that score the film certainly has n't has .
# ----
#
#
# Test: MFT with vocabullary - template279
# Test cases:      16032
# Fails (rate):    14335 (89.4%)
#
# Example fails:
# 0.0 but while the highly bad iq falls short treasure planet is truly gorgeous to behold .
# ----
# 0.0 but while the highly problematic assured falls short treasure planet is truly gorgeous to behold .
# ----
# 0.0 but while the highly third welcome falls short treasure planet is truly gorgeous to behold .
# ----
#
#
# Test: MFT with vocabullary - template280
# Test cases:      167
# Fails (rate):    1 (0.6%)
#
# Example fails:
# 1.0 the latest installment in the pokemon canon pokemon 4ever is surprising less better and better than the last two likely because much of the japanese anime is set in a scenic forest where pokemon graze in peace .
# ----
#
#
# Test: MFT with vocabullary - template281
# Test cases:      16032
# Fails (rate):    4388 (27.4%)
#
# Example fails:
# 0.4 but taken as a stylish and priceless innocuous the queen of the damned can not be said to suck .
# ----
# 0.3 but taken as a stylish and outrageous propriety-obsessed the queen of the damned can not be said to suck .
# ----
# 0.0 but taken as a stylish and sympathetic unnecessary the queen of the damned can not be said to suck .
# ----
#
#
# Test: MFT with vocabullary - template282
# Test cases:      134
# Fails (rate):    7 (5.2%)
#
# Example fails:
# 0.1 have avoids the old boy 's characters more quick-witted than any english lit major would have avoids possible .
# ----
# 0.0 have damned the old boy 's characters more quick-witted than any english lit major would have damned possible .
# ----
# 0.1 have cloying the old boy 's characters more quick-witted than any english lit major would have cloying possible .
# ----
#
#
# Test: MFT with vocabullary - template283
# Test cases:      16032
# Fails (rate):    7830 (48.8%)
#
# Example fails:
# 1.0 there are far tv-style messages to teach a young audience which will probably be perfectly remarkable with the sloppy slapstick comedy .
# ----
# 0.7 there are far glib messages to teach a young audience which will probably be perfectly energetic with the sloppy slapstick comedy .
# ----
# 0.9 there are far self-conscious messages to teach a young audience which will probably be perfectly iq with the sloppy slapstick comedy .
# ----
#
#
# Test: MFT with vocabullary - template284
# Test cases:      22377
# Fails (rate):    1210 (5.4%)
#
# Example fails:
# 0.8 guys go original things and shoot a lot of bullets .
# ----
# 0.8 guys can impossible things and shoot a lot of bullets .
# ----
# 0.6 guys overcome leaky things and shoot a lot of bullets .
# ----
#
#
# Test: MFT with vocabullary - template285
# Test cases:      16032
# Fails (rate):    2314 (14.4%)
#
# Example fails:
# 0.0 delia greta and paula rank as three of the most superficial and enough female characters of the year .
# ----
# 0.0 delia greta and paula rank as three of the most worse and more female characters of the year .
# ----
# 0.0 delia greta and paula rank as three of the most boring and cinematic female characters of the year .
# ----
#
#
# Test: MFT with vocabullary - template286
# Test cases:      22377
# Fails (rate):    4905 (21.9%)
#
# Example fails:
# 0.8 parker associated be commended for taking a fresh approach to familiar material but his determination to remain true to the original text leads him to adopt a somewhat loud tone .
# ----
# 0.9 parker was be commended for taking a fresh approach to familiar material but his determination to remain true to the original text leads him to adopt a somewhat broad tone .
# ----
# 1.0 parker tells be commended for taking a fresh approach to familiar material but his determination to remain true to the original text leads him to adopt a somewhat content tone .
# ----
#
#
# Test: MFT with vocabullary - template287
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template288
# Test cases:      53
# Fails (rate):    29 (54.7%)
#
# Example fails:
# 0.0 the film conveys me of a vastly conveys germanic version of my big fat greek wedding -- with better characters some genuine quirkiness and at least a measure of style .
# ----
# 0.0 the film become me of a vastly become germanic version of my big fat greek wedding -- with better characters some genuine quirkiness and at least a measure of style .
# ----
# 0.0 the film offerings me of a vastly offerings germanic version of my big fat greek wedding -- with better characters some genuine quirkiness and at least a measure of style .
# ----
#
#
# Test: MFT with vocabullary - template289
# Test cases:      167
# Fails (rate):    151 (90.4%)
#
# Example fails:
# 0.0 'pocas ideas interesantes voyeuristic voyeuristic pseudo m ? stico que no corresponde al tono general del filme y que deja una sensaci ? n de inconformidad que hace pensar m ? s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# ----
# 0.5 'pocas ideas interesantes simple simple pseudo m ? stico que no corresponde al tono general del filme y que deja una sensaci ? n de inconformidad que hace pensar m ? s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# ----
# 0.0 'pocas ideas interesantes considerable considerable pseudo m ? stico que no corresponde al tono general del filme y que deja una sensaci ? n de inconformidad que hace pensar m ? s de una vez si vale la pena ir a la taquilla y reclamar el precio del boleto . '
# ----
#
#
# Test: MFT with vocabullary - template290
# Test cases:      96
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template291
# Test cases:      167
# Fails (rate):    78 (46.7%)
#
# Example fails:
# 1.0 harry potter and the chamber of secrets is fable vu all over again and while that is a cliche nothing could be more fable .
# ----
# 0.9 harry potter and the chamber of secrets is multilayered vu all over again and while that is a cliche nothing could be more multilayered .
# ----
# 1.0 harry potter and the chamber of secrets is voyeuristic vu all over again and while that is a cliche nothing could be more voyeuristic .
# ----
#
#
# Test: MFT with vocabullary - template292
# Test cases:      134
# Fails (rate):    9 (6.7%)
#
# Example fails:
# 0.7 the phone rings and a voice strikes you you 've got seven days strikes to live .
# ----
# 0.5 the phone rings and a voice bewildering you you 've got seven days bewildering to live .
# ----
# 0.6 the phone rings and a voice feels you you 've got seven days feels to live .
# ----

# %%
suite.save('./suites/posneg-approach5.suite')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-19-29b9460b64ce> in <module>
# ----> 1 suite.save('./suites/posneg-approach5.suite')
#
# ~\anaconda3\envs\TCC-Adson\lib\site-packages\checklist\test_suite.py in save(self, path)
#     401
#     402         """
# --> 403         dill.dump(self, open(path, 'wb'), recurse=True)
#
# ~\anaconda3\envs\TCC-Adson\lib\site-packages\dill\_dill.py in dump(obj, file, protocol, byref, fmode, recurse, **kwds)
#     265     _kwds = kwds.copy()
#     266     _kwds.update(dict(byref=byref, fmode=fmode, recurse=recurse))
# --> 267     Pickler(file, protocol, **_kwds).dump(obj)
#     268     return
#     269
#
# ~\anaconda3\envs\TCC-Adson\lib\site-packages\dill\_dill.py in dump(self, obj)
#     452             raise PicklingError(msg)
#     453         else:
# --> 454             StockPickler.dump(self, obj)
#     455         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     456         return
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in dump(self, obj)
#     483         if self.proto >= 4:
#     484             self.framer.start_framing()
# --> 485         self.save(obj)
#     486         self.write(STOP)
#     487         self.framer.end_framing()
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\envs\TCC-Adson\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     939             # we only care about session the first pass thru
#     940             pickler._session = False
# --> 941         StockPickler.save_dict(pickler, obj)
#     942         log.info("# D2")
#     943     return
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709
#     710         if dictitems is not None:
# --> 711             self._batch_setitems(dictitems)
#     712
#     713         if state is not None:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\envs\TCC-Adson\lib\site-packages\dill\_dill.py in save_module_dict(pickler, obj)
#     939             # we only care about session the first pass thru
#     940             pickler._session = False
# --> 941         StockPickler.save_dict(pickler, obj)
#     942         log.info("# D2")
#     943     return
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     709
#     710         if dictitems is not None:
# --> 711             self._batch_setitems(dictitems)
#     712
#     713         if state is not None:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in _batch_appends(self, items)
#     951                 write(MARK)
#     952                 for x in tmp:
# --> 953                     save(x)
#     954                 write(APPENDS)
#     955             elif n:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in save_tuple(self, obj)
#     916         # No recursion.
#     917         write(TUPLE)
# --> 918         self.memoize(obj)
#     919
#     920     dispatch[tuple] = save_tuple
#
# ~\anaconda3\envs\TCC-Adson\lib\pickle.py in memoize(self, obj)
#     507         idx = len(self.memo)
#     508         self.write(self.put(idx))
# --> 509         self.memo[id(obj)] = idx, obj
#     510
#     511     # Return a PUT (BINPUT, LONG_BINPUT) opcode string, with argument i.
#
# MemoryError:

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach5.suite')

suite.visual_summary_table()
