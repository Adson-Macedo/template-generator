# %% [markdown]
# # Abordagem 3
#
# Usando a abordagem 3 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística "Vocabulary" com o teste MFT.
#
# As etapas desta abordagem são:
#
# 1. Quebrar a instância em sentenças
# 2. Classificar as sentenças usando um ou mais modelos para ajudar a rotular as sentenças
# 3. Filtrar as sentenças classificadas de forma unânime
# 4. Filtrar as sentenças com alta confiança nas predições
# 5. Rankear as palavras de cada sentença
# 6. Filtrar sentenças com palavras relevantes (verbos e adjetivos)
# 7. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

movie_reviews_rt_df = pd.read_csv('./data/data-rt-100samples.csv')
movie_reviews_rt_df.head(5)
# Out:
#    label  \
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#
#                                                                        text  \
# 0  allen's underestimated charm delivers more goodies than lumps of coal .
# 1                   skip the film and buy the philip glass soundtrack cd .
# 2          involving at times  but lapses quite casually into the absurd .
# 3  while hoffman's performance is great  the subject matter goes nowhere .
# 4   a flick about our infantilized culture that isn't entirely infantile .
#
#    words
# 0     11
# 1     11
# 2     11
# 3     11
# 4     11

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
movie_reviews_models = {
    'bert': 'textattack/bert-base-uncased-rotten-tomatoes', 
    'albert': 'textattack/albert-base-v2-rotten-tomatoes', 
    'distilbert': 'textattack/distilbert-base-uncased-rotten-tomatoes', 
    'roberta': 'textattack/roberta-base-rotten-tomatoes', 
    'xlnet': 'textattack/xlnet-base-cased-rotten-tomatoes'
}

# %%
m1 = load_model(movie_reviews_models['albert'])
m2 = load_model(movie_reviews_models['distilbert'])
m3 = load_model(movie_reviews_models['roberta'])
m4 = load_model(movie_reviews_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(movie_reviews_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-rotten-tomatoes...
# Loading model textattack/distilbert-base-uncased-rotten-tomatoes...
# Loading model textattack/roberta-base-rotten-tomatoes...
# Some weights of the model checkpoint at textattack/roberta-base-rotten-tomatoes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-rotten-tomatoes...
# Loading model textattack/bert-base-uncased-rotten-tomatoes...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp3

tg = PosNegTemplateGeneratorApp3(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = movie_reviews_rt_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates = tg.generate_templates(instances, n_masks=2, range_words=5, min_classification_score=0.80)
# Out:
# Converting texts to sentences...
# :: 6 sentences were generated.
# Predicting inputs...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Sentence predictions done.
# Filtering instances classified unanimously...
# :: 3 sentences remaining.
# Filtering instances by classification score greater than 0.8
# :: 2 sentences remaining.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by relevant words...
# :: 1 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 0 sentences remaining.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 5.7s

# %%
df = tg.to_dataframe()
df
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
tg.lexicons
# Out:
# {'pos_verb': [], 'neg_verb': [], 'pos_adj': [], 'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in movie_reviews_rt_df['text'].values]

# %%
templates = tg.generate_templates(instances, n_masks=2, range_words=5, min_classification_score=0.80)
# Out:
# Converting texts to sentences...
# :: 134 sentences were generated.
# Predicting inputs...
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Sentence predictions done.
# Filtering instances classified unanimously...
# :: 96 sentences remaining.
# Filtering instances by classification score greater than 0.8
# :: 87 sentences remaining.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by relevant words...
# :: 47 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 34 sentences remaining.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 3m 51.2s

# %%
df = tg.to_dataframe()
df
# Out:
#     label  \
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       1
# 6       1
# 7       0
# 8       0
# 9       0
# 10      1
# 11      0
# 12      1
# 13      0
# 14      0
# 15      1
# 16      1
# 17      0
# 18      1
# 19      1
# 20      1
# 21      1
# 22      1
# 23      1
# 24      0
# 25      0
# 26      0
# 27      0
# 28      0
# 29      0
# 30      1
# 31      1
# 32      0
# 33      1
#
#                                                                                                                                                                                                     original_text  \
# 0                                                                                                                                           intelligent  caustic take on a great writer and dubious human being .
# 1                                                                                                                                                it's a bad sign in a thriller when you instantly know whodunit .
# 2                                                                                                                    falsehoods pile up  undermining the movie's reality and stifling its creator's comic voice .
# 3                                                                                                                               this charming  thought-provoking new york fest of life and love has its rewards .
# 4                                                                                                                       a long  dull procession of despair  set to cello music culled from a minimalist funeral .
# 5                                                                                                      awesome creatures breathtaking scenery and epic battle scenes add up to another 'spectacular spectacle . '
# 6                                                                                                             a fascinating dark thriller that keeps you hooked on the delicious pulpiness of its lurid fiction .
# 7                                                                                                                                                      could the country bears really be as bad as its trailers ?
# 8                                                                                                                the movie has generic virtues  and despite a lot of involved talent  seems done by the numbers .
# 9                                                                                                       doesn't get the job done  running off the limited chemistry created by ralph fiennes and jennifer lopez .
# 10                                                                                  the movie is saved from unbearable lightness by the simplicity of the storytelling and the authenticity of the performances .
# 11                                                                                   an empty exercise  a florid but ultimately vapid crime melodrama with lots of surface flash but little emotional resonance .
# 12                                                                                         to the film's credit the acting is fresh and unselfconscious and munch is a marvel of reality versus sappy sentiment .
# 13                                                                                                 hugh grant's act is so consuming that sometimes it's difficult to tell who the other actors in the movie are .
# 14                                                                                          opens at a funeral  ends on the protagonist's death bed and doesn't get much livelier in the three hours in between .
# 15                                                             at its best  this is grand-scale moviemaking for a larger-than-life figure  an artist who has been awarded mythic status in contemporary culture .
# 16                                                      the dramatic crisis doesn't always succeed in its quest to be taken seriously  but huppert's volatile performance makes for a riveting movie experience .
# 17                                            the movie is undone by a filmmaking methodology that's just experimental enough to alienate the mainstream audience while ringing cliched to hardened indie-heads .
# 18                                          this in-depth study of important developments of the computer industry should make it required viewing in university computer science departments for years to come .
# 19                                                           how much you are moved by the emotional tumult of [fran?ois and mich?le's] relationship depends a lot on how interesting and likable you find them .
# 20                   the determination of pinochet's victims to seek justice  and their often heartbreaking testimony  spoken directly into director patricio guzman's camera  pack a powerful emotional wallop .
# 21                                               ozpetek joins the ranks of those gay filmmakers who have used the emigre experience to explore same-sex culture in ways that elude the more nationally settled .
# 22  more concerned with overall feelings  broader ideas  and open-ended questions than concrete story and definitive answers  soderbergh's solaris is a gorgeous and deceptively minimalist cinematic tone poem .
# 23                                                 a time machine  a journey back to your childhood  when cares melted away in the dark theater  and films had the ability to mesmerize  astonish and entertain .
# 24                                   as well-acted and well-intentioned as all or nothing is  however  the film comes perilously close to being too bleak  too pessimistic and too unflinching for its own good .
# 25                               the two leads are almost good enough to camouflage the dopey plot  but so much naturalistic small talk  delivered in almost muffled exchanges  eventually has a lulling effect .
# 26                                                                                     a dreary  incoherent  self-indulgent mess of a movie in which a bunch of pompous windbags drone on inanely for two hours .
# 27                                                  like so many other allegedly scary movies  it gets so tangled up in the twist that it chokes the energy right out of the very audience it seeks to frighten .
# 28        what remains is a variant of the nincompoop benigni persona  here a more annoying  though less angry version of the irresponsible sandlerian manchild  undercut by the voice of the star of road trip .
# 29                                                                                                                 / but daphne  you're too buff / fred thinks he's tough / and velma - wow  you've lost weight !
# 30                                                                                                   is inspiring ironic and revelatory of just how ridiculous and money-oriented the record industry really is .
# 31                                                                                          it also shows how deeply felt emotions can draw people together across the walls that might otherwise separate them .
# 32                                                                                                                                            is an inexpressible and drab wannabe looking for that exact niche .
# 33                                                                                                this is a movie that is what it is : a pleasant distraction a friday night diversion an excuse to eat popcorn .
#
#                                                                                                                                                                                              masked_text  \
# 0                                                                                                                                       {mask} caustic take on a great writer and dubious {mask} being .
# 1                                                                                                                                 it 's a {mask} sign in a thriller when you instantly {mask} whodunit .
# 2                                                                                                       falsehoods {mask} up undermining the movie 's reality and stifling its creator 's {mask} voice .
# 3                                                                                                                                    this {mask} {mask} new york fest of life and love has its rewards .
# 4                                                                                                                  a long {mask} procession of despair set to cello music culled from a {mask} funeral .
# 5                                                                                                    {mask} creatures {mask} scenery and epic battle scenes add up to another 'spectacular spectacle . '
# 6                                                                                                  a fascinating dark thriller that {mask} you hooked on the delicious pulpiness of its {mask} fiction .
# 7                                                                                                                                         {mask} the country bears really be as {mask} as its trailers ?
# 8                                                                                                         the movie has {mask} virtues and despite a lot of involved talent {mask} done by the numbers .
# 9                                                                                                does n't get the job done {mask} off the {mask} chemistry created by ralph fiennes and jennifer lopez .
# 10                                                                            the movie is {mask} from {mask} lightness by the simplicity of the storytelling and the authenticity of the performances .
# 11                                                                          an empty exercise a florid but ultimately {mask} crime melodrama with lots of surface flash but {mask} emotional resonance .
# 12                                                                                    to the film 's credit the acting is fresh and {mask} and munch {mask} a marvel of reality versus sappy sentiment .
# 13                                                                                            hugh grant 's act is so {mask} that sometimes it 's {mask} to tell who the other actors in the movie are .
# 14                                                                            opens at a funeral ends on the protagonist 's death bed and {mask} n't get {mask} livelier in the three hours in between .
# 15                                                                at its best this is {mask} {mask} for a larger-than-life figure an artist who has been awarded mythic status in contemporary culture .
# 16                                            the dramatic crisis {mask} n't always succeed in its quest to be taken seriously but huppert 's volatile performance makes for a {mask} movie experience .
# 17                                   the movie is {mask} by a filmmaking methodology that 's just experimental enough to alienate the mainstream audience while ringing {mask} to hardened indie-heads .
# 18                                   this {mask} study of important developments of the computer industry {mask} make it required viewing in university computer science departments for years to come .
# 19                                          how {mask} you are moved by the emotional tumult of [ fran ? ois and mich ? le 's ] relationship {mask} a lot on how interesting and likable you find them .
# 20                    the determination of pinochet 's victims to seek justice and their often {mask} testimony spoken directly into director patricio guzman 's camera pack a {mask} emotional wallop .
# 21                                     ozpetek joins the ranks of those gay filmmakers who {mask} used the emigre experience to {mask} same-sex culture in ways that elude the more nationally settled .
# 22  more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {mask} and {mask} minimalist cinematic tone poem .
# 23                                                 a time machine a journey back to your childhood when cares melted away in the dark theater and films had the ability to {mask} {mask} and entertain .
# 24                                       as well-acted and well-intentioned as all or nothing is however the film comes perilously close to being too bleak too {mask} and too {mask} for its own good .
# 25                       the two leads are almost good enough to camouflage the dopey plot but so much naturalistic small talk delivered in almost muffled exchanges eventually {mask} a {mask} effect .
# 26                                                                                       a dreary incoherent {mask} mess of a movie in which a bunch of {mask} windbags drone on inanely for two hours .
# 27                                         like so many other allegedly scary movies it gets so tangled up in the twist that it {mask} the energy right out of the very audience it {mask} to frighten .
# 28  what remains {mask} a variant of the {mask} benigni persona here a more annoying though less angry version of the irresponsible sandlerian manchild undercut by the voice of the star of road trip .
# 29                                                                                                     / but daphne you 're too buff / fred {mask} he 's tough / and velma - wow you 've {mask} weight !
# 30                                                                                                 is {mask} ironic and revelatory of just how {mask} and money-oriented the record industry really is .
# 31                                                                                   it also {mask} how deeply felt emotions can draw people together across the walls that might {mask} separate them .
# 32                                                                                                                                  is an inexpressible and {mask} wannabe {mask} for that exact niche .
# 33                                                                                      this is a movie that is what it is : a {mask} distraction a friday night diversion an excuse to {mask} popcorn .
#
#                                                                                                                                                                                                   template_text
# 0                                                                                                                                        {pos_adj} caustic take on a great writer and dubious {neg_adj} being .
# 1                                                                                                                                 it 's a {neg_adj} sign in a thriller when you instantly {pos_verb} whodunit .
# 2                                                                                                       falsehoods {neg_verb} up undermining the movie 's reality and stifling its creator 's {neg_adj} voice .
# 3                                                                                                                                    this {pos_verb} {pos_adj} new york fest of life and love has its rewards .
# 4                                                                                                                   a long {neg_adj} procession of despair set to cello music culled from a {neg_adj} funeral .
# 5                                                                                                    {pos_adj} creatures {pos_verb} scenery and epic battle scenes add up to another 'spectacular spectacle . '
# 6                                                                                                  a fascinating dark thriller that {pos_verb} you hooked on the delicious pulpiness of its {neg_adj} fiction .
# 7                                                                                                                                         {neg_verb} the country bears really be as {neg_adj} as its trailers ?
# 8                                                                                                         the movie has {neg_adj} virtues and despite a lot of involved talent {neg_verb} done by the numbers .
# 9                                                                                                does n't get the job done {neg_verb} off the {pos_adj} chemistry created by ralph fiennes and jennifer lopez .
# 10                                                                            the movie is {pos_verb} from {neg_adj} lightness by the simplicity of the storytelling and the authenticity of the performances .
# 11                                                                           an empty exercise a florid but ultimately {neg_adj} crime melodrama with lots of surface flash but {neg_adj} emotional resonance .
# 12                                                                                    to the film 's credit the acting is fresh and {pos_adj} and munch {pos_verb} a marvel of reality versus sappy sentiment .
# 13                                                                                             hugh grant 's act is so {neg_adj} that sometimes it 's {neg_adj} to tell who the other actors in the movie are .
# 14                                                                            opens at a funeral ends on the protagonist 's death bed and {neg_verb} n't get {pos_adj} livelier in the three hours in between .
# 15                                                                at its best this is {pos_adj} {pos_verb} for a larger-than-life figure an artist who has been awarded mythic status in contemporary culture .
# 16                                            the dramatic crisis {neg_verb} n't always succeed in its quest to be taken seriously but huppert 's volatile performance makes for a {pos_adj} movie experience .
# 17                                   the movie is {neg_adj} by a filmmaking methodology that 's just experimental enough to alienate the mainstream audience while ringing {neg_verb} to hardened indie-heads .
# 18                                   this {pos_adj} study of important developments of the computer industry {neg_verb} make it required viewing in university computer science departments for years to come .
# 19                                          how {pos_adj} you are moved by the emotional tumult of [ fran ? ois and mich ? le 's ] relationship {neg_verb} a lot on how interesting and likable you find them .
# 20                    the determination of pinochet 's victims to seek justice and their often {pos_verb} testimony spoken directly into director patricio guzman 's camera pack a {pos_adj} emotional wallop .
# 21                                    ozpetek joins the ranks of those gay filmmakers who {neg_verb} used the emigre experience to {pos_verb} same-sex culture in ways that elude the more nationally settled .
# 22   more concerned with overall feelings broader ideas and open-ended questions than concrete story and definitive answers soderbergh 's solaris is a {pos_adj} and {pos_adj} minimalist cinematic tone poem .
# 23                                                 a time machine a journey back to your childhood when cares melted away in the dark theater and films had the ability to {pos_verb} {pos_adj} and entertain .
# 24                                        as well-acted and well-intentioned as all or nothing is however the film comes perilously close to being too bleak too {neg_adj} and too {pos_adj} for its own good .
# 25                       the two leads are almost good enough to camouflage the dopey plot but so much naturalistic small talk delivered in almost muffled exchanges eventually {neg_verb} a {neg_adj} effect .
# 26                                                                                        a dreary incoherent {neg_adj} mess of a movie in which a bunch of {neg_adj} windbags drone on inanely for two hours .
# 27                                        like so many other allegedly scary movies it gets so tangled up in the twist that it {neg_verb} the energy right out of the very audience it {neg_verb} to frighten .
# 28  what remains {pos_verb} a variant of the {pos_adj} benigni persona here a more annoying though less angry version of the irresponsible sandlerian manchild undercut by the voice of the star of road trip .
# 29                                                                                                    / but daphne you 're too buff / fred {neg_verb} he 's tough / and velma - wow you 've {neg_verb} weight !
# 30                                                                                                 is {pos_verb} ironic and revelatory of just how {neg_adj} and money-oriented the record industry really is .
# 31                                                                                  it also {neg_verb} how deeply felt emotions can draw people together across the walls that might {neg_verb} separate them .
# 32                                                                                                                                  is an inexpressible and {neg_adj} wannabe {pos_verb} for that exact niche .
# 33                                                                                      this is a movie that is what it is : a {pos_adj} distraction a friday night diversion an excuse to {pos_verb} popcorn .

# %%
tg.lexicons
# Out:
# {'pos_verb': ['breathtaking',
#   'keeps',
#   'explore',
#   'moviemaking',
#   'eat',
#   'mesmerize',
#   'looking',
#   'inspiring',
#   'know',
#   'heartbreaking',
#   'saved',
#   'is',
#   'charming'],
#  'neg_verb': ['cliched',
#   'thinks',
#   'has',
#   'lost',
#   'shows',
#   'should',
#   'running',
#   'depends',
#   'seems',
#   'have',
#   'pile',
#   'seeks',
#   'chokes',
#   'does',
#   'could',
#   'otherwise'],
#  'pos_adj': ['in-depth',
#   'gorgeous',
#   'deceptively',
#   'astonish',
#   'nincompoop',
#   'unselfconscious',
#   'powerful',
#   'much',
#   'unflinching',
#   'awesome',
#   'intelligent',
#   'grand-scale',
#   'limited',
#   'pleasant',
#   'riveting',
#   'thought-provoking'],
#  'neg_adj': ['lulling',
#   'bad',
#   'pompous',
#   'self-indulgent',
#   'undone',
#   'drab',
#   'dull',
#   'comic',
#   'human',
#   'little',
#   'difficult',
#   'pessimistic',
#   'ridiculous',
#   'consuming',
#   'minimalist',
#   'lurid',
#   'unbearable',
#   'vapid',
#   'generic']}

# %% [markdown]
# ## Checklist

# %%
import checklist
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_verb', lexicons['pos_verb'])
editor.add_lexicon('neg_verb', lexicons['neg_verb'])
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
data = []
lbl = []
for template, label in zip(templates, labels):
    t = editor.template(template, remove_duplicates=True, labels=int(label))
    data.extend(t.data)
    lbl.extend(t.labels)

suite.add(MFT(
    data=data,
    labels=lbl,
    capability="Vocabullary",
    name="Template Generator - Vocabulary in MFT",
    description="Testing the model for vocabulary capability"
))

# %%
suite.run(model.predict, overwrite=True)
# Out:
# Running Template Generator - Vocabulary in MFT
# Predicting 6655 examples
# <ipython-input-3-263ca9d23a33>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()

# %%
suite.summary()
# Out:
# Vocabullary
#
# Template Generator - Vocabulary in MFT
# Test cases:      6655
# Fails (rate):    615 (9.2%)
#
# Example fails:
# 0.2 this is a movie that is what it is : a deceptively distraction a friday night diversion an excuse to is popcorn .
# ----
# 0.7 it 's a human sign in a thriller when you instantly saved whodunit .
# ----
# 1.0 does n't get the job done have off the deceptively chemistry created by ralph fiennes and jennifer lopez .
# ----
