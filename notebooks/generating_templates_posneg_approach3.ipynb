# %% [markdown]
# # Abordagem 3
#
# Usando a abordagem 3 para gerar templates com foco em templates positivos e negativos. Uma possível aplicação seria testar a capacidade linguística *Vocabullary* com o teste **MFT**.
#
# As etapas desta abordagem são:
#
# 1. Quebrar a instância em sentenças
# 2. Classificar as sentenças usando o *Oráculo*
# 3. Filtrar as sentenças classificadas de forma unânime
# 4. Filtrar as sentenças com alta confiança nas predições
# 5. Rankear as palavras de cada sentença
# 6. Filtrar sentenças com palavras relevantes (verbos ou adjetivos) bem rankeadas
# 7. Filtrar sentenças com alta confiança na predição das palavras relevantes
# 8. Substituir as palavras relevantes por máscaras

# %%
# %config Completer.use_jedi = False
import sys
sys.path.append('../')

# %% [markdown]
# ## Carregando o dataset, o modelo alvo e os modelos auxiliares

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

imdb_df = pd.read_csv('./data/imdb_sampled/data-1000samples.csv')
imdb_df.head(5)
# Out:
#    label  \
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                                                                                                                                                                                  Here's example number 87,358 of Hollywood's anti-Biblical bias, so typical of them.<br /><br />Early on, Ray Liotta's wife has did and women are being interviewed for the position of housekeeper. The first interviewee is an old-fashioned-looking (dress, mannerisms, speech) who immediately lays down here strict rules, stating that "there will be two hours of Bible study ever day."<br /><br />This is said, of course, to make it sound like reading the Bible is the worse punishment you could ever inflict on someone, especially a kid. Once again, the Bible is equated with stuffy, mean-spirited people. That woman, of course, is dismissed immediately.<br /><br />Naturally, the liberal black woman (Whoopi Goldberg - who else?) is the one who is hired and, voilà, saves the day! <br /><br />Yawn.
# 1                                                                                                                                                                                                                                                                                                                                                  I don't know about the real Cobb but I got the distinct impression that the filmmakers' aim was to try to soften his jagged edges and reputation, not give us a true portrait of the man himself. In the movie, besides a few racist remarks, he's shown to be just another hard-nosed, cantakerous old coot (he's so full of life!) with a heart of gold(more or less). This is also the worst acting I've seen T.L.Jones do(he brings nothing new or subtle to his stereotyped character). He just doesn't flesh out Cobb in a way that pulls me into the movie. Not for one minute did I forget that it was Tommy Lee Jones on the screen pretending to be Ty Cobb. Robert Wuhl didnt impress either. The "comedic" elements in this movie were just distracting and didnt ring true at all. A bloody waste of time, it is
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Reba is a very dumb show. You can predict pretty much anything that's about to happen. Barbra Jean is just too stupid. It's like she's not even a character. A show like this should at least have SOMEONE who resembles a real-life person. I guess Barbra Jean represents a retarded person. Keira or whatever her name is, Reba, Brock, they're all stupid! Keira is like the smartest person on the show, and she's still stupid. EVERYONE IS STUPID! That's my opinion on Reba. Since I have said all I can say about this show, I'll just take up the next few lines of text by saying what I am currently saying right now and do it until there's 10 lines. There. Reba gets 2/10.
# 3                                                                                                                                                                                                                                                                                                                          "One Crazy Summer" is the funniest, craziest (not necessarily the best), movie I have ever seen.<br /><br />Just when one crazy scene is done, another emerges. It never lets you rest. Just one thing after another. The soundtrack is great. The songs are the right ones for the scenes.<br /><br />It is also a clean movie. Little that is dirty in it.<br /><br />Of course, it has the story of the guys you wouldn't trust with your lunch money, taking up a challenge, and winning over people with more resources. Who'd want to see it if they failed? There is a serious side, in that parents and children do not live up to each others' dreams. One should always have an open mind, and weigh all the options. This applies both to parents and children. In "One Crazy Summer", the parents are wrong. This is not always the case.
# 4  "A young man, recently engaged to be married, is the victim of a traffic accident and dies as a result of his injuries. His father, desperate to revive his son, agrees to let a scientist friend try his experimental soul transmigration process to save him. After the young man returns to life, the father and fiancée notice a dark and violent change in the young man's behavior, leading them to believe something went horribly wrong in the revival process," according to the DVD sleeve's synopsis.<br /><br />At one point, Edward Norris (as Philip Bennett) is asked, "What do you think this is, Boys Town?" Mr. Norris should know, since he was in "Boys Town". "The Man with Two Lives " is more like "Black Friday" minus Karloff and Lugosi. You do the math. This film might have been a contender, with a re-worked script; it does feature an intriguing final act. After a tepid "shoot out", hang in for the drama to pick up with a well-played scene between star Norris and pursuing detective Addison Richards (as George Bradley).<br /><br />**** The Man with Two Lives (1942) Phil Rosen ~ Edward Norris, Eleanor Lawson, Addison Richards
#
#    words
# 0    127
# 1    149
# 2    124
# 3    149
# 4    196

# %%
import re
import numpy as np
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def pre_proccess(text):
    text = text.lower()
    text = re.sub('["\',!-.:-@0-9/]()', ' ', text)
    return text

# Wrapper to adapt output format
class SentimentAnalisysModelWrapper:
    def __init__(self, model, tokenizer):
        self.model = model
        self.tokenizer = tokenizer
        
    def __predict(self, text_input):
        text_preprocessed = pre_proccess(text_input)
        tokenized = self.tokenizer(text_preprocessed, padding=True, truncation=True, max_length=512, 
                                    add_special_tokens = True, return_tensors="pt")
        
        tensor_logits = self.model(**tokenized)
        prob = softmax(tensor_logits[0]).detach().numpy()
        pred = np.argmax(prob)
        
        return pred, prob
    
    def predict_label(self, text_inputs):
        return self.predict(text_inputs)[0]
        
    def predict_proba(self, text_inputs):
        return self.predict(text_inputs)[1]
        
    def predict(self, text_inputs):
        if isinstance(text_inputs, str):
            text_inputs = [text_inputs]
        
        preds = []
        probs = []

        for text_input in text_inputs:
            pred, prob = self.__predict(text_input)
            preds.append(pred)
            probs.append(prob[0])

        return np.array(preds), np.array(probs) # ([0, 1], [[0.99, 0.01], [0.03, 0.97]])

# Auxiliar function to load and wrap a model from Hugging Face
def load_model(model_name):
    print(f'Loading model {model_name}...')
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    return SentimentAnalisysModelWrapper(model, tokenizer)

# Hugging Face hosted model names 
imdb_models = {
    'bert': 'textattack/bert-base-uncased-imdb', 
    'albert': 'textattack/albert-base-v2-imdb', 
    'distilbert': 'textattack/distilbert-base-uncased-imdb', 
    'roberta': 'textattack/roberta-base-imdb', 
    'xlnet': 'textattack/xlnet-base-cased-imdb'
}

# %%
m1 = load_model(imdb_models['albert'])
m2 = load_model(imdb_models['distilbert'])
m3 = load_model(imdb_models['roberta'])
m4 = load_model(imdb_models['xlnet'])

# Models to be used as oracle
models = [m1, m2, m3, m4]
# Target model
model = load_model(imdb_models['bert'])
# Out:
# Loading model textattack/albert-base-v2-imdb...
# Loading model textattack/distilbert-base-uncased-imdb...
# Loading model textattack/roberta-base-imdb...
# Some weights of the model checkpoint at textattack/roberta-base-imdb were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading model textattack/xlnet-base-cased-imdb...
# Loading model textattack/bert-base-uncased-imdb...

# %% [markdown]
# # Gerando os templates
# O método de rankeamento das palavras usado no PosNegTemplateGenerator é o Replace-1 Score

# %%
from template_generator.tasks.sentiment_analisys import PosNegTemplateGeneratorApp3

tg = PosNegTemplateGeneratorApp3(model, models)

# %% [markdown]
# ### Número inicial de instâncias: 5

# %%
# Sampling instances
np.random.seed(220)
n_instances = 5
df_sampled = imdb_df.sample(n_instances)

instances = [x for x in df_sampled['text'].values]

# %%
templates = tg.generate_templates(instances, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 31 sentences were generated.
# Predicting inputs...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Sentence predictions done.
# Filtering instances classified unanimously...
# :: 21 sentences remaining.
# Filtering instances by classification score greater than 0.8
# :: 20 sentences remaining.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by relevant words...
# :: 2 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 0 sentences remaining.

# %% [markdown]
# #### Tempo de execução para 5 instâncias: 1m 19.9s

# %%
df = tg.to_dataframe()
df
# Out:
# Empty DataFrame
# Columns: [label, original_text, masked_text, template_text]
# Index: []

# %%
tg.lexicons
# Out:
# {'pos_adj': [], 'neg_adj': []}

# %% [markdown]
# ### Número inicial de instâncias: 100

# %%
# Using all 100 instances
instances = [x for x in imdb_df['text'].values]

# %%
tg = PosNegTemplateGeneratorApp3(model, models)
templates = tg.generate_templates(instances, ranked_words_count=4, min_classification_score=0.8)
# Out:
# Converting texts to sentences...
# :: 7973 sentences were generated.
# Predicting inputs...
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# :: Sentence predictions done.
# Filtering instances classified unanimously...
# :: 5054 sentences remaining.
# Filtering instances by classification score greater than 0.8
# :: 4587 sentences remaining.
# Ranking words using Replace-1 Score...
# :: Word ranking done.
# Filtering instances by relevant words...
# :: 371 sentences remaining.
# Filtering instances by relevant words classification score greater than 0.8
# :: 95 sentences remaining.

# %% [markdown]
# #### Tempo de execução para 100 instâncias: 21m 55.9s

# %%
df = tg.to_dataframe()
df
# Out:
#     label  \
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
# ..    ...
# 90      0
# 91      1
# 92      1
# 93      1
# 94      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          original_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                      It takes someone of Chaplin's skill as a comedian to make something as dreary as trench warfare into such a brilliant comedy, but the irony that he uses in the film makes even the most uncomfortable conditions highly amusing.<br /><br />Like all of the best of Chaplin's films, short films and otherwise, this one is packed with brilliant and memorable scenes, such as the scene where he marks off kills with a piece of chalk on a board in the trench, erasing one when he gets his helmet shot off, the scene where he and his fellow soldiers are sleeping underwater, the opening of the beer bottle and lighting of the cigarette, and of course, the overtaking of the enemy.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I laughed and giggled enough times through the movie so I cannot say with hand on my heart that it was rubbish.<br /><br />It's completely different, this and Epic Movie (Epic Movie sucked bad..
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              The beginning is enticing and leaves much to be expected but it does not hold up and the plot becomes absolutely ridiculous and absurd.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The movie is simple and that seems to be the great thing about it.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I saw a screener of this movie but I am going to buy it not only for myself but for several true film fans i have the unfortunate feeling this great film will be widely unrecognized as is the case with so many other non commercial films this is a comedic yet heart wrenching movie it will make you laugh it will make you cry it will make you think and yes you will think about it when its over and isn't that what a good movie is!
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       The effects are cheap and when they chop of one of her feet it looks so fake.
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   He played a great part, but Hunter and Hurt were good too, specially Hurt, in an relatively unusual role for him.
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Danson is outstanding as the title character and edward fox makes a wonderful villain.
# 93  OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The only positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally.., iwant to know your comment about this movie guys... is it bad or what?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        masked_text  \
# 0                                                                                                                                                                                                                                                                                                                                                It takes someone of Chaplin 's skill as a comedian to make something as dreary as trench warfare into such a brilliant comedy , but the irony that he uses in the film makes even the most uncomfortable conditions highly amusing. < br / > < br / > Like all of the {mask} of Chaplin 's films , short films and otherwise , this one is packed with brilliant and {mask} scenes , such as the scene where he marks off kills with a piece of chalk on a board in the trench , erasing one when he gets his helmet shot off , the scene where he and his fellow soldiers are sleeping underwater , the opening of the beer bottle and lighting of the cigarette , and of course , the overtaking of the enemy .
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I laughed and giggled enough times through the movie so I can not say with hand on my heart that it was {mask} < br / > < br / > It 's completely different , this and Epic Movie ( Epic Movie sucked {mask} ..
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The beginning is enticing and leaves much to be expected but it does not hold up and the plot becomes absolutely {mask} and {mask} .
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The movie is {mask} and that seems to be the {mask} thing about it .
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I saw a screener of this movie but I am going to buy it not only for myself but for several true film fans i have the {mask} feeling this {mask} film will be widely unrecognized as is the case with so many other non commercial films this is a comedic yet heart wrenching movie it will make you laugh it will make you cry it will make you think and yes you will think about it when its over and is n't that what a good movie is !
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The effects are {mask} and when they chop of one of her feet it looks so {mask} .
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          He played a great part , but Hunter and Hurt were {mask} too , specially Hurt , in an relatively {mask} role for him .
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Danson is {mask} as the title character and edward fox makes a {mask} villain .
# 93  OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the {mask} show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the {mask} show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The {mask} positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally .. , iwant to know your comment about this movie guys ... is it {mask} or what ?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            template_text
# 0                                                                                                                                                                                                                                                                                                                                                It takes someone of Chaplin 's skill as a comedian to make something as dreary as trench warfare into such a brilliant comedy , but the irony that he uses in the film makes even the most uncomfortable conditions highly amusing. < br / > < br / > Like all of the {pos_adj} of Chaplin 's films , short films and otherwise , this one is packed with brilliant and {pos_adj} scenes , such as the scene where he marks off kills with a piece of chalk on a board in the trench , erasing one when he gets his helmet shot off , the scene where he and his fellow soldiers are sleeping underwater , the opening of the beer bottle and lighting of the cigarette , and of course , the overtaking of the enemy .
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I laughed and giggled enough times through the movie so I can not say with hand on my heart that it was {neg_adj} < br / > < br / > It 's completely different , this and Epic Movie ( Epic Movie sucked {neg_adj} ..
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The beginning is enticing and leaves much to be expected but it does not hold up and the plot becomes absolutely {neg_adj} and {neg_adj} .
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The movie is {pos_adj} and that seems to be the {pos_adj} thing about it .
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I saw a screener of this movie but I am going to buy it not only for myself but for several true film fans i have the {neg_adj} feeling this {pos_adj} film will be widely unrecognized as is the case with so many other non commercial films this is a comedic yet heart wrenching movie it will make you laugh it will make you cry it will make you think and yes you will think about it when its over and is n't that what a good movie is !
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The effects are {neg_adj} and when they chop of one of her feet it looks so {neg_adj} .
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          He played a great part , but Hunter and Hurt were {pos_adj} too , specially Hurt , in an relatively {pos_adj} role for him .
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Danson is {pos_adj} as the title character and edward fox makes a {pos_adj} villain .
# 93  OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the {pos_adj} show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the {pos_adj} show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full stop.OZ is the greatest show ever mad full
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The {pos_adj} positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally .. , iwant to know your comment about this movie guys ... is it {neg_adj} or what ?
#
# [95 rows x 4 columns]

# %%
tg.lexicons
# Out:
# {'pos_adj': ['Lovecraftian',
#   'smooth',
#   'Incredible',
#   'solid',
#   'remarkable',
#   'outstanding',
#   'simple',
#   'noir',
#   'extraordinary',
#   'hilarious.',
#   'flawless',
#   'good-looking',
#   'unusual',
#   'inspiring',
#   'excellent',
#   'exemplary',
#   'emotional',
#   'fantastic',
#   'cartoonish',
#   'positive',
#   'sci-fi',
#   'palpable',
#   'unique',
#   'reliable',
#   'incredible',
#   'worth',
#   'Satish',
#   'upbeat',
#   'different',
#   'heartfelt.',
#   'brilliant',
#   'authentic',
#   'unpredictable',
#   'Fantastic',
#   'multi-millionaire',
#   'amazing',
#   'hilarious',
#   'elegant',
#   'melodic',
#   'greatest',
#   'happy',
#   'direct-to-video',
#   'musical',
#   'best',
#   'believable',
#   'hot',
#   'intense',
#   'memorable',
#   'perfect',
#   'good',
#   'only',
#   'great',
#   'welcome',
#   'once-in-a-lifetime',
#   'vivid',
#   'self-important',
#   'suspenseful',
#   'wonderful',
#   'romantic'],
#  'neg_adj': ['terrible',
#   'horrendous',
#   'predictable',
#   'worse',
#   'senseless',
#   'laughable',
#   'initial',
#   'trite',
#   'locations-person',
#   'obnoxious',
#   'atrocious',
#   'bad',
#   'hollow',
#   'horrible',
#   'stupid',
#   'bad-movie',
#   'unfunny',
#   'middle-aged',
#   'unfortunate',
#   'tedious',
#   'poor',
#   'loud',
#   'dreadful',
#   'better',
#   'bottom',
#   'unconvincing',
#   'Terrible',
#   'boring',
#   'putrid',
#   'stereotypical',
#   'alien',
#   'forgettable.',
#   'unoriginal',
#   'amateurish.Two',
#   'turgid',
#   'annoying',
#   'imaginable',
#   'dull',
#   'disappointed.',
#   'incomprehensible',
#   'unintentionally',
#   'awful',
#   'pre-Code',
#   'rubbish.',
#   'abusive',
#   'crappy',
#   'tiresome',
#   'officer/bad',
#   'sick',
#   'crappiest',
#   'painful',
#   'fake',
#   'moribund',
#   'absurd',
#   'ridiculous',
#   'rubbish',
#   'cheap',
#   'worst',
#   'disastrous',
#   'cookie-cutter',
#   'clichéd']}

# %% [markdown]
# # Usando os templates gerados pelo TemplateGenerator no CheckList

# %%
from checklist.editor import Editor
from checklist.test_suite import TestSuite
from checklist.test_types import MFT

# %%
lexicons = tg.lexicons
templates = tg.template_texts
masked = tg.masked_texts
labels = [sent.prediction.label for sent in tg.sentences]

editor = Editor()
editor.add_lexicon('pos_adj', lexicons['pos_adj'])
editor.add_lexicon('neg_adj', lexicons['neg_adj'])

suite = TestSuite()

# %%
for template, label, i in zip(templates, labels, range(len(templates))):
    t = editor.template(template, remove_duplicates=True, labels=int(label))

    suite.add(MFT(
        data=t.data,
        labels=label,
        capability="Vocabullary", 
        name=f"Test: MFT with vocabullary - template{i+1}",
        description="Checking if the model can handle vocabullary"))

# %%
suite.run(model.predict, overwrite=True)
suite.save('./suites/posneg-approach3.suite')
# Out:
# Running Test: MFT with vocabullary - template1
# Predicting 59 examples
# <ipython-input-3-3748665271fa>:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   prob = softmax(tensor_logits[0]).detach().numpy()
# Running Test: MFT with vocabullary - template2
# Predicting 61 examples
# Running Test: MFT with vocabullary - template3
# Predicting 61 examples
# Running Test: MFT with vocabullary - template4
# Predicting 59 examples
# Running Test: MFT with vocabullary - template5
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template6
# Predicting 59 examples
# Running Test: MFT with vocabullary - template7
# Predicting 61 examples
# Running Test: MFT with vocabullary - template8
# Predicting 59 examples
# Running Test: MFT with vocabullary - template9
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template10
# Predicting 61 examples
# Running Test: MFT with vocabullary - template11
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template12
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template13
# Predicting 61 examples
# Running Test: MFT with vocabullary - template14
# Predicting 59 examples
# Running Test: MFT with vocabullary - template15
# Predicting 59 examples
# Running Test: MFT with vocabullary - template16
# Predicting 59 examples
# Running Test: MFT with vocabullary - template17
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template18
# Predicting 61 examples
# Running Test: MFT with vocabullary - template19
# Predicting 61 examples
# Running Test: MFT with vocabullary - template20
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template21
# Predicting 61 examples
# Running Test: MFT with vocabullary - template22
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template23
# Predicting 61 examples
# Running Test: MFT with vocabullary - template24
# Predicting 59 examples
# Running Test: MFT with vocabullary - template25
# Predicting 61 examples
# Running Test: MFT with vocabullary - template26
# Predicting 61 examples
# Running Test: MFT with vocabullary - template27
# Predicting 61 examples
# Running Test: MFT with vocabullary - template28
# Predicting 61 examples
# Running Test: MFT with vocabullary - template29
# Predicting 61 examples
# Running Test: MFT with vocabullary - template30
# Predicting 59 examples
# Running Test: MFT with vocabullary - template31
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template32
# Predicting 59 examples
# Running Test: MFT with vocabullary - template33
# Predicting 59 examples
# Running Test: MFT with vocabullary - template34
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template35
# Predicting 59 examples
# Running Test: MFT with vocabullary - template36
# Predicting 59 examples
# Running Test: MFT with vocabullary - template37
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template38
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template39
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template40
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template41
# Predicting 59 examples
# Running Test: MFT with vocabullary - template42
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template43
# Predicting 59 examples
# Running Test: MFT with vocabullary - template44
# Predicting 59 examples
# Running Test: MFT with vocabullary - template45
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template46
# Predicting 61 examples
# Running Test: MFT with vocabullary - template47
# Predicting 61 examples
# Running Test: MFT with vocabullary - template48
# Predicting 61 examples
# Running Test: MFT with vocabullary - template49
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template50
# Predicting 61 examples
# Running Test: MFT with vocabullary - template51
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template52
# Predicting 61 examples
# Running Test: MFT with vocabullary - template53
# Predicting 59 examples
# Running Test: MFT with vocabullary - template54
# Predicting 61 examples
# Running Test: MFT with vocabullary - template55
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template56
# Predicting 59 examples
# Running Test: MFT with vocabullary - template57
# Predicting 61 examples
# Running Test: MFT with vocabullary - template58
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template59
# Predicting 59 examples
# Running Test: MFT with vocabullary - template60
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template61
# Predicting 61 examples
# Running Test: MFT with vocabullary - template62
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template63
# Predicting 59 examples
# Running Test: MFT with vocabullary - template64
# Predicting 59 examples
# Running Test: MFT with vocabullary - template65
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template66
# Predicting 61 examples
# Running Test: MFT with vocabullary - template67
# Predicting 61 examples
# Running Test: MFT with vocabullary - template68
# Predicting 61 examples
# Running Test: MFT with vocabullary - template69
# Predicting 59 examples
# Running Test: MFT with vocabullary - template70
# Predicting 61 examples
# Running Test: MFT with vocabullary - template71
# Predicting 59 examples
# Running Test: MFT with vocabullary - template72
# Predicting 61 examples
# Running Test: MFT with vocabullary - template73
# Predicting 61 examples
# Running Test: MFT with vocabullary - template74
# Predicting 59 examples
# Running Test: MFT with vocabullary - template75
# Predicting 61 examples
# Running Test: MFT with vocabullary - template76
# Predicting 59 examples
# Running Test: MFT with vocabullary - template77
# Predicting 59 examples
# Running Test: MFT with vocabullary - template78
# Predicting 61 examples
# Running Test: MFT with vocabullary - template79
# Predicting 59 examples
# Running Test: MFT with vocabullary - template80
# Predicting 59 examples
# Running Test: MFT with vocabullary - template81
# Predicting 61 examples
# Running Test: MFT with vocabullary - template82
# Predicting 61 examples
# Running Test: MFT with vocabullary - template83
# Predicting 59 examples
# Running Test: MFT with vocabullary - template84
# Predicting 59 examples
# Running Test: MFT with vocabullary - template85
# Predicting 59 examples
# Running Test: MFT with vocabullary - template86
# Predicting 59 examples
# Running Test: MFT with vocabullary - template87
# Predicting 61 examples
# Running Test: MFT with vocabullary - template88
# Predicting 3599 examples
# Running Test: MFT with vocabullary - template89
# Predicting 61 examples
# Running Test: MFT with vocabullary - template90
# Predicting 61 examples
# Running Test: MFT with vocabullary - template91
# Predicting 61 examples
# Running Test: MFT with vocabullary - template92
# Predicting 59 examples
# Running Test: MFT with vocabullary - template93
# Predicting 59 examples
# Running Test: MFT with vocabullary - template94
# Predicting 59 examples
# Running Test: MFT with vocabullary - template95
# Predicting 3599 examples

# %%
suite.summary()
# Out:
# Vocabullary
#
# Test: MFT with vocabullary - template1
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template2
# Test cases:      61
# Fails (rate):    4 (6.6%)
#
# Example fails:
# 0.8 I laughed and giggled enough times through the movie so I can not say with hand on my heart that it was horrendous < br / > < br / > It 's completely different , this and Epic Movie ( Epic Movie sucked horrendous ..
# ----
# 0.8 I laughed and giggled enough times through the movie so I can not say with hand on my heart that it was middle-aged < br / > < br / > It 's completely different , this and Epic Movie ( Epic Movie sucked middle-aged ..
# ----
# 0.5 I laughed and giggled enough times through the movie so I can not say with hand on my heart that it was unconvincing < br / > < br / > It 's completely different , this and Epic Movie ( Epic Movie sucked unconvincing ..
# ----
#
#
# Test: MFT with vocabullary - template3
# Test cases:      61
# Fails (rate):    1 (1.6%)
#
# Example fails:
# 1.0 The beginning is enticing and leaves much to be expected but it does not hold up and the plot becomes absolutely better and better .
# ----
#
#
# Test: MFT with vocabullary - template4
# Test cases:      59
# Fails (rate):    4 (6.8%)
#
# Example fails:
# 0.5 The movie is cartoonish and that seems to be the cartoonish thing about it .
# ----
# 0.4 The movie is only and that seems to be the only thing about it .
# ----
# 0.3 The movie is multi-millionaire and that seems to be the multi-millionaire thing about it .
# ----
#
#
# Test: MFT with vocabullary - template5
# Test cases:      3599
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template6
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template7
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template8
# Test cases:      59
# Fails (rate):    1 (1.7%)
#
# Example fails:
# 0.2 The babbling stops and suddenly there are these good-looking silent , good-looking moments .
# ----
#
#
# Test: MFT with vocabullary - template9
# Test cases:      3599
# Fails (rate):    1577 (43.8%)
#
# Example fails:
# 1.0 This is just a production that really missed the mark , a real low for Austen fans. < br / > < br / > The excellent serviceable version is the one with odd duck ( perfect for the role ) Sylvestra La Touzel ( despite the very very gay Henry Crawford - he 's just worse ) .
# ----
# 1.0 This is just a production that really missed the mark , a real low for Austen fans. < br / > < br / > The hilarious serviceable version is the one with odd duck ( perfect for the role ) Sylvestra La Touzel ( despite the very very gay Henry Crawford - he 's just rubbish ) .
# ----
# 1.0 This is just a production that really missed the mark , a real low for Austen fans. < br / > < br / > The remarkable serviceable version is the one with odd duck ( perfect for the role ) Sylvestra La Touzel ( despite the very very gay Henry Crawford - he 's just crappy ) .
# ----
#
#
# Test: MFT with vocabullary - template10
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template11
# Test cases:      3599
# Fails (rate):    2311 (64.2%)
#
# Example fails:
# 0.0 The scenes between Farley and Spade as nemesis are side-splitting palpable and the premise is also laugh out tedious hilarious .
# ----
# 0.0 The scenes between Farley and Spade as nemesis are side-splitting unusual and the premise is also laugh out dreadful hilarious .
# ----
# 0.0 The scenes between Farley and Spade as nemesis are side-splitting melodic and the premise is also laugh out rubbish. hilarious .
# ----
#
#
# Test: MFT with vocabullary - template12
# Test cases:      3599
# Fails (rate):    595 (16.5%)
#
# Example fails:
# 0.4 And the ending , while bad , is nonetheless elegant .
# ----
# 0.2 And the ending , while cheap , is nonetheless only .
# ----
# 0.2 And the ending , while forgettable. , is nonetheless unusual .
# ----
#
#
# Test: MFT with vocabullary - template13
# Test cases:      61
# Fails (rate):    2 (3.3%)
#
# Example fails:
# 1.0 But the initial acting , amateurish cinematography and terrible dubbing make this film achingly initial .
# ----
# 1.0 But the better acting , amateurish cinematography and terrible dubbing make this film achingly better .
# ----
#
#
# Test: MFT with vocabullary - template14
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template15
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template16
# Test cases:      59
# Fails (rate):    1 (1.7%)
#
# Example fails:
# 0.3 A good-looking , good-looking film , all in all .
# ----
#
#
# Test: MFT with vocabullary - template17
# Test cases:      3599
# Fails (rate):    1 (0.0%)
#
# Example fails:
# 0.6 This loud action  believable movie is a crap .
# ----
#
#
# Test: MFT with vocabullary - template18
# Test cases:      61
# Fails (rate):    9 (14.8%)
#
# Example fails:
# 0.9 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly horrendous and horrendous view of the American police through the King-angle .
# ----
# 1.0 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly better and better view of the American police through the King-angle .
# ----
# 0.7 What saves this film from becoming a Hallmark spectacle and debacle of the usual sort , whenever films about serial killers are concerned , is the direction , which is a double-edged sword ; director Scott L. Flynn sheds focus enough upon the b-actors not to let their flaws shine through too much , but at the same times created a truly sick and sick view of the American police through the King-angle .
# ----
#
#
# Test: MFT with vocabullary - template19
# Test cases:      61
# Fails (rate):    3 (4.9%)
#
# Example fails:
# 0.7 It 's loud loud .
# ----
# 0.6 It 's locations-person locations-person .
# ----
# 0.5 It 's horrendous horrendous .
# ----
#
#
# Test: MFT with vocabullary - template20
# Test cases:      3599
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template21
# Test cases:      61
# Fails (rate):    5 (8.2%)
#
# Example fails:
# 0.9 there is only way to describe this movie. < br / > < br / > so better its hilarious. < br / > < br / > the acting is so better i laughed my ass off throughout .
# ----
# 0.5 there is only way to describe this movie. < br / > < br / > so bottom its hilarious. < br / > < br / > the acting is so bottom i laughed my ass off throughout .
# ----
# 1.0 there is only way to describe this movie. < br / > < br / > so locations-person its hilarious. < br / > < br / > the acting is so locations-person i laughed my ass off throughout .
# ----
#
#
# Test: MFT with vocabullary - template22
# Test cases:      3599
# Fails (rate):    24 (0.7%)
#
# Example fails:
# 0.9 The male lead in this movie trying to use a gun is so ridiculous you would think he was trying to copy a toy action figure , i know this sounds ridiculous but when you see it for yourself you ca n't help but agree. < br / > < br / > the monster looks like a cgi guy trying to recreate the clay monsters you get in old Sinbad movies. < br / > < br / > in short this movie is outstanding for only one thing a really large laugh at how middle-aged movies can get. < br / > < br / > If you want to see bad acting bad script and special effects gone wrong < br / > < br / > THIS IS THE MOVIE FOR YOU
# ----
# 0.8 The male lead in this movie trying to use a gun is so ridiculous you would think he was trying to copy a toy action figure , i know this sounds ridiculous but when you see it for yourself you ca n't help but agree. < br / > < br / > the monster looks like a cgi guy trying to recreate the clay monsters you get in old Sinbad movies. < br / > < br / > in short this movie is outstanding for only one thing a really large laugh at how alien movies can get. < br / > < br / > If you want to see bad acting bad script and special effects gone wrong < br / > < br / > THIS IS THE MOVIE FOR YOU
# ----
# 0.6 The male lead in this movie trying to use a gun is so ridiculous you would think he was trying to copy a toy action figure , i know this sounds ridiculous but when you see it for yourself you ca n't help but agree. < br / > < br / > the monster looks like a cgi guy trying to recreate the clay monsters you get in old Sinbad movies. < br / > < br / > in short this movie is heartfelt. for only one thing a really large laugh at how pre-Code movies can get. < br / > < br / > If you want to see bad acting bad script and special effects gone wrong < br / > < br / > THIS IS THE MOVIE FOR YOU
# ----
#
#
# Test: MFT with vocabullary - template23
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template24
# Test cases:      59
# Fails (rate):    11 (18.6%)
#
# Example fails:
# 0.1 The directing is Lovecraftian , the casting is Lovecraftian ( though I would 've loved to have seen a little more of Aaron Lustig ( from Y & R fame ) , who played Paul Shaffer ) .
# ----
# 0.0 The directing is unpredictable , the casting is unpredictable ( though I would 've loved to have seen a little more of Aaron Lustig ( from Y & R fame ) , who played Paul Shaffer ) .
# ----
# 0.3 The directing is musical , the casting is musical ( though I would 've loved to have seen a little more of Aaron Lustig ( from Y & R fame ) , who played Paul Shaffer ) .
# ----
#
#
# Test: MFT with vocabullary - template25
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template26
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template27
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template28
# Test cases:      61
# Fails (rate):    2 (3.3%)
#
# Example fails:
# 0.6 pre-Code acting , equally pre-Code script .
# ----
# 0.9 better acting , equally better script .
# ----
#
#
# Test: MFT with vocabullary - template29
# Test cases:      61
# Fails (rate):    6 (9.8%)
#
# Example fails:
# 0.7 - The character development is locations-person - The characters that appear in the movie are so locations-person you would < br / > < br / > recognize them in your average comic book .
# ----
# 0.9 - The character development is better - The characters that appear in the movie are so better you would < br / > < br / > recognize them in your average comic book .
# ----
# 1.0 - The character development is loud - The characters that appear in the movie are so loud you would < br / > < br / > recognize them in your average comic book .
# ----
#
#
# Test: MFT with vocabullary - template30
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template31
# Test cases:      3599
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template32
# Test cases:      59
# Fails (rate):    2 (3.4%)
#
# Example fails:
# 0.4 What a direct-to-video film , a direct-to-video cast as well .
# ----
# 0.0 What a only film , a only cast as well .
# ----
#
#
# Test: MFT with vocabullary - template33
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template34
# Test cases:      3599
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template35
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template36
# Test cases:      59
# Fails (rate):    20 (33.9%)
#
# Example fails:
# 0.4 They invite the Italian specialist in safes and reliable wolf Cesar ( Perlo Vita ) to join their team and they plot a reliable heist .
# ----
# 0.3 They invite the Italian specialist in safes and once-in-a-lifetime wolf Cesar ( Perlo Vita ) to join their team and they plot a once-in-a-lifetime heist .
# ----
# 0.3 They invite the Italian specialist in safes and hot wolf Cesar ( Perlo Vita ) to join their team and they plot a hot heist .
# ----
#
#
# Test: MFT with vocabullary - template37
# Test cases:      3599
# Fails (rate):    1531 (42.5%)
#
# Example fails:
# 1.0 A flawless camp film , but a very imaginable film overall .
# ----
# 1.0 A different camp film , but a very middle-aged film overall .
# ----
# 0.8 A exemplary camp film , but a very cheap film overall .
# ----
#
#
# Test: MFT with vocabullary - template38
# Test cases:      3599
# Fails (rate):    496 (13.8%)
#
# Example fails:
# 0.7 The plot relies on a series of incredibly improbable coincidences ; there 's a hefty dose of conspiracy theory which would be much more palatable if we did n't know that Seagal takes it all literally ; and once again , stupid amazing Seagal tells us all about the evils of The Rich. < br / > < br / > Seagal 's survival relies , as usual , on the fact that Bad Guys never fire their guns from out of arm 's reach , and always like to give a little `` I 'm gon na kill you '' speech before blowing a man 's head off. < br / > < br / > Watch this one right after the even-worse * Fire Down Below * and note how the carpet in Keenen Ivory Wayans 's apartment is more flammable than a big puddle of gasoline. < br / > < br / > Oh , and watch in the final fight scene for the Incredible Disappearing Forehead Wound , which is probably the most entertaining thing in the film .
# ----
# 1.0 The plot relies on a series of incredibly improbable coincidences ; there 's a hefty dose of conspiracy theory which would be much more palatable if we did n't know that Seagal takes it all literally ; and once again , loud excellent Seagal tells us all about the evils of The Rich. < br / > < br / > Seagal 's survival relies , as usual , on the fact that Bad Guys never fire their guns from out of arm 's reach , and always like to give a little `` I 'm gon na kill you '' speech before blowing a man 's head off. < br / > < br / > Watch this one right after the even-worse * Fire Down Below * and note how the carpet in Keenen Ivory Wayans 's apartment is more flammable than a big puddle of gasoline. < br / > < br / > Oh , and watch in the final fight scene for the Incredible Disappearing Forehead Wound , which is probably the most entertaining thing in the film .
# ----
# 0.8 The plot relies on a series of incredibly improbable coincidences ; there 's a hefty dose of conspiracy theory which would be much more palatable if we did n't know that Seagal takes it all literally ; and once again , initial perfect Seagal tells us all about the evils of The Rich. < br / > < br / > Seagal 's survival relies , as usual , on the fact that Bad Guys never fire their guns from out of arm 's reach , and always like to give a little `` I 'm gon na kill you '' speech before blowing a man 's head off. < br / > < br / > Watch this one right after the even-worse * Fire Down Below * and note how the carpet in Keenen Ivory Wayans 's apartment is more flammable than a big puddle of gasoline. < br / > < br / > Oh , and watch in the final fight scene for the Incredible Disappearing Forehead Wound , which is probably the most entertaining thing in the film .
# ----
#
#
# Test: MFT with vocabullary - template39
# Test cases:      3599
# Fails (rate):    11 (0.3%)
#
# Example fails:
# 0.5 Let me explain why these turkeys Mr. David Varod produces are shot mainly in my beautiful homeland , Bulgaria ( just in BTW , for the illiterate people around - this country is IN EUROPE , based north to Greece and has absolutely nothing to do with Mexico and Uruguay ) Some years ago , NU Image has invaded our country and started making dreadful mostly extraordinary releases .
# ----
# 0.9 Let me explain why these turkeys Mr. David Varod produces are shot mainly in my beautiful homeland , Bulgaria ( just in BTW , for the illiterate people around - this country is IN EUROPE , based north to Greece and has absolutely nothing to do with Mexico and Uruguay ) Some years ago , NU Image has invaded our country and started making horrendous mostly perfect releases .
# ----
# 0.7 Let me explain why these turkeys Mr. David Varod produces are shot mainly in my beautiful homeland , Bulgaria ( just in BTW , for the illiterate people around - this country is IN EUROPE , based north to Greece and has absolutely nothing to do with Mexico and Uruguay ) Some years ago , NU Image has invaded our country and started making horrendous mostly wonderful releases .
# ----
#
#
# Test: MFT with vocabullary - template40
# Test cases:      3599
# Fails (rate):    21 (0.6%)
#
# Example fails:
# 0.7 And the scene where Zucco demonstrates his wolf-man technique to those who doubted him ( again shades of Dr. Jekyll and Mr Hyde ) is horrendous excellent < br / > < br / > Not one of the better 40s B movies .
# ----
# 0.7 And the scene where Zucco demonstrates his wolf-man technique to those who doubted him ( again shades of Dr. Jekyll and Mr Hyde ) is absurd believable < br / > < br / > Not one of the better 40s B movies .
# ----
# 0.8 And the scene where Zucco demonstrates his wolf-man technique to those who doubted him ( again shades of Dr. Jekyll and Mr Hyde ) is loud believable < br / > < br / > Not one of the better 40s B movies .
# ----
#
#
# Test: MFT with vocabullary - template41
# Test cases:      59
# Fails (rate):    2 (3.4%)
#
# Example fails:
# 0.3 The mystery and its solution was a multi-millionaire multi-millionaire conceit .
# ----
# 0.2 The mystery and its solution was a good-looking good-looking conceit .
# ----
#
#
# Test: MFT with vocabullary - template42
# Test cases:      3599
# Fails (rate):    889 (24.7%)
#
# Example fails:
# 0.0 He seems to find the only angle of the joke , not the tedious sitcom path ... thank God .
# ----
# 0.1 He seems to find the sci-fi angle of the joke , not the horrible sitcom path ... thank God .
# ----
# 0.1 He seems to find the romantic angle of the joke , not the sick sitcom path ... thank God .
# ----
#
#
# Test: MFT with vocabullary - template43
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template44
# Test cases:      59
# Fails (rate):    7 (11.9%)
#
# Example fails:
# 0.0 However she learns that things are n't as they seem and the couple gets a bit creepy after she spends some time on the road with them. < br / > < br / > Everyone in it was just so only for their parts you just about believe that you are watching this happen in real life in front of you. < br / > < br / > Newcomer Emily Grace did a only job as the really cute , yet somewhat shy Alice .
# ----
# 0.1 However she learns that things are n't as they seem and the couple gets a bit creepy after she spends some time on the road with them. < br / > < br / > Everyone in it was just so unpredictable for their parts you just about believe that you are watching this happen in real life in front of you. < br / > < br / > Newcomer Emily Grace did a unpredictable job as the really cute , yet somewhat shy Alice .
# ----
# 0.0 However she learns that things are n't as they seem and the couple gets a bit creepy after she spends some time on the road with them. < br / > < br / > Everyone in it was just so Lovecraftian for their parts you just about believe that you are watching this happen in real life in front of you. < br / > < br / > Newcomer Emily Grace did a Lovecraftian job as the really cute , yet somewhat shy Alice .
# ----
#
#
# Test: MFT with vocabullary - template45
# Test cases:      3599
# Fails (rate):    371 (10.3%)
#
# Example fails:
# 0.0 An especially direct-to-video scene is when she confronts an cheap husband , telling him firmly , `` If you ever touch that child again , we 're going to dance ! ''
# ----
# 0.3 An especially inspiring scene is when she confronts an ridiculous husband , telling him firmly , `` If you ever touch that child again , we 're going to dance ! ''
# ----
# 0.0 An especially direct-to-video scene is when she confronts an obnoxious husband , telling him firmly , `` If you ever touch that child again , we 're going to dance ! ''
# ----
#
#
# Test: MFT with vocabullary - template46
# Test cases:      61
# Fails (rate):    6 (9.8%)
#
# Example fails:
# 0.9 It aligns cliche after cliche and even manages to grow locations-person as it goes along with some moments that are bad enough to be hilariously funny. < br / > < br / > If you can laugh about really locations-person quality in script writing and production values , you might enjoy it .
# ----
# 0.9 It aligns cliche after cliche and even manages to grow loud as it goes along with some moments that are bad enough to be hilariously funny. < br / > < br / > If you can laugh about really loud quality in script writing and production values , you might enjoy it .
# ----
# 0.6 It aligns cliche after cliche and even manages to grow horrendous as it goes along with some moments that are bad enough to be hilariously funny. < br / > < br / > If you can laugh about really horrendous quality in script writing and production values , you might enjoy it .
# ----
#
#
# Test: MFT with vocabullary - template47
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template48
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template49
# Test cases:      3599
# Fails (rate):    2046 (56.8%)
#
# Example fails:
# 0.0 And I 've been in Evie 's shoes , chasing away opportunity out of fear and out of devotion to others. < br / > < br / > Amy Madigan 's disappointment in her daughters was almost melodic on screen and the awkward moments where she tried to bridge the gap with Evie were raw and tedious to watch .
# ----
# 0.0 And I 've been in Evie 's shoes , chasing away opportunity out of fear and out of devotion to others. < br / > < br / > Amy Madigan 's disappointment in her daughters was almost Lovecraftian on screen and the awkward moments where she tried to bridge the gap with Evie were raw and cheap to watch .
# ----
# 0.0 And I 've been in Evie 's shoes , chasing away opportunity out of fear and out of devotion to others. < br / > < br / > Amy Madigan 's disappointment in her daughters was almost solid on screen and the awkward moments where she tried to bridge the gap with Evie were raw and predictable to watch .
# ----
#
#
# Test: MFT with vocabullary - template50
# Test cases:      61
# Fails (rate):    13 (21.3%)
#
# Example fails:
# 0.8 Old theme good better officer that 's highly better .
# ----
# 0.9 Old theme good locations-person officer that 's highly locations-person .
# ----
# 1.0 Old theme good horrendous officer that 's highly horrendous .
# ----
#
#
# Test: MFT with vocabullary - template51
# Test cases:      3599
# Fails (rate):    202 (5.6%)
#
# Example fails:
# 0.0 < br / > < br / > Sound - 10/10 , since i am a metal fan I loved the fight music .. and piano just reaches right in there .. It is a only ST and I was not turgid < br / > < br / > Tilt/Replay 10/10 - Enjoyable every time .
# ----
# 0.4 < br / > < br / > Sound - 10/10 , since i am a metal fan I loved the fight music .. and piano just reaches right in there .. It is a once-in-a-lifetime ST and I was not loud < br / > < br / > Tilt/Replay 10/10 - Enjoyable every time .
# ----
# 0.2 < br / > < br / > Sound - 10/10 , since i am a metal fan I loved the fight music .. and piano just reaches right in there .. It is a positive ST and I was not turgid < br / > < br / > Tilt/Replay 10/10 - Enjoyable every time .
# ----
#
#
# Test: MFT with vocabullary - template52
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template53
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template54
# Test cases:      61
# Fails (rate):    40 (65.6%)
#
# Example fails:
# 0.7 It is no worst or no worst than any cheesy 80 's flick .
# ----
# 0.7 It is no atrocious or no atrocious than any cheesy 80 's flick .
# ----
# 0.8 It is no bad or no bad than any cheesy 80 's flick .
# ----
#
#
# Test: MFT with vocabullary - template55
# Test cases:      3599
# Fails (rate):    7 (0.2%)
#
# Example fails:
# 0.6 The dialog was better and uninteresting , the characters were almost believable in their lack of dimension and complexity , and why did everyone need to be gay ?
# ----
# 0.5 The dialog was better and uninteresting , the characters were almost great in their lack of dimension and complexity , and why did everyone need to be gay ?
# ----
# 0.8 The dialog was better and uninteresting , the characters were almost excellent in their lack of dimension and complexity , and why did everyone need to be gay ?
# ----
#
#
# Test: MFT with vocabullary - template56
# Test cases:      59
# Fails (rate):    1 (1.7%)
#
# Example fails:
# 0.3 His cutting , combined with the only music cues , is only .
# ----
#
#
# Test: MFT with vocabullary - template57
# Test cases:      61
# Fails (rate):    1 (1.6%)
#
# Example fails:
# 0.5 The hilarity is centered around cannibalism and mental retardation , which is just loud humor , in a loud way. < br / > < br / > I should have walked out of this film and I 'm kicking myself because I did n't .
# ----
#
#
# Test: MFT with vocabullary - template58
# Test cases:      3599
# Fails (rate):    2061 (57.3%)
#
# Example fails:
# 0.0 Most striking is Guy Kibbee , Incredible known for playing fatuous rich men , as a grinning and mendacious hit-man. < br / > < br / > There are n't nearly enough of these pre-Code films available on VHS or DVD , so if you ca n't find a crappiest festival near you , try campaigning Turner Classic Movies for a broadcast !
# ----
# 0.2 Most striking is Guy Kibbee , remarkable known for playing fatuous rich men , as a grinning and mendacious hit-man. < br / > < br / > There are n't nearly enough of these pre-Code films available on VHS or DVD , so if you ca n't find a tiresome festival near you , try campaigning Turner Classic Movies for a broadcast !
# ----
# 0.3 Most striking is Guy Kibbee , good known for playing fatuous rich men , as a grinning and mendacious hit-man. < br / > < br / > There are n't nearly enough of these pre-Code films available on VHS or DVD , so if you ca n't find a unfortunate festival near you , try campaigning Turner Classic Movies for a broadcast !
# ----
#
#
# Test: MFT with vocabullary - template59
# Test cases:      59
# Fails (rate):    5 (8.5%)
#
# Example fails:
# 0.2 `` Cover Girl '' is the good-looking good-looking Rita Hayworth ever made .
# ----
# 0.4 `` Cover Girl '' is the sci-fi sci-fi Rita Hayworth ever made .
# ----
# 0.4 `` Cover Girl '' is the cartoonish cartoonish Rita Hayworth ever made .
# ----
#
#
# Test: MFT with vocabullary - template60
# Test cases:      3599
# Fails (rate):    243 (6.8%)
#
# Example fails:
# 0.7 Even the usually musical Millard Mitchell is horrendous .
# ----
# 1.0 Even the usually flawless Millard Mitchell is horrendous .
# ----
# 1.0 Even the usually hilarious. Millard Mitchell is horrendous .
# ----
#
#
# Test: MFT with vocabullary - template61
# Test cases:      61
# Fails (rate):    14 (23.0%)
#
# Example fails:
# 0.8 He made several sick comedies , and this one is his sick .
# ----
# 1.0 He made several bottom comedies , and this one is his bottom .
# ----
# 0.9 He made several putrid comedies , and this one is his putrid .
# ----
#
#
# Test: MFT with vocabullary - template62
# Test cases:      3599
# Fails (rate):    921 (25.6%)
#
# Example fails:
# 1.0 She has to be the most horrendous unpredictable woman on TV since Rosie O'Donnell left `` The View '' .
# ----
# 1.0 She has to be the most cookie-cutter brilliant woman on TV since Rosie O'Donnell left `` The View '' .
# ----
# 1.0 She has to be the most cookie-cutter worth woman on TV since Rosie O'Donnell left `` The View '' .
# ----
#
#
# Test: MFT with vocabullary - template63
# Test cases:      59
# Fails (rate):    39 (66.1%)
#
# Example fails:
# 0.0 Geddy 's vocals are elegant , Alex 's guitar playing is still elegant , and Neil - absolutely no words to say .
# ----
# 0.1 Geddy 's vocals are welcome , Alex 's guitar playing is still welcome , and Neil - absolutely no words to say .
# ----
# 0.0 Geddy 's vocals are Lovecraftian , Alex 's guitar playing is still Lovecraftian , and Neil - absolutely no words to say .
# ----
#
#
# Test: MFT with vocabullary - template64
# Test cases:      59
# Fails (rate):    6 (10.2%)
#
# Example fails:
# 0.5 Bill Macy ( as Oscar Payne ) is Satish in a part that would have been played by John Karlen ( in a Dan Curtis production ) . < br / > < br / > There are Satish cameos by Joan Blondell , John Carradine , and Dorothy Lamour .
# ----
# 0.1 Bill Macy ( as Oscar Payne ) is sci-fi in a part that would have been played by John Karlen ( in a Dan Curtis production ) . < br / > < br / > There are sci-fi cameos by Joan Blondell , John Carradine , and Dorothy Lamour .
# ----
# 0.1 Bill Macy ( as Oscar Payne ) is musical in a part that would have been played by John Karlen ( in a Dan Curtis production ) . < br / > < br / > There are musical cameos by Joan Blondell , John Carradine , and Dorothy Lamour .
# ----
#
#
# Test: MFT with vocabullary - template65
# Test cases:      3599
# Fails (rate):    711 (19.8%)
#
# Example fails:
# 0.1 The story is good : a dull but still only woman finds a new love .
# ----
# 0.0 The story is good : a amateurish.Two but still good-looking woman finds a new love .
# ----
# 0.1 The story is good : a crappy but still noir woman finds a new love .
# ----
#
#
# Test: MFT with vocabullary - template66
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template67
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template68
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template69
# Test cases:      59
# Fails (rate):    1 (1.7%)
#
# Example fails:
# 0.2 Another only piece of animation was O ' Malley looking into Duchess 's eyes , as their romance was so only while not obvious .
# ----
#
#
# Test: MFT with vocabullary - template70
# Test cases:      61
# Fails (rate):    6 (9.8%)
#
# Example fails:
# 1.0 It 's a absurd , absurd movie .
# ----
# 0.7 It 's a pre-Code , pre-Code movie .
# ----
# 0.5 It 's a bottom , bottom movie .
# ----
#
#
# Test: MFT with vocabullary - template71
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template72
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template73
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template74
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template75
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template76
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template77
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template78
# Test cases:      61
# Fails (rate):    5 (8.2%)
#
# Example fails:
# 1.0 As the film was in 1986 , was Ashton Kutcher just a babe in the woods at that time ? < br / > < br / > Moore 's grandfather has died and his home is on the verge of being sold to ruthless people with a father and son who bring a new meaning to the term mean. < br / > < br / > Bobcat Goldthwait , with that horrendous voice is in the film , as well as two brothers , who make dumb and dumber look more and more intelligent. < br / > < br / > The writing is absolutely horrendous .
# ----
# 0.9 As the film was in 1986 , was Ashton Kutcher just a babe in the woods at that time ? < br / > < br / > Moore 's grandfather has died and his home is on the verge of being sold to ruthless people with a father and son who bring a new meaning to the term mean. < br / > < br / > Bobcat Goldthwait , with that loud voice is in the film , as well as two brothers , who make dumb and dumber look more and more intelligent. < br / > < br / > The writing is absolutely loud .
# ----
# 0.9 As the film was in 1986 , was Ashton Kutcher just a babe in the woods at that time ? < br / > < br / > Moore 's grandfather has died and his home is on the verge of being sold to ruthless people with a father and son who bring a new meaning to the term mean. < br / > < br / > Bobcat Goldthwait , with that cookie-cutter voice is in the film , as well as two brothers , who make dumb and dumber look more and more intelligent. < br / > < br / > The writing is absolutely cookie-cutter .
# ----
#
#
# Test: MFT with vocabullary - template79
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template80
# Test cases:      59
# Fails (rate):    3 (5.1%)
#
# Example fails:
# 0.1 Not a very good-looking film but definitely good-looking seeing .
# ----
# 0.4 Not a very reliable film but definitely reliable seeing .
# ----
# 0.4 Not a very positive film but definitely positive seeing .
# ----
#
#
# Test: MFT with vocabullary - template81
# Test cases:      61
# Fails (rate):    2 (3.3%)
#
# Example fails:
# 0.8 Go watch Team America ( hilarious btw ; - ) ) and forget about Ocean 's Twelve. < br / > < br / > In my opinion the most loud and loud peace of crap to be on the screen in years .
# ----
# 0.8 Go watch Team America ( hilarious btw ; - ) ) and forget about Ocean 's Twelve. < br / > < br / > In my opinion the most better and better peace of crap to be on the screen in years .
# ----
#
#
# Test: MFT with vocabullary - template82
# Test cases:      61
# Fails (rate):    2 (3.3%)
#
# Example fails:
# 0.6 even the bad guys were instantly loud < br / > < br / > loud movie .
# ----
# 0.7 even the bad guys were instantly better < br / > < br / > better movie .
# ----
#
#
# Test: MFT with vocabullary - template83
# Test cases:      59
# Fails (rate):    3 (5.1%)
#
# Example fails:
# 0.2 Linda Kash is romantic in her romantic role as the hometown waffle waitress longing for adventure .
# ----
# 0.2 Linda Kash is multi-millionaire in her multi-millionaire role as the hometown waffle waitress longing for adventure .
# ----
# 0.1 Linda Kash is good-looking in her good-looking role as the hometown waffle waitress longing for adventure .
# ----
#
#
# Test: MFT with vocabullary - template84
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template85
# Test cases:      59
# Fails (rate):    10 (16.9%)
#
# Example fails:
# 0.7 Nothing different , or particularly different .
# ----
# 0.8 Nothing greatest , or particularly greatest .
# ----
# 0.8 Nothing unpredictable , or particularly unpredictable .
# ----
#
#
# Test: MFT with vocabullary - template86
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template87
# Test cases:      61
# Fails (rate):    4 (6.6%)
#
# Example fails:
# 1.0 The better gets to work overtime in this obvious and better love story .
# ----
# 1.0 The absurd gets to work overtime in this obvious and absurd love story .
# ----
# 0.5 The painful gets to work overtime in this obvious and painful love story .
# ----
#
#
# Test: MFT with vocabullary - template88
# Test cases:      3599
# Fails (rate):    102 (2.8%)
#
# Example fails:
# 0.9 There are some simple directors but many a horrendous ones too .
# ----
# 0.9 There are some different directors but many a better ones too .
# ----
# 1.0 There are some unique directors but many a better ones too .
# ----
#
#
# Test: MFT with vocabullary - template89
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template90
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template91
# Test cases:      61
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template92
# Test cases:      59
# Fails (rate):    10 (16.9%)
#
# Example fails:
# 0.1 He played a great part , but Hunter and Hurt were good-looking too , specially Hurt , in an relatively good-looking role for him .
# ----
# 0.1 He played a great part , but Hunter and Hurt were only too , specially Hurt , in an relatively only role for him .
# ----
# 0.5 He played a great part , but Hunter and Hurt were multi-millionaire too , specially Hurt , in an relatively multi-millionaire role for him .
# ----
#
#
# Test: MFT with vocabullary - template93
# Test cases:      59
# Fails (rate):    1 (1.7%)
#
# Example fails:
# 0.5 Danson is only as the title character and edward fox makes a only villain .
# ----
#
#
# Test: MFT with vocabullary - template94
# Test cases:      59
# Fails (rate):    0 (0.0%)
#
#
# Test: MFT with vocabullary - template95
# Test cases:      3599
# Fails (rate):    305 (8.5%)
#
# Example fails:
# 0.7 The wonderful positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally .. , iwant to know your comment about this movie guys ... is it cheap or what ?
# ----
# 0.6 The remarkable positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally .. , iwant to know your comment about this movie guys ... is it bottom or what ?
# ----
# 1.0 The unique positive in the movie is the presence of some talented actors who did not help much text to explode their talents Finally .. , iwant to know your comment about this movie guys ... is it painful or what ?
# ----

# %% [markdown]
# # Carregando suite de teste

# %%
from checklist.test_suite import TestSuite
suite = TestSuite.from_file('./suites/posneg-approach3.suite')

suite.visual_summary_table()
# Out:
# Please wait as we prepare the table data...
# SuiteSummarizer(stats={'npassed': 0, 'nfailed': 0, 'nfiltered': 0}, test_infos=[{'name': 'Test: MFT with vocab…
